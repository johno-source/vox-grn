# %% [markdown]
# # Segment GRN data using pyAudioAnalysis
#
# The group of notebooks SegmentPyVOXn.ipynb (n=0-9) will be used to segment the data using the segmentation algorithm I developed in DevelopASSegmentation.ipynb. It follows the same pattern as used in SegmentFVOXn.ipynb.
#
# # Data to be Created
#
# Three sets of data will be made, 4, 6, and 10 second data.
#
# This file will take a long time to run. For that reason it will check point its progress at regular intervals by writing smaller files. If its progress is restarted for any reason it will use those files to determine where it was up to. Segmenting the data is the slow part. For each audio file a segment file will be generated. If mp3 files are to be generated later using different parameters the segmented files should make the process much quicker.
#
# The input to this process is the same as SegmentFVOX.ipynb. We actually use its division of the files into 10 groups.
#
# The output will be:
#
#     1. /media/originals/py_audio_seg/[iso]/[filename].pkl
#         where each pkl file contains the list of raw segments for the item.
#     2. /media/originals/py_audio_seg/seg_4sec.csv
#         all the metadata for the seg_4sec dataset. Metadata needed for the dataset can be derived from this.
#     3. /media/originals/py_audio_seg/seg_6sec.csv
#         all the metadata for the seg_6sec dataset. Metadata needed for the dataset can be derived from this.
#     4. /media/originals/py_audio_seg/seg_10sec.csv
#         all the metadata for the seg_10sec dataset. Metadata needed for the dataset can be derived from this.
#     5. /media/originals/datasets/py_audio_seg_4sec/data/[iso]/[program_id]_[item_no]_[seg].mp3
#         which is an mp3 for each segment
#     6. /media/originals/datasets/py_audio_seg_6sec/data/[iso]/[program_id]_[item_no]_[seg].mp3
#         which is an mp3 for each segment
#     7. /media/originals/datasets/py_audio_seg_10sec/data/[iso]/[program_id]_[item_no]_[seg].mp3
#         which is an mp3 for each segment

# %%
import pandas as pd
import numpy as np
import os
import sys
import time
import pickle as pkl
from pathlib import Path
import glob

module_path = os.path.abspath(os.path.join('~/work/pyAudioAnalysis'))
if module_path not in sys.path:
    sys.path.append(module_path)
from collections import namedtuple
from pydub import AudioSegment

from pyAudioAnalysis import audioSegmentation as aS
from pyAudioAnalysis import audioTrainTest as at
from pyAudioAnalysis import MidTermFeatures as mtf
from pyAudioAnalysis import audioBasicIO as aIO

# %%
# define the locations for each of the file types
NOTEBOOK_ID=5
SEGMENTS_DIR = '/media/originals/py_audio_seg/'
DATASETS_DIR = '/media/originals/datasets/'
SEC_4_DATA_DIR = 'py_audio_seg_4sec/data/'
SEC_6_DATA_DIR = 'py_audio_seg_6sec/data/'
SEC_10_DATA_DIR = 'py_audio_seg_10sec/data/'

# define specific files used in the process
SEG_4_SEC_DF = f'{SEGMENTS_DIR}seg_4sec_{NOTEBOOK_ID}.csv'
SEG_6_SEC_DF = f'{SEGMENTS_DIR}seg_6sec_{NOTEBOOK_ID}.csv'
SEG_10_SEC_DF = f'{SEGMENTS_DIR}seg_10sec_{NOTEBOOK_ID}.csv'

# define segment sizes for each dataset
SEG_4_SEC = 4.0
SEG_6_SEC = 6.0
SEG_10_SEC = 10.0

SAMPLING_RATE = 16000

def convert_to_ms(sec):
    return int(sec*1000.0)

# %%
# Now read in the description of the input and remove the unwanted columns and rename the rest to be python attribute names.
fd = pd.read_csv(f'/media/originals/fsegs/files_{NOTEBOOK_ID}.csv')
fd.set_index('ID', inplace=True)
fd.columns
# Out:
# Index(['Unnamed: 0', 'iso', 'language_name', 'track', 'location', 'year',
#        'path', 'filename', 'length', 'program'],
#       dtype='object')

# %%
print(fd.iloc[100])
# Out:
# Unnamed: 0                                   72080
# iso                                            mfi
# language_name                              Mandara
# track                                           10
# location                                       NaN
# year                                        2008.0
# path             Programs/62/62919/A62919/PM-1301/
# filename                            A62919-010.wav
# length                                   56.922569
# program                                      62919
# Name: 62919_010, dtype: object

# %%
print(fd.index)
# Out:
# Index(['65407_038', '65407_036', '65407_035', '65407_024', '65407_034',
#        '65407_032', '65407_031', '65407_030', '65407_029', '65407_028',
#        ...
#        '65174_007', '65174_006', '65174_005', '65174_004', '65856_001',
#        '65174_003', '65174_002', '65174_001', '65463_002', '65463_001'],
#       dtype='object', name='ID', length=20837)

# %%
# generate directories and filenames
def prepare_dir(dirname):
    if dirname[-1] != '/':
        dirname = dirname + '/'
    Path(dirname).mkdir(parents=True, exist_ok=True)
    return dirname

def prepare_raw_seg_dir(fd):
    return prepare_dir(SEGMENTS_DIR + fd.iso)

def raw_seg_filename(fd):
    return f'{fd.filename}.pkl'

def prepare_dataset_data_dir(fd, dataset_dir):
    return prepare_dir(DATASETS_DIR + dataset_dir + fd.iso)

def seg_mp3_filename(fd, seg):
    return f'{fd.filename[:-4]}_{seg:03d}.mp3'

def get_fname(fd):
    path = fd.path
    if path[-1] != '/':
        path = path + '/'
    files = glob.glob('/media/programs/' + path + fd.filename.replace('\ufffd', '*'))
    if len(files) == 1:
        return files[0]
    return '/media/programs/' + path + fd.filename

# %%
def condition_audio_segment(audio_seg):
    if audio_seg.channels != 1:
        audio_seg = audio_seg.set_channels(1)

    if audio_seg.sample_width != 2:
        audio_seg = audio_seg.set_sample_width(2)

    if audio_seg.frame_rate != SAMPLING_RATE:
        audio_seg = audio_seg.set_frame_rate(SAMPLING_RATE)
    return audio_seg

# %%
import warnings
# sklearn puts out a lot of annoying warnings
warnings.filterwarnings('ignore')

Segment = namedtuple('Segment', ['start', 'end', 'classification'])

# re-implement a simplified version of mid_term_file_classification
# it is implemented as a class to allow the model to be cached.
class ExtractVoiceSegments():
    classifier, mean, std, class_names, mt_win, mid_step, st_win, \
         st_step, compute_beat = at.load_model('/home/jovyan/work/pyAudioAnalysis/pyAudioAnalysis/data/models/svm_rbf_4class')

    def __init__(self):
        pass

    def segments_in(self, signal, sampling_rate, offset):
        labels = []

        # mid-term feature extraction:
        mt_feats, _, _ = \
            mtf.mid_feature_extraction(signal, sampling_rate,
                                    ExtractVoiceSegments.mt_win * sampling_rate,
                                    ExtractVoiceSegments.mid_step * sampling_rate,
                                    round(sampling_rate * ExtractVoiceSegments.st_win),
                                    round(sampling_rate * ExtractVoiceSegments.st_step))

        # for each feature vector (i.e. for each fix-sized segment):
        for col_index in range(mt_feats.shape[1]):
            # normalize current feature v
            feature_vector = (mt_feats[:, col_index] - ExtractVoiceSegments.mean) / ExtractVoiceSegments.std

            # classify vector:
            label_predicted, _ = \
                at.classifier_wrapper(ExtractVoiceSegments.classifier, 'svm', feature_vector)
            labels.append(label_predicted)

        segs, classes = aS.labels_to_segments(labels, ExtractVoiceSegments.mid_step)
        # there is a bug in labels to segments when there is a single label. In this case it returns a list rather than a list of lists
        if len(labels) == 1:
            segs = [].append(segs)
        return [] if segs is None else [Segment(seg[0]+offset, seg[1]+offset, ExtractVoiceSegments.class_names[int(label)]) for seg, label in zip(segs, classes)]



"""
This function performs mid-term classification of an audio stream.
Towards this end, supervised knowledge is used,
i.e. a pre-trained classifier.
ARGUMENTS:
    - input_file:        path of the input WAV/mp3 file
RETURNS:
    - list of Segments (see above tuple)
"""
def extract_voice_segments(input_file, *, __extract_voice_segments=ExtractVoiceSegments()):
    segments = []

    # load input file
    sampling_rate, signal = aIO.read_audio_file(input_file)

    # could not read file
    if sampling_rate == 0:
        return segments

    # convert stereo (if) to mono
    signal = aIO.stereo_to_mono(signal)

    # find the silence segments
    non_silent_segments = aS.silence_removal(signal, sampling_rate, 0.02, 0.02, smooth_window=1.0, weight=0.3)

    # work through each segment
    for seg in non_silent_segments:
        start = int(seg[0]*sampling_rate)
        stop = int(seg[1]*sampling_rate)
        sig = signal[start:stop]

        segments.extend(__extract_voice_segments.segments_in(signal[start:stop], sampling_rate, seg[0]))

    return segments

# %%
Epoch = namedtuple('Epoch', ['start', 'end'])
def speech_epochs_from_segments(segments, epoch_length=4.0, silence_tolerance=0.0):
    epochs = []
    i = 0
    silence_this_epoch = silence_tolerance
    while i < len(segments):
        seg_duration = segments[i].end - segments[i].start
        if segments[i].classification != 'speech':
            silence_this_epoch = silence_tolerance

        elif seg_duration >= epoch_length:
            epochs.append(Epoch(segments[i].start, segments[i].start+epoch_length))
            silence_this_epoch = silence_tolerance
            # process the same segment again with a smaller size
            new_start = segments[i].start+epoch_length
            new_end = segments[i].end
            if new_start < new_end:
                segments[i] = Segment(new_start, new_end, segments[i].classification)
                continue
        else:
            if i+1 < len(segments):
                if (segments[i].end + silence_this_epoch) >= segments[i+1].start and segments[i+1].classification == 'speech':
                    # did we use up any silence tolerence
                    if segments[i].end < segments[i+1].start:
                        silence_this_epoch -= (segments[i+1].start - segments[i].end)
                    segments[i+1] = Segment(segments[i].start, segments[i+1].end, segments[i].classification)
                else:
                    silence_this_epoch = silence_tolerance

        i+=1

    return epochs

# %%
def save_the_segment_info(fd, segs):
    fname = prepare_raw_seg_dir(fd) + raw_seg_filename(fd)
    with open(fname, 'wb') as pklFile:
         pkl.dump(segs, pklFile)

def read_the_segment_info(fd):
    fname = prepare_raw_seg_dir(fd) + raw_seg_filename(fd)
    if os.path.exists(fname):
        if os.path.getsize(fname) > 0:
            with open(fname, 'rb') as pklFile:
                return pkl.load(pklFile)
    return []
    
def update_dataframes(seg_df_csv, seg_records):
    # now update the dataframes
    if len(seg_records) > 0:
        if os.path.isfile(seg_df_csv):
            seg_sec_df = pd.concat([pd.read_csv(seg_df_csv, index_col='file_name'), pd.DataFrame.from_records(seg_records, index='file_name')])
        else:
            seg_sec_df = pd.DataFrame.from_records(seg_records, index='file_name')
        seg_sec_df.to_csv(seg_df_csv)

# %%
def extract_audio_segments_for_file(fd):
    fmt = 'wav'
    if fd.filename[-4:].lower() == '.mp3' :
        fmt = 'mp3'
    audio_seg = AudioSegment.from_file(get_fname(fd), format=fmt)

    # now condition the segment and extract the raw segments.
    audio_seg = condition_audio_segment(audio_seg)
    segs = read_the_segment_info(fd)
    if len(segs) == 0:
        segs = extract_voice_segments(get_fname(fd))
        save_the_segment_info(fd, segs)

    return audio_seg, segs


def create_mp3_files(audio_seg, segs, time_per_segment, dataset_dir, fd):
    epochs_for_time = speech_epochs_from_segments(segs, epoch_length=time_per_segment, silence_tolerance=time_per_segment/4.0)

    # now write out the 4 sec segments
    dirname = prepare_dataset_data_dir(fd, dataset_dir)
    rows = list()

    for i, seg in enumerate(epochs_for_time):
        file_name = dataset_dir + fd.iso + '/' + seg_mp3_filename(fd, i)
        fname = dirname + seg_mp3_filename(fd, i)
        start = convert_to_ms(seg.start)
        stop = convert_to_ms(seg.end)
        if not os.path.exists(fname):
            audio_seg[start:stop].export(fname, format='mp3', bitrate='32k')
        desc = dict(fd._asdict())
        desc['seg_start'] = start
        desc['seg_stop'] = stop
        desc['seg'] = i
        desc['file_name'] = file_name
        rows.append(desc)

    return rows

# %%
# processing these items might take a very long time. To permit the process to be interrupted and restarted the indexes of processed items
# are maintained in a set that is pickled on each batch. This allows the batch to quickly pick up where it left off.
def process_record_batch(files_df, *, batch_size=10):
    batch_proc = 0
    processed_file = f'{SEGMENTS_DIR}processed16_{NOTEBOOK_ID}.pkl'
    if os.path.isfile(processed_file):
        with open(processed_file, 'rb') as pklFile:
            processed_files = pkl.load(pklFile)
    else:
        processed_files = set()

    segmented_4sec_segs = []
    segmented_6sec_segs = []
    segmented_10sec_segs = []

    for fd in files_df.itertuples():
        if batch_proc < batch_size:
            if fd.Index not in processed_files:
                try:
                    audio_seg, voice_segs = extract_audio_segments_for_file(fd)

                    segmented_4sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_4_SEC, SEC_4_DATA_DIR, fd))
                    segmented_6sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_6_SEC, SEC_6_DATA_DIR, fd))
                    segmented_10sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_10_SEC, SEC_10_DATA_DIR, fd))
                except:
                    print(f'exception {fd.filename}')
                    pass

                # we want to add an fd that has an exception so it is not reprocessed on every batch
                processed_files.add(fd.Index)
                batch_proc += 1

        else:
            break

    update_dataframes(SEG_4_SEC_DF, segmented_4sec_segs)
    update_dataframes(SEG_6_SEC_DF, segmented_6sec_segs)
    update_dataframes(SEG_10_SEC_DF, segmented_10sec_segs)

    with open(processed_file, 'wb') as pklFile:
        pkl.dump(processed_files, pklFile)

    return processed_files

# %%
start_time = time.time()
# form the language classification file
files_processed = 0
files_to_process = len(fd)
while files_to_process > files_processed:
    processed_files = process_record_batch(fd, batch_size=10)
    files_processed = len(processed_files)
    print(f'Processed {files_processed} out of {files_to_process} in {time.time()-start_time:.2f} seconds')
# Out:
# Processed 10 out of 20837 in 10.53 seconds
# Processed 20 out of 20837 in 37.72 seconds
# Processed 30 out of 20837 in 78.56 seconds
# Processed 40 out of 20837 in 576.80 seconds
# Processed 50 out of 20837 in 819.19 seconds
# Processed 60 out of 20837 in 1014.63 seconds
# Processed 70 out of 20837 in 1086.99 seconds
# Processed 80 out of 20837 in 1200.15 seconds
# Processed 90 out of 20837 in 1281.00 seconds
# Processed 100 out of 20837 in 1367.53 seconds
# Processed 110 out of 20837 in 1465.92 seconds
# Processed 120 out of 20837 in 1630.16 seconds
# Processed 130 out of 20837 in 1776.72 seconds
# Processed 140 out of 20837 in 1879.86 seconds
# Processed 150 out of 20837 in 1980.26 seconds
# Processed 160 out of 20837 in 2135.77 seconds
# Processed 170 out of 20837 in 2290.73 seconds
# Processed 180 out of 20837 in 2423.06 seconds
# Processed 190 out of 20837 in 2528.62 seconds
# Processed 200 out of 20837 in 2675.18 seconds
# Processed 210 out of 20837 in 3064.69 seconds
# Processed 220 out of 20837 in 3174.21 seconds
# Processed 230 out of 20837 in 3303.74 seconds
# Processed 240 out of 20837 in 3419.18 seconds
# Processed 250 out of 20837 in 3514.89 seconds
# Processed 260 out of 20837 in 3607.14 seconds
# Processed 270 out of 20837 in 3766.49 seconds
# Processed 280 out of 20837 in 4795.73 seconds
# Processed 290 out of 20837 in 5045.92 seconds
# Processed 300 out of 20837 in 5243.26 seconds
# Processed 310 out of 20837 in 5411.91 seconds
# Processed 320 out of 20837 in 5786.71 seconds
# Processed 330 out of 20837 in 5975.60 seconds
# Processed 340 out of 20837 in 6048.76 seconds
# Processed 350 out of 20837 in 6117.25 seconds
# Processed 360 out of 20837 in 6176.43 seconds
# Processed 370 out of 20837 in 6252.17 seconds
# Processed 380 out of 20837 in 6322.14 seconds
# Processed 390 out of 20837 in 6398.58 seconds
# Processed 400 out of 20837 in 6482.58 seconds
# Processed 410 out of 20837 in 6548.87 seconds
# Processed 420 out of 20837 in 6616.32 seconds
# Processed 430 out of 20837 in 6678.40 seconds
# Processed 440 out of 20837 in 6767.56 seconds
# Processed 450 out of 20837 in 6897.25 seconds
# Processed 460 out of 20837 in 7035.73 seconds
# Processed 470 out of 20837 in 7099.01 seconds
# Processed 480 out of 20837 in 7211.66 seconds
# Processed 490 out of 20837 in 7349.78 seconds
# Processed 500 out of 20837 in 7415.95 seconds
# Processed 510 out of 20837 in 7481.71 seconds
# Processed 520 out of 20837 in 7567.77 seconds
# Processed 530 out of 20837 in 7641.99 seconds
# Processed 540 out of 20837 in 7706.89 seconds
# Processed 550 out of 20837 in 7782.05 seconds
# Processed 560 out of 20837 in 7851.32 seconds
# Processed 570 out of 20837 in 7927.84 seconds
# Processed 580 out of 20837 in 7988.50 seconds
# Processed 590 out of 20837 in 8034.51 seconds
# Processed 600 out of 20837 in 8094.72 seconds
# Processed 610 out of 20837 in 8155.51 seconds
# Processed 620 out of 20837 in 8277.64 seconds
# Processed 630 out of 20837 in 8382.37 seconds
# Processed 640 out of 20837 in 8544.59 seconds
# Processed 650 out of 20837 in 8694.62 seconds
# Processed 660 out of 20837 in 8775.78 seconds
# Processed 670 out of 20837 in 8860.36 seconds
# Processed 680 out of 20837 in 9057.63 seconds
# Processed 690 out of 20837 in 9140.69 seconds
# Processed 700 out of 20837 in 9248.53 seconds
# Processed 710 out of 20837 in 9334.88 seconds
# Processed 720 out of 20837 in 9450.50 seconds
# Processed 730 out of 20837 in 9554.57 seconds
# Processed 740 out of 20837 in 9673.35 seconds
# Processed 750 out of 20837 in 9819.32 seconds
# Processed 760 out of 20837 in 10004.26 seconds
# Processed 770 out of 20837 in 10143.28 seconds
# Processed 780 out of 20837 in 10293.21 seconds
# Processed 790 out of 20837 in 10473.75 seconds
# Processed 800 out of 20837 in 10615.37 seconds
# Processed 810 out of 20837 in 10748.74 seconds
# Processed 820 out of 20837 in 10937.68 seconds
# Processed 830 out of 20837 in 11060.88 seconds
# Processed 840 out of 20837 in 11172.17 seconds
# Processed 850 out of 20837 in 11300.21 seconds
# Processed 860 out of 20837 in 11435.61 seconds
# Processed 870 out of 20837 in 11654.38 seconds
# Processed 880 out of 20837 in 11905.87 seconds
# Processed 890 out of 20837 in 12097.29 seconds
# Processed 900 out of 20837 in 12283.08 seconds
# Processed 910 out of 20837 in 12631.61 seconds
# Processed 920 out of 20837 in 12864.35 seconds
# Processed 930 out of 20837 in 12906.73 seconds
# Processed 940 out of 20837 in 12949.43 seconds
# Processed 950 out of 20837 in 13039.22 seconds
# Processed 960 out of 20837 in 13104.88 seconds
# Processed 970 out of 20837 in 13306.32 seconds
# Processed 980 out of 20837 in 13470.65 seconds
# Processed 990 out of 20837 in 14195.23 seconds
# Processed 1000 out of 20837 in 14528.74 seconds
# Processed 1010 out of 20837 in 14621.52 seconds
# Processed 1020 out of 20837 in 14694.57 seconds
# Processed 1030 out of 20837 in 14794.24 seconds
# Processed 1040 out of 20837 in 14896.61 seconds
# Processed 1050 out of 20837 in 14979.71 seconds
# Processed 1060 out of 20837 in 15078.12 seconds
# Processed 1070 out of 20837 in 15189.88 seconds
# Processed 1080 out of 20837 in 15327.13 seconds
# Processed 1090 out of 20837 in 15427.78 seconds
# Processed 1100 out of 20837 in 15537.29 seconds
# Processed 1110 out of 20837 in 15686.23 seconds
# Processed 1120 out of 20837 in 15782.15 seconds
# Processed 1130 out of 20837 in 15892.09 seconds
# Processed 1140 out of 20837 in 15982.68 seconds
# Processed 1150 out of 20837 in 16069.49 seconds
# Processed 1160 out of 20837 in 16176.37 seconds
# Processed 1170 out of 20837 in 16301.31 seconds
# Processed 1180 out of 20837 in 16482.90 seconds
# Processed 1190 out of 20837 in 16596.29 seconds
# Processed 1200 out of 20837 in 16684.74 seconds
# Processed 1210 out of 20837 in 17076.32 seconds
# Processed 1220 out of 20837 in 17439.66 seconds
# Processed 1230 out of 20837 in 17568.19 seconds
# Processed 1240 out of 20837 in 17697.38 seconds
# Processed 1250 out of 20837 in 18467.20 seconds
# Processed 1260 out of 20837 in 18552.97 seconds
# Processed 1270 out of 20837 in 18687.23 seconds
# Processed 1280 out of 20837 in 18790.05 seconds
# Processed 1290 out of 20837 in 18889.19 seconds
# Processed 1300 out of 20837 in 18949.89 seconds
# Processed 1310 out of 20837 in 19038.28 seconds
# Processed 1320 out of 20837 in 19197.38 seconds
# Processed 1330 out of 20837 in 19400.18 seconds
# Processed 1340 out of 20837 in 19482.35 seconds
# Processed 1350 out of 20837 in 19590.74 seconds
# Processed 1360 out of 20837 in 19672.72 seconds
# Processed 1370 out of 20837 in 19758.10 seconds
# Processed 1380 out of 20837 in 19924.70 seconds
# Processed 1390 out of 20837 in 20413.43 seconds
# Processed 1400 out of 20837 in 20528.74 seconds
# Processed 1410 out of 20837 in 20710.09 seconds
# Processed 1420 out of 20837 in 20870.17 seconds
# Processed 1430 out of 20837 in 21122.40 seconds
# Processed 1440 out of 20837 in 21308.10 seconds
# Processed 1450 out of 20837 in 21395.16 seconds
# Processed 1460 out of 20837 in 21535.55 seconds
# Processed 1470 out of 20837 in 21743.06 seconds
# Processed 1480 out of 20837 in 21945.73 seconds
# Processed 1490 out of 20837 in 22092.93 seconds
# Processed 1500 out of 20837 in 22221.43 seconds
# Processed 1510 out of 20837 in 22380.97 seconds
# Processed 1520 out of 20837 in 22505.96 seconds
# Processed 1530 out of 20837 in 22655.07 seconds
# Processed 1540 out of 20837 in 22779.88 seconds
# Processed 1550 out of 20837 in 22992.50 seconds
# Processed 1560 out of 20837 in 23263.40 seconds
# Processed 1570 out of 20837 in 23450.16 seconds
# Processed 1580 out of 20837 in 23649.04 seconds
# Processed 1590 out of 20837 in 23888.89 seconds
# Processed 1600 out of 20837 in 24103.55 seconds
# Processed 1610 out of 20837 in 24285.51 seconds
# Processed 1620 out of 20837 in 24492.30 seconds
# Processed 1630 out of 20837 in 24702.06 seconds
# Processed 1640 out of 20837 in 24892.28 seconds
# Processed 1650 out of 20837 in 25097.15 seconds
# Processed 1660 out of 20837 in 25293.35 seconds
# Processed 1670 out of 20837 in 25494.97 seconds
# Processed 1680 out of 20837 in 25701.07 seconds
# Processed 1690 out of 20837 in 25914.35 seconds
# Processed 1700 out of 20837 in 25948.21 seconds
# Processed 1710 out of 20837 in 25997.51 seconds
# Processed 1720 out of 20837 in 26058.44 seconds
# Processed 1730 out of 20837 in 26181.11 seconds
# Processed 1740 out of 20837 in 26275.10 seconds
# Processed 1750 out of 20837 in 26363.31 seconds
# Processed 1760 out of 20837 in 26408.32 seconds
# Processed 1770 out of 20837 in 26508.61 seconds
# Processed 1780 out of 20837 in 26649.76 seconds
# Processed 1790 out of 20837 in 26699.29 seconds
# Processed 1800 out of 20837 in 26880.32 seconds
# Processed 1810 out of 20837 in 26934.89 seconds
# Processed 1820 out of 20837 in 26990.39 seconds
# Processed 1830 out of 20837 in 27032.98 seconds
# Processed 1840 out of 20837 in 27076.20 seconds
# Processed 1850 out of 20837 in 27140.84 seconds
# Processed 1860 out of 20837 in 27222.25 seconds
# Processed 1870 out of 20837 in 27306.74 seconds
# Processed 1880 out of 20837 in 27382.49 seconds
# Processed 1890 out of 20837 in 27462.02 seconds
# Processed 1900 out of 20837 in 27555.03 seconds
# Processed 1910 out of 20837 in 27658.09 seconds
# Processed 1920 out of 20837 in 27740.24 seconds
# Processed 1930 out of 20837 in 27828.29 seconds
# Processed 1940 out of 20837 in 27911.17 seconds
# Processed 1950 out of 20837 in 28002.63 seconds
# Processed 1960 out of 20837 in 28090.67 seconds
# Processed 1970 out of 20837 in 28164.65 seconds
# Processed 1980 out of 20837 in 28220.96 seconds
# Processed 1990 out of 20837 in 28273.65 seconds
# Processed 2000 out of 20837 in 28382.91 seconds
# Processed 2010 out of 20837 in 28448.12 seconds
# Processed 2020 out of 20837 in 28516.51 seconds
# Processed 2030 out of 20837 in 28767.77 seconds
# Processed 2040 out of 20837 in 29015.82 seconds
# Processed 2050 out of 20837 in 29106.49 seconds
# Processed 2060 out of 20837 in 29256.76 seconds
# Processed 2070 out of 20837 in 29329.70 seconds
# Processed 2080 out of 20837 in 29431.58 seconds
# Processed 2090 out of 20837 in 29581.95 seconds
# Processed 2100 out of 20837 in 29658.04 seconds
# Processed 2110 out of 20837 in 29903.87 seconds
# Processed 2120 out of 20837 in 30095.63 seconds
# Processed 2130 out of 20837 in 30174.32 seconds
# Processed 2140 out of 20837 in 30272.50 seconds
# Processed 2150 out of 20837 in 30587.14 seconds
# Processed 2160 out of 20837 in 30706.59 seconds
# Processed 2170 out of 20837 in 30778.88 seconds
# Processed 2180 out of 20837 in 30896.05 seconds
# Processed 2190 out of 20837 in 31018.04 seconds
# Processed 2200 out of 20837 in 31138.55 seconds
# Processed 2210 out of 20837 in 31242.86 seconds
# Processed 2220 out of 20837 in 31345.01 seconds
# Processed 2230 out of 20837 in 31473.01 seconds
# Processed 2240 out of 20837 in 31594.58 seconds
# Processed 2250 out of 20837 in 31721.56 seconds
# Processed 2260 out of 20837 in 31849.09 seconds
# Processed 2270 out of 20837 in 31986.79 seconds
# Processed 2280 out of 20837 in 32146.18 seconds
# Processed 2290 out of 20837 in 32257.99 seconds
# Processed 2300 out of 20837 in 32339.62 seconds
# Processed 2310 out of 20837 in 32472.09 seconds
# Processed 2320 out of 20837 in 32688.31 seconds
# Processed 2330 out of 20837 in 32940.46 seconds
# Processed 2340 out of 20837 in 33206.21 seconds
# Processed 2350 out of 20837 in 33440.49 seconds
# Processed 2360 out of 20837 in 33712.03 seconds
# Processed 2370 out of 20837 in 33854.95 seconds
# Processed 2380 out of 20837 in 33979.17 seconds
# Processed 2390 out of 20837 in 34132.29 seconds
# Processed 2400 out of 20837 in 34233.76 seconds
# Processed 2410 out of 20837 in 34370.98 seconds
# Processed 2420 out of 20837 in 34498.87 seconds
# Processed 2430 out of 20837 in 34595.15 seconds
# Processed 2440 out of 20837 in 34696.23 seconds
# Processed 2450 out of 20837 in 34887.00 seconds
# Processed 2460 out of 20837 in 35129.86 seconds
# Processed 2470 out of 20837 in 35274.08 seconds
# Processed 2480 out of 20837 in 35335.89 seconds
# Processed 2490 out of 20837 in 35410.07 seconds
# Processed 2500 out of 20837 in 35494.78 seconds
# Processed 2510 out of 20837 in 35554.74 seconds
# Processed 2520 out of 20837 in 35608.30 seconds
# Processed 2530 out of 20837 in 35717.23 seconds
# Processed 2540 out of 20837 in 35853.75 seconds
# Processed 2550 out of 20837 in 35968.96 seconds
# Processed 2560 out of 20837 in 36102.50 seconds
# Processed 2570 out of 20837 in 36222.44 seconds
# Processed 2580 out of 20837 in 36336.82 seconds
# Processed 2590 out of 20837 in 36485.68 seconds
# Processed 2600 out of 20837 in 36611.64 seconds
# Processed 2610 out of 20837 in 36711.31 seconds
# Processed 2620 out of 20837 in 36822.98 seconds
# Processed 2630 out of 20837 in 36977.89 seconds
# Processed 2640 out of 20837 in 37130.03 seconds
# Processed 2650 out of 20837 in 37225.79 seconds
# Processed 2660 out of 20837 in 37303.75 seconds
# Processed 2670 out of 20837 in 37431.64 seconds
# Processed 2680 out of 20837 in 37536.11 seconds
# Processed 2690 out of 20837 in 37657.36 seconds
# Processed 2700 out of 20837 in 37745.67 seconds
# Processed 2710 out of 20837 in 37794.37 seconds
# Processed 2720 out of 20837 in 37837.05 seconds
# Processed 2730 out of 20837 in 37883.45 seconds
# Processed 2740 out of 20837 in 37928.21 seconds
# Processed 2750 out of 20837 in 38056.77 seconds
# Processed 2760 out of 20837 in 38250.93 seconds
# Processed 2770 out of 20837 in 38418.32 seconds
# Processed 2780 out of 20837 in 38539.37 seconds
# Processed 2790 out of 20837 in 38629.55 seconds
# Processed 2800 out of 20837 in 38790.98 seconds
# Processed 2810 out of 20837 in 38962.27 seconds
# Processed 2820 out of 20837 in 39170.97 seconds
# Processed 2830 out of 20837 in 39359.78 seconds
# Processed 2840 out of 20837 in 39549.10 seconds
# Processed 2850 out of 20837 in 39787.34 seconds
# Processed 2860 out of 20837 in 39961.06 seconds
# Processed 2870 out of 20837 in 40154.65 seconds
# Processed 2880 out of 20837 in 40212.25 seconds
# Processed 2890 out of 20837 in 40323.87 seconds
# Processed 2900 out of 20837 in 40373.11 seconds
# Processed 2910 out of 20837 in 40457.13 seconds
# Processed 2920 out of 20837 in 40544.68 seconds
# Processed 2930 out of 20837 in 40717.62 seconds
# Processed 2940 out of 20837 in 40828.11 seconds
# Processed 2950 out of 20837 in 40909.71 seconds
# Processed 2960 out of 20837 in 41239.82 seconds
# Processed 2970 out of 20837 in 41429.92 seconds
# Processed 2980 out of 20837 in 41486.21 seconds
# Processed 2990 out of 20837 in 41553.50 seconds
# Processed 3000 out of 20837 in 41678.08 seconds
# Processed 3010 out of 20837 in 41887.04 seconds
# Processed 3020 out of 20837 in 42005.15 seconds
# Processed 3030 out of 20837 in 42083.82 seconds
# Processed 3040 out of 20837 in 42244.86 seconds
# Processed 3050 out of 20837 in 42334.34 seconds
# Processed 3060 out of 20837 in 42402.18 seconds
# Processed 3070 out of 20837 in 42632.48 seconds
# Processed 3080 out of 20837 in 42703.96 seconds
# Processed 3090 out of 20837 in 42769.27 seconds
# Processed 3100 out of 20837 in 42821.37 seconds
# Processed 3110 out of 20837 in 42872.94 seconds
# Processed 3120 out of 20837 in 42931.27 seconds
# Processed 3130 out of 20837 in 42982.26 seconds
# Processed 3140 out of 20837 in 43167.63 seconds
# Processed 3150 out of 20837 in 43238.90 seconds
# Processed 3160 out of 20837 in 43300.90 seconds
# Processed 3170 out of 20837 in 43372.67 seconds
# Processed 3180 out of 20837 in 43445.79 seconds
# Processed 3190 out of 20837 in 43515.14 seconds
# Processed 3200 out of 20837 in 43597.82 seconds
# Processed 3210 out of 20837 in 43705.59 seconds
# Processed 3220 out of 20837 in 43793.83 seconds
# Processed 3230 out of 20837 in 43922.92 seconds
# Processed 3240 out of 20837 in 44021.69 seconds
# Processed 3250 out of 20837 in 44160.61 seconds
# Processed 3260 out of 20837 in 44308.17 seconds
# Processed 3270 out of 20837 in 44365.80 seconds
# Processed 3280 out of 20837 in 44430.44 seconds
# Processed 3290 out of 20837 in 44495.26 seconds
# Processed 3300 out of 20837 in 44565.08 seconds
# Processed 3310 out of 20837 in 44614.50 seconds
# Processed 3320 out of 20837 in 44670.40 seconds
# Processed 3330 out of 20837 in 44724.61 seconds
# Processed 3340 out of 20837 in 44774.70 seconds
# Processed 3350 out of 20837 in 44829.33 seconds
# Processed 3360 out of 20837 in 44877.46 seconds
# Processed 3370 out of 20837 in 44916.92 seconds
# Processed 3380 out of 20837 in 44972.99 seconds
# Processed 3390 out of 20837 in 45022.57 seconds
# Processed 3400 out of 20837 in 45089.11 seconds
# Processed 3410 out of 20837 in 45148.93 seconds
# Processed 3420 out of 20837 in 45204.01 seconds
# Processed 3430 out of 20837 in 45252.10 seconds
# Processed 3440 out of 20837 in 45452.38 seconds
# Processed 3450 out of 20837 in 45660.69 seconds
# Processed 3460 out of 20837 in 45852.56 seconds
# Processed 3470 out of 20837 in 46054.68 seconds
# Processed 3480 out of 20837 in 46252.86 seconds
# Processed 3490 out of 20837 in 46463.59 seconds
# Processed 3500 out of 20837 in 46802.27 seconds
# Processed 3510 out of 20837 in 47095.16 seconds
# Processed 3520 out of 20837 in 47658.18 seconds
# Processed 3530 out of 20837 in 48017.06 seconds
# Processed 3540 out of 20837 in 48238.08 seconds
# Processed 3550 out of 20837 in 48423.53 seconds
# Processed 3560 out of 20837 in 48685.23 seconds
# Processed 3570 out of 20837 in 48736.59 seconds
# Processed 3580 out of 20837 in 48880.15 seconds
# Processed 3590 out of 20837 in 49052.86 seconds
# Processed 3600 out of 20837 in 49208.89 seconds
# Processed 3610 out of 20837 in 49325.31 seconds
# Processed 3620 out of 20837 in 49385.07 seconds
# Processed 3630 out of 20837 in 49515.53 seconds
# Processed 3640 out of 20837 in 49718.57 seconds
# Processed 3650 out of 20837 in 49870.09 seconds
# Processed 3660 out of 20837 in 49993.19 seconds
# Processed 3670 out of 20837 in 50086.42 seconds
# Processed 3680 out of 20837 in 50148.60 seconds
# Processed 3690 out of 20837 in 50292.26 seconds
# Processed 3700 out of 20837 in 50433.88 seconds
# Processed 3710 out of 20837 in 50506.60 seconds
# Processed 3720 out of 20837 in 50568.63 seconds
# Processed 3730 out of 20837 in 50620.20 seconds
# Processed 3740 out of 20837 in 50730.19 seconds
# Processed 3750 out of 20837 in 50821.27 seconds
# Processed 3760 out of 20837 in 50905.56 seconds
# Processed 3770 out of 20837 in 50981.49 seconds
# Processed 3780 out of 20837 in 52246.79 seconds
# Processed 3790 out of 20837 in 52471.05 seconds
# Processed 3800 out of 20837 in 52793.72 seconds
# Processed 3810 out of 20837 in 52989.95 seconds
# Processed 3820 out of 20837 in 53094.45 seconds
# Processed 3830 out of 20837 in 53192.17 seconds
# Processed 3840 out of 20837 in 53267.84 seconds
# Processed 3850 out of 20837 in 53375.10 seconds
# Processed 3860 out of 20837 in 53480.92 seconds
# Processed 3870 out of 20837 in 53605.37 seconds
# Processed 3880 out of 20837 in 53734.82 seconds
# Processed 3890 out of 20837 in 53848.34 seconds
# Processed 3900 out of 20837 in 53977.08 seconds
# Processed 3910 out of 20837 in 54170.97 seconds
# Processed 3920 out of 20837 in 54320.33 seconds
# Processed 3930 out of 20837 in 54486.01 seconds
# Processed 3940 out of 20837 in 54658.10 seconds
# Processed 3950 out of 20837 in 54798.61 seconds
# Processed 3960 out of 20837 in 54943.42 seconds
# Processed 3970 out of 20837 in 55058.16 seconds
# Processed 3980 out of 20837 in 55174.87 seconds
# Processed 3990 out of 20837 in 55272.23 seconds
# Processed 4000 out of 20837 in 55378.04 seconds
# Processed 4010 out of 20837 in 55486.17 seconds
# Processed 4020 out of 20837 in 55648.69 seconds
# Processed 4030 out of 20837 in 55791.80 seconds
# Processed 4040 out of 20837 in 55912.68 seconds
# Processed 4050 out of 20837 in 56018.43 seconds
# Processed 4060 out of 20837 in 56119.67 seconds
# Processed 4070 out of 20837 in 56228.88 seconds
# Processed 4080 out of 20837 in 56329.01 seconds
# Processed 4090 out of 20837 in 56372.82 seconds
# Processed 4100 out of 20837 in 56430.46 seconds
# Processed 4110 out of 20837 in 56488.25 seconds
# Processed 4120 out of 20837 in 56682.36 seconds
# Processed 4130 out of 20837 in 56927.45 seconds
# Processed 4140 out of 20837 in 57003.49 seconds
# Processed 4150 out of 20837 in 57072.34 seconds
# Processed 4160 out of 20837 in 57439.82 seconds
# Processed 4170 out of 20837 in 57537.06 seconds
# Processed 4180 out of 20837 in 57749.43 seconds
# Processed 4190 out of 20837 in 57970.65 seconds
# Processed 4200 out of 20837 in 58062.28 seconds
# Processed 4210 out of 20837 in 58166.27 seconds
# Processed 4220 out of 20837 in 58290.23 seconds
# Processed 4230 out of 20837 in 58394.58 seconds
# Processed 4240 out of 20837 in 58488.92 seconds
# Processed 4250 out of 20837 in 58582.75 seconds
# Processed 4260 out of 20837 in 58681.93 seconds
# Processed 4270 out of 20837 in 58769.61 seconds
# Processed 4280 out of 20837 in 58879.43 seconds
# Processed 4290 out of 20837 in 59010.70 seconds
# Processed 4300 out of 20837 in 59114.97 seconds
# Processed 4310 out of 20837 in 59240.12 seconds
# Processed 4320 out of 20837 in 59312.65 seconds
# Processed 4330 out of 20837 in 59406.73 seconds
# Processed 4340 out of 20837 in 59538.40 seconds
# Processed 4350 out of 20837 in 59688.26 seconds
# Processed 4360 out of 20837 in 59800.78 seconds
# Processed 4370 out of 20837 in 60116.48 seconds
# Processed 4380 out of 20837 in 60309.63 seconds
# Processed 4390 out of 20837 in 60412.84 seconds
# Processed 4400 out of 20837 in 60503.93 seconds
# Processed 4410 out of 20837 in 60634.05 seconds
# Processed 4420 out of 20837 in 60810.98 seconds
# Processed 4430 out of 20837 in 60955.75 seconds
# Processed 4440 out of 20837 in 61118.08 seconds
# Processed 4450 out of 20837 in 61368.78 seconds
# Processed 4460 out of 20837 in 61464.11 seconds
# Processed 4470 out of 20837 in 61538.51 seconds
# Processed 4480 out of 20837 in 61593.86 seconds
# Processed 4490 out of 20837 in 61643.90 seconds
# Processed 4500 out of 20837 in 61691.00 seconds
# Processed 4510 out of 20837 in 61761.97 seconds
# Processed 4520 out of 20837 in 61824.74 seconds
# Processed 4530 out of 20837 in 61889.40 seconds
# Processed 4540 out of 20837 in 61943.78 seconds
# Processed 4550 out of 20837 in 62030.06 seconds
# Processed 4560 out of 20837 in 62154.14 seconds
# Processed 4570 out of 20837 in 62239.40 seconds
# Processed 4580 out of 20837 in 62304.54 seconds
# Processed 4590 out of 20837 in 62388.79 seconds
# Processed 4600 out of 20837 in 62488.59 seconds
# Processed 4610 out of 20837 in 62576.55 seconds
# Processed 4620 out of 20837 in 62669.41 seconds
# Processed 4630 out of 20837 in 62753.17 seconds
# Processed 4640 out of 20837 in 62819.40 seconds
# Processed 4650 out of 20837 in 62888.14 seconds
# Processed 4660 out of 20837 in 62963.39 seconds
# Processed 4670 out of 20837 in 63029.29 seconds
# Processed 4680 out of 20837 in 63145.47 seconds
# Processed 4690 out of 20837 in 63293.41 seconds
# Processed 4700 out of 20837 in 63372.07 seconds
# Processed 4710 out of 20837 in 63439.70 seconds
# Processed 4720 out of 20837 in 63512.49 seconds
# Processed 4730 out of 20837 in 63584.29 seconds
# Processed 4740 out of 20837 in 63707.64 seconds
# Processed 4750 out of 20837 in 63772.00 seconds
# Processed 4760 out of 20837 in 63833.02 seconds
# Processed 4770 out of 20837 in 64002.57 seconds
# Processed 4780 out of 20837 in 64207.50 seconds
# Processed 4790 out of 20837 in 64337.69 seconds
# Processed 4800 out of 20837 in 64449.16 seconds
# Processed 4810 out of 20837 in 64532.11 seconds
# Processed 4820 out of 20837 in 64622.64 seconds
# Processed 4830 out of 20837 in 64695.31 seconds
# Processed 4840 out of 20837 in 64798.43 seconds
# Processed 4850 out of 20837 in 64860.86 seconds
# Processed 4860 out of 20837 in 64929.07 seconds
# Processed 4870 out of 20837 in 65001.42 seconds
# Processed 4880 out of 20837 in 65068.19 seconds
# Processed 4890 out of 20837 in 65371.60 seconds
# Processed 4900 out of 20837 in 65741.82 seconds
# Processed 4910 out of 20837 in 65907.86 seconds
# Processed 4920 out of 20837 in 66040.75 seconds
# Processed 4930 out of 20837 in 66084.88 seconds
# Processed 4940 out of 20837 in 66134.64 seconds
# Processed 4950 out of 20837 in 66424.04 seconds
# Processed 4960 out of 20837 in 66531.27 seconds
# Processed 4970 out of 20837 in 66727.20 seconds
# Processed 4980 out of 20837 in 66935.59 seconds
# Processed 4990 out of 20837 in 67120.97 seconds
# Processed 5000 out of 20837 in 67299.64 seconds
# Processed 5010 out of 20837 in 67348.93 seconds
# Processed 5020 out of 20837 in 67391.57 seconds
# Processed 5030 out of 20837 in 67436.18 seconds
# Processed 5040 out of 20837 in 67552.57 seconds
# Processed 5050 out of 20837 in 67955.29 seconds
# Processed 5060 out of 20837 in 68728.20 seconds
# Processed 5070 out of 20837 in 68805.65 seconds
# Processed 5080 out of 20837 in 68892.45 seconds
# Processed 5090 out of 20837 in 68952.33 seconds
# Processed 5100 out of 20837 in 69041.47 seconds
# Processed 5110 out of 20837 in 69162.43 seconds
# Processed 5120 out of 20837 in 69239.24 seconds
# Processed 5130 out of 20837 in 69345.28 seconds
# Processed 5140 out of 20837 in 69500.70 seconds
# Processed 5150 out of 20837 in 69772.98 seconds
# Processed 5160 out of 20837 in 70201.64 seconds
# Processed 5170 out of 20837 in 70395.07 seconds
# Processed 5180 out of 20837 in 70554.78 seconds
# Processed 5190 out of 20837 in 70631.13 seconds
# Processed 5200 out of 20837 in 70742.26 seconds
# Processed 5210 out of 20837 in 70824.74 seconds
# Processed 5220 out of 20837 in 70943.97 seconds
# Processed 5230 out of 20837 in 71039.90 seconds
# Processed 5240 out of 20837 in 71146.07 seconds
# Processed 5250 out of 20837 in 71231.26 seconds
# Processed 5260 out of 20837 in 71368.32 seconds
# Processed 5270 out of 20837 in 71464.02 seconds
# Processed 5280 out of 20837 in 71568.57 seconds
# Processed 5290 out of 20837 in 71709.17 seconds
# Processed 5300 out of 20837 in 71821.89 seconds
# Processed 5310 out of 20837 in 71936.27 seconds
# Processed 5320 out of 20837 in 72067.27 seconds
# Processed 5330 out of 20837 in 72179.63 seconds
# Processed 5340 out of 20837 in 72301.98 seconds
# Processed 5350 out of 20837 in 72409.52 seconds
# Processed 5360 out of 20837 in 72536.13 seconds
# Processed 5370 out of 20837 in 72630.08 seconds
# Processed 5380 out of 20837 in 72798.24 seconds
# Processed 5390 out of 20837 in 72950.20 seconds
# Processed 5400 out of 20837 in 73032.69 seconds
# Processed 5410 out of 20837 in 73108.54 seconds
# Processed 5420 out of 20837 in 73145.81 seconds
# Processed 5430 out of 20837 in 73172.02 seconds
# Processed 5440 out of 20837 in 73223.17 seconds
# Processed 5450 out of 20837 in 73395.98 seconds
# Processed 5460 out of 20837 in 73697.12 seconds
# Processed 5470 out of 20837 in 73838.33 seconds
# Processed 5480 out of 20837 in 73949.01 seconds
# Processed 5490 out of 20837 in 74046.89 seconds
# Processed 5500 out of 20837 in 74173.86 seconds
# Processed 5510 out of 20837 in 74358.95 seconds
# Processed 5520 out of 20837 in 74542.88 seconds
# Processed 5530 out of 20837 in 74695.49 seconds
# Processed 5540 out of 20837 in 74813.73 seconds
# Processed 5550 out of 20837 in 74903.04 seconds
# Processed 5560 out of 20837 in 74998.14 seconds
# Processed 5570 out of 20837 in 75107.12 seconds
# Processed 5580 out of 20837 in 75190.36 seconds
# Processed 5590 out of 20837 in 75292.72 seconds
# Processed 5600 out of 20837 in 75388.62 seconds
# Processed 5610 out of 20837 in 75519.51 seconds
# Processed 5620 out of 20837 in 75634.88 seconds
# Processed 5630 out of 20837 in 75746.89 seconds
# Processed 5640 out of 20837 in 75837.51 seconds
# Processed 5650 out of 20837 in 75931.50 seconds
# Processed 5660 out of 20837 in 76015.51 seconds
# Processed 5670 out of 20837 in 76194.38 seconds
# Processed 5680 out of 20837 in 76382.43 seconds
# Processed 5690 out of 20837 in 76431.54 seconds
# Processed 5700 out of 20837 in 76475.96 seconds
# Processed 5710 out of 20837 in 76923.84 seconds
# Processed 5720 out of 20837 in 77368.37 seconds
# Processed 5730 out of 20837 in 77718.76 seconds
# Processed 5740 out of 20837 in 78072.48 seconds
# Processed 5750 out of 20837 in 78165.53 seconds
# Processed 5760 out of 20837 in 78254.27 seconds
# Processed 5770 out of 20837 in 78337.35 seconds
# Processed 5780 out of 20837 in 78475.85 seconds
# Processed 5790 out of 20837 in 78645.36 seconds
# Processed 5800 out of 20837 in 78829.30 seconds
# Processed 5810 out of 20837 in 79080.19 seconds
# Processed 5820 out of 20837 in 79333.91 seconds
# Processed 5830 out of 20837 in 79446.80 seconds
# Processed 5840 out of 20837 in 79524.70 seconds
# Processed 5850 out of 20837 in 79613.98 seconds
# Processed 5860 out of 20837 in 79714.81 seconds
# Processed 5870 out of 20837 in 79821.08 seconds
# Processed 5880 out of 20837 in 79903.47 seconds
# Processed 5890 out of 20837 in 79988.73 seconds
# Processed 5900 out of 20837 in 80069.27 seconds
# Processed 5910 out of 20837 in 80151.25 seconds
# Processed 5920 out of 20837 in 80231.88 seconds
# Processed 5930 out of 20837 in 80317.26 seconds
# Processed 5940 out of 20837 in 80398.67 seconds
# Processed 5950 out of 20837 in 80494.67 seconds
# Processed 5960 out of 20837 in 80568.00 seconds
# Processed 5970 out of 20837 in 80643.75 seconds
# Processed 5980 out of 20837 in 80933.72 seconds
# Processed 5990 out of 20837 in 81225.55 seconds
# Processed 6000 out of 20837 in 81370.64 seconds
# Processed 6010 out of 20837 in 81453.58 seconds
# Processed 6020 out of 20837 in 81536.21 seconds
# Processed 6030 out of 20837 in 81606.70 seconds
# Processed 6040 out of 20837 in 81683.44 seconds
# Processed 6050 out of 20837 in 81863.41 seconds
# Processed 6060 out of 20837 in 82038.31 seconds
# Processed 6070 out of 20837 in 82237.25 seconds
# Processed 6080 out of 20837 in 82792.05 seconds
# Processed 6090 out of 20837 in 83002.98 seconds
# Processed 6100 out of 20837 in 83062.10 seconds
# Processed 6110 out of 20837 in 83140.11 seconds
# Processed 6120 out of 20837 in 83213.32 seconds
# Processed 6130 out of 20837 in 83294.25 seconds
# Processed 6140 out of 20837 in 83399.84 seconds
# Processed 6150 out of 20837 in 83484.64 seconds
# Processed 6160 out of 20837 in 83591.18 seconds
# Processed 6170 out of 20837 in 83710.59 seconds
# Processed 6180 out of 20837 in 83816.89 seconds
# Processed 6190 out of 20837 in 84206.92 seconds
# Processed 6200 out of 20837 in 84286.37 seconds
# Processed 6210 out of 20837 in 84354.18 seconds
# Processed 6220 out of 20837 in 84417.98 seconds
# Processed 6230 out of 20837 in 84573.78 seconds
# Processed 6240 out of 20837 in 84928.28 seconds
# Processed 6250 out of 20837 in 84986.53 seconds
# Processed 6260 out of 20837 in 85043.34 seconds
# Processed 6270 out of 20837 in 85095.75 seconds
# Processed 6280 out of 20837 in 85410.91 seconds
# Processed 6290 out of 20837 in 85626.83 seconds
# Processed 6300 out of 20837 in 85751.37 seconds
# Processed 6310 out of 20837 in 85874.77 seconds
# Processed 6320 out of 20837 in 85967.77 seconds
# Processed 6330 out of 20837 in 86226.79 seconds
# Processed 6340 out of 20837 in 86361.17 seconds
# Processed 6350 out of 20837 in 86408.04 seconds
# Processed 6360 out of 20837 in 86495.99 seconds
# Processed 6370 out of 20837 in 86579.28 seconds
# Processed 6380 out of 20837 in 86627.81 seconds
# Processed 6390 out of 20837 in 86691.10 seconds
# Processed 6400 out of 20837 in 86986.19 seconds
# Processed 6410 out of 20837 in 87070.80 seconds
# Processed 6420 out of 20837 in 87176.22 seconds
# Processed 6430 out of 20837 in 87275.37 seconds
# Processed 6440 out of 20837 in 87637.54 seconds
# Processed 6450 out of 20837 in 87937.97 seconds
# Processed 6460 out of 20837 in 88014.82 seconds
# Processed 6470 out of 20837 in 88092.56 seconds
# Processed 6480 out of 20837 in 88155.33 seconds
# Processed 6490 out of 20837 in 88485.92 seconds
# Processed 6500 out of 20837 in 88765.87 seconds
# Processed 6510 out of 20837 in 89147.44 seconds
# Processed 6520 out of 20837 in 89250.79 seconds
# Processed 6530 out of 20837 in 89400.61 seconds
# Processed 6540 out of 20837 in 89810.93 seconds
# Processed 6550 out of 20837 in 90104.48 seconds
# Processed 6560 out of 20837 in 90335.50 seconds
# Processed 6570 out of 20837 in 90792.88 seconds
# Processed 6580 out of 20837 in 90973.97 seconds
# Processed 6590 out of 20837 in 91094.18 seconds
# Processed 6600 out of 20837 in 91506.60 seconds
# Processed 6610 out of 20837 in 91736.27 seconds
# Processed 6620 out of 20837 in 91794.47 seconds
# Processed 6630 out of 20837 in 91855.74 seconds
# Processed 6640 out of 20837 in 92051.91 seconds
# Processed 6650 out of 20837 in 92121.91 seconds
# Processed 6660 out of 20837 in 92232.06 seconds
# Processed 6670 out of 20837 in 92356.87 seconds
# Processed 6680 out of 20837 in 92504.81 seconds
# Processed 6690 out of 20837 in 92692.39 seconds
# Processed 6700 out of 20837 in 92862.81 seconds
# Processed 6710 out of 20837 in 92977.17 seconds
# Processed 6720 out of 20837 in 93389.90 seconds
# Processed 6730 out of 20837 in 93677.37 seconds
# Processed 6740 out of 20837 in 93789.76 seconds
# Processed 6750 out of 20837 in 93928.94 seconds
# Processed 6760 out of 20837 in 94171.97 seconds
# Processed 6770 out of 20837 in 94281.13 seconds
# Processed 6780 out of 20837 in 94397.20 seconds
# Processed 6790 out of 20837 in 94486.98 seconds
# Processed 6800 out of 20837 in 94579.69 seconds
# Processed 6810 out of 20837 in 94689.67 seconds
# Processed 6820 out of 20837 in 94830.82 seconds
# Processed 6830 out of 20837 in 95011.26 seconds
# Processed 6840 out of 20837 in 95162.73 seconds
# Processed 6850 out of 20837 in 95288.43 seconds
# Processed 6860 out of 20837 in 95407.46 seconds
# Processed 6870 out of 20837 in 95535.53 seconds
# Processed 6880 out of 20837 in 95654.59 seconds
# Processed 6890 out of 20837 in 95736.12 seconds
# Processed 6900 out of 20837 in 95843.79 seconds
# Processed 6910 out of 20837 in 95950.48 seconds
# Processed 6920 out of 20837 in 96042.98 seconds
# Processed 6930 out of 20837 in 96161.50 seconds
# Processed 6940 out of 20837 in 96228.02 seconds
# Processed 6950 out of 20837 in 96349.82 seconds
# Processed 6960 out of 20837 in 96486.15 seconds
# Processed 6970 out of 20837 in 96577.83 seconds
# Processed 6980 out of 20837 in 96661.41 seconds
# Processed 6990 out of 20837 in 96757.19 seconds
# Processed 7000 out of 20837 in 96840.01 seconds
# Processed 7010 out of 20837 in 96904.12 seconds
# Processed 7020 out of 20837 in 97103.01 seconds
# Processed 7030 out of 20837 in 97181.52 seconds
# Processed 7040 out of 20837 in 97283.94 seconds
# Processed 7050 out of 20837 in 97341.73 seconds
# Processed 7060 out of 20837 in 97449.19 seconds
# Processed 7070 out of 20837 in 97548.51 seconds
# Processed 7080 out of 20837 in 97649.20 seconds
# Processed 7090 out of 20837 in 97715.02 seconds
# Processed 7100 out of 20837 in 97771.96 seconds
# Processed 7110 out of 20837 in 97869.60 seconds
# Processed 7120 out of 20837 in 97934.02 seconds
# Processed 7130 out of 20837 in 97998.17 seconds
# Processed 7140 out of 20837 in 98048.87 seconds
# Processed 7150 out of 20837 in 98143.19 seconds
# Processed 7160 out of 20837 in 98206.91 seconds
# Processed 7170 out of 20837 in 98266.12 seconds
# Processed 7180 out of 20837 in 98317.77 seconds
# Processed 7190 out of 20837 in 98388.32 seconds
# Processed 7200 out of 20837 in 98455.01 seconds
# Processed 7210 out of 20837 in 98510.16 seconds
# Processed 7220 out of 20837 in 98563.13 seconds
# Processed 7230 out of 20837 in 98628.44 seconds
# Processed 7240 out of 20837 in 98702.99 seconds
# Processed 7250 out of 20837 in 98823.92 seconds
# Processed 7260 out of 20837 in 98948.77 seconds
# Processed 7270 out of 20837 in 98998.35 seconds
# Processed 7280 out of 20837 in 99053.71 seconds
# Processed 7290 out of 20837 in 99116.47 seconds
# Processed 7300 out of 20837 in 99217.00 seconds
# Processed 7310 out of 20837 in 99302.85 seconds
# Processed 7320 out of 20837 in 99410.27 seconds
# Processed 7330 out of 20837 in 99516.09 seconds
# Processed 7340 out of 20837 in 99928.06 seconds
# Processed 7350 out of 20837 in 100124.26 seconds
# Processed 7360 out of 20837 in 100422.57 seconds
# Processed 7370 out of 20837 in 100533.93 seconds
# Processed 7380 out of 20837 in 100625.08 seconds
# Processed 7390 out of 20837 in 100695.49 seconds
# Processed 7400 out of 20837 in 100760.95 seconds
# Processed 7410 out of 20837 in 100817.14 seconds
# Processed 7420 out of 20837 in 101082.64 seconds
# Processed 7430 out of 20837 in 101785.45 seconds
# Processed 7440 out of 20837 in 102069.46 seconds
# Processed 7450 out of 20837 in 102196.98 seconds
# Processed 7460 out of 20837 in 102266.61 seconds
# Processed 7470 out of 20837 in 102347.91 seconds
# Processed 7480 out of 20837 in 102422.41 seconds
# Processed 7490 out of 20837 in 103553.22 seconds
# Processed 7500 out of 20837 in 103666.62 seconds
# Processed 7510 out of 20837 in 103826.56 seconds
# Processed 7520 out of 20837 in 103952.38 seconds
# Processed 7530 out of 20837 in 104047.17 seconds
# Processed 7540 out of 20837 in 104130.20 seconds
# Processed 7550 out of 20837 in 104243.01 seconds
# Processed 7560 out of 20837 in 104327.80 seconds
# Processed 7570 out of 20837 in 104431.29 seconds
# Processed 7580 out of 20837 in 104598.83 seconds
# Processed 7590 out of 20837 in 104751.47 seconds
# Processed 7600 out of 20837 in 104861.38 seconds
# Processed 7610 out of 20837 in 105070.92 seconds
# Processed 7620 out of 20837 in 105149.32 seconds
# Processed 7630 out of 20837 in 105796.46 seconds
# Processed 7640 out of 20837 in 105899.02 seconds
# Processed 7650 out of 20837 in 106053.81 seconds
# Processed 7660 out of 20837 in 106120.49 seconds
# Processed 7670 out of 20837 in 106226.79 seconds
# Processed 7680 out of 20837 in 106317.39 seconds
# Processed 7690 out of 20837 in 106421.12 seconds
# Processed 7700 out of 20837 in 106485.39 seconds
# Processed 7710 out of 20837 in 106579.34 seconds
# Processed 7720 out of 20837 in 106656.03 seconds
# Processed 7730 out of 20837 in 106744.79 seconds
# Processed 7740 out of 20837 in 106812.90 seconds
# Processed 7750 out of 20837 in 106903.58 seconds
# Processed 7760 out of 20837 in 107044.48 seconds
# Processed 7770 out of 20837 in 107125.98 seconds
# Processed 7780 out of 20837 in 107220.32 seconds
# Processed 7790 out of 20837 in 107408.45 seconds
# Processed 7800 out of 20837 in 107502.11 seconds
# Processed 7810 out of 20837 in 107571.33 seconds
# Processed 7820 out of 20837 in 107633.18 seconds
# Processed 7830 out of 20837 in 107717.01 seconds
# Processed 7840 out of 20837 in 107812.44 seconds
# Processed 7850 out of 20837 in 107879.19 seconds
# Processed 7860 out of 20837 in 107936.93 seconds
# Processed 7870 out of 20837 in 108011.45 seconds
# Processed 7880 out of 20837 in 108088.02 seconds
# Processed 7890 out of 20837 in 108147.52 seconds
# Processed 7900 out of 20837 in 108208.11 seconds
# Processed 7910 out of 20837 in 108319.12 seconds
# Processed 7920 out of 20837 in 108389.71 seconds
# Processed 7930 out of 20837 in 108480.49 seconds
# Processed 7940 out of 20837 in 108557.24 seconds
# Processed 7950 out of 20837 in 108643.87 seconds
# Processed 7960 out of 20837 in 108746.38 seconds
# Processed 7970 out of 20837 in 108846.43 seconds
# Processed 7980 out of 20837 in 108965.30 seconds
# Processed 7990 out of 20837 in 109483.53 seconds
# Processed 8000 out of 20837 in 109699.05 seconds
# Processed 8010 out of 20837 in 109903.41 seconds
# Processed 8020 out of 20837 in 110112.06 seconds
# Processed 8030 out of 20837 in 110312.14 seconds
# Processed 8040 out of 20837 in 110492.36 seconds
# Processed 8050 out of 20837 in 110651.51 seconds
# Processed 8060 out of 20837 in 110810.74 seconds
# Processed 8070 out of 20837 in 110947.09 seconds
# Processed 8080 out of 20837 in 111099.73 seconds
# Processed 8090 out of 20837 in 111275.85 seconds
# Processed 8100 out of 20837 in 111453.40 seconds
# Processed 8110 out of 20837 in 111839.12 seconds
# Processed 8120 out of 20837 in 111942.79 seconds
# Processed 8130 out of 20837 in 112146.12 seconds
# Processed 8140 out of 20837 in 112384.77 seconds
# Processed 8150 out of 20837 in 112749.73 seconds
# Processed 8160 out of 20837 in 113260.60 seconds
# Processed 8170 out of 20837 in 113545.05 seconds
# Processed 8180 out of 20837 in 113795.39 seconds
# Processed 8190 out of 20837 in 113942.15 seconds
# Processed 8200 out of 20837 in 114136.26 seconds
# Processed 8210 out of 20837 in 114327.28 seconds
# Processed 8220 out of 20837 in 114515.79 seconds
# Processed 8230 out of 20837 in 114759.02 seconds
# Processed 8240 out of 20837 in 114956.72 seconds
# Processed 8250 out of 20837 in 115130.14 seconds
# Processed 8260 out of 20837 in 115413.00 seconds
# Processed 8270 out of 20837 in 115630.10 seconds
# Processed 8280 out of 20837 in 115835.72 seconds
# Processed 8290 out of 20837 in 115947.93 seconds
# Processed 8300 out of 20837 in 116196.59 seconds
# Processed 8310 out of 20837 in 116425.87 seconds
# Processed 8320 out of 20837 in 116584.37 seconds
# Processed 8330 out of 20837 in 116744.47 seconds
# Processed 8340 out of 20837 in 116921.89 seconds
# Processed 8350 out of 20837 in 117088.91 seconds
# Processed 8360 out of 20837 in 117211.76 seconds
# Processed 8370 out of 20837 in 117269.72 seconds
# Processed 8380 out of 20837 in 117389.05 seconds
# Processed 8390 out of 20837 in 117514.89 seconds
# Processed 8400 out of 20837 in 117611.30 seconds
# Processed 8410 out of 20837 in 117772.81 seconds
# Processed 8420 out of 20837 in 117843.14 seconds
# Processed 8430 out of 20837 in 117911.26 seconds
# Processed 8440 out of 20837 in 117978.87 seconds
# Processed 8450 out of 20837 in 118051.07 seconds
# Processed 8460 out of 20837 in 118161.70 seconds
# Processed 8470 out of 20837 in 118280.15 seconds
# Processed 8480 out of 20837 in 118389.76 seconds
# Processed 8490 out of 20837 in 118470.68 seconds
# Processed 8500 out of 20837 in 118554.46 seconds
# Processed 8510 out of 20837 in 118698.52 seconds
# Processed 8520 out of 20837 in 118811.25 seconds
# Processed 8530 out of 20837 in 118967.37 seconds
# Processed 8540 out of 20837 in 119067.03 seconds
# Processed 8550 out of 20837 in 119167.09 seconds
# Processed 8560 out of 20837 in 119427.21 seconds
# Processed 8570 out of 20837 in 119500.01 seconds
# Processed 8580 out of 20837 in 119570.44 seconds
# Processed 8590 out of 20837 in 119635.23 seconds
# Processed 8600 out of 20837 in 119946.55 seconds
# Processed 8610 out of 20837 in 120124.46 seconds
# Processed 8620 out of 20837 in 120308.53 seconds
# Processed 8630 out of 20837 in 120576.77 seconds
# Processed 8640 out of 20837 in 120721.63 seconds
# Processed 8650 out of 20837 in 120934.65 seconds
# Processed 8660 out of 20837 in 121130.13 seconds
# Processed 8670 out of 20837 in 121154.26 seconds
# Processed 8680 out of 20837 in 121258.62 seconds
# Processed 8690 out of 20837 in 121597.65 seconds
# Processed 8700 out of 20837 in 121653.61 seconds
# Processed 8710 out of 20837 in 121772.62 seconds
# Processed 8720 out of 20837 in 122096.66 seconds
# Processed 8730 out of 20837 in 122589.75 seconds
# Processed 8740 out of 20837 in 123004.26 seconds
# Processed 8750 out of 20837 in 123059.09 seconds
# Processed 8760 out of 20837 in 123111.88 seconds
# Processed 8770 out of 20837 in 123170.51 seconds
# Processed 8780 out of 20837 in 123401.20 seconds
# Processed 8790 out of 20837 in 123468.39 seconds
# Processed 8800 out of 20837 in 123542.89 seconds
# Processed 8810 out of 20837 in 123618.13 seconds
# Processed 8820 out of 20837 in 123880.98 seconds
# Processed 8830 out of 20837 in 124634.54 seconds
# Processed 8840 out of 20837 in 125364.89 seconds
# Processed 8850 out of 20837 in 125423.27 seconds
# Processed 8860 out of 20837 in 125490.03 seconds
# Processed 8870 out of 20837 in 125565.22 seconds
# Processed 8880 out of 20837 in 125643.07 seconds
# Processed 8890 out of 20837 in 125706.58 seconds
# Processed 8900 out of 20837 in 125751.17 seconds
# Processed 8910 out of 20837 in 125799.97 seconds
# Processed 8920 out of 20837 in 125857.08 seconds
# Processed 8930 out of 20837 in 125918.23 seconds
# Processed 8940 out of 20837 in 125993.75 seconds
# Processed 8950 out of 20837 in 126094.79 seconds
# Processed 8960 out of 20837 in 126421.84 seconds
# Processed 8970 out of 20837 in 126651.44 seconds
# Processed 8980 out of 20837 in 126768.12 seconds
# Processed 8990 out of 20837 in 126951.09 seconds
# Processed 9000 out of 20837 in 127053.98 seconds
# Processed 9010 out of 20837 in 127269.99 seconds
# Processed 9020 out of 20837 in 127490.63 seconds
# Processed 9030 out of 20837 in 127607.04 seconds
# Processed 9040 out of 20837 in 127752.73 seconds
# Processed 9050 out of 20837 in 127869.12 seconds
# Processed 9060 out of 20837 in 127935.71 seconds
# Processed 9070 out of 20837 in 128018.13 seconds
# Processed 9080 out of 20837 in 128090.50 seconds
# Processed 9090 out of 20837 in 128176.25 seconds
# Processed 9100 out of 20837 in 128348.09 seconds
# Processed 9110 out of 20837 in 128453.45 seconds
# Processed 9120 out of 20837 in 128577.34 seconds
# Processed 9130 out of 20837 in 128659.87 seconds
# Processed 9140 out of 20837 in 128750.65 seconds
# Processed 9150 out of 20837 in 128879.09 seconds
# Processed 9160 out of 20837 in 129292.83 seconds
# Processed 9170 out of 20837 in 129402.22 seconds
# Processed 9180 out of 20837 in 129523.76 seconds
# Processed 9190 out of 20837 in 129766.32 seconds
# Processed 9200 out of 20837 in 129840.09 seconds
# Processed 9210 out of 20837 in 129926.95 seconds
# Processed 9220 out of 20837 in 130024.02 seconds
# Processed 9230 out of 20837 in 130131.31 seconds
# Processed 9240 out of 20837 in 130283.00 seconds
# Processed 9250 out of 20837 in 130498.00 seconds
# Processed 9260 out of 20837 in 130628.46 seconds
# Processed 9270 out of 20837 in 130739.75 seconds
# Processed 9280 out of 20837 in 130905.83 seconds
# Processed 9290 out of 20837 in 131350.68 seconds
# Processed 9300 out of 20837 in 131495.30 seconds
# Processed 9310 out of 20837 in 131768.22 seconds
# Processed 9320 out of 20837 in 131918.02 seconds
# Processed 9330 out of 20837 in 132065.70 seconds
# Processed 9340 out of 20837 in 132650.82 seconds
# Processed 9350 out of 20837 in 132881.20 seconds
# Processed 9360 out of 20837 in 133024.87 seconds
# Processed 9370 out of 20837 in 133183.07 seconds
# Processed 9380 out of 20837 in 133313.18 seconds
# Processed 9390 out of 20837 in 133450.09 seconds
# Processed 9400 out of 20837 in 133559.41 seconds
# Processed 9410 out of 20837 in 133656.42 seconds
# Processed 9420 out of 20837 in 133766.90 seconds
# Processed 9430 out of 20837 in 133897.09 seconds
# Processed 9440 out of 20837 in 134146.88 seconds
# Processed 9450 out of 20837 in 134278.85 seconds
# Processed 9460 out of 20837 in 134611.43 seconds
# Processed 9470 out of 20837 in 135303.72 seconds
# Processed 9480 out of 20837 in 135602.36 seconds
# Processed 9490 out of 20837 in 135702.20 seconds
# Processed 9500 out of 20837 in 135864.38 seconds
# Processed 9510 out of 20837 in 136157.89 seconds
# Processed 9520 out of 20837 in 136292.40 seconds
# Processed 9530 out of 20837 in 136940.55 seconds
# Processed 9540 out of 20837 in 137335.09 seconds
# Processed 9550 out of 20837 in 137613.36 seconds
# Processed 9560 out of 20837 in 137959.89 seconds
# Processed 9570 out of 20837 in 138409.81 seconds
# Processed 9580 out of 20837 in 138567.58 seconds
# Processed 9590 out of 20837 in 138732.72 seconds
# Processed 9600 out of 20837 in 138834.95 seconds
# Processed 9610 out of 20837 in 138892.20 seconds
# Processed 9620 out of 20837 in 139113.86 seconds
# Processed 9630 out of 20837 in 139622.34 seconds
# Processed 9640 out of 20837 in 139874.78 seconds
# Processed 9650 out of 20837 in 140318.60 seconds
# Processed 9660 out of 20837 in 140433.01 seconds
# Processed 9670 out of 20837 in 140541.32 seconds
# Processed 9680 out of 20837 in 140813.46 seconds
# Processed 9690 out of 20837 in 140970.98 seconds
# Processed 9700 out of 20837 in 141103.83 seconds
# Processed 9710 out of 20837 in 141249.21 seconds
# Processed 9720 out of 20837 in 141381.02 seconds
# Processed 9730 out of 20837 in 141522.51 seconds
# Processed 9740 out of 20837 in 141637.01 seconds
# Processed 9750 out of 20837 in 141712.98 seconds
# Processed 9760 out of 20837 in 141810.79 seconds
# Processed 9770 out of 20837 in 141914.43 seconds
# Processed 9780 out of 20837 in 142017.36 seconds
# Processed 9790 out of 20837 in 142125.01 seconds
# Processed 9800 out of 20837 in 142276.72 seconds
# Processed 9810 out of 20837 in 142401.56 seconds
# Processed 9820 out of 20837 in 142514.92 seconds
# Processed 9830 out of 20837 in 142588.12 seconds
# Processed 9840 out of 20837 in 142657.03 seconds
# Processed 9850 out of 20837 in 142712.96 seconds
# Processed 9860 out of 20837 in 142872.25 seconds
# Processed 9870 out of 20837 in 143210.66 seconds
# Processed 9880 out of 20837 in 143274.69 seconds
# Processed 9890 out of 20837 in 143374.05 seconds
# Processed 9900 out of 20837 in 143609.11 seconds
# Processed 9910 out of 20837 in 143670.49 seconds
# Processed 9920 out of 20837 in 143730.58 seconds
# Processed 9930 out of 20837 in 144454.05 seconds
# Processed 9940 out of 20837 in 144927.91 seconds
# Processed 9950 out of 20837 in 145080.50 seconds
# Processed 9960 out of 20837 in 145154.38 seconds
# Processed 9970 out of 20837 in 145230.54 seconds
# Processed 9980 out of 20837 in 145375.39 seconds
# ...
# Processed 17650 out of 20837 in 286425.92 seconds
# Processed 17660 out of 20837 in 286522.85 seconds
# Processed 17670 out of 20837 in 286611.67 seconds
# Processed 17680 out of 20837 in 286689.07 seconds
# Processed 17690 out of 20837 in 286938.23 seconds
# Processed 17700 out of 20837 in 287034.35 seconds
# Processed 17710 out of 20837 in 287496.19 seconds
# Processed 17720 out of 20837 in 287553.52 seconds
# Processed 17730 out of 20837 in 287712.23 seconds
# Processed 17740 out of 20837 in 288266.79 seconds
# Processed 17750 out of 20837 in 288362.05 seconds
# Processed 17760 out of 20837 in 288464.13 seconds
# Processed 17770 out of 20837 in 288594.70 seconds
# Processed 17780 out of 20837 in 288687.85 seconds
# Processed 17790 out of 20837 in 288813.37 seconds
# Processed 17800 out of 20837 in 288943.98 seconds
# Processed 17810 out of 20837 in 289089.46 seconds
# Processed 17820 out of 20837 in 289171.63 seconds
# Processed 17830 out of 20837 in 289258.66 seconds
# Processed 17840 out of 20837 in 289351.25 seconds
# Processed 17850 out of 20837 in 289444.96 seconds
# Processed 17860 out of 20837 in 289566.02 seconds
# Processed 17870 out of 20837 in 289652.95 seconds
# Processed 17880 out of 20837 in 289881.64 seconds
# Processed 17890 out of 20837 in 290186.18 seconds
# Processed 17900 out of 20837 in 291081.82 seconds
# Processed 17910 out of 20837 in 291139.53 seconds
# Processed 17920 out of 20837 in 291192.02 seconds
# Processed 17930 out of 20837 in 291248.91 seconds
# Processed 17940 out of 20837 in 291319.51 seconds
# Processed 17950 out of 20837 in 291689.15 seconds
# Processed 17960 out of 20837 in 292106.48 seconds
# Processed 17970 out of 20837 in 292325.10 seconds
# Processed 17980 out of 20837 in 292407.52 seconds
# Processed 17990 out of 20837 in 292494.41 seconds
# Processed 18000 out of 20837 in 292567.17 seconds
# Processed 18010 out of 20837 in 292672.21 seconds
# Processed 18020 out of 20837 in 292789.01 seconds
# Processed 18030 out of 20837 in 292856.39 seconds
# Processed 18040 out of 20837 in 292948.21 seconds
# Processed 18050 out of 20837 in 293018.41 seconds
# Processed 18060 out of 20837 in 293088.90 seconds
# Processed 18070 out of 20837 in 293167.41 seconds
# Processed 18080 out of 20837 in 293238.40 seconds
# Processed 18090 out of 20837 in 293310.46 seconds
# Processed 18100 out of 20837 in 293384.82 seconds
# Processed 18110 out of 20837 in 293447.75 seconds
# Processed 18120 out of 20837 in 293505.08 seconds
# Processed 18130 out of 20837 in 293567.46 seconds
# Processed 18140 out of 20837 in 293644.13 seconds
# Processed 18150 out of 20837 in 293735.44 seconds
# Processed 18160 out of 20837 in 293787.16 seconds
# Processed 18170 out of 20837 in 293845.93 seconds
# Processed 18180 out of 20837 in 294329.82 seconds
# Processed 18190 out of 20837 in 294417.30 seconds
# Processed 18200 out of 20837 in 294541.76 seconds
# Processed 18210 out of 20837 in 294659.62 seconds
# Processed 18220 out of 20837 in 294732.54 seconds
# Processed 18230 out of 20837 in 294834.45 seconds
# Processed 18240 out of 20837 in 294946.21 seconds
# Processed 18250 out of 20837 in 295048.59 seconds
# Processed 18260 out of 20837 in 295139.62 seconds
# Processed 18270 out of 20837 in 295230.94 seconds
# Processed 18280 out of 20837 in 295293.92 seconds
# Processed 18290 out of 20837 in 295353.97 seconds
# Processed 18300 out of 20837 in 295435.09 seconds
# Processed 18310 out of 20837 in 295496.33 seconds
# Processed 18320 out of 20837 in 295567.50 seconds
# Processed 18330 out of 20837 in 295850.66 seconds
# Processed 18340 out of 20837 in 295928.95 seconds
# Processed 18350 out of 20837 in 296079.30 seconds
# Processed 18360 out of 20837 in 296232.69 seconds
# Processed 18370 out of 20837 in 296549.62 seconds
# Processed 18380 out of 20837 in 296678.23 seconds
# Processed 18390 out of 20837 in 296760.08 seconds
# Processed 18400 out of 20837 in 296881.24 seconds
# Processed 18410 out of 20837 in 297000.39 seconds
# Processed 18420 out of 20837 in 297116.58 seconds
# Processed 18430 out of 20837 in 297201.20 seconds
# Processed 18440 out of 20837 in 297299.15 seconds
# Processed 18450 out of 20837 in 297415.45 seconds
# Processed 18460 out of 20837 in 297538.35 seconds
# Processed 18470 out of 20837 in 297682.57 seconds
# Processed 18480 out of 20837 in 297772.05 seconds
# Processed 18490 out of 20837 in 297884.60 seconds
# Processed 18500 out of 20837 in 297990.61 seconds
# Processed 18510 out of 20837 in 298095.51 seconds
# Processed 18520 out of 20837 in 298206.76 seconds
# Processed 18530 out of 20837 in 298314.31 seconds
# Processed 18540 out of 20837 in 299013.62 seconds
# Processed 18550 out of 20837 in 299472.92 seconds
# Processed 18560 out of 20837 in 299531.61 seconds
# Processed 18570 out of 20837 in 299666.58 seconds
# Processed 18580 out of 20837 in 299779.53 seconds
# Processed 18590 out of 20837 in 299867.20 seconds
# Processed 18600 out of 20837 in 299929.51 seconds
# Processed 18610 out of 20837 in 300161.22 seconds
# Processed 18620 out of 20837 in 300270.55 seconds
# Processed 18630 out of 20837 in 300394.73 seconds
# Processed 18640 out of 20837 in 300540.43 seconds
# Processed 18650 out of 20837 in 300642.39 seconds
# Processed 18660 out of 20837 in 300727.64 seconds
# Processed 18670 out of 20837 in 300804.58 seconds
# Processed 18680 out of 20837 in 300889.00 seconds
# Processed 18690 out of 20837 in 300970.98 seconds
# Processed 18700 out of 20837 in 301023.65 seconds
# Processed 18710 out of 20837 in 301122.93 seconds
# Processed 18720 out of 20837 in 301268.08 seconds
# Processed 18730 out of 20837 in 301436.31 seconds
# Processed 18740 out of 20837 in 301838.87 seconds
# Processed 18750 out of 20837 in 302171.96 seconds
# Processed 18760 out of 20837 in 302285.37 seconds
# Processed 18770 out of 20837 in 302414.80 seconds
# Processed 18780 out of 20837 in 302572.90 seconds
# Processed 18790 out of 20837 in 302800.75 seconds
# Processed 18800 out of 20837 in 302965.37 seconds
# Processed 18810 out of 20837 in 303119.06 seconds
# Processed 18820 out of 20837 in 303461.89 seconds
# Processed 18830 out of 20837 in 303580.81 seconds
# Processed 18840 out of 20837 in 303690.46 seconds
# Processed 18850 out of 20837 in 303781.20 seconds
# Processed 18860 out of 20837 in 303890.20 seconds
# Processed 18870 out of 20837 in 303974.78 seconds
# Processed 18880 out of 20837 in 304025.15 seconds
# Processed 18890 out of 20837 in 304223.71 seconds
# Processed 18900 out of 20837 in 304318.64 seconds
# Processed 18910 out of 20837 in 304456.19 seconds
# Processed 18920 out of 20837 in 304629.91 seconds
# Processed 18930 out of 20837 in 304785.14 seconds
# Processed 18940 out of 20837 in 305015.20 seconds
# Processed 18950 out of 20837 in 305153.86 seconds
# Processed 18960 out of 20837 in 305423.28 seconds
# Processed 18970 out of 20837 in 305656.76 seconds
# Processed 18980 out of 20837 in 305825.43 seconds
# Processed 18990 out of 20837 in 305984.01 seconds
# Processed 19000 out of 20837 in 306155.29 seconds
# Processed 19010 out of 20837 in 306329.38 seconds
# Processed 19020 out of 20837 in 306414.13 seconds
# Processed 19030 out of 20837 in 306509.01 seconds
# Processed 19040 out of 20837 in 306646.56 seconds
# Processed 19050 out of 20837 in 306819.98 seconds
# Processed 19060 out of 20837 in 306966.57 seconds
# Processed 19070 out of 20837 in 307073.75 seconds
# Processed 19080 out of 20837 in 307266.14 seconds
# Processed 19090 out of 20837 in 307432.17 seconds
# Processed 19100 out of 20837 in 307605.48 seconds
# Processed 19110 out of 20837 in 307743.68 seconds
# Processed 19120 out of 20837 in 308017.69 seconds
# Processed 19130 out of 20837 in 308245.31 seconds
# Processed 19140 out of 20837 in 308458.06 seconds
# Processed 19150 out of 20837 in 308742.27 seconds
# Processed 19160 out of 20837 in 308929.55 seconds
# Processed 19170 out of 20837 in 309029.42 seconds
# Processed 19180 out of 20837 in 309109.74 seconds
# Processed 19190 out of 20837 in 309172.23 seconds
# Processed 19200 out of 20837 in 309241.38 seconds
# Processed 19210 out of 20837 in 309337.94 seconds
# Processed 19220 out of 20837 in 309436.05 seconds
# Processed 19230 out of 20837 in 309505.45 seconds
# Processed 19240 out of 20837 in 309688.27 seconds
# Processed 19250 out of 20837 in 309816.41 seconds
# Processed 19260 out of 20837 in 309915.71 seconds
# Processed 19270 out of 20837 in 309970.31 seconds
# Processed 19280 out of 20837 in 310030.42 seconds
# Processed 19290 out of 20837 in 310104.48 seconds
# Processed 19300 out of 20837 in 310160.72 seconds
# Processed 19310 out of 20837 in 310282.23 seconds
# Processed 19320 out of 20837 in 310354.51 seconds
# Processed 19330 out of 20837 in 310435.22 seconds
# Processed 19340 out of 20837 in 310516.66 seconds
# Processed 19350 out of 20837 in 310748.66 seconds
# Processed 19360 out of 20837 in 311006.32 seconds
# Processed 19370 out of 20837 in 311082.99 seconds
# Processed 19380 out of 20837 in 311136.09 seconds
# Processed 19390 out of 20837 in 311201.87 seconds
# Processed 19400 out of 20837 in 311594.46 seconds
# Processed 19410 out of 20837 in 311680.33 seconds
# Processed 19420 out of 20837 in 311732.64 seconds
# Processed 19430 out of 20837 in 311795.51 seconds
# Processed 19440 out of 20837 in 311963.69 seconds
# Processed 19450 out of 20837 in 312153.49 seconds
# Processed 19460 out of 20837 in 312204.55 seconds
# Processed 19470 out of 20837 in 312273.06 seconds
# Processed 19480 out of 20837 in 312451.25 seconds
# Processed 19490 out of 20837 in 312651.26 seconds
# Processed 19500 out of 20837 in 312767.36 seconds
# Processed 19510 out of 20837 in 312931.61 seconds
# Processed 19520 out of 20837 in 313081.80 seconds
# Processed 19530 out of 20837 in 313129.45 seconds
# Processed 19540 out of 20837 in 313182.77 seconds
# Processed 19550 out of 20837 in 313283.73 seconds
# Processed 19560 out of 20837 in 313349.93 seconds
# Processed 19570 out of 20837 in 313422.51 seconds
# Processed 19580 out of 20837 in 313502.19 seconds
# Processed 19590 out of 20837 in 313648.26 seconds
# Processed 19600 out of 20837 in 314000.44 seconds
# Processed 19610 out of 20837 in 314139.59 seconds
# Processed 19620 out of 20837 in 314187.80 seconds
# Processed 19630 out of 20837 in 314287.36 seconds
# Processed 19640 out of 20837 in 314353.23 seconds
# Processed 19650 out of 20837 in 314480.48 seconds
# Processed 19660 out of 20837 in 315398.97 seconds
# Processed 19670 out of 20837 in 316235.34 seconds
# Processed 19680 out of 20837 in 316540.86 seconds
# Processed 19690 out of 20837 in 316622.53 seconds
# Processed 19700 out of 20837 in 316740.04 seconds
# Processed 19710 out of 20837 in 316808.28 seconds
# Processed 19720 out of 20837 in 316976.35 seconds
# Processed 19730 out of 20837 in 317036.65 seconds
# Processed 19740 out of 20837 in 317465.26 seconds
# Processed 19750 out of 20837 in 317596.61 seconds
# Processed 19760 out of 20837 in 317740.18 seconds
# Processed 19770 out of 20837 in 317927.77 seconds
# Processed 19780 out of 20837 in 318020.32 seconds
# Processed 19790 out of 20837 in 318069.13 seconds
# Processed 19800 out of 20837 in 318123.00 seconds
# Processed 19810 out of 20837 in 318561.49 seconds
# Processed 19820 out of 20837 in 318644.88 seconds
# Processed 19830 out of 20837 in 318717.82 seconds
# Processed 19840 out of 20837 in 318816.93 seconds
# Processed 19850 out of 20837 in 318939.69 seconds
# Processed 19860 out of 20837 in 319221.69 seconds
# Processed 19870 out of 20837 in 319273.86 seconds
# Processed 19880 out of 20837 in 319368.65 seconds
# Processed 19890 out of 20837 in 319919.96 seconds
# Processed 19900 out of 20837 in 320528.25 seconds
# Processed 19910 out of 20837 in 320713.04 seconds
# Processed 19920 out of 20837 in 320795.45 seconds
# Processed 19930 out of 20837 in 320868.30 seconds
# Processed 19940 out of 20837 in 320933.06 seconds
# Processed 19950 out of 20837 in 320993.29 seconds
# Processed 19960 out of 20837 in 321072.80 seconds
# Processed 19970 out of 20837 in 321331.21 seconds
# Processed 19980 out of 20837 in 321395.75 seconds
# Processed 19990 out of 20837 in 321471.36 seconds
# Processed 20000 out of 20837 in 321623.30 seconds
# Processed 20010 out of 20837 in 321719.83 seconds
# Processed 20020 out of 20837 in 321844.28 seconds
# Processed 20030 out of 20837 in 321971.77 seconds
# Processed 20040 out of 20837 in 322105.99 seconds
# Processed 20050 out of 20837 in 322225.51 seconds
# Processed 20060 out of 20837 in 322639.28 seconds
# Processed 20070 out of 20837 in 322759.89 seconds
# Processed 20080 out of 20837 in 322857.88 seconds
# Processed 20090 out of 20837 in 322953.64 seconds
# Processed 20100 out of 20837 in 323062.23 seconds
# Processed 20110 out of 20837 in 323143.22 seconds
# Processed 20120 out of 20837 in 323244.84 seconds
# Processed 20130 out of 20837 in 323347.62 seconds
# Processed 20140 out of 20837 in 323463.55 seconds
# Processed 20150 out of 20837 in 323564.88 seconds
# Processed 20160 out of 20837 in 323651.43 seconds
# Processed 20170 out of 20837 in 323751.37 seconds
# Processed 20180 out of 20837 in 323845.38 seconds
# Processed 20190 out of 20837 in 323929.52 seconds
# Processed 20200 out of 20837 in 324199.07 seconds
# Processed 20210 out of 20837 in 324718.73 seconds
# Processed 20220 out of 20837 in 325643.66 seconds
# Processed 20230 out of 20837 in 326122.51 seconds
# Processed 20240 out of 20837 in 326525.83 seconds
# Processed 20250 out of 20837 in 326798.02 seconds
# Processed 20260 out of 20837 in 327789.47 seconds
# Processed 20270 out of 20837 in 328539.49 seconds
# Processed 20280 out of 20837 in 328783.12 seconds
# Processed 20290 out of 20837 in 329166.28 seconds
# Processed 20300 out of 20837 in 329740.20 seconds
# Processed 20310 out of 20837 in 329919.23 seconds
# Processed 20320 out of 20837 in 330195.32 seconds
# Processed 20330 out of 20837 in 330300.81 seconds
# Processed 20340 out of 20837 in 330418.96 seconds
# Processed 20350 out of 20837 in 330484.18 seconds
# Processed 20360 out of 20837 in 330552.18 seconds
# Processed 20370 out of 20837 in 330623.56 seconds
# Processed 20380 out of 20837 in 330697.27 seconds
# Processed 20390 out of 20837 in 330777.61 seconds
# Processed 20400 out of 20837 in 330862.03 seconds
# Processed 20410 out of 20837 in 330956.43 seconds
# Processed 20420 out of 20837 in 331028.13 seconds
# Processed 20430 out of 20837 in 331103.18 seconds
# Processed 20440 out of 20837 in 331193.37 seconds
# Processed 20450 out of 20837 in 331259.24 seconds
# Processed 20460 out of 20837 in 331326.51 seconds
# Processed 20470 out of 20837 in 331396.97 seconds
# Processed 20480 out of 20837 in 331465.30 seconds
# Processed 20490 out of 20837 in 331535.99 seconds
# Processed 20500 out of 20837 in 331709.32 seconds
# Processed 20510 out of 20837 in 332071.46 seconds
# Processed 20520 out of 20837 in 332198.93 seconds
# Processed 20530 out of 20837 in 332285.96 seconds
# Processed 20540 out of 20837 in 332997.04 seconds
# Processed 20550 out of 20837 in 333063.86 seconds
# Processed 20560 out of 20837 in 333124.36 seconds
# Processed 20570 out of 20837 in 333200.17 seconds
# Processed 20580 out of 20837 in 333269.25 seconds
# Processed 20590 out of 20837 in 333351.25 seconds
# Processed 20600 out of 20837 in 333413.61 seconds
# Processed 20610 out of 20837 in 333509.97 seconds
# Processed 20620 out of 20837 in 333667.69 seconds
# Processed 20630 out of 20837 in 333898.59 seconds
# Processed 20640 out of 20837 in 334090.28 seconds
# Processed 20650 out of 20837 in 334452.43 seconds
# Processed 20660 out of 20837 in 334579.87 seconds
# Processed 20670 out of 20837 in 334653.61 seconds
# Processed 20680 out of 20837 in 334802.16 seconds
# Processed 20690 out of 20837 in 334871.48 seconds
# Processed 20700 out of 20837 in 334950.95 seconds
# Processed 20710 out of 20837 in 335077.77 seconds
# Processed 20720 out of 20837 in 335280.06 seconds
# Processed 20730 out of 20837 in 335480.99 seconds
# Processed 20740 out of 20837 in 335591.99 seconds
# Processed 20750 out of 20837 in 335690.66 seconds
# Processed 20760 out of 20837 in 335966.87 seconds
# Processed 20770 out of 20837 in 336382.73 seconds
# Processed 20780 out of 20837 in 336613.67 seconds
# Processed 20790 out of 20837 in 336899.93 seconds
# Processed 20800 out of 20837 in 337190.14 seconds
# Processed 20810 out of 20837 in 337756.34 seconds
# Processed 20820 out of 20837 in 337859.15 seconds
# Processed 20830 out of 20837 in 337950.39 seconds
# Processed 20837 out of 20837 in 338272.79 seconds
