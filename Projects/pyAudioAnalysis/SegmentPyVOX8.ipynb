# %% [markdown]
# # Segment GRN data using pyAudioAnalysis
#
# The group of notebooks SegmentPyVOXn.ipynb (n=0-9) will be used to segment the data using the segmentation algorithm I developed in DevelopASSegmentation.ipynb. It follows the same pattern as used in SegmentFVOXn.ipynb.
#
# # Data to be Created
#
# Three sets of data will be made, 4, 6, and 10 second data.
#
# This file will take a long time to run. For that reason it will check point its progress at regular intervals by writing smaller files. If its progress is restarted for any reason it will use those files to determine where it was up to. Segmenting the data is the slow part. For each audio file a segment file will be generated. If mp3 files are to be generated later using different parameters the segmented files should make the process much quicker.
#
# The input to this process is the same as SegmentFVOX.ipynb. We actually use its division of the files into 10 groups.
#
# The output will be:
#
#     1. /media/originals/py_audio_seg/[iso]/[filename].pkl
#         where each pkl file contains the list of raw segments for the item.
#     2. /media/originals/py_audio_seg/seg_4sec.csv
#         all the metadata for the seg_4sec dataset. Metadata needed for the dataset can be derived from this.
#     3. /media/originals/py_audio_seg/seg_6sec.csv
#         all the metadata for the seg_6sec dataset. Metadata needed for the dataset can be derived from this.
#     4. /media/originals/py_audio_seg/seg_10sec.csv
#         all the metadata for the seg_10sec dataset. Metadata needed for the dataset can be derived from this.
#     5. /media/originals/datasets/py_audio_seg_4sec/data/[iso]/[program_id]_[item_no]_[seg].mp3
#         which is an mp3 for each segment
#     6. /media/originals/datasets/py_audio_seg_6sec/data/[iso]/[program_id]_[item_no]_[seg].mp3
#         which is an mp3 for each segment
#     7. /media/originals/datasets/py_audio_seg_10sec/data/[iso]/[program_id]_[item_no]_[seg].mp3
#         which is an mp3 for each segment

# %%
import pandas as pd
import numpy as np
import os
import sys
import time
import pickle as pkl
from pathlib import Path
import glob

module_path = os.path.abspath(os.path.join('~/work/pyAudioAnalysis'))
if module_path not in sys.path:
    sys.path.append(module_path)
from collections import namedtuple
from pydub import AudioSegment

from pyAudioAnalysis import audioSegmentation as aS
from pyAudioAnalysis import audioTrainTest as at
from pyAudioAnalysis import MidTermFeatures as mtf
from pyAudioAnalysis import audioBasicIO as aIO

# %%
# define the locations for each of the file types
NOTEBOOK_ID=8
SEGMENTS_DIR = '/media/originals/py_audio_seg/'
DATASETS_DIR = '/media/originals/datasets/'
SEC_4_DATA_DIR = 'py_audio_seg_4sec/data/'
SEC_6_DATA_DIR = 'py_audio_seg_6sec/data/'
SEC_10_DATA_DIR = 'py_audio_seg_10sec/data/'

# define specific files used in the process
SEG_4_SEC_DF = f'{SEGMENTS_DIR}seg_4sec_{NOTEBOOK_ID}.csv'
SEG_6_SEC_DF = f'{SEGMENTS_DIR}seg_6sec_{NOTEBOOK_ID}.csv'
SEG_10_SEC_DF = f'{SEGMENTS_DIR}seg_10sec_{NOTEBOOK_ID}.csv'

# define segment sizes for each dataset
SEG_4_SEC = 4.0
SEG_6_SEC = 6.0
SEG_10_SEC = 10.0

SAMPLING_RATE = 16000

def convert_to_ms(sec):
    return int(sec*1000.0)

# %%
# Now read in the description of the input and remove the unwanted columns and rename the rest to be python attribute names.
fd = pd.read_csv(f'/media/originals/fsegs/files_{NOTEBOOK_ID}.csv')
fd.set_index('ID', inplace=True)
fd.columns
# Out:
# Index(['Unnamed: 0', 'iso', 'language_name', 'track', 'location', 'year',
#        'path', 'filename', 'length', 'program'],
#       dtype='object')

# %%
# augment the fd with 1/3 of files 9
fd9 = pd.read_csv(f'/media/originals/fsegs/files_9.csv')
fd9.set_index('ID', inplace=True)
print(len(fd9))
# Out:
# 20841

# %%
third = int(len(fd9)/3)
fd = pd.concat([fd, fd9.iloc[2*third:]])

# %%
print(fd.iloc[100])
# Out:
# Unnamed: 0                                  139718
# iso                                            suv
# language_name                               Puroik
# track                                           16
# location                               West Kameng
# year                                        2004.0
# path             Programs/62/62122/A62122/PM-2005/
# filename                            A62122-016.wav
# length                                        98.0
# program                                      62122
# Name: 62122_016, dtype: object

# %%
print(fd.index)
# Out:
# Index(['32641_031', '32641_030', '29470_007', '29470_015', '32641_033',
#        '29470_014', '29470_009', '29440_002', '29470_012', '29470_011',
#        ...
#        '29531_002', '29531_006', '32241_002', '29531_008', '29531_009',
#        '29531_010', '29531_011', '32241_001', '29531_007', '29541_002'],
#       dtype='object', name='ID', length=27784)

# %%
# generate directories and filenames
def prepare_dir(dirname):
    if dirname[-1] != '/':
        dirname = dirname + '/'
    Path(dirname).mkdir(parents=True, exist_ok=True)
    return dirname

def prepare_raw_seg_dir(fd):
    return prepare_dir(SEGMENTS_DIR + fd.iso)

def raw_seg_filename(fd):
    return f'{fd.filename}.pkl'

def prepare_dataset_data_dir(fd, dataset_dir):
    return prepare_dir(DATASETS_DIR + dataset_dir + fd.iso)

def seg_mp3_filename(fd, seg):
    return f'{fd.filename[:-4]}_{seg:03d}.mp3'

def get_fname(fd):
    path = fd.path
    if path[-1] != '/':
        path = path + '/'
    files = glob.glob('/media/programs/' + path + fd.filename.replace('\ufffd', '*'))
    if len(files) == 1:
        return files[0]
    return '/media/programs/' + path + fd.filename

# %%
def condition_audio_segment(audio_seg):
    if audio_seg.channels != 1:
        audio_seg = audio_seg.set_channels(1)

    if audio_seg.sample_width != 2:
        audio_seg = audio_seg.set_sample_width(2)

    if audio_seg.frame_rate != SAMPLING_RATE:
        audio_seg = audio_seg.set_frame_rate(SAMPLING_RATE)
    return audio_seg

# %%
import warnings
# sklearn puts out a lot of annoying warnings
warnings.filterwarnings('ignore')

Segment = namedtuple('Segment', ['start', 'end', 'classification'])

# re-implement a simplified version of mid_term_file_classification
# it is implemented as a class to allow the model to be cached.
class ExtractVoiceSegments():
    classifier, mean, std, class_names, mt_win, mid_step, st_win, \
         st_step, compute_beat = at.load_model('/home/jovyan/work/pyAudioAnalysis/pyAudioAnalysis/data/models/svm_rbf_4class')

    def __init__(self):
        pass

    def segments_in(self, signal, sampling_rate, offset):
        labels = []

        # mid-term feature extraction:
        mt_feats, _, _ = \
            mtf.mid_feature_extraction(signal, sampling_rate,
                                    ExtractVoiceSegments.mt_win * sampling_rate,
                                    ExtractVoiceSegments.mid_step * sampling_rate,
                                    round(sampling_rate * ExtractVoiceSegments.st_win),
                                    round(sampling_rate * ExtractVoiceSegments.st_step))

        # for each feature vector (i.e. for each fix-sized segment):
        for col_index in range(mt_feats.shape[1]):
            # normalize current feature v
            feature_vector = (mt_feats[:, col_index] - ExtractVoiceSegments.mean) / ExtractVoiceSegments.std

            # classify vector:
            label_predicted, _ = \
                at.classifier_wrapper(ExtractVoiceSegments.classifier, 'svm', feature_vector)
            labels.append(label_predicted)

        segs, classes = aS.labels_to_segments(labels, ExtractVoiceSegments.mid_step)
        # there is a bug in labels to segments when there is a single label. In this case it returns a list rather than a list of lists
        if len(labels) == 1:
            segs = [].append(segs)
        return [] if segs is None else [Segment(seg[0]+offset, seg[1]+offset, ExtractVoiceSegments.class_names[int(label)]) for seg, label in zip(segs, classes)]



"""
This function performs mid-term classification of an audio stream.
Towards this end, supervised knowledge is used,
i.e. a pre-trained classifier.
ARGUMENTS:
    - input_file:        path of the input WAV/mp3 file
RETURNS:
    - list of Segments (see above tuple)
"""
def extract_voice_segments(input_file, *, __extract_voice_segments=ExtractVoiceSegments()):
    segments = []

    # load input file
    sampling_rate, signal = aIO.read_audio_file(input_file)

    # could not read file
    if sampling_rate == 0:
        return segments

    # convert stereo (if) to mono
    signal = aIO.stereo_to_mono(signal)

    # find the silence segments
    non_silent_segments = aS.silence_removal(signal, sampling_rate, 0.02, 0.02, smooth_window=1.0, weight=0.3)

    # work through each segment
    for seg in non_silent_segments:
        start = int(seg[0]*sampling_rate)
        stop = int(seg[1]*sampling_rate)
        sig = signal[start:stop]

        segments.extend(__extract_voice_segments.segments_in(signal[start:stop], sampling_rate, seg[0]))

    return segments

# %%
Epoch = namedtuple('Epoch', ['start', 'end'])
def speech_epochs_from_segments(segments, epoch_length=4.0, silence_tolerance=0.0):
    epochs = []
    i = 0
    silence_this_epoch = silence_tolerance
    while i < len(segments):
        seg_duration = segments[i].end - segments[i].start
        if segments[i].classification != 'speech':
            silence_this_epoch = silence_tolerance

        elif seg_duration >= epoch_length:
            epochs.append(Epoch(segments[i].start, segments[i].start+epoch_length))
            silence_this_epoch = silence_tolerance
            # process the same segment again with a smaller size
            new_start = segments[i].start+epoch_length
            new_end = segments[i].end
            if new_start < new_end:
                segments[i] = Segment(new_start, new_end, segments[i].classification)
                continue
        else:
            if i+1 < len(segments):
                if (segments[i].end + silence_this_epoch) >= segments[i+1].start and segments[i+1].classification == 'speech':
                    # did we use up any silence tolerence
                    if segments[i].end < segments[i+1].start:
                        silence_this_epoch -= (segments[i+1].start - segments[i].end)
                    segments[i+1] = Segment(segments[i].start, segments[i+1].end, segments[i].classification)
                else:
                    silence_this_epoch = silence_tolerance

        i+=1

    return epochs

# %%
def save_the_segment_info(fd, segs):
    fname = prepare_raw_seg_dir(fd) + raw_seg_filename(fd)
    with open(fname, 'wb') as pklFile:
         pkl.dump(segs, pklFile)

def read_the_segment_info(fd):
    fname = prepare_raw_seg_dir(fd) + raw_seg_filename(fd)
    if os.path.exists(fname):
        if os.path.getsize(fname) > 0:
            with open(fname, 'rb') as pklFile:
                return pkl.load(pklFile)
    return []
    
def update_dataframes(seg_df_csv, seg_records):
    # now update the dataframes
    if len(seg_records) > 0:
        if os.path.isfile(seg_df_csv):
            seg_sec_df = pd.concat([pd.read_csv(seg_df_csv, index_col='file_name'), pd.DataFrame.from_records(seg_records, index='file_name')])
        else:
            seg_sec_df = pd.DataFrame.from_records(seg_records, index='file_name')
        seg_sec_df.to_csv(seg_df_csv)

# %%
def extract_audio_segments_for_file(fd):
    fmt = 'wav'
    if fd.filename[-4:].lower() == '.mp3' :
        fmt = 'mp3'
    audio_seg = AudioSegment.from_file(get_fname(fd), format=fmt)

    # now condition the segment and extract the raw segments.
    audio_seg = condition_audio_segment(audio_seg)
    segs = read_the_segment_info(fd)
    if len(segs) == 0:
        segs = extract_voice_segments(get_fname(fd))
        save_the_segment_info(fd, segs)

    return audio_seg, segs


def create_mp3_files(audio_seg, segs, time_per_segment, dataset_dir, fd):
    epochs_for_time = speech_epochs_from_segments(segs, epoch_length=time_per_segment, silence_tolerance=time_per_segment/4.0)

    # now write out the 4 sec segments
    dirname = prepare_dataset_data_dir(fd, dataset_dir)
    rows = list()

    for i, seg in enumerate(epochs_for_time):
        file_name = dataset_dir + fd.iso + '/' + seg_mp3_filename(fd, i)
        fname = dirname + seg_mp3_filename(fd, i)
        start = convert_to_ms(seg.start)
        stop = convert_to_ms(seg.end)
        if not os.path.exists(fname):
            audio_seg[start:stop].export(fname, format='mp3', bitrate='32k')
        desc = dict(fd._asdict())
        desc['seg_start'] = start
        desc['seg_stop'] = stop
        desc['seg'] = i
        desc['file_name'] = file_name
        rows.append(desc)

    return rows

# %%
# processing these items might take a very long time. To permit the process to be interrupted and restarted the indexes of processed items
# are maintained in a set that is pickled on each batch. This allows the batch to quickly pick up where it left off.
def process_record_batch(files_df, *, batch_size=10):
    batch_proc = 0
    processed_file = f'{SEGMENTS_DIR}processed16_{NOTEBOOK_ID}.pkl'
    if os.path.isfile(processed_file):
        with open(processed_file, 'rb') as pklFile:
            processed_files = pkl.load(pklFile)
    else:
        processed_files = set()

    segmented_4sec_segs = []
    segmented_6sec_segs = []
    segmented_10sec_segs = []

    for fd in files_df.itertuples():
        if batch_proc < batch_size:
            if fd.Index not in processed_files:
                try:
                    audio_seg, voice_segs = extract_audio_segments_for_file(fd)

                    segmented_4sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_4_SEC, SEC_4_DATA_DIR, fd))
                    segmented_6sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_6_SEC, SEC_6_DATA_DIR, fd))
                    segmented_10sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_10_SEC, SEC_10_DATA_DIR, fd))
                except:
                    print(f'exception {fd.filename}')
                    pass

                # we want to add an fd that has an exception so it is not reprocessed on every batch
                processed_files.add(fd.Index)
                batch_proc += 1

        else:
            break

    update_dataframes(SEG_4_SEC_DF, segmented_4sec_segs)
    update_dataframes(SEG_6_SEC_DF, segmented_6sec_segs)
    update_dataframes(SEG_10_SEC_DF, segmented_10sec_segs)

    with open(processed_file, 'wb') as pklFile:
        pkl.dump(processed_files, pklFile)

    return processed_files

# %%
def format_time(seconds):
    hours, remainder = divmod(int(seconds), 3600)
    minutes, seconds = divmod(remainder, 60)
    return f"{hours:02}:{minutes:02}:{seconds:02}"

start_time = time.time()
# form the language classification file
files_processed = 0
files_to_process = len(fd)
while files_to_process > files_processed:
    processed_files = process_record_batch(fd, batch_size=20)
    files_processed = len(processed_files)
    print(f'Processed {files_processed} out of {files_to_process} in {format_time(time.time()-start_time)}')
# Out:
# Processed 8780 out of 27784 in 00:06:05
# Processed 8800 out of 27784 in 00:11:43
# Processed 8820 out of 27784 in 00:20:40
# Processed 8840 out of 27784 in 00:26:17
# Processed 8860 out of 27784 in 00:32:09
# Processed 8880 out of 27784 in 00:35:23
# Processed 8900 out of 27784 in 00:39:38
# Processed 8920 out of 27784 in 00:46:48
# Processed 8940 out of 27784 in 00:50:05
# Processed 8960 out of 27784 in 00:53:16
# Processed 8980 out of 27784 in 01:00:27
# Processed 9000 out of 27784 in 01:03:32
# Processed 9020 out of 27784 in 01:11:33
# Processed 9040 out of 27784 in 01:26:22
# Processed 9060 out of 27784 in 01:30:45
# Processed 9080 out of 27784 in 01:33:41
# Processed 9100 out of 27784 in 01:38:33
# Processed 9120 out of 27784 in 01:41:31
# Processed 9140 out of 27784 in 01:44:40
# Processed 9160 out of 27784 in 01:47:37
# Processed 9180 out of 27784 in 01:50:03
# Processed 9200 out of 27784 in 01:54:38
# Processed 9220 out of 27784 in 02:04:42
# Processed 9240 out of 27784 in 02:13:37
# Processed 9260 out of 27784 in 02:19:21
# Processed 9280 out of 27784 in 02:25:37
# Processed 9300 out of 27784 in 02:32:31
# Processed 9320 out of 27784 in 02:38:56
# Processed 9340 out of 27784 in 02:43:21
# Processed 9360 out of 27784 in 02:47:41
# Processed 9380 out of 27784 in 02:55:42
# Processed 9400 out of 27784 in 03:00:14
# Processed 9420 out of 27784 in 03:05:49
# Processed 9440 out of 27784 in 03:09:59
# Processed 9460 out of 27784 in 03:14:10
# Processed 9480 out of 27784 in 03:18:59
# Processed 9500 out of 27784 in 03:22:56
# Processed 9520 out of 27784 in 03:27:09
# Processed 9540 out of 27784 in 03:31:13
# Processed 9560 out of 27784 in 03:34:24
# Processed 9580 out of 27784 in 03:38:05
# Processed 9600 out of 27784 in 03:44:03
# Processed 9620 out of 27784 in 03:50:35
# Processed 9640 out of 27784 in 04:08:43
# Processed 9660 out of 27784 in 04:16:51
# Processed 9680 out of 27784 in 04:44:56
# Processed 9700 out of 27784 in 04:51:08
# Processed 9720 out of 27784 in 04:55:06
# Processed 9740 out of 27784 in 04:59:03
# Processed 9760 out of 27784 in 05:02:35
# Processed 9780 out of 27784 in 05:06:49
# Processed 9800 out of 27784 in 05:09:58
# Processed 9820 out of 27784 in 05:13:43
# Processed 9840 out of 27784 in 05:17:46
# Processed 9860 out of 27784 in 05:21:56
# Processed 9880 out of 27784 in 05:26:38
# Processed 9900 out of 27784 in 05:30:58
# Processed 9920 out of 27784 in 05:35:28
# Processed 9940 out of 27784 in 05:40:06
# Processed 9960 out of 27784 in 05:44:54
# Processed 9980 out of 27784 in 05:48:37
# Processed 10000 out of 27784 in 05:52:54
# Processed 10020 out of 27784 in 06:11:36
# Processed 10040 out of 27784 in 06:25:44
# Processed 10060 out of 27784 in 06:31:11
# Processed 10080 out of 27784 in 06:33:33
# Processed 10100 out of 27784 in 06:37:16
# Processed 10120 out of 27784 in 06:45:14
# Processed 10140 out of 27784 in 06:51:17
# Processed 10160 out of 27784 in 07:01:51
# Processed 10180 out of 27784 in 07:22:28
# Processed 10200 out of 27784 in 07:28:52
# Processed 10220 out of 27784 in 07:58:21
# Processed 10240 out of 27784 in 08:12:21
# Processed 10260 out of 27784 in 09:04:05
# Processed 10280 out of 27784 in 09:18:14
# Processed 10300 out of 27784 in 09:22:11
# Processed 10320 out of 27784 in 09:28:10
# Processed 10340 out of 27784 in 09:31:23
# Processed 10360 out of 27784 in 09:34:19
# Processed 10380 out of 27784 in 09:36:29
# Processed 10400 out of 27784 in 09:39:20
# Processed 10420 out of 27784 in 09:41:59
# Processed 10440 out of 27784 in 09:46:03
# Processed 10460 out of 27784 in 09:50:17
# Processed 10480 out of 27784 in 10:00:44
# Processed 10500 out of 27784 in 10:05:32
# Processed 10520 out of 27784 in 10:07:28
# Processed 10540 out of 27784 in 10:09:31
# Processed 10560 out of 27784 in 10:12:09
# Processed 10580 out of 27784 in 10:16:20
# Processed 10600 out of 27784 in 10:18:13
# Processed 10620 out of 27784 in 10:20:05
# Processed 10640 out of 27784 in 10:31:26
# Processed 10660 out of 27784 in 10:37:27
# Processed 10680 out of 27784 in 10:42:56
# Processed 10700 out of 27784 in 10:48:05
# Processed 10720 out of 27784 in 10:50:51
# Processed 10740 out of 27784 in 10:53:17
# Processed 10760 out of 27784 in 11:01:51
# Processed 10780 out of 27784 in 11:16:04
# Processed 10800 out of 27784 in 11:24:09
# Processed 10820 out of 27784 in 11:30:04
# Processed 10840 out of 27784 in 11:37:45
# Processed 10860 out of 27784 in 11:43:16
# Processed 10880 out of 27784 in 11:52:06
# Processed 10900 out of 27784 in 12:17:29
# Processed 10920 out of 27784 in 12:20:23
# Processed 10940 out of 27784 in 12:23:26
# Processed 10960 out of 27784 in 12:26:50
# Processed 10980 out of 27784 in 12:29:38
# Processed 11000 out of 27784 in 12:33:26
# Processed 11020 out of 27784 in 12:35:20
# Processed 11040 out of 27784 in 12:37:17
# Processed 11060 out of 27784 in 12:40:54
# Processed 11080 out of 27784 in 12:50:11
# Processed 11100 out of 27784 in 12:58:21
# Processed 11120 out of 27784 in 13:01:32
# Processed 11140 out of 27784 in 13:08:56
# Processed 11160 out of 27784 in 13:18:52
# Processed 11180 out of 27784 in 13:40:35
# Processed 11200 out of 27784 in 13:51:04
# Processed 11220 out of 27784 in 13:56:41
# Processed 11240 out of 27784 in 14:00:20
# Processed 11260 out of 27784 in 14:04:43
# Processed 11280 out of 27784 in 14:09:07
# Processed 11300 out of 27784 in 14:12:50
# Processed 11320 out of 27784 in 14:16:50
# Processed 11340 out of 27784 in 14:20:40
# Processed 11360 out of 27784 in 14:25:35
# Processed 11380 out of 27784 in 14:29:47
# Processed 11400 out of 27784 in 14:34:34
# Processed 11420 out of 27784 in 14:38:38
# Processed 11440 out of 27784 in 14:42:53
# Processed 11460 out of 27784 in 14:54:24
# Processed 11480 out of 27784 in 15:05:16
# Processed 11500 out of 27784 in 15:09:56
# Processed 11520 out of 27784 in 15:16:39
# Processed 11540 out of 27784 in 15:19:31
# Processed 11560 out of 27784 in 15:22:27
# Processed 11580 out of 27784 in 15:25:39
# Processed 11600 out of 27784 in 15:28:25
# Processed 11620 out of 27784 in 15:31:18
# Processed 11640 out of 27784 in 15:34:59
# Processed 11660 out of 27784 in 15:41:05
# Processed 11680 out of 27784 in 15:45:19
# Processed 11700 out of 27784 in 15:52:46
# Processed 11720 out of 27784 in 15:57:13
# Processed 11740 out of 27784 in 16:00:21
# Processed 11760 out of 27784 in 16:05:00
# Processed 11780 out of 27784 in 16:16:10
# Processed 11800 out of 27784 in 16:20:06
# Processed 11820 out of 27784 in 16:23:42
# Processed 11840 out of 27784 in 16:27:30
# Processed 11860 out of 27784 in 17:06:30
# Processed 11880 out of 27784 in 17:20:26
# Processed 11900 out of 27784 in 17:37:56
# Processed 11920 out of 27784 in 17:56:13
# Processed 11940 out of 27784 in 18:12:48
# Processed 11960 out of 27784 in 18:26:44
# Processed 11980 out of 27784 in 18:30:26
# Processed 12000 out of 27784 in 18:33:15
# Processed 12020 out of 27784 in 18:36:14
# Processed 12040 out of 27784 in 18:39:23
# Processed 12060 out of 27784 in 18:41:52
# Processed 12080 out of 27784 in 18:44:30
# Processed 12100 out of 27784 in 18:47:27
# Processed 12120 out of 27784 in 18:51:54
# Processed 12140 out of 27784 in 18:54:58
# Processed 12160 out of 27784 in 18:58:09
# Processed 12180 out of 27784 in 19:01:17
# Processed 12200 out of 27784 in 19:04:22
# Processed 12220 out of 27784 in 19:07:30
# Processed 12240 out of 27784 in 19:11:46
# Processed 12260 out of 27784 in 19:15:52
# Processed 12280 out of 27784 in 19:20:13
# Processed 12300 out of 27784 in 19:23:22
# Processed 12320 out of 27784 in 19:27:01
# Processed 12340 out of 27784 in 19:30:46
# Processed 12360 out of 27784 in 19:36:09
# Processed 12380 out of 27784 in 19:39:33
# Processed 12400 out of 27784 in 19:43:11
# Processed 12420 out of 27784 in 19:48:59
# Processed 12440 out of 27784 in 19:50:15
# Processed 12460 out of 27784 in 19:55:59
# Processed 12480 out of 27784 in 20:07:57
# Processed 12500 out of 27784 in 20:11:52
# Processed 12520 out of 27784 in 20:16:40
# Processed 12540 out of 27784 in 20:23:06
# Processed 12560 out of 27784 in 20:28:24
# Processed 12580 out of 27784 in 20:34:13
# Processed 12600 out of 27784 in 20:38:18
# Processed 12620 out of 27784 in 20:42:23
# Processed 12640 out of 27784 in 20:45:54
# Processed 12660 out of 27784 in 20:50:56
# Processed 12680 out of 27784 in 20:55:48
# Processed 12700 out of 27784 in 20:59:41
# Processed 12720 out of 27784 in 21:13:20
# Processed 12740 out of 27784 in 21:17:03
# Processed 12760 out of 27784 in 21:22:37
# Processed 12780 out of 27784 in 21:25:39
# Processed 12800 out of 27784 in 21:28:58
# Processed 12820 out of 27784 in 21:33:22
# Processed 12840 out of 27784 in 21:36:03
# Processed 12860 out of 27784 in 21:39:39
# Processed 12880 out of 27784 in 21:42:49
# Processed 12900 out of 27784 in 21:46:07
# Processed 12920 out of 27784 in 21:50:50
# Processed 12940 out of 27784 in 22:06:31
# Processed 12960 out of 27784 in 22:18:35
# Processed 12980 out of 27784 in 22:25:32
# Processed 13000 out of 27784 in 22:29:30
# Processed 13020 out of 27784 in 22:33:39
# Processed 13040 out of 27784 in 22:37:01
# Processed 13060 out of 27784 in 22:40:01
# Processed 13080 out of 27784 in 22:43:24
# Processed 13100 out of 27784 in 22:46:45
# Processed 13120 out of 27784 in 22:49:47
# Processed 13140 out of 27784 in 22:52:28
# Processed 13160 out of 27784 in 22:54:32
# Processed 13180 out of 27784 in 22:58:01
# Processed 13200 out of 27784 in 23:01:36
# Processed 13220 out of 27784 in 23:04:56
# Processed 13240 out of 27784 in 23:07:12
# Processed 13260 out of 27784 in 23:09:46
# Processed 13280 out of 27784 in 23:12:09
# Processed 13300 out of 27784 in 23:15:09
# Processed 13320 out of 27784 in 23:17:12
# Processed 13340 out of 27784 in 23:20:02
# Processed 13360 out of 27784 in 23:23:45
# Processed 13380 out of 27784 in 23:28:54
# Processed 13400 out of 27784 in 23:33:12
# Processed 13420 out of 27784 in 23:36:26
# Processed 13440 out of 27784 in 23:38:28
# Processed 13460 out of 27784 in 23:41:54
# Processed 13480 out of 27784 in 23:46:12
# Processed 13500 out of 27784 in 24:03:25
# Processed 13520 out of 27784 in 24:13:55
# Processed 13540 out of 27784 in 24:17:01
# Processed 13560 out of 27784 in 24:19:03
# Processed 13580 out of 27784 in 24:25:55
# Processed 13600 out of 27784 in 24:33:28
# Processed 13620 out of 27784 in 24:39:57
# Processed 13640 out of 27784 in 24:43:38
# Processed 13660 out of 27784 in 24:48:43
# Processed 13680 out of 27784 in 24:52:26
# Processed 13700 out of 27784 in 24:55:36
# Processed 13720 out of 27784 in 24:58:32
# Processed 13740 out of 27784 in 25:01:13
# Processed 13760 out of 27784 in 25:05:21
# Processed 13780 out of 27784 in 25:07:44
# Processed 13800 out of 27784 in 25:11:04
# Processed 13820 out of 27784 in 25:13:40
# Processed 13840 out of 27784 in 25:17:07
# Processed 13860 out of 27784 in 25:21:45
# Processed 13880 out of 27784 in 25:25:48
# Processed 13900 out of 27784 in 25:28:27
# Processed 13920 out of 27784 in 25:32:29
# Processed 13940 out of 27784 in 25:35:18
# Processed 13960 out of 27784 in 25:38:10
# Processed 13980 out of 27784 in 25:40:36
# Processed 14000 out of 27784 in 25:45:02
# Processed 14020 out of 27784 in 25:48:56
# Processed 14040 out of 27784 in 25:53:11
# Processed 14060 out of 27784 in 26:00:23
# Processed 14080 out of 27784 in 26:06:06
# Processed 14100 out of 27784 in 26:13:17
# Processed 14120 out of 27784 in 26:16:51
# Processed 14140 out of 27784 in 26:25:24
# Processed 14160 out of 27784 in 26:28:41
# Processed 14180 out of 27784 in 26:31:58
# Processed 14200 out of 27784 in 26:34:41
# Processed 14220 out of 27784 in 26:42:10
# Processed 14240 out of 27784 in 26:49:32
# Processed 14260 out of 27784 in 26:54:23
# Processed 14280 out of 27784 in 27:01:22
# Processed 14300 out of 27784 in 27:07:08
# Processed 14320 out of 27784 in 27:14:13
# Processed 14340 out of 27784 in 27:21:40
# Processed 14360 out of 27784 in 27:28:06
# Processed 14380 out of 27784 in 27:35:26
# Processed 14400 out of 27784 in 27:42:16
# Processed 14420 out of 27784 in 27:48:29
# Processed 14440 out of 27784 in 27:56:33
# Processed 14460 out of 27784 in 28:00:31
# Processed 14480 out of 27784 in 28:07:16
# Processed 14500 out of 27784 in 28:13:48
# Processed 14520 out of 27784 in 28:17:04
# Processed 14540 out of 27784 in 28:19:15
# Processed 14560 out of 27784 in 28:21:19
# Processed 14580 out of 27784 in 28:23:16
# Processed 14600 out of 27784 in 28:25:08
# Processed 14620 out of 27784 in 28:27:03
# Processed 14640 out of 27784 in 28:29:18
# Processed 14660 out of 27784 in 28:31:30
# Processed 14680 out of 27784 in 28:35:04
# Processed 14700 out of 27784 in 28:38:05
# Processed 14720 out of 27784 in 28:40:25
# Processed 14740 out of 27784 in 28:42:07
# Processed 14760 out of 27784 in 28:44:17
# Processed 14780 out of 27784 in 28:48:05
# Processed 14800 out of 27784 in 28:51:38
# Processed 14820 out of 27784 in 28:53:55
# Processed 14840 out of 27784 in 28:57:38
# Processed 14860 out of 27784 in 29:03:26
# Processed 14880 out of 27784 in 29:05:37
# Processed 14900 out of 27784 in 29:09:04
# Processed 14920 out of 27784 in 29:12:08
# Processed 14940 out of 27784 in 29:16:43
# Processed 14960 out of 27784 in 29:20:54
# Processed 14980 out of 27784 in 29:23:08
# Processed 15000 out of 27784 in 29:25:33
# Processed 15020 out of 27784 in 29:27:51
# Processed 15040 out of 27784 in 29:32:07
# Processed 15060 out of 27784 in 29:34:10
# Processed 15080 out of 27784 in 29:35:56
# Processed 15100 out of 27784 in 29:43:38
# Processed 15120 out of 27784 in 29:45:40
# Processed 15140 out of 27784 in 29:55:18
# Processed 15160 out of 27784 in 30:01:11
# Processed 15180 out of 27784 in 30:09:24
# Processed 15200 out of 27784 in 30:25:59
# Processed 15220 out of 27784 in 30:48:25
# Processed 15240 out of 27784 in 31:03:51
# Processed 15260 out of 27784 in 31:05:08
# Processed 15280 out of 27784 in 31:09:56
# Processed 15300 out of 27784 in 31:26:44
# Processed 15320 out of 27784 in 31:29:21
# Processed 15340 out of 27784 in 31:39:33
# Processed 15360 out of 27784 in 31:44:00
# Processed 15380 out of 27784 in 31:50:31
# Processed 15400 out of 27784 in 31:53:51
# Processed 15420 out of 27784 in 31:59:08
# Processed 15440 out of 27784 in 32:02:38
# Processed 15460 out of 27784 in 32:06:07
# Processed 15480 out of 27784 in 32:10:47
# Processed 15500 out of 27784 in 32:13:52
# Processed 15520 out of 27784 in 32:17:15
# Processed 15540 out of 27784 in 32:21:22
# Processed 15560 out of 27784 in 32:24:55
# Processed 15580 out of 27784 in 32:28:15
# Processed 15600 out of 27784 in 32:32:31
# Processed 15620 out of 27784 in 32:35:38
# Processed 15640 out of 27784 in 32:38:24
# Processed 15660 out of 27784 in 32:41:24
# Processed 15680 out of 27784 in 32:46:01
# Processed 15700 out of 27784 in 32:50:28
# Processed 15720 out of 27784 in 32:54:17
# Processed 15740 out of 27784 in 32:59:26
# Processed 15760 out of 27784 in 33:05:51
# Processed 15780 out of 27784 in 33:12:29
# Processed 15800 out of 27784 in 33:19:52
# Processed 15820 out of 27784 in 33:24:56
# Processed 15840 out of 27784 in 33:30:41
# Processed 15860 out of 27784 in 33:37:38
# Processed 15880 out of 27784 in 33:41:30
# Processed 15900 out of 27784 in 33:43:12
# Processed 15920 out of 27784 in 33:49:51
# Processed 15940 out of 27784 in 33:54:19
# Processed 15960 out of 27784 in 34:00:56
# Processed 15980 out of 27784 in 34:08:20
# Processed 16000 out of 27784 in 34:15:26
# Processed 16020 out of 27784 in 34:20:32
# Processed 16040 out of 27784 in 34:23:56
# Processed 16060 out of 27784 in 34:27:42
# Processed 16080 out of 27784 in 34:32:22
# Processed 16100 out of 27784 in 34:37:02
# Processed 16120 out of 27784 in 34:43:23
# Processed 16140 out of 27784 in 34:48:21
# Processed 16160 out of 27784 in 34:55:08
# Processed 16180 out of 27784 in 35:01:33
# Processed 16200 out of 27784 in 35:03:55
# Processed 16220 out of 27784 in 35:09:05
# Processed 16240 out of 27784 in 35:17:30
# Processed 16260 out of 27784 in 35:26:32
# Processed 16280 out of 27784 in 35:32:33
# Processed 16300 out of 27784 in 36:04:30
# Processed 16320 out of 27784 in 36:08:54
# Processed 16340 out of 27784 in 36:11:15
# Processed 16360 out of 27784 in 36:15:56
# Processed 16380 out of 27784 in 36:20:46
# Processed 16400 out of 27784 in 36:23:43
# Processed 16420 out of 27784 in 36:26:05
# Processed 16440 out of 27784 in 36:28:03
# Processed 16460 out of 27784 in 36:36:54
# Processed 16480 out of 27784 in 36:41:49
# Processed 16500 out of 27784 in 36:47:24
# Processed 16520 out of 27784 in 36:49:28
# Processed 16540 out of 27784 in 36:51:20
# Processed 16560 out of 27784 in 36:54:23
# Processed 16580 out of 27784 in 36:56:58
# Processed 16600 out of 27784 in 37:00:45
# Processed 16620 out of 27784 in 37:04:15
# Processed 16640 out of 27784 in 37:14:19
# Processed 16660 out of 27784 in 37:22:18
# Processed 16680 out of 27784 in 37:26:31
# Processed 16700 out of 27784 in 37:31:15
# Processed 16720 out of 27784 in 37:36:07
# Processed 16740 out of 27784 in 37:38:55
# Processed 16760 out of 27784 in 37:45:09
# Processed 16780 out of 27784 in 37:47:14
# Processed 16800 out of 27784 in 37:50:19
# Processed 16820 out of 27784 in 37:52:27
# Processed 16840 out of 27784 in 37:54:28
# Processed 16860 out of 27784 in 37:56:23
# Processed 16880 out of 27784 in 37:58:18
# Processed 16900 out of 27784 in 38:01:09
# Processed 16920 out of 27784 in 38:06:44
# Processed 16940 out of 27784 in 38:08:30
# Processed 16960 out of 27784 in 38:12:16
# Processed 16980 out of 27784 in 38:14:25
# Processed 17000 out of 27784 in 38:16:30
# Processed 17020 out of 27784 in 38:20:44
# Processed 17040 out of 27784 in 38:22:57
# Processed 17060 out of 27784 in 38:25:42
# Processed 17080 out of 27784 in 38:28:56
# Processed 17100 out of 27784 in 38:31:07
# Processed 17120 out of 27784 in 38:41:28
# Processed 17140 out of 27784 in 38:46:12
# Processed 17160 out of 27784 in 38:51:31
# Processed 17180 out of 27784 in 38:54:05
# Processed 17200 out of 27784 in 38:59:35
# Processed 17220 out of 27784 in 39:06:07
# Processed 17240 out of 27784 in 39:15:00
# Processed 17260 out of 27784 in 39:20:52
# Processed 17280 out of 27784 in 39:23:11
# Processed 17300 out of 27784 in 39:25:27
# Processed 17320 out of 27784 in 39:28:14
# Processed 17340 out of 27784 in 39:32:12
# Processed 17360 out of 27784 in 39:35:21
# Processed 17380 out of 27784 in 39:38:03
# Processed 17400 out of 27784 in 39:41:53
# Processed 17420 out of 27784 in 39:45:32
# Processed 17440 out of 27784 in 39:50:28
# Processed 17460 out of 27784 in 39:54:40
# Processed 17480 out of 27784 in 39:58:48
# Processed 17500 out of 27784 in 40:02:47
# Processed 17520 out of 27784 in 40:06:56
# Processed 17540 out of 27784 in 40:10:24
# Processed 17560 out of 27784 in 40:14:01
# Processed 17580 out of 27784 in 40:17:51
# Processed 17600 out of 27784 in 40:21:42
# Processed 17620 out of 27784 in 40:28:07
# Processed 17640 out of 27784 in 40:35:10
# Processed 17660 out of 27784 in 40:40:12
# Processed 17680 out of 27784 in 40:46:53
# Processed 17700 out of 27784 in 40:59:27
# Processed 17720 out of 27784 in 41:04:39
# Processed 17740 out of 27784 in 41:08:28
# Processed 17760 out of 27784 in 41:11:15
# Processed 17780 out of 27784 in 41:13:23
# Processed 17800 out of 27784 in 41:15:54
# Processed 17820 out of 27784 in 41:22:01
# Processed 17840 out of 27784 in 41:26:19
# Processed 17860 out of 27784 in 41:29:55
# Processed 17880 out of 27784 in 41:35:45
# Processed 17900 out of 27784 in 42:19:44
# Processed 17920 out of 27784 in 42:40:18
# Processed 17940 out of 27784 in 43:13:39
# Processed 17960 out of 27784 in 43:30:33
# Processed 17980 out of 27784 in 43:36:09
# Processed 18000 out of 27784 in 43:40:20
# Processed 18020 out of 27784 in 43:43:38
# Processed 18040 out of 27784 in 43:46:38
# Processed 18060 out of 27784 in 43:49:24
# Processed 18080 out of 27784 in 43:52:43
# Processed 18100 out of 27784 in 43:56:53
# Processed 18120 out of 27784 in 44:04:25
# Processed 18140 out of 27784 in 44:08:07
# Processed 18160 out of 27784 in 44:11:17
# Processed 18180 out of 27784 in 44:14:50
# Processed 18200 out of 27784 in 44:17:56
# Processed 18220 out of 27784 in 44:21:10
# Processed 18240 out of 27784 in 44:24:13
# Processed 18260 out of 27784 in 44:36:49
# Processed 18280 out of 27784 in 44:41:23
# Processed 18300 out of 27784 in 44:45:20
# Processed 18320 out of 27784 in 44:53:57
# Processed 18340 out of 27784 in 45:00:15
# Processed 18360 out of 27784 in 45:04:11
# Processed 18380 out of 27784 in 45:08:46
# Processed 18400 out of 27784 in 45:13:38
# Processed 18420 out of 27784 in 45:17:44
# Processed 18440 out of 27784 in 45:22:00
# Processed 18460 out of 27784 in 45:30:52
# Processed 18480 out of 27784 in 45:33:56
# Processed 18500 out of 27784 in 45:41:27
# Processed 18520 out of 27784 in 45:43:23
# Processed 18540 out of 27784 in 45:45:52
# Processed 18560 out of 27784 in 45:48:54
# Processed 18580 out of 27784 in 45:51:52
# Processed 18600 out of 27784 in 45:54:25
# Processed 18620 out of 27784 in 45:57:24
# Processed 18640 out of 27784 in 46:00:19
# Processed 18660 out of 27784 in 46:03:10
# Processed 18680 out of 27784 in 46:06:12
# Processed 18700 out of 27784 in 46:09:10
# Processed 18720 out of 27784 in 46:12:19
# Processed 18740 out of 27784 in 46:15:09
# Processed 18760 out of 27784 in 46:18:10
# Processed 18780 out of 27784 in 46:31:53
# Processed 18800 out of 27784 in 46:39:38
# Processed 18820 out of 27784 in 46:43:19
# Processed 18840 out of 27784 in 46:45:30
# Processed 18860 out of 27784 in 46:48:20
# Processed 18880 out of 27784 in 46:51:34
# Processed 18900 out of 27784 in 46:54:36
# Processed 18920 out of 27784 in 46:58:02
# Processed 18940 out of 27784 in 47:01:05
# Processed 18960 out of 27784 in 47:04:10
# Processed 18980 out of 27784 in 47:06:31
# Processed 19000 out of 27784 in 47:12:06
# Processed 19020 out of 27784 in 47:15:56
# Processed 19040 out of 27784 in 47:25:11
# Processed 19060 out of 27784 in 47:28:01
# Processed 19080 out of 27784 in 47:31:39
# Processed 19100 out of 27784 in 47:36:34
# Processed 19120 out of 27784 in 47:39:50
# Processed 19140 out of 27784 in 47:42:52
# Processed 19160 out of 27784 in 47:45:39
# Processed 19180 out of 27784 in 47:48:05
# Processed 19200 out of 27784 in 47:51:00
# Processed 19220 out of 27784 in 47:52:46
# Processed 19240 out of 27784 in 47:55:01
# Processed 19260 out of 27784 in 47:58:55
# Processed 19280 out of 27784 in 48:02:40
# Processed 19300 out of 27784 in 48:05:00
# Processed 19320 out of 27784 in 48:07:42
# Processed 19340 out of 27784 in 48:10:15
# Processed 19360 out of 27784 in 48:12:50
# Processed 19380 out of 27784 in 48:15:11
# Processed 19400 out of 27784 in 48:18:10
# Processed 19420 out of 27784 in 48:21:13
# Processed 19440 out of 27784 in 48:28:02
# Processed 19460 out of 27784 in 48:36:14
# Processed 19480 out of 27784 in 48:42:19
# Processed 19500 out of 27784 in 48:45:58
# Processed 19520 out of 27784 in 48:50:34
# Processed 19540 out of 27784 in 48:54:37
# Processed 19560 out of 27784 in 49:00:14
# Processed 19580 out of 27784 in 49:04:20
# Processed 19600 out of 27784 in 49:07:43
# Processed 19620 out of 27784 in 49:10:07
# Processed 19640 out of 27784 in 49:12:31
# Processed 19660 out of 27784 in 49:14:14
# Processed 19680 out of 27784 in 49:16:13
# Processed 19700 out of 27784 in 49:18:28
# Processed 19720 out of 27784 in 49:21:38
# Processed 19740 out of 27784 in 49:28:26
# Processed 19760 out of 27784 in 49:35:13
# Processed 19780 out of 27784 in 49:40:47
# Processed 19800 out of 27784 in 49:44:45
# Processed 19820 out of 27784 in 49:51:33
# Processed 19840 out of 27784 in 49:56:03
# Processed 19860 out of 27784 in 49:59:05
# Processed 19880 out of 27784 in 50:03:40
# Processed 19900 out of 27784 in 50:08:58
# Processed 19920 out of 27784 in 50:12:12
# Processed 19940 out of 27784 in 50:14:10
# Processed 19960 out of 27784 in 50:16:22
# Processed 19980 out of 27784 in 50:19:56
# Processed 20000 out of 27784 in 50:28:24
# Processed 20020 out of 27784 in 50:37:09
# Processed 20040 out of 27784 in 50:42:31
# Processed 20060 out of 27784 in 50:45:37
# Processed 20080 out of 27784 in 50:50:15
# Processed 20100 out of 27784 in 50:53:40
# Processed 20120 out of 27784 in 50:58:44
# Processed 20140 out of 27784 in 51:04:01
# Processed 20160 out of 27784 in 51:11:27
# Processed 20180 out of 27784 in 51:13:58
# Processed 20200 out of 27784 in 51:18:54
# Processed 20220 out of 27784 in 51:21:51
# Processed 20240 out of 27784 in 51:23:14
# Processed 20260 out of 27784 in 51:26:50
# Processed 20280 out of 27784 in 51:34:35
# Processed 20300 out of 27784 in 51:41:44
# Processed 20320 out of 27784 in 51:45:23
# Processed 20340 out of 27784 in 51:48:04
# Processed 20360 out of 27784 in 51:54:46
# Processed 20380 out of 27784 in 52:00:38
# Processed 20400 out of 27784 in 52:07:06
# Processed 20420 out of 27784 in 52:13:57
# Processed 20440 out of 27784 in 52:18:28
# Processed 20460 out of 27784 in 52:21:36
# Processed 20480 out of 27784 in 52:23:41
# Processed 20500 out of 27784 in 52:25:47
# Processed 20520 out of 27784 in 52:28:11
# Processed 20540 out of 27784 in 52:31:32
# Processed 20560 out of 27784 in 52:36:30
# Processed 20580 out of 27784 in 52:38:34
# Processed 20600 out of 27784 in 52:41:51
# Processed 20620 out of 27784 in 52:48:45
# Processed 20640 out of 27784 in 52:55:32
# Processed 20660 out of 27784 in 53:01:59
# Processed 20680 out of 27784 in 53:07:30
# Processed 20700 out of 27784 in 53:09:25
# Processed 20720 out of 27784 in 53:11:42
# Processed 20740 out of 27784 in 53:14:24
# Processed 20760 out of 27784 in 53:16:47
# Processed 20780 out of 27784 in 53:18:29
# Processed 20800 out of 27784 in 53:21:17
# Processed 20820 out of 27784 in 53:26:06
# Processed 20840 out of 27784 in 53:30:33
# Processed 20860 out of 27784 in 53:35:21
# Processed 20880 out of 27784 in 53:44:27
# Processed 20900 out of 27784 in 53:48:32
# Processed 20920 out of 27784 in 53:55:45
# Processed 20940 out of 27784 in 54:02:21
# Processed 20960 out of 27784 in 54:06:10
# Processed 20980 out of 27784 in 54:15:16
# Processed 21000 out of 27784 in 54:19:28
# Processed 21020 out of 27784 in 54:27:47
# Processed 21040 out of 27784 in 54:34:44
# Processed 21060 out of 27784 in 54:37:58
# Processed 21080 out of 27784 in 54:40:28
# Processed 21100 out of 27784 in 54:43:19
# Processed 21120 out of 27784 in 54:49:15
# Processed 21140 out of 27784 in 54:52:23
# Processed 21160 out of 27784 in 54:55:14
# Processed 21180 out of 27784 in 54:57:52
# Processed 21200 out of 27784 in 55:00:01
# Processed 21220 out of 27784 in 55:02:20
# Processed 21240 out of 27784 in 55:04:39
# Processed 21260 out of 27784 in 55:06:58
# Processed 21280 out of 27784 in 55:09:15
# Processed 21300 out of 27784 in 55:12:36
# Processed 21320 out of 27784 in 55:16:27
# Processed 21340 out of 27784 in 55:19:09
# Processed 21360 out of 27784 in 55:21:20
# Processed 21380 out of 27784 in 55:23:42
# Processed 21400 out of 27784 in 55:32:46
# Processed 21420 out of 27784 in 55:36:55
# Processed 21440 out of 27784 in 55:41:22
# Processed 21460 out of 27784 in 55:46:21
# Processed 21480 out of 27784 in 55:50:07
# Processed 21500 out of 27784 in 55:53:55
# Processed 21520 out of 27784 in 55:57:46
# Processed 21540 out of 27784 in 56:00:50
# Processed 21560 out of 27784 in 56:03:53
# Processed 21580 out of 27784 in 56:06:22
# Processed 21600 out of 27784 in 56:09:41
# Processed 21620 out of 27784 in 56:13:06
# Processed 21640 out of 27784 in 56:16:15
# Processed 21660 out of 27784 in 56:19:28
# Processed 21680 out of 27784 in 56:23:09
# Processed 21700 out of 27784 in 56:25:48
# Processed 21720 out of 27784 in 56:31:53
# Processed 21740 out of 27784 in 56:35:27
# Processed 21760 out of 27784 in 56:38:53
# Processed 21780 out of 27784 in 56:42:10
# Processed 21800 out of 27784 in 56:45:26
# Processed 21820 out of 27784 in 56:48:24
# Processed 21840 out of 27784 in 56:50:59
# Processed 21860 out of 27784 in 56:53:36
# Processed 21880 out of 27784 in 56:55:34
# Processed 21900 out of 27784 in 56:58:48
# Processed 21920 out of 27784 in 57:03:04
# Processed 21940 out of 27784 in 57:07:23
# Processed 21960 out of 27784 in 57:25:08
# Processed 21980 out of 27784 in 57:32:59
# Processed 22000 out of 27784 in 57:39:50
# Processed 22020 out of 27784 in 57:45:38
# Processed 22040 out of 27784 in 57:49:15
# Processed 22060 out of 27784 in 57:55:13
# Processed 22080 out of 27784 in 58:02:04
# Processed 22100 out of 27784 in 58:10:41
# Processed 22120 out of 27784 in 58:14:07
# Processed 22140 out of 27784 in 58:16:12
# Processed 22160 out of 27784 in 58:19:59
# Processed 22180 out of 27784 in 58:24:08
# Processed 22200 out of 27784 in 58:27:49
# Processed 22220 out of 27784 in 58:30:58
# Processed 22240 out of 27784 in 58:37:21
# Processed 22260 out of 27784 in 58:45:32
# Processed 22280 out of 27784 in 58:49:58
# Processed 22300 out of 27784 in 58:51:23
# Processed 22320 out of 27784 in 59:00:56
# Processed 22340 out of 27784 in 59:03:30
# Processed 22360 out of 27784 in 59:06:12
# Processed 22380 out of 27784 in 59:10:40
# Processed 22400 out of 27784 in 59:14:31
# Processed 22420 out of 27784 in 59:19:44
# Processed 22440 out of 27784 in 59:33:58
# Processed 22460 out of 27784 in 59:36:31
# Processed 22480 out of 27784 in 59:39:57
# Processed 22500 out of 27784 in 59:42:40
# Processed 22520 out of 27784 in 59:45:26
# Processed 22540 out of 27784 in 59:48:37
# Processed 22560 out of 27784 in 59:53:19
# Processed 22580 out of 27784 in 60:01:46
# Processed 22600 out of 27784 in 60:12:43
# Processed 22620 out of 27784 in 60:17:46
# Processed 22640 out of 27784 in 60:20:55
# Processed 22660 out of 27784 in 60:24:05
# Processed 22680 out of 27784 in 60:26:08
# Processed 22700 out of 27784 in 60:28:21
# Processed 22720 out of 27784 in 60:30:41
# Processed 22740 out of 27784 in 60:55:01
# Processed 22760 out of 27784 in 61:04:43
# Processed 22780 out of 27784 in 61:09:52
# Processed 22800 out of 27784 in 61:15:18
# Processed 22820 out of 27784 in 61:17:09
# Processed 22840 out of 27784 in 61:21:39
# Processed 22860 out of 27784 in 61:26:31
# Processed 22880 out of 27784 in 61:46:28
# Processed 22900 out of 27784 in 61:48:46
# Processed 22920 out of 27784 in 61:51:39
# Processed 22940 out of 27784 in 61:58:46
# Processed 22960 out of 27784 in 62:04:35
# Processed 22980 out of 27784 in 62:10:25
# Processed 23000 out of 27784 in 62:15:09
# Processed 23020 out of 27784 in 62:21:01
# Processed 23040 out of 27784 in 62:23:44
# Processed 23060 out of 27784 in 62:25:58
# Processed 23080 out of 27784 in 62:29:41
# Processed 23100 out of 27784 in 62:31:47
# Processed 23120 out of 27784 in 62:33:26
# Processed 23140 out of 27784 in 62:35:16
# Processed 23160 out of 27784 in 62:37:12
# Processed 23180 out of 27784 in 62:39:10
# Processed 23200 out of 27784 in 62:40:54
# Processed 23220 out of 27784 in 62:42:47
# Processed 23240 out of 27784 in 62:44:56
# Processed 23260 out of 27784 in 62:47:20
# Processed 23280 out of 27784 in 62:49:58
# Processed 23300 out of 27784 in 62:52:05
# Processed 23320 out of 27784 in 62:54:35
# Processed 23340 out of 27784 in 62:57:29
# Processed 23360 out of 27784 in 63:01:42
# Processed 23380 out of 27784 in 63:13:51
# Processed 23400 out of 27784 in 63:25:56
# Processed 23420 out of 27784 in 63:34:22
# Processed 23440 out of 27784 in 63:37:46
# Processed 23460 out of 27784 in 63:42:10
# Processed 23480 out of 27784 in 63:44:28
# Processed 23500 out of 27784 in 63:51:57
# Processed 23520 out of 27784 in 63:56:02
# Processed 23540 out of 27784 in 63:58:52
# Processed 23560 out of 27784 in 64:02:59
# Processed 23580 out of 27784 in 64:05:41
# Processed 23600 out of 27784 in 64:09:29
# Processed 23620 out of 27784 in 64:13:52
# Processed 23640 out of 27784 in 64:18:56
# Processed 23660 out of 27784 in 64:23:30
# Processed 23680 out of 27784 in 64:28:49
# Processed 23700 out of 27784 in 64:32:25
# Processed 23720 out of 27784 in 64:35:38
# Processed 23740 out of 27784 in 64:39:37
# Processed 23760 out of 27784 in 64:43:04
# Processed 23780 out of 27784 in 64:50:28
# Processed 23800 out of 27784 in 64:59:07
# Processed 23820 out of 27784 in 65:06:05
# exception V37849 NHEENGATU GNAV 1.m4v
# exception V37850 NHEENGATU GNAV 2.m4v
# Processed 23840 out of 27784 in 65:09:14
# Processed 23860 out of 27784 in 65:12:42
# Processed 23880 out of 27784 in 65:15:28
# Processed 23900 out of 27784 in 65:20:00
# Processed 23920 out of 27784 in 65:33:22
# Processed 23940 out of 27784 in 65:35:06
# Processed 23960 out of 27784 in 65:38:04
# Processed 23980 out of 27784 in 65:48:08
# Processed 24000 out of 27784 in 65:51:20
# Processed 24020 out of 27784 in 65:55:13
# Processed 24040 out of 27784 in 65:59:31
# Processed 24060 out of 27784 in 66:05:35
# Processed 24080 out of 27784 in 66:13:47
# Processed 24100 out of 27784 in 66:16:17
# Processed 24120 out of 27784 in 66:18:32
# Processed 24140 out of 27784 in 66:20:02
# Processed 24160 out of 27784 in 66:22:09
# Processed 24180 out of 27784 in 66:26:33
# Processed 24200 out of 27784 in 66:29:21
# Processed 24220 out of 27784 in 66:31:50
# Processed 24240 out of 27784 in 66:34:06
# Processed 24260 out of 27784 in 66:36:42
# Processed 24280 out of 27784 in 66:46:04
# Processed 24300 out of 27784 in 66:48:59
# Processed 24320 out of 27784 in 66:54:03
# Processed 24340 out of 27784 in 66:59:42
# Processed 24360 out of 27784 in 67:10:48
# Processed 24380 out of 27784 in 67:19:41
# Processed 24400 out of 27784 in 67:27:05
# Processed 24420 out of 27784 in 67:31:26
# Processed 24440 out of 27784 in 67:38:52
# Processed 24460 out of 27784 in 67:47:18
# Processed 24480 out of 27784 in 67:58:50
# Processed 24500 out of 27784 in 68:03:48
# Processed 24520 out of 27784 in 68:07:50
# Processed 24540 out of 27784 in 68:10:29
# Processed 24560 out of 27784 in 68:15:19
# Processed 24580 out of 27784 in 68:20:03
# Processed 24600 out of 27784 in 68:23:42
# Processed 24620 out of 27784 in 68:27:12
# Processed 24640 out of 27784 in 68:36:12
# Processed 24660 out of 27784 in 68:37:58
# Processed 24680 out of 27784 in 68:40:25
# Processed 24700 out of 27784 in 68:42:33
# Processed 24720 out of 27784 in 68:43:53
# Processed 24740 out of 27784 in 68:46:29
# Processed 24760 out of 27784 in 68:49:36
# Processed 24780 out of 27784 in 68:54:12
# Processed 24800 out of 27784 in 68:56:55
# Processed 24820 out of 27784 in 68:58:22
# Processed 24840 out of 27784 in 68:59:56
# Processed 24860 out of 27784 in 69:03:31
# Processed 24880 out of 27784 in 69:07:59
# Processed 24900 out of 27784 in 69:09:35
# Processed 24920 out of 27784 in 69:12:06
# Processed 24940 out of 27784 in 69:17:49
# Processed 24960 out of 27784 in 69:22:05
# Processed 24980 out of 27784 in 69:23:22
# Processed 25000 out of 27784 in 69:25:10
# Processed 25020 out of 27784 in 69:30:34
# Processed 25040 out of 27784 in 69:38:32
# Processed 25060 out of 27784 in 69:40:28
# Processed 25080 out of 27784 in 69:42:09
# Processed 25100 out of 27784 in 69:45:56
# Processed 25120 out of 27784 in 69:50:42
# Processed 25140 out of 27784 in 69:57:38
# Processed 25160 out of 27784 in 70:00:08
# Processed 25180 out of 27784 in 70:02:26
# Processed 25200 out of 27784 in 70:07:23
# Processed 25220 out of 27784 in 70:13:58
# Processed 25240 out of 27784 in 70:21:00
# Processed 25260 out of 27784 in 70:29:14
# Processed 25280 out of 27784 in 70:33:38
# Processed 25300 out of 27784 in 70:37:11
# Processed 25320 out of 27784 in 70:45:15
# Processed 25340 out of 27784 in 70:47:43
# Processed 25360 out of 27784 in 70:50:16
# Processed 25380 out of 27784 in 70:53:15
# Processed 25400 out of 27784 in 70:55:56
# Processed 25420 out of 27784 in 70:58:16
# Processed 25440 out of 27784 in 71:04:38
# Processed 25460 out of 27784 in 71:12:37
# Processed 25480 out of 27784 in 71:23:41
# Processed 25500 out of 27784 in 71:31:20
# Processed 25520 out of 27784 in 71:35:10
# Processed 25540 out of 27784 in 71:38:30
# Processed 25560 out of 27784 in 71:44:43
# Processed 25580 out of 27784 in 71:49:34
# Processed 25600 out of 27784 in 71:52:45
# Processed 25620 out of 27784 in 72:04:48
# Processed 25640 out of 27784 in 72:10:03
# Processed 25660 out of 27784 in 72:15:06
# Processed 25680 out of 27784 in 72:21:02
# Processed 25700 out of 27784 in 72:24:26
# Processed 25720 out of 27784 in 72:27:34
# Processed 25740 out of 27784 in 72:30:05
# Processed 25760 out of 27784 in 72:32:11
# Processed 25780 out of 27784 in 72:33:06
# Processed 25800 out of 27784 in 72:36:54
# Processed 25820 out of 27784 in 72:46:17
# Processed 25840 out of 27784 in 72:59:24
# Processed 25860 out of 27784 in 73:05:33
# Processed 25880 out of 27784 in 73:06:52
# Processed 25900 out of 27784 in 73:08:12
# Processed 25920 out of 27784 in 73:10:43
# Processed 25940 out of 27784 in 73:13:31
# Processed 25960 out of 27784 in 73:16:15
# Processed 25980 out of 27784 in 73:18:09
# Processed 26000 out of 27784 in 73:19:56
# Processed 26020 out of 27784 in 73:21:32
# Processed 26040 out of 27784 in 73:23:15
# Processed 26060 out of 27784 in 73:25:04
# Processed 26080 out of 27784 in 73:26:58
# Processed 26100 out of 27784 in 73:38:04
# Processed 26120 out of 27784 in 73:40:05
# Processed 26140 out of 27784 in 73:52:44
# Processed 26160 out of 27784 in 74:04:11
# Processed 26180 out of 27784 in 74:06:27
# Processed 26200 out of 27784 in 74:10:38
# Processed 26220 out of 27784 in 74:14:27
# Processed 26240 out of 27784 in 74:19:55
# Processed 26260 out of 27784 in 74:25:14
# Processed 26280 out of 27784 in 74:30:07
# Processed 26300 out of 27784 in 74:34:19
# Processed 26320 out of 27784 in 74:40:44
# Processed 26340 out of 27784 in 74:43:56
# Processed 26360 out of 27784 in 74:47:38
# Processed 26380 out of 27784 in 74:51:06
# Processed 26400 out of 27784 in 74:55:23
# Processed 26420 out of 27784 in 74:58:53
# Processed 26440 out of 27784 in 75:13:56
# Processed 26460 out of 27784 in 75:23:27
# Processed 26480 out of 27784 in 75:25:35
# Processed 26500 out of 27784 in 75:27:43
# Processed 26520 out of 27784 in 75:31:05
# Processed 26540 out of 27784 in 75:35:42
# Processed 26560 out of 27784 in 75:39:13
# Processed 26580 out of 27784 in 75:41:16
# Processed 26600 out of 27784 in 75:42:51
# Processed 26620 out of 27784 in 75:44:28
# Processed 26640 out of 27784 in 75:49:55
# Processed 26660 out of 27784 in 75:54:31
# Processed 26680 out of 27784 in 75:58:11
# Processed 26700 out of 27784 in 76:00:58
# Processed 26720 out of 27784 in 76:02:06
# Processed 26740 out of 27784 in 76:04:39
# Processed 26760 out of 27784 in 76:10:29
# Processed 26780 out of 27784 in 76:13:45
# Processed 26800 out of 27784 in 76:15:53
# Processed 26820 out of 27784 in 76:16:58
# Processed 26840 out of 27784 in 76:20:35
# Processed 26860 out of 27784 in 76:25:41
# Processed 26880 out of 27784 in 76:27:01
# Processed 26900 out of 27784 in 76:29:31
# Processed 26920 out of 27784 in 76:32:00
# Processed 26940 out of 27784 in 76:34:59
# Processed 26960 out of 27784 in 76:36:46
# Processed 26980 out of 27784 in 76:39:53
# Processed 27000 out of 27784 in 76:40:51
# Processed 27020 out of 27784 in 76:46:22
# Processed 27040 out of 27784 in 76:49:30
# Processed 27060 out of 27784 in 76:52:05
# Processed 27080 out of 27784 in 77:01:13
# Processed 27100 out of 27784 in 77:08:45
# Processed 27120 out of 27784 in 77:11:10
# Processed 27140 out of 27784 in 77:15:13
# Processed 27160 out of 27784 in 77:20:27
# Processed 27180 out of 27784 in 77:27:55
# Processed 27200 out of 27784 in 77:29:33
# Processed 27220 out of 27784 in 77:30:52
# Processed 27240 out of 27784 in 77:32:09
# Processed 27260 out of 27784 in 77:34:05
# Processed 27280 out of 27784 in 77:35:17
# Processed 27300 out of 27784 in 77:37:43
# Processed 27320 out of 27784 in 77:43:34
# Processed 27340 out of 27784 in 77:45:23
# Processed 27360 out of 27784 in 77:48:42
# Processed 27380 out of 27784 in 77:51:14
# Processed 27400 out of 27784 in 77:54:29
# Processed 27420 out of 27784 in 77:57:20
# Processed 27440 out of 27784 in 78:00:01
# Processed 27460 out of 27784 in 78:09:28
# Processed 27480 out of 27784 in 78:13:19
# Processed 27500 out of 27784 in 78:14:45
# Processed 27520 out of 27784 in 78:16:18
# Processed 27540 out of 27784 in 78:19:05
# Processed 27560 out of 27784 in 78:22:08
# Processed 27580 out of 27784 in 78:25:21
# Processed 27600 out of 27784 in 78:30:39
# Processed 27620 out of 27784 in 78:34:52
# Processed 27640 out of 27784 in 78:46:45
# Processed 27660 out of 27784 in 78:54:56
# Processed 27680 out of 27784 in 78:58:30
# Processed 27700 out of 27784 in 79:05:22
# Processed 27720 out of 27784 in 79:09:28
# Processed 27740 out of 27784 in 79:11:22
# Processed 27760 out of 27784 in 79:13:05
# Processed 27780 out of 27784 in 79:21:16
# Processed 27784 out of 27784 in 79:25:57
