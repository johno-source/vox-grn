# %% [markdown]
# # Form Local DB
# This notebook aims to collate the output of the file generation and make a locally accessible HF DB.

# %% [markdown]
# ## 10 Sec Data
# Lets start with the 10 sec data.

# %%
import pandas as pd
import numpy as np
import os
import sys
import pickle as pkl
from pathlib import Path

# %%
SEGMENTS_DIR = '/media/originals/py_audio_seg/'
DATASETS_DIR = '/media/originals/datasets/'
SEC_4_DATA_DIR = 'py_audio_seg_4sec/data/'
SEC_6_DATA_DIR = 'py_audio_seg_6sec/data/'
SEC_10_DATA_DIR = 'py_audio_seg_10sec/data/'

# %% [markdown]
# ## Form a DF from the segments

# %%
# concatenate all the csv files together. 
seg_10_df = pd.read_csv(f'{SEGMENTS_DIR}seg_10sec_0.csv', index_col='file_name')
seg_10_df = pd.concat([seg_10_df, pd.read_csv(f'{SEGMENTS_DIR}seg_10sec_1.csv', index_col='file_name')])
seg_10_df = pd.concat([seg_10_df, pd.read_csv(f'{SEGMENTS_DIR}seg_10sec_2.csv', index_col='file_name')])
seg_10_df = pd.concat([seg_10_df, pd.read_csv(f'{SEGMENTS_DIR}seg_10sec_3.csv', index_col='file_name')])
seg_10_df = pd.concat([seg_10_df, pd.read_csv(f'{SEGMENTS_DIR}seg_10sec_4.csv', index_col='file_name')])
seg_10_df = pd.concat([seg_10_df, pd.read_csv(f'{SEGMENTS_DIR}seg_10sec_5.csv', index_col='file_name')])
seg_10_df = pd.concat([seg_10_df, pd.read_csv(f'{SEGMENTS_DIR}seg_10sec_6.csv', index_col='file_name')])
seg_10_df = pd.concat([seg_10_df, pd.read_csv(f'{SEGMENTS_DIR}seg_10sec_7.csv', index_col='file_name')])
seg_10_df = pd.concat([seg_10_df, pd.read_csv(f'{SEGMENTS_DIR}seg_10sec_8.csv', index_col='file_name')])

print(seg_10_df.head())
# Out:
#                                                         Index      _1  iso  \
# file_name
# py_audio_seg_10sec/data/aaa/C14610A Region 00_0...  14610_002   10622  aaa
# py_audio_seg_10sec/data/aab/Alumu-Tesu Messages...  13981_002  204137  aab
# py_audio_seg_10sec/data/aab/Alumu-Tesu Messages...  13981_002  204137  aab
# py_audio_seg_10sec/data/aab/Alumu-Tesu Messages...  13981_002  204137  aab
# py_audio_seg_10sec/data/aab/Alumu-Tesu Messages...  13981_002  204137  aab
#
#                                                    language_name  track  \
# file_name
# py_audio_seg_10sec/data/aaa/C14610A Region 00_0...          Otwa      2
# py_audio_seg_10sec/data/aab/Alumu-Tesu Messages...    Alumu-Tesu      2
# py_audio_seg_10sec/data/aab/Alumu-Tesu Messages...    Alumu-Tesu      2
# py_audio_seg_10sec/data/aab/Alumu-Tesu Messages...    Alumu-Tesu      2
# py_audio_seg_10sec/data/aab/Alumu-Tesu Messages...    Alumu-Tesu      2
#
#                                                             location    year  \
# file_name
# py_audio_seg_10sec/data/aaa/C14610A Region 00_0...            Igarra  1963.0
# py_audio_seg_10sec/data/aab/Alumu-Tesu Messages...  KANGA NEAR WAMBA  1962.0
# py_audio_seg_10sec/data/aab/Alumu-Tesu Messages...  KANGA NEAR WAMBA  1962.0
# py_audio_seg_10sec/data/aab/Alumu-Tesu Messages...  KANGA NEAR WAMBA  1962.0
# py_audio_seg_10sec/data/aab/Alumu-Tesu Messages...  KANGA NEAR WAMBA  1962.0
#
#                                                                                  path  \
# file_name
# py_audio_seg_10sec/data/aaa/C14610A Region 00_0...  Programs/14/14610/A14610/From_CM/
# py_audio_seg_10sec/data/aab/Alumu-Tesu Messages...         vox_grn/Audio_MP3/13/13981
# py_audio_seg_10sec/data/aab/Alumu-Tesu Messages...         vox_grn/Audio_MP3/13/13981
# py_audio_seg_10sec/data/aab/Alumu-Tesu Messages...         vox_grn/Audio_MP3/13/13981
# py_audio_seg_10sec/data/aab/Alumu-Tesu Messages...         vox_grn/Audio_MP3/13/13981
#
#                                                                                              filename  \
# file_name
# py_audio_seg_10sec/data/aaa/C14610A Region 00_0...  C14610A Region 00_03_40_970 to 00_06_59_423 (0...
# py_audio_seg_10sec/data/aab/Alumu-Tesu Messages...  Alumu-Tesu Messages 002 What is a Christian ♦ ...
# py_audio_seg_10sec/data/aab/Alumu-Tesu Messages...  Alumu-Tesu Messages 002 What is a Christian ♦ ...
# py_audio_seg_10sec/data/aab/Alumu-Tesu Messages...  Alumu-Tesu Messages 002 What is a Christian ♦ ...
# py_audio_seg_10sec/data/aab/Alumu-Tesu Messages...  Alumu-Tesu Messages 002 What is a Christian ♦ ...
#
#                                                         length  program  \
# file_name
# py_audio_seg_10sec/data/aaa/C14610A Region 00_0...  198.453313    14610
# py_audio_seg_10sec/data/aab/Alumu-Tesu Messages...  794.856000    13981
# py_audio_seg_10sec/data/aab/Alumu-Tesu Messages...  794.856000    13981
# py_audio_seg_10sec/data/aab/Alumu-Tesu Messages...  794.856000    13981
# py_audio_seg_10sec/data/aab/Alumu-Tesu Messages...  794.856000    13981
#
#                                                     seg_start  seg_stop  seg
# file_name
# py_audio_seg_10sec/data/aaa/C14610A Region 00_0...     142480    152480    0
# py_audio_seg_10sec/data/aab/Alumu-Tesu Messages...     160540    170540    0
# py_audio_seg_10sec/data/aab/Alumu-Tesu Messages...     170540    180540    1
# py_audio_seg_10sec/data/aab/Alumu-Tesu Messages...     463800    473800    2
# py_audio_seg_10sec/data/aab/Alumu-Tesu Messages...     477940    487940    3

# %% [markdown]
# ## Extract the Languages

# %%
langs = seg_10_df['iso'].value_counts()

# %%
# what languages do we have
lang_ids = sorted(list(langs.index))

# %%
import csv
with open('lang10.csv', 'w') as csv_file:
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(lang_ids)

# %%
# now write the languages out into 10 separate groups for processing. 
lang_divisions = [i for i in range(len(lang_ids)//10, len(lang_ids), len(lang_ids)//10)]
lang_sets = []
start = 0
for lang_end in lang_divisions:
    lang_sets.append(lang_ids[start:lang_end])
    start = lang_end
lang_sets.append(lang_ids[start:])
# now write the divided rows out as csv files
for i, s in enumerate(lang_sets):
    with open(f'lang10_{i}.pkl', 'wb') as pkl_file:
        pkl.dump(s, pkl_file)

# %% [markdown]
# ## Get some stats
# So there are 3940 languages, 3032 of which have at least 100 4 second segments of data.
# There are 2.4 million 4 sec segments. 592 languages have at least 1000 segments.
#
# How much audio is there?

# %%
audio_length = seg_10_df['seg_stop'] - seg_10_df['seg_start']
duration = int(sum(audio_length))//1000
hours = duration//3600
minutes = (duration - hours * 3600)//60
print(f'{hours}:{minutes}:{duration%60} {duration}')
# Out:
# 403:52:28 1453948

# %%
seg_10_df.shape[0] * 16497
# Out:
# 40318222581

# %%
seg_10_df.to_csv("../../data/seg_10_df.csv")

# %% [markdown]
# ## Create the meta data
# At first I tried creating a json file for the meta data. This proved difficult because the json created by the dataset is ill-formed. Inspired by [Minds14](https://huggingface.co/datasets/PolyAI/minds14/blob/main/minds14.py) I decided to use csv files. The granularity that I want to allow users to have on gaining the data should be per language, so it follows that there should be a csv file per language. Before getting into that let me give an account of my understanding of how HF datasets work when using a script to download. The user executes:
#
# ```
# load_dataset([string to identify db], [string to identify config], [args])
# ```
# The `string to identify db` can be either a pointer to a local directory or to a HF space. This is neat because it lets you test things locally before deploying them on HF. Once `load_dataset` finds the location it looks for a python script file of the same name in that directory and executes it. There are two things the script needs to do:
#
#     * Define (instantiate) the legal configurations
#     * Define (instantiate) a builder
#
# After `load_dataset` has executed the script it checks that there is a configuration that matches the one the user has given. It has to match both the name and the names of the arguments. If that occurs it then sets the builders config member to the config and calls `_split_generators`. That function needs to load the metadata required for the requested configuration. That metadata could exist locally, on a hugging face space with the script file, or on a third party server. Similarly it has to load the data required for the configuration. The data can also be located in any of the same three locations. After loading the metadata and the data, `_split_generators` creates and returns a list of `dataset.SplitGenerator`s, one for each split requested. It must pass the necessary metadata and data to each one. `load_dataset` then calls `_generate_examples` on the builder - once for each split. This generator has to load the data for a single record from the data provided. It is a generator, so it yields the data one record at a time.
#
# With that background here is how I intend to set up the database. First the legal calls to `load_dataset` are:
# ```
# load_dataset('[path|HF space]/VoxGRN', '[seg_4sec|seg_10sec|seg_10sec]', languages=['all', 'aaa', ...])
# ```
# where `languages` is a list of the iso codes of the languages to load, or some macro calls like all. It will also accept ISO-639-1 codes as well.
#
# The metadata exists in a tar.gz file. This has the csv files for every language. There is one tar.gz file for each of the three configurations. These files will exist on the SIL server.
#
# The data for each language is a tar.gz file of the mp3 files for the language. These files will exist on the sil server. There is one tar.gz file per language per configuration.
#
# This means I need to:
#
#     1. Create a csv file for the meta data of each language in each configuration
#     2. Create a tar.gz file of the mp3 files for each language in each configuration
#     3. Move the tar.gz files to the SIL server.
#     4. Get the script file loading the tar.gz files from the SIL server.
#     5. Check the script file into the HF space.
#
# I will test all the files locally before moving them to their remote locations.

# %% [markdown]
# ## Create the CSV files

# %%
seg_10_df = seg_10_df.drop(columns=['Index', 'year', 'path', 'filename'])
seg_10_df.rename(inplace=True, columns={ 'file_name' : 'file', 'start' : 'item_start', 'end' : 'item_end'})

# %%
# now the index did not rename. Lets try making it a column
seg_10_df['file'] = seg_10_df.index
seg_10_df['file'] = seg_10_df['file'].apply( lambda x : './' + x)

# %%
# change the index
seg_10_df.set_index('file', inplace=True)

# %%
# write out a csv file for every language
for lang in lang_ids:
    lang_df = seg_10_df[seg_10_df['iso'] == lang]
    lang_df.to_csv(f'/media/originals/datasets/seg_10sec_py/{lang}.csv', header=False)

# %% [markdown]
# Sanity check - are we able to load the dataset with the tar.gz metadata file located locally?

# %%
from datasets import load_dataset
grnvox_test = load_dataset('/home/jovyan/grnvox_test', 'seg_4sec', languages=['aaa', 'aac'])
# Out:
# Using custom data configuration seg_4sec-7e13906d46e1114d
# Downloading and preparing dataset grnvox_test/seg_4sec to /home/jovyan/.cache/huggingface/datasets/grnvox_test/seg_4sec-7e13906d46e1114d/0.0.0/7cad7bd8d099aedf768182b0300e5231ce223ba4fd15db3f13ffd038c2aa6374...
# Downloading data:   0%|          | 0.00/914k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/2.45M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset grnvox_test downloaded and prepared to /home/jovyan/.cache/huggingface/datasets/grnvox_test/seg_4sec-7e13906d46e1114d/0.0.0/7cad7bd8d099aedf768182b0300e5231ce223ba4fd15db3f13ffd038c2aa6374. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
grnvox_test['train'][0]['audio']
# Out:
# {'path': '/home/jovyan/.cache/huggingface/datasets/downloads/extracted/5796cd957238728f8aeddc5080d3081ffa4132aafbe25c0dcc09047d130bbd31/seg_4sec/data/aaa/A14610_001_001.mp3',
#  'array': array([ 0.        ,  0.        ,  0.        , ..., -0.05321169,
#         -0.03989655, -0.03859127], dtype=float32),
#  'sampling_rate': 16000}

# %%
import IPython.display as ipd
ipd.Audio(data=grnvox_test['train'][0]['audio']['array'], rate=grnvox_test['train'][0]['audio']['sampling_rate'])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Great! Now lets create all the tar.gz files.

# %%
class cd:
    """Context manager for changing the current working directory"""
    def __init__(self, newPath):
        self.newPath = os.path.expanduser(newPath)

    def __enter__(self):
        self.savedPath = os.getcwd()
        os.chdir(self.newPath)

    def __exit__(self, etype, value, traceback):
        os.chdir(self.savedPath)

# %% [markdown]
# Warning: This takes about 6 hours to run.

# %%
with cd('/media/originals/datasets'):
    for lang in lang_ids:
        os.system(f'tar -czf voxgrn_py_audio_10sec_{lang}.tar.gz py_audio_seg_10sec/data/{lang}')

# %% [markdown]
# ## Uploading files
# To upload files to the SIL Amazon servr we first have to log on.

# %%
import boto3
import getpass

# %%
access_key = getpass.getpass('key')
secret = getpass.getpass('secret')

# %%
session = boto3.session.Session()
client = session.client('s3',
                        region_name='us-east-1',
                        aws_access_key_id=access_key,
                        aws_secret_access_key=secret)

# %% [markdown]
# ### Upload the meta data

# %%
# lets upload the grn data
client.upload_file('/home/jovyan/grnvox_test/vox_grn_4sec_csv.tar.gz', 'grn-media', 'archives/seg_4sec/vox_grn_4sec_csv.tar.gz')

# %% [markdown]
# ### Upload the language files
# This will take a while and may get interrupted. To ensure we can pick up where we left off a pkl of the uploaded files will be kept.

# %%
class persistent_set:
    """Context manager for keeping track of a persistent variable"""
    def __init__(self, setname):
        self.pkl_filename = f'{setname}.pkl'
        self.the_set = set()

    def __enter__(self):
        if os.path.isfile(self.pkl_filename):
            with open(self.pkl_filename, 'rb') as pklFile:
                self.the_set = pkl.load(pklFile)
        return self.the_set

    def __exit__(self, etype, value, traceback):
        with open(self.pkl_filename, 'wb') as pklFile:
            pkl.dump(self.the_set, pklFile)

# %%
import time
start_time = time.time()
items_to_upload = len(lang_ids)
for lang in lang_ids:
    with persistent_set('uploaded_4sec') as uploaded:
        if lang not in uploaded:
            client.upload_file(f'/media/originals/datasets/vox_grn_4sec_{lang}.tar.gz', 'grn-media', f'archives/seg_4sec/data/vox_grn_4sec_{lang}.tar.gz')
            uploaded.add(lang)
            items_uploaded = len(uploaded)
            if items_uploaded % 10 == 0:
                print(f'Uploaded {items_uploaded} out of {items_to_upload} in {time.time()-start_time} seconds')
# Out:
# Uploaded 10 out of 3153 in 147.65817785263062 seconds
# Uploaded 20 out of 3153 in 321.1371548175812 seconds
# Uploaded 30 out of 3153 in 691.7319128513336 seconds
# Uploaded 40 out of 3153 in 992.736917257309 seconds
# Uploaded 50 out of 3153 in 2225.234810113907 seconds
# Uploaded 60 out of 3153 in 2529.969522714615 seconds
# Uploaded 70 out of 3153 in 2798.333982229233 seconds
# Uploaded 80 out of 3153 in 2951.5486624240875 seconds
# Uploaded 90 out of 3153 in 3343.21928024292 seconds
# Uploaded 100 out of 3153 in 3456.551223754883 seconds
# Uploaded 110 out of 3153 in 3739.9261951446533 seconds
# Uploaded 120 out of 3153 in 3981.182122707367 seconds
# Uploaded 130 out of 3153 in 4103.039168357849 seconds
# Uploaded 140 out of 3153 in 4497.39616394043 seconds
# Uploaded 150 out of 3153 in 4692.543757200241 seconds
# Uploaded 160 out of 3153 in 5005.599019050598 seconds
# Uploaded 170 out of 3153 in 5229.098614931107 seconds
# Uploaded 180 out of 3153 in 5368.917381763458 seconds
# Uploaded 190 out of 3153 in 5733.442268371582 seconds
# Uploaded 200 out of 3153 in 5937.856170892715 seconds
# Uploaded 210 out of 3153 in 6084.141567468643 seconds
# Uploaded 220 out of 3153 in 6215.017156839371 seconds
# Uploaded 230 out of 3153 in 6367.668304204941 seconds
# Uploaded 240 out of 3153 in 6546.206500053406 seconds
# Uploaded 250 out of 3153 in 6711.788005113602 seconds
# Uploaded 260 out of 3153 in 6862.341004371643 seconds
# Uploaded 270 out of 3153 in 7071.814258575439 seconds
# Uploaded 280 out of 3153 in 7624.885303020477 seconds
# Uploaded 290 out of 3153 in 7915.165862798691 seconds
# Uploaded 300 out of 3153 in 8153.141343355179 seconds
# Uploaded 310 out of 3153 in 8345.519502878189 seconds
# Uploaded 320 out of 3153 in 8634.38691663742 seconds
# Uploaded 330 out of 3153 in 9066.172293901443 seconds
# Uploaded 340 out of 3153 in 9379.914347410202 seconds
# Uploaded 350 out of 3153 in 9612.567884922028 seconds
# Uploaded 360 out of 3153 in 9771.672987222672 seconds
# Uploaded 370 out of 3153 in 10072.984457969666 seconds
# Uploaded 380 out of 3153 in 10371.175742149353 seconds
# Uploaded 390 out of 3153 in 10509.900964021683 seconds
# Uploaded 400 out of 3153 in 10756.861169099808 seconds
# Uploaded 410 out of 3153 in 10890.552933454514 seconds
# Uploaded 420 out of 3153 in 11116.7045648098 seconds
# Uploaded 430 out of 3153 in 11225.791925430298 seconds
# Uploaded 440 out of 3153 in 11482.635316610336 seconds
# Uploaded 450 out of 3153 in 11601.989154100418 seconds
# Uploaded 460 out of 3153 in 11758.039937973022 seconds
# Uploaded 470 out of 3153 in 12080.074322938919 seconds
# Uploaded 480 out of 3153 in 12437.932225465775 seconds
# Uploaded 490 out of 3153 in 13016.788244962692 seconds
# Uploaded 500 out of 3153 in 13246.588959217072 seconds
# Uploaded 510 out of 3153 in 13382.372316360474 seconds
# Uploaded 520 out of 3153 in 13597.61837220192 seconds
# Uploaded 530 out of 3153 in 13765.446805715561 seconds
# Uploaded 540 out of 3153 in 13944.399860620499 seconds
# Uploaded 550 out of 3153 in 14164.852055549622 seconds
# Uploaded 560 out of 3153 in 14326.71312379837 seconds
# Uploaded 570 out of 3153 in 14452.458857297897 seconds
# Uploaded 580 out of 3153 in 14702.484728813171 seconds
# Uploaded 590 out of 3153 in 14834.820556640625 seconds
# Uploaded 600 out of 3153 in 15473.387834072113 seconds
# Uploaded 610 out of 3153 in 15591.617278814316 seconds
# Uploaded 620 out of 3153 in 15690.63401722908 seconds
# Uploaded 630 out of 3153 in 16022.487269639969 seconds
# Uploaded 640 out of 3153 in 16235.660532712936 seconds
# Uploaded 650 out of 3153 in 16398.686304807663 seconds
# Uploaded 660 out of 3153 in 16660.84550023079 seconds
# Uploaded 670 out of 3153 in 16980.21303844452 seconds
# Uploaded 680 out of 3153 in 17287.066999673843 seconds
# Uploaded 690 out of 3153 in 17538.486675024033 seconds
# Uploaded 700 out of 3153 in 17854.806656837463 seconds
# Uploaded 710 out of 3153 in 18087.958637714386 seconds
# Uploaded 720 out of 3153 in 18258.352408885956 seconds
# Uploaded 730 out of 3153 in 18484.57080411911 seconds
# Uploaded 740 out of 3153 in 18677.67698907852 seconds
# Uploaded 750 out of 3153 in 18999.068054914474 seconds
# Uploaded 760 out of 3153 in 19328.64043188095 seconds
# Uploaded 770 out of 3153 in 19473.008929491043 seconds
# Uploaded 780 out of 3153 in 20497.269676923752 seconds
# Uploaded 790 out of 3153 in 20668.56557893753 seconds
# Uploaded 800 out of 3153 in 20805.592109680176 seconds
# Uploaded 810 out of 3153 in 21133.48261332512 seconds
# Uploaded 820 out of 3153 in 21338.27741074562 seconds
# Uploaded 830 out of 3153 in 21848.435371637344 seconds
# Uploaded 840 out of 3153 in 22343.931276082993 seconds
# Uploaded 850 out of 3153 in 22717.612411260605 seconds
# Uploaded 860 out of 3153 in 22949.97225880623 seconds
# Uploaded 870 out of 3153 in 23149.919431209564 seconds
# Uploaded 880 out of 3153 in 23281.641840696335 seconds
# Uploaded 890 out of 3153 in 23465.011926651 seconds
# Uploaded 900 out of 3153 in 23701.88879609108 seconds
# Uploaded 910 out of 3153 in 23925.32983493805 seconds
# Uploaded 920 out of 3153 in 24455.963636159897 seconds
# Uploaded 930 out of 3153 in 24614.544815778732 seconds
# Uploaded 940 out of 3153 in 24884.061338186264 seconds
# Uploaded 950 out of 3153 in 25443.313613653183 seconds
# Uploaded 960 out of 3153 in 26210.57462501526 seconds
# Uploaded 970 out of 3153 in 26389.496158838272 seconds
# Uploaded 980 out of 3153 in 26529.37541294098 seconds
# Uploaded 990 out of 3153 in 26915.876776218414 seconds
# Uploaded 1000 out of 3153 in 27154.28263449669 seconds
# Uploaded 1010 out of 3153 in 27472.732668876648 seconds
# Uploaded 1020 out of 3153 in 27706.942635774612 seconds
# Uploaded 1030 out of 3153 in 27935.7522585392 seconds
# Uploaded 1040 out of 3153 in 28168.05177283287 seconds
# Uploaded 1050 out of 3153 in 28323.56391954422 seconds
# Uploaded 1060 out of 3153 in 28581.839116811752 seconds
# Uploaded 1070 out of 3153 in 28874.050355672836 seconds
# Uploaded 1080 out of 3153 in 29071.956440210342 seconds
# Uploaded 1090 out of 3153 in 29275.76288461685 seconds
# Uploaded 1100 out of 3153 in 29509.09375333786 seconds
# Uploaded 1110 out of 3153 in 29853.43049955368 seconds
# Uploaded 1120 out of 3153 in 30267.61246585846 seconds
# Uploaded 1130 out of 3153 in 30488.391020298004 seconds
# Uploaded 1140 out of 3153 in 30669.05388379097 seconds
# Uploaded 1150 out of 3153 in 30765.245859622955 seconds
# Uploaded 1160 out of 3153 in 30898.90930199623 seconds
# Uploaded 1170 out of 3153 in 31150.429903507233 seconds
# Uploaded 1180 out of 3153 in 31317.93155813217 seconds
# Uploaded 1190 out of 3153 in 31543.321227312088 seconds
# Uploaded 1200 out of 3153 in 31761.632989406586 seconds
# Uploaded 1210 out of 3153 in 32024.80258154869 seconds
# Uploaded 1220 out of 3153 in 32117.362200021744 seconds
# Uploaded 1230 out of 3153 in 32427.852947473526 seconds
# Uploaded 1240 out of 3153 in 32636.749417066574 seconds
# Uploaded 1250 out of 3153 in 32797.21561908722 seconds
# Uploaded 1260 out of 3153 in 33064.495329618454 seconds
# Uploaded 1270 out of 3153 in 33404.35044336319 seconds
# Uploaded 1280 out of 3153 in 33811.28112220764 seconds
# Uploaded 1290 out of 3153 in 34044.520908117294 seconds
# Uploaded 1300 out of 3153 in 34392.43490600586 seconds
# Uploaded 1310 out of 3153 in 34606.112590551376 seconds
# Uploaded 1320 out of 3153 in 34709.28508520126 seconds
# Uploaded 1330 out of 3153 in 34935.48359155655 seconds
# Uploaded 1340 out of 3153 in 35147.00109052658 seconds
# Uploaded 1350 out of 3153 in 35398.81376481056 seconds
# Uploaded 1360 out of 3153 in 35734.94111061096 seconds
# Uploaded 1370 out of 3153 in 35875.4282207489 seconds
# Uploaded 1380 out of 3153 in 36051.60245394707 seconds
# Uploaded 1390 out of 3153 in 36866.48587155342 seconds
# Uploaded 1400 out of 3153 in 37086.465608119965 seconds
# Uploaded 1410 out of 3153 in 37249.69224739075 seconds
# Uploaded 1420 out of 3153 in 37592.1194562912 seconds
# Uploaded 1430 out of 3153 in 37866.4104385376 seconds
# Uploaded 1440 out of 3153 in 37999.59538793564 seconds
# Uploaded 1450 out of 3153 in 38128.19924354553 seconds
# Uploaded 1460 out of 3153 in 38374.9480881691 seconds
# Uploaded 1470 out of 3153 in 38512.98168802261 seconds
# Uploaded 1480 out of 3153 in 38703.55722236633 seconds
# Uploaded 1490 out of 3153 in 38891.61785340309 seconds
# Uploaded 1500 out of 3153 in 39305.95773720741 seconds
# Uploaded 1510 out of 3153 in 39697.42750167847 seconds
# Uploaded 1520 out of 3153 in 39777.06883096695 seconds
# Uploaded 1530 out of 3153 in 40020.44827365875 seconds
# Uploaded 1540 out of 3153 in 40251.87383937836 seconds
# Uploaded 1550 out of 3153 in 40808.48830938339 seconds
# Uploaded 1560 out of 3153 in 41018.03482723236 seconds
# Uploaded 1570 out of 3153 in 41166.104741573334 seconds
# Uploaded 1580 out of 3153 in 41379.51265668869 seconds
# Uploaded 1590 out of 3153 in 41636.98999929428 seconds
# Uploaded 1600 out of 3153 in 41800.54681324959 seconds
# Uploaded 1610 out of 3153 in 42041.83731198311 seconds
# Uploaded 1620 out of 3153 in 42422.58711051941 seconds
# Uploaded 1630 out of 3153 in 42706.64540743828 seconds
# Uploaded 1640 out of 3153 in 43119.76173710823 seconds
# Uploaded 1650 out of 3153 in 43365.62809705734 seconds
# Uploaded 1660 out of 3153 in 43465.23306941986 seconds
# Uploaded 1670 out of 3153 in 43644.332911491394 seconds
# Uploaded 1680 out of 3153 in 43800.756483078 seconds
# Uploaded 1690 out of 3153 in 44264.747015953064 seconds
# Uploaded 1700 out of 3153 in 44529.365245342255 seconds
# Uploaded 1710 out of 3153 in 44820.223227739334 seconds
# Uploaded 1720 out of 3153 in 45136.09749007225 seconds
# Uploaded 1730 out of 3153 in 45465.99602866173 seconds
# Uploaded 1740 out of 3153 in 45675.997673749924 seconds
# Uploaded 1750 out of 3153 in 45918.98707604408 seconds
# Uploaded 1760 out of 3153 in 46261.46121644974 seconds
# Uploaded 1770 out of 3153 in 46576.57418560982 seconds
# Uploaded 1780 out of 3153 in 46816.56686067581 seconds
# Uploaded 1790 out of 3153 in 46919.392540216446 seconds
# Uploaded 1800 out of 3153 in 47227.72520685196 seconds
# Uploaded 1810 out of 3153 in 47412.95111131668 seconds
# Uploaded 1820 out of 3153 in 47683.28382706642 seconds
# Uploaded 1830 out of 3153 in 47883.739600896835 seconds
# Uploaded 1840 out of 3153 in 48175.82954072952 seconds
# Uploaded 1850 out of 3153 in 48358.46942567825 seconds
# Uploaded 1860 out of 3153 in 48485.42269349098 seconds
# Uploaded 1870 out of 3153 in 48744.193563222885 seconds
# Uploaded 1880 out of 3153 in 49076.77978181839 seconds
# Uploaded 1890 out of 3153 in 49600.84044623375 seconds
# Uploaded 1900 out of 3153 in 49760.55553650856 seconds
# Uploaded 1910 out of 3153 in 50167.11478757858 seconds
# Uploaded 1920 out of 3153 in 50358.344182014465 seconds
# Uploaded 1930 out of 3153 in 50799.49907827377 seconds
# Uploaded 1940 out of 3153 in 51117.39718556404 seconds
# Uploaded 1950 out of 3153 in 51340.842591524124 seconds
# Uploaded 1960 out of 3153 in 51473.346997737885 seconds
# Uploaded 1970 out of 3153 in 51720.12353658676 seconds
# Uploaded 1980 out of 3153 in 51912.74540901184 seconds
# Uploaded 1990 out of 3153 in 52144.41274046898 seconds
# Uploaded 2000 out of 3153 in 52550.61525154114 seconds
# Uploaded 2010 out of 3153 in 52692.25376725197 seconds
# Uploaded 2020 out of 3153 in 53119.52463841438 seconds
# Uploaded 2030 out of 3153 in 53308.325135707855 seconds
# Uploaded 2040 out of 3153 in 53585.69060277939 seconds
# Uploaded 2050 out of 3153 in 53908.43215870857 seconds
# Uploaded 2060 out of 3153 in 54450.53108382225 seconds
# Uploaded 2070 out of 3153 in 54936.93320655823 seconds
# Uploaded 2080 out of 3153 in 55153.96386265755 seconds
# Uploaded 2090 out of 3153 in 55531.27657222748 seconds
# Uploaded 2100 out of 3153 in 55862.84118247032 seconds
# Uploaded 2110 out of 3153 in 56018.8788664341 seconds
# Uploaded 2120 out of 3153 in 56173.522795677185 seconds
# Uploaded 2130 out of 3153 in 56561.9684574604 seconds
# Uploaded 2140 out of 3153 in 56827.81093978882 seconds
# Uploaded 2150 out of 3153 in 57026.74389100075 seconds
# Uploaded 2160 out of 3153 in 57467.15454244614 seconds
# Uploaded 2170 out of 3153 in 57726.81521034241 seconds
# Uploaded 2180 out of 3153 in 57954.165426015854 seconds
# Uploaded 2190 out of 3153 in 58457.41425395012 seconds
# Uploaded 2200 out of 3153 in 58633.809732198715 seconds
# Uploaded 2210 out of 3153 in 59013.91286087036 seconds
# Uploaded 2220 out of 3153 in 59192.74919247627 seconds
# Uploaded 2230 out of 3153 in 59390.824972867966 seconds
# Uploaded 2240 out of 3153 in 59565.93545460701 seconds
# Uploaded 2250 out of 3153 in 59986.98691916466 seconds
# Uploaded 2260 out of 3153 in 60223.12954354286 seconds
# Uploaded 2270 out of 3153 in 60502.41121840477 seconds
# Uploaded 2280 out of 3153 in 60743.883351802826 seconds
# Uploaded 2290 out of 3153 in 61052.345120191574 seconds
# Uploaded 2300 out of 3153 in 61314.45169663429 seconds
# Uploaded 2310 out of 3153 in 61530.92061138153 seconds
# Uploaded 2320 out of 3153 in 61862.665169000626 seconds
# Uploaded 2330 out of 3153 in 62013.635426044464 seconds
# Uploaded 2340 out of 3153 in 62348.231895923615 seconds
# Uploaded 2350 out of 3153 in 62682.79420018196 seconds
# Uploaded 2360 out of 3153 in 63657.57142663002 seconds
# Uploaded 2370 out of 3153 in 63916.439462423325 seconds
# Uploaded 2380 out of 3153 in 64242.527349472046 seconds
# Uploaded 2390 out of 3153 in 64522.450273513794 seconds
# Uploaded 2400 out of 3153 in 64718.80684924126 seconds
# Uploaded 2410 out of 3153 in 64922.01409482956 seconds
# Uploaded 2420 out of 3153 in 65265.122717142105 seconds
# Uploaded 2430 out of 3153 in 65499.34101200104 seconds
# Uploaded 2440 out of 3153 in 65674.25217413902 seconds
# Uploaded 2450 out of 3153 in 65878.23430967331 seconds
# Uploaded 2460 out of 3153 in 66317.72567558289 seconds
# Uploaded 2470 out of 3153 in 66508.63140845299 seconds
# Uploaded 2480 out of 3153 in 66803.73110604286 seconds
# Uploaded 2490 out of 3153 in 66906.58666968346 seconds
# Uploaded 2500 out of 3153 in 67270.65751194954 seconds
# Uploaded 2510 out of 3153 in 67534.46365046501 seconds
# Uploaded 2520 out of 3153 in 68278.91297984123 seconds
# Uploaded 2530 out of 3153 in 68416.55769824982 seconds
# Uploaded 2540 out of 3153 in 68962.3399014473 seconds
# Uploaded 2550 out of 3153 in 69116.25286221504 seconds
# Uploaded 2560 out of 3153 in 69490.96807360649 seconds
# Uploaded 2570 out of 3153 in 70096.96745109558 seconds
# Uploaded 2580 out of 3153 in 70280.70888137817 seconds
# Uploaded 2590 out of 3153 in 70575.14384794235 seconds
# Uploaded 2600 out of 3153 in 70706.14589691162 seconds
# Uploaded 2610 out of 3153 in 70987.78768181801 seconds
# Uploaded 2620 out of 3153 in 71148.48922300339 seconds
# Uploaded 2630 out of 3153 in 71375.05768537521 seconds
# Uploaded 2640 out of 3153 in 71755.42091941833 seconds
# Uploaded 2650 out of 3153 in 71948.25728559494 seconds
# Uploaded 2660 out of 3153 in 72619.05767536163 seconds
# Uploaded 2670 out of 3153 in 72873.00998687744 seconds
# Uploaded 2680 out of 3153 in 73081.08876895905 seconds
# Uploaded 2690 out of 3153 in 73284.00998926163 seconds
# Uploaded 2700 out of 3153 in 73436.1692082882 seconds
# Uploaded 2710 out of 3153 in 73640.09925436974 seconds
# Uploaded 2720 out of 3153 in 74297.71126031876 seconds
# Uploaded 2730 out of 3153 in 74552.27902698517 seconds
# Uploaded 2740 out of 3153 in 74961.67665171623 seconds
# Uploaded 2750 out of 3153 in 75195.3839211464 seconds
# Uploaded 2760 out of 3153 in 75302.67149090767 seconds
# Uploaded 2770 out of 3153 in 75671.35061264038 seconds
# Uploaded 2780 out of 3153 in 76121.69893693924 seconds
# Uploaded 2790 out of 3153 in 76484.82541704178 seconds
# Uploaded 2800 out of 3153 in 76719.71987247467 seconds
# Uploaded 2810 out of 3153 in 77108.9545032978 seconds
# Uploaded 2820 out of 3153 in 77293.91764783859 seconds
# Uploaded 2830 out of 3153 in 77500.89822459221 seconds
# Uploaded 2840 out of 3153 in 77731.26519656181 seconds
# Uploaded 2850 out of 3153 in 78081.23227930069 seconds
# Uploaded 2860 out of 3153 in 78419.22593641281 seconds
# Uploaded 2870 out of 3153 in 78624.09065270424 seconds
# Uploaded 2880 out of 3153 in 78814.34637951851 seconds
# Uploaded 2890 out of 3153 in 79086.0190217495 seconds
# Uploaded 2900 out of 3153 in 79376.18301868439 seconds
# Uploaded 2910 out of 3153 in 79587.11325263977 seconds
# Uploaded 2920 out of 3153 in 80241.65877246857 seconds
# Uploaded 2930 out of 3153 in 80442.46470713615 seconds
# Uploaded 2940 out of 3153 in 80586.6718609333 seconds
# Uploaded 2950 out of 3153 in 80835.32601833344 seconds
# Uploaded 2960 out of 3153 in 81094.80186533928 seconds
# Uploaded 2970 out of 3153 in 81336.29948973656 seconds
# Uploaded 2980 out of 3153 in 81651.81540513039 seconds
# Uploaded 2990 out of 3153 in 81921.26418972015 seconds
# Uploaded 3000 out of 3153 in 82228.8813560009 seconds
# Uploaded 3010 out of 3153 in 82587.12551426888 seconds
# Uploaded 3020 out of 3153 in 82709.39424443245 seconds
# Uploaded 3030 out of 3153 in 82841.41821813583 seconds
# Uploaded 3040 out of 3153 in 83045.0291492939 seconds
# Uploaded 3050 out of 3153 in 83294.7409427166 seconds
# Uploaded 3060 out of 3153 in 83551.46931791306 seconds
# Uploaded 3070 out of 3153 in 83785.86431312561 seconds
# Uploaded 3080 out of 3153 in 83965.46123981476 seconds
# Uploaded 3090 out of 3153 in 84089.87396073341 seconds
# Uploaded 3100 out of 3153 in 84343.7827591896 seconds
# Uploaded 3110 out of 3153 in 84558.40801215172 seconds
# Uploaded 3120 out of 3153 in 84663.9310555458 seconds
# Uploaded 3130 out of 3153 in 84770.57894515991 seconds
# Uploaded 3140 out of 3153 in 84930.43635368347 seconds
# Uploaded 3150 out of 3153 in 85022.94851279259 seconds

# %% [markdown]
# Now I have commited the script file. Lets test that it works from hugging face.

# %%
from datasets import load_dataset
grnvox_test = load_dataset('johno-grn/grnvox_test', 'seg_10sec', languages=['aad', 'aac'])
# Out:
# Downloading builder script:   0%|          | 0.00/28.9k [00:00<?, ?B/s]
# Using custom data configuration seg_10sec-6ede14c4d3193064
# Downloading and preparing dataset grnvox_test/seg_10sec to /home/jovyan/.cache/huggingface/datasets/johno-grn___grnvox_test/seg_10sec-6ede14c4d3193064/0.0.0/8ddc29269740b672479647faf8981fe5eab5f08d1c231872b740e80d869b8065...
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset grnvox_test downloaded and prepared to /home/jovyan/.cache/huggingface/datasets/johno-grn___grnvox_test/seg_10sec-6ede14c4d3193064/0.0.0/8ddc29269740b672479647faf8981fe5eab5f08d1c231872b740e80d869b8065. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
import IPython.display as ipd
ipd.Audio(data=grnvox_test['train'][2]['audio']['array'], rate=grnvox_test['train'][0]['audio']['sampling_rate'])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
grnvox_test.cleanup_cache_files()
# Out:
# {'train': 0}

# %%
# read the file back using the web address
import requests

url = 'https://grn-media.s3.amazonaws.com/archives/seg_4sec/vox_grn_4sec_csv.tar.gz'
r = requests.get(url, allow_redirects=True)

# %%
s3 = boto3.resource('s3',                        
                    region_name='us-east-1',
                    aws_access_key_id=access_key,
                    aws_secret_access_key=secret)
bucket = s3.Bucket('grn-media')

# %% [markdown]
# We need to find if all the files were uploaded correctly.

# %%
import datetime
e = datetime.datetime.now()
t_obj = list(bucket.objects.filter(Prefix='archives/seg_6sec/data'))
print(f'Processed {len(list(t_obj))} at {e.hour:02d}:{e.minute:02d}:{e.second:02d}')
# Out:
# Processed 1930 at 10:54:09

# %%
e = datetime.datetime.now()
t_obj = list(bucket.objects.filter(Prefix='archives/seg_10sec/data'))
print(f'Processed {len(list(t_obj))} at {e.hour:02d}:{e.minute:02d}:{e.second:02d}')
# Out:
# Processed 1875 at 10:54:27

# %%
print(t_obj[110])
# Out:
# s3.ObjectSummary(bucket_name='grn-media', key='archives/seg_4sec/data/vox_grn_4sec_gvn.tar.gz')

# %%
print(grnvox_test['train'][0]['iso'])
# Out:
# gvn

# %%
print(grnvox_test['train'].features)
# Out:
# {'file': Value(dtype='string', id=None), 'audio': Audio(sampling_rate=16000, mono=True, decode=True, id=None), 'iso': Value(dtype='string', id=None), 'program': Value(dtype='string', id=None), 'location': Value(dtype='string', id=None), 'item_no': Value(dtype='string', id=None), 'title': Value(dtype='string', id=None), 'item_start': Value(dtype='float32', id=None), 'item_end': Value(dtype='float32', id=None), 'seg_start': Value(dtype='float32', id=None), 'seg_end': Value(dtype='float32', id=None), 'seg': Value(dtype='int32', id=None)}
