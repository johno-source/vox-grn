# %% [markdown]
# # Segment GRN data using pyAudioAnalysis
#
# The group of notebooks SegmentPyVOXn.ipynb (n=0-9) will be used to segment the data using the segmentation algorithm I developed in DevelopASSegmentation.ipynb. It follows the same pattern as used in SegmentFVOXn.ipynb.
#
# # Data to be Created
#
# Three sets of data will be made, 4, 6, and 10 second data.
#
# This file will take a long time to run. For that reason it will check point its progress at regular intervals by writing smaller files. If its progress is restarted for any reason it will use those files to determine where it was up to. Segmenting the data is the slow part. For each audio file a segment file will be generated. If mp3 files are to be generated later using different parameters the segmented files should make the process much quicker.
#
# The input to this process is the same as SegmentFVOX.ipynb. We actually use its division of the files into 10 groups.
#
# The output will be:
#
#     1. /media/originals/py_audio_seg/[iso]/[filename].pkl
#         where each pkl file contains the list of raw segments for the item.
#     2. /media/originals/py_audio_seg/seg_4sec.csv
#         all the metadata for the seg_4sec dataset. Metadata needed for the dataset can be derived from this.
#     3. /media/originals/py_audio_seg/seg_6sec.csv
#         all the metadata for the seg_6sec dataset. Metadata needed for the dataset can be derived from this.
#     4. /media/originals/py_audio_seg/seg_10sec.csv
#         all the metadata for the seg_10sec dataset. Metadata needed for the dataset can be derived from this.
#     5. /media/originals/datasets/py_audio_seg_4sec/data/[iso]/[program_id]_[item_no]_[seg].mp3
#         which is an mp3 for each segment
#     6. /media/originals/datasets/py_audio_seg_6sec/data/[iso]/[program_id]_[item_no]_[seg].mp3
#         which is an mp3 for each segment
#     7. /media/originals/datasets/py_audio_seg_10sec/data/[iso]/[program_id]_[item_no]_[seg].mp3
#         which is an mp3 for each segment

# %%
import pandas as pd
import numpy as np
import os
import sys
import time
import pickle as pkl
from pathlib import Path
import glob

module_path = os.path.abspath(os.path.join('~/work/pyAudioAnalysis'))
if module_path not in sys.path:
    sys.path.append(module_path)
from collections import namedtuple
from pydub import AudioSegment

from pyAudioAnalysis import audioSegmentation as aS
from pyAudioAnalysis import audioTrainTest as at
from pyAudioAnalysis import MidTermFeatures as mtf
from pyAudioAnalysis import audioBasicIO as aIO

# %%
# define the locations for each of the file types
NOTEBOOK_ID=7
SEGMENTS_DIR = '/media/originals/py_audio_seg/'
DATASETS_DIR = '/media/originals/datasets/'
SEC_4_DATA_DIR = 'py_audio_seg_4sec/data/'
SEC_6_DATA_DIR = 'py_audio_seg_6sec/data/'
SEC_10_DATA_DIR = 'py_audio_seg_10sec/data/'

# define specific files used in the process
SEG_4_SEC_DF = f'{SEGMENTS_DIR}seg_4sec_{NOTEBOOK_ID}.csv'
SEG_6_SEC_DF = f'{SEGMENTS_DIR}seg_6sec_{NOTEBOOK_ID}.csv'
SEG_10_SEC_DF = f'{SEGMENTS_DIR}seg_10sec_{NOTEBOOK_ID}.csv'

# define segment sizes for each dataset
SEG_4_SEC = 4.0
SEG_6_SEC = 6.0
SEG_10_SEC = 10.0

SAMPLING_RATE = 16000

def convert_to_ms(sec):
    return int(sec*1000.0)

# %%
# Now read in the description of the input and remove the unwanted columns and rename the rest to be python attribute names.
fd = pd.read_csv(f'/media/originals/fsegs/files_{NOTEBOOK_ID}.csv')
fd.set_index('ID', inplace=True)
fd.columns
# Out:
# Index(['Unnamed: 0', 'iso', 'language_name', 'track', 'location', 'year',
#        'path', 'filename', 'length', 'program'],
#       dtype='object')

# %%
# augment the fd with 1/3 of files 9
fd9 = pd.read_csv(f'/media/originals/fsegs/files_9.csv')
fd9.set_index('ID', inplace=True)
print(len(fd9))
# Out:
# 20841

# %%
third = int(len(fd9)/3)
fd = pd.concat([fd, fd9.iloc[third:2*third]])

# %%
print(fd.iloc[100])
# Out:
# Unnamed: 0                                   70361
# iso                                            raw
# language_name                               Rawang
# track                                           29
# location                                    Yangon
# year                                        2005.0
# path             Programs/62/62595/A62595/PM-0603/
# filename                             A62595-29.wav
# length                                   48.413333
# program                                      62595
# Name: 62595_029, dtype: object

# %%
print(fd.index)
# Out:
# Index(['37914_039', '37914_038', '37914_030', '37914_031', '37914_032',
#        '37914_033', '37914_034', '37914_035', '37914_036', '37914_020',
#        ...
#        '38296_010', '38296_011', '38296_012', '38296_007', '38296_006',
#        '38296_005', '38296_004', '12390_001', '12390_002', '12390_003'],
#       dtype='object', name='ID', length=27784)

# %%
# generate directories and filenames
def prepare_dir(dirname):
    if dirname[-1] != '/':
        dirname = dirname + '/'
    Path(dirname).mkdir(parents=True, exist_ok=True)
    return dirname

def prepare_raw_seg_dir(fd):
    return prepare_dir(SEGMENTS_DIR + fd.iso)

def raw_seg_filename(fd):
    return f'{fd.filename}.pkl'

def prepare_dataset_data_dir(fd, dataset_dir):
    return prepare_dir(DATASETS_DIR + dataset_dir + fd.iso)

def seg_mp3_filename(fd, seg):
    return f'{fd.filename[:-4]}_{seg:03d}.mp3'

def get_fname(fd):
    path = fd.path
    if path[-1] != '/':
        path = path + '/'
    files = glob.glob('/media/programs/' + path + fd.filename.replace('\ufffd', '*'))
    if len(files) == 1:
        return files[0]
    return '/media/programs/' + path + fd.filename

# %%
def condition_audio_segment(audio_seg):
    if audio_seg.channels != 1:
        audio_seg = audio_seg.set_channels(1)

    if audio_seg.sample_width != 2:
        audio_seg = audio_seg.set_sample_width(2)

    if audio_seg.frame_rate != SAMPLING_RATE:
        audio_seg = audio_seg.set_frame_rate(SAMPLING_RATE)
    return audio_seg

# %%
import warnings
# sklearn puts out a lot of annoying warnings
warnings.filterwarnings('ignore')

Segment = namedtuple('Segment', ['start', 'end', 'classification'])

# re-implement a simplified version of mid_term_file_classification
# it is implemented as a class to allow the model to be cached.
class ExtractVoiceSegments():
    classifier, mean, std, class_names, mt_win, mid_step, st_win, \
         st_step, compute_beat = at.load_model('/home/jovyan/work/pyAudioAnalysis/pyAudioAnalysis/data/models/svm_rbf_4class')

    def __init__(self):
        pass

    def segments_in(self, signal, sampling_rate, offset):
        labels = []

        # mid-term feature extraction:
        mt_feats, _, _ = \
            mtf.mid_feature_extraction(signal, sampling_rate,
                                    ExtractVoiceSegments.mt_win * sampling_rate,
                                    ExtractVoiceSegments.mid_step * sampling_rate,
                                    round(sampling_rate * ExtractVoiceSegments.st_win),
                                    round(sampling_rate * ExtractVoiceSegments.st_step))

        # for each feature vector (i.e. for each fix-sized segment):
        for col_index in range(mt_feats.shape[1]):
            # normalize current feature v
            feature_vector = (mt_feats[:, col_index] - ExtractVoiceSegments.mean) / ExtractVoiceSegments.std

            # classify vector:
            label_predicted, _ = \
                at.classifier_wrapper(ExtractVoiceSegments.classifier, 'svm', feature_vector)
            labels.append(label_predicted)

        segs, classes = aS.labels_to_segments(labels, ExtractVoiceSegments.mid_step)
        # there is a bug in labels to segments when there is a single label. In this case it returns a list rather than a list of lists
        if len(labels) == 1:
            segs = [].append(segs)
        return [] if segs is None else [Segment(seg[0]+offset, seg[1]+offset, ExtractVoiceSegments.class_names[int(label)]) for seg, label in zip(segs, classes)]



"""
This function performs mid-term classification of an audio stream.
Towards this end, supervised knowledge is used,
i.e. a pre-trained classifier.
ARGUMENTS:
    - input_file:        path of the input WAV/mp3 file
RETURNS:
    - list of Segments (see above tuple)
"""
def extract_voice_segments(input_file, *, __extract_voice_segments=ExtractVoiceSegments()):
    segments = []

    # load input file
    sampling_rate, signal = aIO.read_audio_file(input_file)

    # could not read file
    if sampling_rate == 0:
        return segments

    # convert stereo (if) to mono
    signal = aIO.stereo_to_mono(signal)

    # find the silence segments
    non_silent_segments = aS.silence_removal(signal, sampling_rate, 0.02, 0.02, smooth_window=1.0, weight=0.3)

    # work through each segment
    for seg in non_silent_segments:
        start = int(seg[0]*sampling_rate)
        stop = int(seg[1]*sampling_rate)
        sig = signal[start:stop]

        segments.extend(__extract_voice_segments.segments_in(signal[start:stop], sampling_rate, seg[0]))

    return segments

# %%
Epoch = namedtuple('Epoch', ['start', 'end'])
def speech_epochs_from_segments(segments, epoch_length=4.0, silence_tolerance=0.0):
    epochs = []
    i = 0
    silence_this_epoch = silence_tolerance
    while i < len(segments):
        seg_duration = segments[i].end - segments[i].start
        if segments[i].classification != 'speech':
            silence_this_epoch = silence_tolerance

        elif seg_duration >= epoch_length:
            epochs.append(Epoch(segments[i].start, segments[i].start+epoch_length))
            silence_this_epoch = silence_tolerance
            # process the same segment again with a smaller size
            new_start = segments[i].start+epoch_length
            new_end = segments[i].end
            if new_start < new_end:
                segments[i] = Segment(new_start, new_end, segments[i].classification)
                continue
        else:
            if i+1 < len(segments):
                if (segments[i].end + silence_this_epoch) >= segments[i+1].start and segments[i+1].classification == 'speech':
                    # did we use up any silence tolerence
                    if segments[i].end < segments[i+1].start:
                        silence_this_epoch -= (segments[i+1].start - segments[i].end)
                    segments[i+1] = Segment(segments[i].start, segments[i+1].end, segments[i].classification)
                else:
                    silence_this_epoch = silence_tolerance

        i+=1

    return epochs

# %%
def save_the_segment_info(fd, segs):
    fname = prepare_raw_seg_dir(fd) + raw_seg_filename(fd)
    with open(fname, 'wb') as pklFile:
         pkl.dump(segs, pklFile)

def read_the_segment_info(fd):
    fname = prepare_raw_seg_dir(fd) + raw_seg_filename(fd)
    if os.path.exists(fname):
        if os.path.getsize(fname) > 0:
            with open(fname, 'rb') as pklFile:
                return pkl.load(pklFile)
    return []
    
def update_dataframes(seg_df_csv, seg_records):
    # now update the dataframes
    if len(seg_records) > 0:
        if os.path.isfile(seg_df_csv):
            seg_sec_df = pd.concat([pd.read_csv(seg_df_csv, index_col='file_name'), pd.DataFrame.from_records(seg_records, index='file_name')])
        else:
            seg_sec_df = pd.DataFrame.from_records(seg_records, index='file_name')
        seg_sec_df.to_csv(seg_df_csv)

# %%
def extract_audio_segments_for_file(fd):
    fmt = 'wav'
    if fd.filename[-4:].lower() == '.mp3' :
        fmt = 'mp3'
    audio_seg = AudioSegment.from_file(get_fname(fd), format=fmt)

    # now condition the segment and extract the raw segments.
    audio_seg = condition_audio_segment(audio_seg)
    segs = read_the_segment_info(fd)
    if len(segs) == 0:
        segs = extract_voice_segments(get_fname(fd))
        save_the_segment_info(fd, segs)

    return audio_seg, segs


def create_mp3_files(audio_seg, segs, time_per_segment, dataset_dir, fd):
    epochs_for_time = speech_epochs_from_segments(segs, epoch_length=time_per_segment, silence_tolerance=time_per_segment/4.0)

    # now write out the 4 sec segments
    dirname = prepare_dataset_data_dir(fd, dataset_dir)
    rows = list()

    for i, seg in enumerate(epochs_for_time):
        file_name = dataset_dir + fd.iso + '/' + seg_mp3_filename(fd, i)
        fname = dirname + seg_mp3_filename(fd, i)
        start = convert_to_ms(seg.start)
        stop = convert_to_ms(seg.end)
        if not os.path.exists(fname):
            audio_seg[start:stop].export(fname, format='mp3', bitrate='32k')
        desc = dict(fd._asdict())
        desc['seg_start'] = start
        desc['seg_stop'] = stop
        desc['seg'] = i
        desc['file_name'] = file_name
        rows.append(desc)

    return rows

# %%
# processing these items might take a very long time. To permit the process to be interrupted and restarted the indexes of processed items
# are maintained in a set that is pickled on each batch. This allows the batch to quickly pick up where it left off.
def process_record_batch(files_df, *, batch_size=10):
    batch_proc = 0
    processed_file = f'{SEGMENTS_DIR}processed16_{NOTEBOOK_ID}.pkl'
    if os.path.isfile(processed_file):
        with open(processed_file, 'rb') as pklFile:
            processed_files = pkl.load(pklFile)
    else:
        processed_files = set()

    segmented_4sec_segs = []
    segmented_6sec_segs = []
    segmented_10sec_segs = []

    for fd in files_df.itertuples():
        if batch_proc < batch_size:
            if fd.Index not in processed_files:
                try:
                    audio_seg, voice_segs = extract_audio_segments_for_file(fd)

                    segmented_4sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_4_SEC, SEC_4_DATA_DIR, fd))
                    segmented_6sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_6_SEC, SEC_6_DATA_DIR, fd))
                    segmented_10sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_10_SEC, SEC_10_DATA_DIR, fd))
                except:
                    print(f'exception {fd.filename}')
                    pass

                # we want to add an fd that has an exception so it is not reprocessed on every batch
                processed_files.add(fd.Index)
                batch_proc += 1

        else:
            break

    update_dataframes(SEG_4_SEC_DF, segmented_4sec_segs)
    update_dataframes(SEG_6_SEC_DF, segmented_6sec_segs)
    update_dataframes(SEG_10_SEC_DF, segmented_10sec_segs)

    with open(processed_file, 'wb') as pklFile:
        pkl.dump(processed_files, pklFile)

    return processed_files

# %%
def format_time(seconds):
    hours, remainder = divmod(int(seconds), 3600)
    minutes, seconds = divmod(remainder, 60)
    return f"{hours:02}:{minutes:02}:{seconds:02}"

start_time = time.time()
# form the language classification file
files_processed = 0
files_to_process = len(fd)
while files_to_process > files_processed:
    processed_files = process_record_batch(fd, batch_size=20)
    files_processed = len(processed_files)
    print(f'Processed {files_processed} out of {files_to_process} in {format_time(time.time()-start_time)}')
# Out:
# Processed 9840 out of 27784 in 00:02:33
# Processed 9860 out of 27784 in 00:05:36
# Processed 9880 out of 27784 in 00:09:09
# Processed 9900 out of 27784 in 00:12:17
# Processed 9920 out of 27784 in 00:20:44
# Processed 9940 out of 27784 in 00:24:53
# Processed 9960 out of 27784 in 00:27:49
# Processed 9980 out of 27784 in 00:31:47
# Processed 10000 out of 27784 in 00:36:40
# Processed 10020 out of 27784 in 00:41:53
# Processed 10040 out of 27784 in 00:44:54
# Processed 10060 out of 27784 in 00:48:30
# Processed 10080 out of 27784 in 00:51:45
# Processed 10100 out of 27784 in 00:54:22
# Processed 10120 out of 27784 in 00:57:32
# Processed 10140 out of 27784 in 01:02:13
# Processed 10160 out of 27784 in 01:05:34
# Processed 10180 out of 27784 in 01:09:27
# Processed 10200 out of 27784 in 01:14:25
# Processed 10220 out of 27784 in 01:20:48
# Processed 10240 out of 27784 in 01:51:23
# Processed 10260 out of 27784 in 01:56:17
# Processed 10280 out of 27784 in 02:04:28
# Processed 10300 out of 27784 in 02:12:10
# Processed 10320 out of 27784 in 02:18:43
# Processed 10340 out of 27784 in 02:23:45
# Processed 10360 out of 27784 in 02:31:29
# Processed 10380 out of 27784 in 02:33:11
# Processed 10400 out of 27784 in 02:38:51
# Processed 10420 out of 27784 in 02:45:25
# Processed 10440 out of 27784 in 02:51:35
# Processed 10460 out of 27784 in 02:55:07
# Processed 10480 out of 27784 in 02:58:36
# Processed 10500 out of 27784 in 03:02:15
# Processed 10520 out of 27784 in 03:06:02
# Processed 10540 out of 27784 in 03:09:23
# Processed 10560 out of 27784 in 03:12:49
# Processed 10580 out of 27784 in 03:15:42
# Processed 10600 out of 27784 in 03:22:53
# Processed 10620 out of 27784 in 03:30:30
# Processed 10640 out of 27784 in 03:41:08
# Processed 10660 out of 27784 in 03:44:47
# Processed 10680 out of 27784 in 03:47:29
# Processed 10700 out of 27784 in 03:50:53
# Processed 10720 out of 27784 in 03:54:16
# Processed 10740 out of 27784 in 04:03:36
# Processed 10760 out of 27784 in 04:06:39
# Processed 10780 out of 27784 in 04:09:22
# Processed 10800 out of 27784 in 04:13:02
# Processed 10820 out of 27784 in 04:16:55
# Processed 10840 out of 27784 in 04:21:50
# Processed 10860 out of 27784 in 04:25:12
# Processed 10880 out of 27784 in 04:29:24
# Processed 10900 out of 27784 in 04:33:27
# Processed 10920 out of 27784 in 04:37:40
# Processed 10940 out of 27784 in 04:44:48
# Processed 10960 out of 27784 in 04:48:56
# Processed 10980 out of 27784 in 04:51:59
# Processed 11000 out of 27784 in 05:02:26
# Processed 11020 out of 27784 in 05:05:16
# Processed 11040 out of 27784 in 05:08:35
# Processed 11060 out of 27784 in 05:11:52
# Processed 11080 out of 27784 in 05:14:59
# Processed 11100 out of 27784 in 05:24:46
# Processed 11120 out of 27784 in 05:28:21
# Processed 11140 out of 27784 in 05:32:02
# Processed 11160 out of 27784 in 05:36:29
# Processed 11180 out of 27784 in 05:46:46
# Processed 11200 out of 27784 in 05:53:06
# Processed 11220 out of 27784 in 05:55:21
# Processed 11240 out of 27784 in 06:02:21
# Processed 11260 out of 27784 in 06:06:41
# Processed 11280 out of 27784 in 06:15:18
# Processed 11300 out of 27784 in 06:20:39
# Processed 11320 out of 27784 in 06:27:41
# Processed 11340 out of 27784 in 06:30:03
# Processed 11360 out of 27784 in 06:35:43
# Processed 11380 out of 27784 in 06:38:20
# Processed 11400 out of 27784 in 06:41:03
# Processed 11420 out of 27784 in 06:43:31
# Processed 11440 out of 27784 in 06:44:44
# Processed 11460 out of 27784 in 06:51:45
# Processed 11480 out of 27784 in 06:53:43
# Processed 11500 out of 27784 in 06:57:04
# Processed 11520 out of 27784 in 06:59:22
# Processed 11540 out of 27784 in 07:02:20
# Processed 11560 out of 27784 in 07:13:58
# Processed 11580 out of 27784 in 07:22:29
# Processed 11600 out of 27784 in 07:26:45
# Processed 11620 out of 27784 in 07:30:14
# Processed 11640 out of 27784 in 07:35:26
# Processed 11660 out of 27784 in 07:38:45
# Processed 11680 out of 27784 in 07:42:17
# Processed 11700 out of 27784 in 07:45:38
# Processed 11720 out of 27784 in 07:49:06
# Processed 11740 out of 27784 in 07:51:50
# Processed 11760 out of 27784 in 07:54:51
# Processed 11780 out of 27784 in 07:58:36
# Processed 11800 out of 27784 in 08:03:01
# Processed 11820 out of 27784 in 08:05:53
# Processed 11840 out of 27784 in 08:08:34
# Processed 11860 out of 27784 in 08:11:38
# Processed 11880 out of 27784 in 08:14:35
# Processed 11900 out of 27784 in 08:17:36
# Processed 11920 out of 27784 in 08:24:16
# Processed 11940 out of 27784 in 08:29:32
# Processed 11960 out of 27784 in 08:46:13
# Processed 11980 out of 27784 in 08:48:23
# Processed 12000 out of 27784 in 08:54:53
# Processed 12020 out of 27784 in 08:59:43
# Processed 12040 out of 27784 in 09:06:22
# Processed 12060 out of 27784 in 09:10:13
# Processed 12080 out of 27784 in 09:12:48
# Processed 12100 out of 27784 in 09:15:18
# Processed 12120 out of 27784 in 09:18:41
# Processed 12140 out of 27784 in 09:22:46
# Processed 12160 out of 27784 in 09:27:18
# Processed 12180 out of 27784 in 09:31:19
# Processed 12200 out of 27784 in 09:33:51
# Processed 12220 out of 27784 in 09:38:40
# Processed 12240 out of 27784 in 09:46:46
# Processed 12260 out of 27784 in 09:50:43
# Processed 12280 out of 27784 in 09:56:06
# Processed 12300 out of 27784 in 10:01:13
# Processed 12320 out of 27784 in 10:11:27
# Processed 12340 out of 27784 in 10:13:39
# Processed 12360 out of 27784 in 10:16:43
# Processed 12380 out of 27784 in 10:22:24
# Processed 12400 out of 27784 in 10:26:28
# Processed 12420 out of 27784 in 10:29:53
# Processed 12440 out of 27784 in 10:32:57
# Processed 12460 out of 27784 in 10:35:40
# Processed 12480 out of 27784 in 10:38:37
# Processed 12500 out of 27784 in 10:41:48
# Processed 12520 out of 27784 in 10:51:29
# Processed 12540 out of 27784 in 10:55:37
# Processed 12560 out of 27784 in 10:57:54
# Processed 12580 out of 27784 in 11:00:15
# Processed 12600 out of 27784 in 11:02:06
# Processed 12620 out of 27784 in 11:04:10
# Processed 12640 out of 27784 in 11:06:25
# Processed 12660 out of 27784 in 11:08:43
# Processed 12680 out of 27784 in 11:10:57
# Processed 12700 out of 27784 in 11:17:00
# Processed 12720 out of 27784 in 11:20:37
# Processed 12740 out of 27784 in 11:24:48
# Processed 12760 out of 27784 in 11:31:05
# Processed 12780 out of 27784 in 11:33:32
# Processed 12800 out of 27784 in 11:35:46
# Processed 12820 out of 27784 in 11:38:40
# Processed 12840 out of 27784 in 11:40:55
# Processed 12860 out of 27784 in 11:46:58
# Processed 12880 out of 27784 in 11:49:14
# Processed 12900 out of 27784 in 11:51:04
# Processed 12920 out of 27784 in 11:53:06
# Processed 12940 out of 27784 in 11:54:41
# Processed 12960 out of 27784 in 11:56:17
# Processed 12980 out of 27784 in 11:58:03
# Processed 13000 out of 27784 in 12:00:00
# Processed 13020 out of 27784 in 12:04:03
# Processed 13040 out of 27784 in 12:07:55
# Processed 13060 out of 27784 in 12:10:09
# Processed 13080 out of 27784 in 12:12:06
# Processed 13100 out of 27784 in 12:14:16
# Processed 13120 out of 27784 in 12:34:17
# Processed 13140 out of 27784 in 12:39:36
# Processed 13160 out of 27784 in 12:41:36
# Processed 13180 out of 27784 in 12:53:00
# Processed 13200 out of 27784 in 13:05:01
# Processed 13220 out of 27784 in 13:07:26
# Processed 13240 out of 27784 in 13:12:23
# Processed 13260 out of 27784 in 13:15:36
# Processed 13280 out of 27784 in 13:18:40
# Processed 13300 out of 27784 in 13:26:14
# Processed 13320 out of 27784 in 13:31:45
# Processed 13340 out of 27784 in 13:33:01
# Processed 13360 out of 27784 in 13:36:38
# Processed 13380 out of 27784 in 13:40:31
# Processed 13400 out of 27784 in 13:44:24
# Processed 13420 out of 27784 in 13:48:25
# Processed 13440 out of 27784 in 13:52:25
# Processed 13460 out of 27784 in 13:56:32
# Processed 13480 out of 27784 in 14:00:59
# Processed 13500 out of 27784 in 14:05:20
# Processed 13520 out of 27784 in 14:09:49
# Processed 13540 out of 27784 in 14:15:26
# Processed 13560 out of 27784 in 14:21:11
# Processed 13580 out of 27784 in 14:25:08
# Processed 13600 out of 27784 in 14:28:50
# Processed 13620 out of 27784 in 14:32:05
# Processed 13640 out of 27784 in 14:35:47
# Processed 13660 out of 27784 in 14:39:13
# Processed 13680 out of 27784 in 14:43:35
# Processed 13700 out of 27784 in 14:47:12
# Processed 13720 out of 27784 in 14:50:56
# Processed 13740 out of 27784 in 14:53:54
# Processed 13760 out of 27784 in 15:00:08
# Processed 13780 out of 27784 in 15:08:28
# Processed 13800 out of 27784 in 15:13:37
# Processed 13820 out of 27784 in 15:16:19
# Processed 13840 out of 27784 in 15:26:07
# Processed 13860 out of 27784 in 15:29:45
# Processed 13880 out of 27784 in 15:34:49
# Processed 13900 out of 27784 in 15:39:45
# Processed 13920 out of 27784 in 15:42:09
# Processed 13940 out of 27784 in 15:45:06
# Processed 13960 out of 27784 in 15:47:01
# Processed 13980 out of 27784 in 15:48:55
# Processed 14000 out of 27784 in 15:52:58
# Processed 14020 out of 27784 in 15:55:31
# Processed 14040 out of 27784 in 15:57:33
# Processed 14060 out of 27784 in 15:59:48
# Processed 14080 out of 27784 in 16:02:54
# Processed 14100 out of 27784 in 16:04:11
# Processed 14120 out of 27784 in 16:10:23
# Processed 14140 out of 27784 in 16:17:42
# Processed 14160 out of 27784 in 16:20:26
# Processed 14180 out of 27784 in 16:23:01
# Processed 14200 out of 27784 in 16:26:27
# Processed 14220 out of 27784 in 16:30:11
# Processed 14240 out of 27784 in 16:32:39
# Processed 14260 out of 27784 in 16:34:50
# Processed 14280 out of 27784 in 16:37:14
# Processed 14300 out of 27784 in 16:43:01
# Processed 14320 out of 27784 in 16:45:22
# Processed 14340 out of 27784 in 16:48:07
# Processed 14360 out of 27784 in 16:50:33
# Processed 14380 out of 27784 in 16:52:34
# Processed 14400 out of 27784 in 16:55:36
# Processed 14420 out of 27784 in 16:58:07
# Processed 14440 out of 27784 in 17:00:33
# Processed 14460 out of 27784 in 17:10:23
# Processed 14480 out of 27784 in 17:14:14
# Processed 14500 out of 27784 in 17:17:50
# Processed 14520 out of 27784 in 17:20:09
# Processed 14540 out of 27784 in 17:22:18
# Processed 14560 out of 27784 in 17:25:22
# Processed 14580 out of 27784 in 17:29:13
# Processed 14600 out of 27784 in 17:31:28
# Processed 14620 out of 27784 in 17:35:05
# Processed 14640 out of 27784 in 17:39:33
# Processed 14660 out of 27784 in 17:43:59
# Processed 14680 out of 27784 in 17:49:21
# Processed 14700 out of 27784 in 17:57:26
# Processed 14720 out of 27784 in 18:06:25
# Processed 14740 out of 27784 in 18:14:03
# Processed 14760 out of 27784 in 18:16:02
# Processed 14780 out of 27784 in 18:22:17
# Processed 14800 out of 27784 in 18:33:58
# Processed 14820 out of 27784 in 18:50:17
# Processed 14840 out of 27784 in 19:24:18
# Processed 14860 out of 27784 in 19:33:38
# Processed 14880 out of 27784 in 19:41:41
# Processed 14900 out of 27784 in 19:50:26
# Processed 14920 out of 27784 in 20:00:27
# Processed 14940 out of 27784 in 20:09:03
# Processed 14960 out of 27784 in 20:20:28
# Processed 14980 out of 27784 in 20:22:47
# Processed 15000 out of 27784 in 20:26:31
# Processed 15020 out of 27784 in 20:28:34
# Processed 15040 out of 27784 in 20:30:36
# Processed 15060 out of 27784 in 20:35:05
# Processed 15080 out of 27784 in 20:39:43
# Processed 15100 out of 27784 in 20:44:38
# Processed 15120 out of 27784 in 20:49:25
# Processed 15140 out of 27784 in 20:53:50
# Processed 15160 out of 27784 in 20:58:20
# Processed 15180 out of 27784 in 21:02:26
# Processed 15200 out of 27784 in 21:08:36
# Processed 15220 out of 27784 in 21:15:24
# Processed 15240 out of 27784 in 21:21:26
# Processed 15260 out of 27784 in 21:26:12
# Processed 15280 out of 27784 in 21:33:05
# Processed 15300 out of 27784 in 21:37:18
# Processed 15320 out of 27784 in 21:40:28
# Processed 15340 out of 27784 in 21:44:27
# Processed 15360 out of 27784 in 21:52:55
# Processed 15380 out of 27784 in 21:57:56
# Processed 15400 out of 27784 in 22:02:20
# Processed 15420 out of 27784 in 22:10:24
# Processed 15440 out of 27784 in 22:21:19
# Processed 15460 out of 27784 in 22:29:49
# Processed 15480 out of 27784 in 22:37:56
# Processed 15500 out of 27784 in 22:46:06
# Processed 15520 out of 27784 in 22:54:05
# Processed 15540 out of 27784 in 23:00:33
# Processed 15560 out of 27784 in 23:07:11
# Processed 15580 out of 27784 in 23:15:18
# Processed 15600 out of 27784 in 23:24:40
# Processed 15620 out of 27784 in 23:32:28
# Processed 15640 out of 27784 in 23:38:34
# Processed 15660 out of 27784 in 23:43:26
# Processed 15680 out of 27784 in 23:50:16
# Processed 15700 out of 27784 in 23:59:54
# Processed 15720 out of 27784 in 24:03:21
# Processed 15740 out of 27784 in 24:06:58
# Processed 15760 out of 27784 in 24:12:09
# Processed 15780 out of 27784 in 24:18:02
# Processed 15800 out of 27784 in 24:22:51
# Processed 15820 out of 27784 in 24:26:08
# Processed 15840 out of 27784 in 24:30:21
# Processed 15860 out of 27784 in 24:33:41
# Processed 15880 out of 27784 in 24:37:16
# Processed 15900 out of 27784 in 24:41:05
# Processed 15920 out of 27784 in 24:44:26
# Processed 15940 out of 27784 in 24:54:21
# Processed 15960 out of 27784 in 24:57:47
# Processed 15980 out of 27784 in 25:00:34
# Processed 16000 out of 27784 in 25:02:57
# Processed 16020 out of 27784 in 25:06:14
# Processed 16040 out of 27784 in 25:09:25
# Processed 16060 out of 27784 in 25:12:21
# Processed 16080 out of 27784 in 25:15:57
# Processed 16100 out of 27784 in 25:19:30
# Processed 16120 out of 27784 in 25:24:57
# Processed 16140 out of 27784 in 25:30:22
# Processed 16160 out of 27784 in 25:40:55
# Processed 16180 out of 27784 in 25:45:53
# Processed 16200 out of 27784 in 25:50:09
# Processed 16220 out of 27784 in 25:55:02
# Processed 16240 out of 27784 in 25:58:50
# Processed 16260 out of 27784 in 26:00:49
# Processed 16280 out of 27784 in 26:03:27
# Processed 16300 out of 27784 in 26:06:23
# Processed 16320 out of 27784 in 26:11:21
# Processed 16340 out of 27784 in 26:16:01
# Processed 16360 out of 27784 in 26:27:36
# Processed 16380 out of 27784 in 26:30:27
# Processed 16400 out of 27784 in 26:37:00
# Processed 16420 out of 27784 in 26:44:07
# Processed 16440 out of 27784 in 26:46:41
# Processed 16460 out of 27784 in 26:51:21
# Processed 16480 out of 27784 in 26:57:21
# Processed 16500 out of 27784 in 27:03:30
# Processed 16520 out of 27784 in 27:09:01
# Processed 16540 out of 27784 in 27:14:02
# Processed 16560 out of 27784 in 27:16:30
# Processed 16580 out of 27784 in 27:20:09
# Processed 16600 out of 27784 in 27:24:10
# Processed 16620 out of 27784 in 27:26:07
# Processed 16640 out of 27784 in 27:27:44
# Processed 16660 out of 27784 in 27:29:52
# Processed 16680 out of 27784 in 27:34:54
# Processed 16700 out of 27784 in 27:37:55
# Processed 16720 out of 27784 in 27:40:15
# Processed 16740 out of 27784 in 27:42:22
# Processed 16760 out of 27784 in 27:44:12
# Processed 16780 out of 27784 in 27:46:32
# Processed 16800 out of 27784 in 27:48:32
# Processed 16820 out of 27784 in 27:50:48
# Processed 16840 out of 27784 in 27:54:01
# Processed 16860 out of 27784 in 27:55:34
# Processed 16880 out of 27784 in 27:57:29
# Processed 16900 out of 27784 in 27:59:44
# Processed 16920 out of 27784 in 28:01:59
# Processed 16940 out of 27784 in 28:04:41
# Processed 16960 out of 27784 in 28:07:20
# Processed 16980 out of 27784 in 28:12:32
# Processed 17000 out of 27784 in 28:15:28
# Processed 17020 out of 27784 in 28:17:46
# Processed 17040 out of 27784 in 28:20:03
# Processed 17060 out of 27784 in 28:26:53
# Processed 17080 out of 27784 in 28:31:33
# Processed 17100 out of 27784 in 28:38:12
# Processed 17120 out of 27784 in 28:42:26
# Processed 17140 out of 27784 in 28:46:19
# Processed 17160 out of 27784 in 28:51:34
# Processed 17180 out of 27784 in 28:56:23
# Processed 17200 out of 27784 in 29:02:58
# Processed 17220 out of 27784 in 29:13:23
# Processed 17240 out of 27784 in 29:21:59
# Processed 17260 out of 27784 in 29:28:21
# Processed 17280 out of 27784 in 29:37:49
# Processed 17300 out of 27784 in 29:43:55
# Processed 17320 out of 27784 in 29:53:18
# Processed 17340 out of 27784 in 29:56:03
# Processed 17360 out of 27784 in 30:01:10
# Processed 17380 out of 27784 in 30:06:19
# Processed 17400 out of 27784 in 30:11:09
# Processed 17420 out of 27784 in 30:17:23
# Processed 17440 out of 27784 in 30:19:50
# Processed 17460 out of 27784 in 30:23:54
# Processed 17480 out of 27784 in 30:28:22
# Processed 17500 out of 27784 in 30:34:55
# Processed 17520 out of 27784 in 30:38:37
# Processed 17540 out of 27784 in 30:42:55
# Processed 17560 out of 27784 in 30:45:09
# Processed 17580 out of 27784 in 30:47:30
# Processed 17600 out of 27784 in 30:50:01
# Processed 17620 out of 27784 in 30:57:29
# Processed 17640 out of 27784 in 31:37:36
# Processed 17660 out of 27784 in 31:59:44
# Processed 17680 out of 27784 in 32:11:33
# Processed 17700 out of 27784 in 32:15:56
# Processed 17720 out of 27784 in 32:18:56
# Processed 17740 out of 27784 in 32:27:08
# Processed 17760 out of 27784 in 32:35:16
# Processed 17780 out of 27784 in 32:40:09
# Processed 17800 out of 27784 in 32:43:33
# Processed 17820 out of 27784 in 32:50:30
# Processed 17840 out of 27784 in 32:59:01
# Processed 17860 out of 27784 in 33:03:12
# Processed 17880 out of 27784 in 33:07:10
# Processed 17900 out of 27784 in 33:24:37
# Processed 17920 out of 27784 in 33:31:06
# Processed 17940 out of 27784 in 33:36:53
# Processed 17960 out of 27784 in 33:40:08
# Processed 17980 out of 27784 in 33:43:14
# Processed 18000 out of 27784 in 33:48:46
# Processed 18020 out of 27784 in 33:51:53
# Processed 18040 out of 27784 in 33:55:00
# Processed 18060 out of 27784 in 33:57:18
# Processed 18080 out of 27784 in 33:59:09
# Processed 18100 out of 27784 in 34:07:47
# Processed 18120 out of 27784 in 34:13:25
# Processed 18140 out of 27784 in 34:18:33
# Processed 18160 out of 27784 in 34:21:27
# Processed 18180 out of 27784 in 34:24:10
# Processed 18200 out of 27784 in 34:27:31
# Processed 18220 out of 27784 in 34:30:07
# Processed 18240 out of 27784 in 34:32:09
# Processed 18260 out of 27784 in 34:34:25
# Processed 18280 out of 27784 in 34:38:24
# Processed 18300 out of 27784 in 34:41:29
# Processed 18320 out of 27784 in 34:44:44
# Processed 18340 out of 27784 in 34:47:45
# Processed 18360 out of 27784 in 34:51:05
# Processed 18380 out of 27784 in 34:54:38
# Processed 18400 out of 27784 in 34:57:34
# Processed 18420 out of 27784 in 35:00:12
# Processed 18440 out of 27784 in 35:04:22
# Processed 18460 out of 27784 in 35:08:47
# Processed 18480 out of 27784 in 35:11:42
# Processed 18500 out of 27784 in 35:14:25
# Processed 18520 out of 27784 in 35:18:06
# Processed 18540 out of 27784 in 35:20:36
# Processed 18560 out of 27784 in 35:22:41
# Processed 18580 out of 27784 in 35:30:45
# Processed 18600 out of 27784 in 35:38:01
# Processed 18620 out of 27784 in 35:45:28
# Processed 18640 out of 27784 in 35:49:34
# Processed 18660 out of 27784 in 35:52:24
# Processed 18680 out of 27784 in 35:56:09
# Processed 18700 out of 27784 in 36:00:16
# Processed 18720 out of 27784 in 36:03:51
# Processed 18740 out of 27784 in 36:07:45
# Processed 18760 out of 27784 in 36:11:23
# Processed 18780 out of 27784 in 36:14:29
# Processed 18800 out of 27784 in 36:17:47
# Processed 18820 out of 27784 in 36:21:40
# Processed 18840 out of 27784 in 36:25:57
# Processed 18860 out of 27784 in 36:36:10
# Processed 18880 out of 27784 in 36:40:43
# Processed 18900 out of 27784 in 36:53:16
# Processed 18920 out of 27784 in 36:58:34
# Processed 18940 out of 27784 in 37:02:36
# Processed 18960 out of 27784 in 37:06:03
# Processed 18980 out of 27784 in 37:10:25
# Processed 19000 out of 27784 in 37:12:15
# Processed 19020 out of 27784 in 37:19:51
# Processed 19040 out of 27784 in 37:26:14
# Processed 19060 out of 27784 in 37:28:02
# Processed 19080 out of 27784 in 37:30:05
# Processed 19100 out of 27784 in 37:31:22
# Processed 19120 out of 27784 in 37:32:32
# Processed 19140 out of 27784 in 37:39:06
# Processed 19160 out of 27784 in 37:43:18
# Processed 19180 out of 27784 in 37:45:25
# Processed 19200 out of 27784 in 37:47:48
# Processed 19220 out of 27784 in 37:50:30
# Processed 19240 out of 27784 in 37:52:49
# Processed 19260 out of 27784 in 37:55:14
# Processed 19280 out of 27784 in 37:57:34
# Processed 19300 out of 27784 in 37:59:58
# Processed 19320 out of 27784 in 38:02:11
# Processed 19340 out of 27784 in 38:04:22
# Processed 19360 out of 27784 in 38:06:13
# Processed 19380 out of 27784 in 38:08:57
# Processed 19400 out of 27784 in 38:11:15
# Processed 19420 out of 27784 in 38:12:59
# Processed 19440 out of 27784 in 38:15:27
# Processed 19460 out of 27784 in 38:18:01
# Processed 19480 out of 27784 in 38:21:53
# Processed 19500 out of 27784 in 38:26:54
# Processed 19520 out of 27784 in 38:31:12
# Processed 19540 out of 27784 in 38:33:17
# Processed 19560 out of 27784 in 38:36:31
# Processed 19580 out of 27784 in 38:40:58
# Processed 19600 out of 27784 in 38:44:11
# Processed 19620 out of 27784 in 38:47:02
# Processed 19640 out of 27784 in 38:49:56
# Processed 19660 out of 27784 in 38:52:52
# Processed 19680 out of 27784 in 38:55:52
# Processed 19700 out of 27784 in 38:58:22
# Processed 19720 out of 27784 in 39:01:27
# Processed 19740 out of 27784 in 39:07:07
# Processed 19760 out of 27784 in 39:10:12
# Processed 19780 out of 27784 in 39:13:04
# Processed 19800 out of 27784 in 39:15:50
# Processed 19820 out of 27784 in 39:19:06
# Processed 19840 out of 27784 in 39:27:58
# Processed 19860 out of 27784 in 39:37:36
# Processed 19880 out of 27784 in 39:39:42
# Processed 19900 out of 27784 in 39:41:53
# Processed 19920 out of 27784 in 39:44:13
# Processed 19940 out of 27784 in 39:52:39
# Processed 19960 out of 27784 in 39:54:28
# Processed 19980 out of 27784 in 39:58:29
# Processed 20000 out of 27784 in 40:05:18
# Processed 20020 out of 27784 in 40:17:12
# Processed 20040 out of 27784 in 40:25:49
# Processed 20060 out of 27784 in 40:28:09
# Processed 20080 out of 27784 in 40:30:49
# Processed 20100 out of 27784 in 40:42:42
# Processed 20120 out of 27784 in 40:47:58
# Processed 20140 out of 27784 in 40:50:29
# Processed 20160 out of 27784 in 40:52:25
# Processed 20180 out of 27784 in 40:55:35
# Processed 20200 out of 27784 in 40:58:51
# Processed 20220 out of 27784 in 41:00:59
# Processed 20240 out of 27784 in 41:02:55
# Processed 20260 out of 27784 in 41:11:46
# Processed 20280 out of 27784 in 41:14:51
# Processed 20300 out of 27784 in 41:18:24
# Processed 20320 out of 27784 in 41:21:28
# Processed 20340 out of 27784 in 42:05:00
# Processed 20360 out of 27784 in 42:28:11
# Processed 20380 out of 27784 in 42:33:05
# Processed 20400 out of 27784 in 42:37:35
# Processed 20420 out of 27784 in 42:42:16
# Processed 20440 out of 27784 in 42:46:56
# Processed 20460 out of 27784 in 42:51:45
# Processed 20480 out of 27784 in 42:56:35
# Processed 20500 out of 27784 in 43:01:01
# Processed 20520 out of 27784 in 43:05:51
# Processed 20540 out of 27784 in 43:10:56
# Processed 20560 out of 27784 in 43:15:38
# Processed 20580 out of 27784 in 43:24:15
# Processed 20600 out of 27784 in 43:34:44
# Processed 20620 out of 27784 in 43:54:45
# Processed 20640 out of 27784 in 44:45:12
# Processed 20660 out of 27784 in 45:17:03
# Processed 20680 out of 27784 in 45:43:58
# Processed 20700 out of 27784 in 45:53:42
# Processed 20720 out of 27784 in 46:33:10
# Processed 20740 out of 27784 in 46:38:38
# Processed 20760 out of 27784 in 46:41:08
# Processed 20780 out of 27784 in 46:41:37
# Processed 20800 out of 27784 in 46:49:00
# Processed 20820 out of 27784 in 46:53:52
# Processed 20840 out of 27784 in 47:03:30
# Processed 20860 out of 27784 in 47:11:09
# Processed 20880 out of 27784 in 47:17:30
# Processed 20900 out of 27784 in 47:32:24
# Processed 20920 out of 27784 in 47:46:45
# Processed 20940 out of 27784 in 48:03:13
# Processed 20960 out of 27784 in 48:12:38
# Processed 20980 out of 27784 in 48:25:41
# Processed 21000 out of 27784 in 48:37:35
# Processed 21020 out of 27784 in 48:39:52
# Processed 21040 out of 27784 in 48:43:19
# Processed 21060 out of 27784 in 48:48:49
# Processed 21080 out of 27784 in 48:50:53
# Processed 21100 out of 27784 in 48:56:31
# Processed 21120 out of 27784 in 49:02:15
# Processed 21140 out of 27784 in 49:04:28
# Processed 21160 out of 27784 in 49:12:45
# Processed 21180 out of 27784 in 49:31:28
# Processed 21200 out of 27784 in 49:57:17
# Processed 21220 out of 27784 in 49:59:57
# Processed 21240 out of 27784 in 50:03:04
# Processed 21260 out of 27784 in 50:11:11
# Processed 21280 out of 27784 in 50:24:19
# Processed 21300 out of 27784 in 50:44:06
# Processed 21320 out of 27784 in 51:01:24
# Processed 21340 out of 27784 in 51:16:05
# Processed 21360 out of 27784 in 51:29:21
# Processed 21380 out of 27784 in 51:37:53
# Processed 21400 out of 27784 in 51:42:28
# Processed 21420 out of 27784 in 51:46:33
# Processed 21440 out of 27784 in 51:49:50
# Processed 21460 out of 27784 in 51:53:08
# Processed 21480 out of 27784 in 51:57:32
# Processed 21500 out of 27784 in 52:00:49
# Processed 21520 out of 27784 in 52:10:11
# Processed 21540 out of 27784 in 52:25:00
# Processed 21560 out of 27784 in 52:34:17
# Processed 21580 out of 27784 in 52:42:00
# Processed 21600 out of 27784 in 52:46:25
# Processed 21620 out of 27784 in 52:49:50
# Processed 21640 out of 27784 in 52:56:42
# Processed 21660 out of 27784 in 53:07:21
# Processed 21680 out of 27784 in 53:19:52
# Processed 21700 out of 27784 in 53:28:33
# Processed 21720 out of 27784 in 53:37:38
# Processed 21740 out of 27784 in 53:48:00
# Processed 21760 out of 27784 in 53:58:31
# Processed 21780 out of 27784 in 54:05:15
# Processed 21800 out of 27784 in 54:10:45
# Processed 21820 out of 27784 in 54:13:29
# Processed 21840 out of 27784 in 54:16:18
# Processed 21860 out of 27784 in 54:19:16
# Processed 21880 out of 27784 in 54:24:40
# Processed 21900 out of 27784 in 54:30:03
# Processed 21920 out of 27784 in 54:33:40
# Processed 21940 out of 27784 in 54:37:18
# Processed 21960 out of 27784 in 54:40:38
# Processed 21980 out of 27784 in 54:43:55
# Processed 22000 out of 27784 in 54:47:33
# Processed 22020 out of 27784 in 54:51:15
# Processed 22040 out of 27784 in 54:55:11
# Processed 22060 out of 27784 in 54:58:49
# Processed 22080 out of 27784 in 55:02:28
# Processed 22100 out of 27784 in 55:06:51
# Processed 22120 out of 27784 in 55:11:55
# Processed 22140 out of 27784 in 55:16:52
# Processed 22160 out of 27784 in 55:21:15
# Processed 22180 out of 27784 in 55:23:49
# Processed 22200 out of 27784 in 55:27:12
# Processed 22220 out of 27784 in 55:31:30
# Processed 22240 out of 27784 in 55:36:32
# Processed 22260 out of 27784 in 55:40:58
# Processed 22280 out of 27784 in 55:45:44
# Processed 22300 out of 27784 in 55:50:54
# Processed 22320 out of 27784 in 55:55:08
# Processed 22340 out of 27784 in 55:59:27
# Processed 22360 out of 27784 in 56:02:38
# Processed 22380 out of 27784 in 56:05:00
# Processed 22400 out of 27784 in 56:07:05
# Processed 22420 out of 27784 in 56:18:02
# Processed 22440 out of 27784 in 56:23:43
# Processed 22460 out of 27784 in 56:27:52
# Processed 22480 out of 27784 in 56:31:21
# Processed 22500 out of 27784 in 56:34:22
# Processed 22520 out of 27784 in 56:36:56
# Processed 22540 out of 27784 in 56:40:31
# Processed 22560 out of 27784 in 56:43:19
# Processed 22580 out of 27784 in 56:46:01
# Processed 22600 out of 27784 in 56:48:37
# Processed 22620 out of 27784 in 56:50:59
# Processed 22640 out of 27784 in 56:53:46
# Processed 22660 out of 27784 in 56:56:22
# Processed 22680 out of 27784 in 56:59:05
# Processed 22700 out of 27784 in 57:02:28
# Processed 22720 out of 27784 in 57:05:29
# Processed 22740 out of 27784 in 57:08:30
# Processed 22760 out of 27784 in 57:11:56
# Processed 22780 out of 27784 in 57:15:17
# Processed 22800 out of 27784 in 57:18:16
# Processed 22820 out of 27784 in 57:21:22
# Processed 22840 out of 27784 in 57:24:23
# Processed 22860 out of 27784 in 57:27:24
# Processed 22880 out of 27784 in 57:29:09
# Processed 22900 out of 27784 in 57:33:33
# Processed 22920 out of 27784 in 57:35:56
# Processed 22940 out of 27784 in 57:37:57
# Processed 22960 out of 27784 in 57:41:15
# Processed 22980 out of 27784 in 57:44:06
# Processed 23000 out of 27784 in 57:47:08
# Processed 23020 out of 27784 in 57:49:44
# Processed 23040 out of 27784 in 57:51:38
# Processed 23060 out of 27784 in 57:59:10
# Processed 23080 out of 27784 in 58:03:43
# Processed 23100 out of 27784 in 58:05:32
# Processed 23120 out of 27784 in 58:08:20
# Processed 23140 out of 27784 in 58:10:56
# Processed 23160 out of 27784 in 58:13:05
# Processed 23180 out of 27784 in 58:15:55
# Processed 23200 out of 27784 in 58:26:47
# Processed 23220 out of 27784 in 58:29:38
# Processed 23240 out of 27784 in 58:32:50
# Processed 23260 out of 27784 in 58:34:29
# Processed 23280 out of 27784 in 58:36:46
# Processed 23300 out of 27784 in 58:45:56
# Processed 23320 out of 27784 in 58:48:10
# Processed 23340 out of 27784 in 58:49:38
# Processed 23360 out of 27784 in 58:51:42
# Processed 23380 out of 27784 in 58:53:01
# Processed 23400 out of 27784 in 58:58:13
# Processed 23420 out of 27784 in 59:00:07
# Processed 23440 out of 27784 in 59:02:05
# Processed 23460 out of 27784 in 59:04:11
# Processed 23480 out of 27784 in 59:06:41
# Processed 23500 out of 27784 in 59:11:31
# Processed 23520 out of 27784 in 59:20:13
# Processed 23540 out of 27784 in 59:22:20
# Processed 23560 out of 27784 in 59:25:47
# Processed 23580 out of 27784 in 59:30:55
# Processed 23600 out of 27784 in 59:32:46
# Processed 23620 out of 27784 in 59:39:52
# Processed 23640 out of 27784 in 59:51:34
# Processed 23660 out of 27784 in 59:58:48
# Processed 23680 out of 27784 in 60:04:22
# Processed 23700 out of 27784 in 60:11:39
# Processed 23720 out of 27784 in 60:21:52
# Processed 23740 out of 27784 in 60:31:23
# Processed 23760 out of 27784 in 60:34:01
# Processed 23780 out of 27784 in 60:36:02
# Processed 23800 out of 27784 in 60:38:17
# Processed 23820 out of 27784 in 60:48:44
# Processed 23840 out of 27784 in 60:50:25
# Processed 23860 out of 27784 in 60:59:25
# Processed 23880 out of 27784 in 61:03:28
# Processed 23900 out of 27784 in 61:08:29
# Processed 23920 out of 27784 in 61:12:53
# Processed 23940 out of 27784 in 61:14:36
# Processed 23960 out of 27784 in 61:16:59
# Processed 23980 out of 27784 in 61:22:30
# Processed 24000 out of 27784 in 61:24:14
# Processed 24020 out of 27784 in 61:26:10
# Processed 24040 out of 27784 in 61:35:28
# Processed 24060 out of 27784 in 61:37:16
# Processed 24080 out of 27784 in 61:39:15
# Processed 24100 out of 27784 in 61:43:35
# Processed 24120 out of 27784 in 61:47:07
# Processed 24140 out of 27784 in 61:48:59
# Processed 24160 out of 27784 in 61:50:42
# Processed 24180 out of 27784 in 62:00:33
# Processed 24200 out of 27784 in 62:06:48
# Processed 24220 out of 27784 in 62:08:35
# Processed 24240 out of 27784 in 62:10:31
# Processed 24260 out of 27784 in 62:12:28
# Processed 24280 out of 27784 in 62:14:34
# Processed 24300 out of 27784 in 62:22:56
# Processed 24320 out of 27784 in 62:33:38
# Processed 24340 out of 27784 in 62:35:52
# Processed 24360 out of 27784 in 62:38:28
# Processed 24380 out of 27784 in 62:42:02
# Processed 24400 out of 27784 in 62:45:53
# Processed 24420 out of 27784 in 62:49:01
# Processed 24440 out of 27784 in 62:51:13
# Processed 24460 out of 27784 in 62:53:51
# Processed 24480 out of 27784 in 62:56:49
# Processed 24500 out of 27784 in 63:01:40
# Processed 24520 out of 27784 in 63:06:24
# Processed 24540 out of 27784 in 63:08:16
# Processed 24560 out of 27784 in 63:09:43
# Processed 24580 out of 27784 in 63:11:05
# Processed 24600 out of 27784 in 63:13:58
# Processed 24620 out of 27784 in 63:15:48
# Processed 24640 out of 27784 in 63:19:40
# Processed 24660 out of 27784 in 63:23:15
# Processed 24680 out of 27784 in 63:24:16
# Processed 24700 out of 27784 in 63:26:18
# Processed 24720 out of 27784 in 63:31:22
# Processed 24740 out of 27784 in 63:34:01
# Processed 24760 out of 27784 in 63:35:57
# Processed 24780 out of 27784 in 63:39:34
# Processed 24800 out of 27784 in 63:41:46
# Processed 24820 out of 27784 in 63:46:54
# Processed 24840 out of 27784 in 63:57:13
# Processed 24860 out of 27784 in 63:59:23
# Processed 24880 out of 27784 in 64:03:01
# Processed 24900 out of 27784 in 64:05:51
# Processed 24920 out of 27784 in 64:08:55
# Processed 24940 out of 27784 in 64:15:12
# Processed 24960 out of 27784 in 64:17:43
# Processed 24980 out of 27784 in 64:22:06
# Processed 25000 out of 27784 in 64:24:36
# Processed 25020 out of 27784 in 64:28:32
# Processed 25040 out of 27784 in 64:31:13
# Processed 25060 out of 27784 in 64:36:30
# Processed 25080 out of 27784 in 64:39:25
# Processed 25100 out of 27784 in 64:41:38
# Processed 25120 out of 27784 in 64:44:10
# Processed 25140 out of 27784 in 64:46:54
# Processed 25160 out of 27784 in 64:49:21
# Processed 25180 out of 27784 in 64:51:45
# Processed 25200 out of 27784 in 64:57:17
# Processed 25220 out of 27784 in 65:04:34
# Processed 25240 out of 27784 in 65:07:21
# Processed 25260 out of 27784 in 65:09:23
# Processed 25280 out of 27784 in 65:11:21
# Processed 25300 out of 27784 in 65:15:19
# Processed 25320 out of 27784 in 65:17:44
# Processed 25340 out of 27784 in 65:20:21
# Processed 25360 out of 27784 in 65:22:43
# Processed 25380 out of 27784 in 65:25:27
# Processed 25400 out of 27784 in 65:28:37
# Processed 25420 out of 27784 in 65:30:39
# Processed 25440 out of 27784 in 65:32:38
# Processed 25460 out of 27784 in 65:34:52
# Processed 25480 out of 27784 in 65:37:24
# Processed 25500 out of 27784 in 65:40:32
# Processed 25520 out of 27784 in 65:43:26
# Processed 25540 out of 27784 in 65:45:05
# Processed 25560 out of 27784 in 65:52:50
# Processed 25580 out of 27784 in 65:54:53
# Processed 25600 out of 27784 in 65:56:58
# Processed 25620 out of 27784 in 66:23:55
# Processed 25640 out of 27784 in 66:34:23
# Processed 25660 out of 27784 in 66:36:34
# Processed 25680 out of 27784 in 66:41:17
# Processed 25700 out of 27784 in 66:43:39
# Processed 25720 out of 27784 in 66:45:50
# Processed 25740 out of 27784 in 66:48:05
# Processed 25760 out of 27784 in 66:50:20
# Processed 25780 out of 27784 in 66:53:41
# Processed 25800 out of 27784 in 66:56:49
# Processed 25820 out of 27784 in 67:00:06
# Processed 25840 out of 27784 in 67:01:53
# Processed 25860 out of 27784 in 67:08:47
# Processed 25880 out of 27784 in 67:10:20
# Processed 25900 out of 27784 in 67:29:14
# Processed 25920 out of 27784 in 67:53:00
# Processed 25940 out of 27784 in 67:57:54
# Processed 25960 out of 27784 in 67:59:53
# Processed 25980 out of 27784 in 68:01:46
# Processed 26000 out of 27784 in 68:03:39
# Processed 26020 out of 27784 in 68:05:40
# Processed 26040 out of 27784 in 68:08:27
# Processed 26060 out of 27784 in 68:10:51
# Processed 26080 out of 27784 in 68:12:37
# Processed 26100 out of 27784 in 68:16:02
# Processed 26120 out of 27784 in 68:20:01
# Processed 26140 out of 27784 in 68:21:59
# Processed 26160 out of 27784 in 68:23:55
# Processed 26180 out of 27784 in 68:25:42
# Processed 26200 out of 27784 in 68:27:28
# Processed 26220 out of 27784 in 68:31:41
# Processed 26240 out of 27784 in 68:36:11
# Processed 26260 out of 27784 in 68:40:23
# Processed 26280 out of 27784 in 68:43:28
# Processed 26300 out of 27784 in 68:52:01
# Processed 26320 out of 27784 in 68:57:37
# Processed 26340 out of 27784 in 69:03:34
# Processed 26360 out of 27784 in 69:08:57
# Processed 26380 out of 27784 in 69:14:40
# Processed 26400 out of 27784 in 69:28:54
# Processed 26420 out of 27784 in 69:39:22
# Processed 26440 out of 27784 in 69:46:37
# Processed 26460 out of 27784 in 69:54:37
# Processed 26480 out of 27784 in 70:02:28
# Processed 26500 out of 27784 in 70:24:13
# Processed 26520 out of 27784 in 70:30:04
# Processed 26540 out of 27784 in 70:37:33
# Processed 26560 out of 27784 in 70:43:46
# Processed 26580 out of 27784 in 70:52:01
# Processed 26600 out of 27784 in 70:58:06
# Processed 26620 out of 27784 in 71:01:14
# Processed 26640 out of 27784 in 71:05:01
# Processed 26660 out of 27784 in 71:09:31
# Processed 26680 out of 27784 in 71:16:26
# Processed 26700 out of 27784 in 71:18:32
# Processed 26720 out of 27784 in 71:22:25
# Processed 26740 out of 27784 in 71:24:37
# Processed 26760 out of 27784 in 71:26:58
# Processed 26780 out of 27784 in 71:29:40
# Processed 26800 out of 27784 in 71:34:24
# Processed 26820 out of 27784 in 71:37:07
# Processed 26840 out of 27784 in 71:39:05
# Processed 26860 out of 27784 in 71:41:16
# Processed 26880 out of 27784 in 71:44:02
# Processed 26900 out of 27784 in 71:47:28
# Processed 26920 out of 27784 in 71:49:43
# Processed 26940 out of 27784 in 71:52:10
# Processed 26960 out of 27784 in 71:56:11
# Processed 26980 out of 27784 in 72:01:35
# Processed 27000 out of 27784 in 72:03:34
# Processed 27020 out of 27784 in 72:04:52
# Processed 27040 out of 27784 in 72:06:18
# Processed 27060 out of 27784 in 72:08:36
# Processed 27080 out of 27784 in 72:11:25
# Processed 27100 out of 27784 in 72:15:45
# Processed 27120 out of 27784 in 72:18:08
# Processed 27140 out of 27784 in 72:20:08
# Processed 27160 out of 27784 in 72:22:04
# Processed 27180 out of 27784 in 72:29:22
# Processed 27200 out of 27784 in 72:32:47
# Processed 27220 out of 27784 in 72:34:27
# Processed 27240 out of 27784 in 72:36:28
# Processed 27260 out of 27784 in 72:39:42
# Processed 27280 out of 27784 in 72:46:47
# Processed 27300 out of 27784 in 72:49:57
# Processed 27320 out of 27784 in 72:53:30
# Processed 27340 out of 27784 in 73:01:17
# Processed 27360 out of 27784 in 73:07:03
# Processed 27380 out of 27784 in 73:10:40
# Processed 27400 out of 27784 in 73:13:32
# Processed 27420 out of 27784 in 73:16:19
# Processed 27440 out of 27784 in 73:18:32
# Processed 27460 out of 27784 in 73:20:47
# Processed 27480 out of 27784 in 73:23:12
# Processed 27500 out of 27784 in 73:25:42
# Processed 27520 out of 27784 in 73:28:05
# Processed 27540 out of 27784 in 73:30:49
# Processed 27560 out of 27784 in 73:33:13
# Processed 27580 out of 27784 in 73:35:32
# Processed 27600 out of 27784 in 73:38:07
# Processed 27620 out of 27784 in 73:40:20
# Processed 27640 out of 27784 in 73:43:29
# Processed 27660 out of 27784 in 73:46:09
# Processed 27680 out of 27784 in 73:53:17
# Processed 27700 out of 27784 in 73:59:44
# Processed 27720 out of 27784 in 74:01:40
# Processed 27740 out of 27784 in 74:15:30
# Processed 27760 out of 27784 in 74:20:07
# Processed 27780 out of 27784 in 74:23:03
# Processed 27784 out of 27784 in 74:24:02
