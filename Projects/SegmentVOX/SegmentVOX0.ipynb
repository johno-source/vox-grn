# %% [markdown]
# # Partial Process of Segment GRN Data for vox-grn
#
# See SegmentVox.ipynb for full description.
#
# In an attempt to speed up the processing I have divided the items up into 10 groups and want to have them all process in parallel. It probably won't be 10 times faster but it should still be quicker.

# %%
import pandas as pd
import numpy as np
import os
import sys
module_path = os.path.abspath(os.path.join('../vad_utils'))
if module_path not in sys.path:
    sys.path.append(module_path)
from vad_utils import SAMPLING_RATE, FRAME_SIZE_MS, SAMPLES_PER_FRAME
import vad_utils as vu
from pydub import AudioSegment
import pickle as pkl
from pathlib import Path
import time

# %%
# define the locations for each of the file types
NOTEBOOK_ID=0
SEGMENTS_DIR = '/media/originals/segments/'
DATASETS_DIR = '/media/originals/datasets/'
SEC_4_DATA_DIR = 'seg_4sec/data/'
SEC_6_DATA_DIR = 'seg_6sec/data/'
SEC_10_DATA_DIR = 'seg_10sec/data/'

# define specific files used in the process
SEG_4_SEC_DF = f'{SEGMENTS_DIR}seg_4sec_{NOTEBOOK_ID}.csv'
SEG_6_SEC_DF = f'{SEGMENTS_DIR}seg_6sec_{NOTEBOOK_ID}.csv'
SEG_10_SEC_DF = f'{SEGMENTS_DIR}seg_10sec_{NOTEBOOK_ID}.csv'

# define segment sizes for each dataset
SEG_4_SEC = 4.0
SEG_6_SEC = 6.0
SEG_10_SEC = 10.0

# %%
# Now read in the description of the input and remove the unwanted columns and rename the rest to be python attribute names.
items = pd.read_csv(f'/media/originals/segments/items_{NOTEBOOK_ID}.csv')
items.set_index('ID', inplace=True)
items.columns
# Out:
# Index(['iso', 'program', 'location', 'year', 'path', 'filename', 'item_no',
#        'title', 'start', 'end'],
#       dtype='object')

# %%
print(items.iloc[100])
# Out:
# iso                                    aau
# program                             A80135
# location    Amanab, Sandaun Prov, PNGuinea
# year                                1995.0
# path          Programs/80/80135/A80135/PM/
# filename                     A80135-33.wav
# item_no                                 33
# title                           Picture 31
# start                                  0.0
# end                                   29.0
# Name: A80135_033, dtype: object

# %%
print(items.index)
# Out:
# Index(['A14610_001', 'A14610_002', 'A13581_006', 'A13581_001', 'A13581_003',
#        'A13581_005', 'A13581_008', 'A63494_002', 'A63494_004', 'A63494_005',
#        ...
#        'A01911_003', 'A01911_001', 'A18841_001', 'A18841_002', 'A18841_004',
#        'A18841_006', 'A01471_003', 'A01471_001', 'A01471_005', 'A01471_004'],
#       dtype='object', name='ID', length=17198)

# %%
# generate directories and filenames
def prepare_dir(dirname):
    if dirname[-1] != '/':
        dirname = dirname + '/'
    Path(dirname).mkdir(parents=True, exist_ok=True)
    return dirname

def prepare_raw_seg_dir(item):
    return prepare_dir(SEGMENTS_DIR + item.iso)

def raw_seg_filename(item):
    return f'{item.program}_{item.item_no:03d}.pkl'

def prepare_dataset_data_dir(item, dataset_dir):
    return prepare_dir(DATASETS_DIR + dataset_dir + item.iso)

def seg_mp3_filename(item, seg):
    return f'{item.program}_{item.item_no:03d}_{seg:03d}.mp3'

# %%
def condition_audio_segment(audio_seg):
    if audio_seg.channels != 1:
        audio_seg = audio_seg.set_channels(1)

    if audio_seg.sample_width != 2:
        audio_seg = audio_seg.set_sample_width(2)

    if audio_seg.frame_rate != SAMPLING_RATE:
        audio_seg = audio_seg.set_frame_rate(SAMPLING_RATE)

    return audio_seg

# %%
def save_the_segment_info(item, segs):
    fname = prepare_raw_seg_dir(item) + raw_seg_filename(item)
    with open(fname, 'wb') as pklFile:
         pkl.dump(segs, pklFile)

def read_the_segment_info(item):
    fname = prepare_raw_seg_dir(item) + raw_seg_filename(item)
    if os.path.exists(fname):
        if os.path.getsize(fname) > 0:
            with open(fname, 'rb') as pklFile:
                return pkl.load(pklFile)
    return []
    
def extract_audio_segment_for_item(item):
    fmt = 'wav'
    if item.filename[-4:] == '.mp3' :
        fmt = 'mp3'
    audio_seg = AudioSegment.from_file('/media/programs/' + item.path + item.filename, format=fmt)
    start_ms = int(item.start * 1000)
    end_ms = int(item.end * 1000)
    audio_seg = audio_seg[start_ms:end_ms]

    # now condition the segment and extract the raw segments.
    audio_seg = condition_audio_segment(audio_seg)
    segs = read_the_segment_info(item)
    if len(segs) == 0:
        segs = vu.audio_to_raw_voice_segments(audio_seg)
        save_the_segment_info(item, segs)

    return audio_seg, segs

def create_mp3_files(audio_seg, segs, time_per_segment, dataset_dir, item):
    segs_for_time = vu.divide_into_segments(segs, time_per_segment)

    # now write out the 4 sec segments
    dirname = prepare_dataset_data_dir(item, dataset_dir)
    rows = list()
    for i, seg in enumerate(segs_for_time):
        file_name = dataset_dir + item.iso + '/' + seg_mp3_filename(item, i)
        fname = dirname + seg_mp3_filename(item, i)
        if not os.path.exists(fname):
            start = vu.convert_frames_to_ms(seg.start)
            stop = vu.convert_frames_to_ms(seg.stop)
            audio_seg[start:stop].export(fname, format='mp3', bitrate='32k')
        desc = dict(item._asdict())
        desc['seg_start'] = vu.convert_frames_to_seconds(seg.start)
        desc['seg_stop'] = vu.convert_frames_to_seconds(seg.stop)
        desc['seg'] = i
        desc['file_name'] = file_name
        rows.append(desc)

    return rows

def update_dataframes(seg_df_csv, seg_records):
    # now update the dataframes
    if len(seg_records) > 0:
        if os.path.isfile(seg_df_csv):
            seg_sec_df = pd.concat([pd.read_csv(seg_df_csv, index_col='file_name'), pd.DataFrame.from_records(seg_records, index='file_name')])
        else:
            seg_sec_df = pd.DataFrame.from_records(seg_records, index='file_name')
        seg_sec_df.to_csv(seg_df_csv)

# %%
# processing these items might take a very long time. To permit the process to be interrupted and restarted the indexes of processed items
# are maintained in a set that is pickled on each batch. This allows the batch to quickly pick up where it left off.
def process_record_batch(items_df, *, batch_size=10):
    batch_proc = 0
    processed_file = f'/media/originals/segments/processed16_{NOTEBOOK_ID}.pkl'
    if os.path.isfile(processed_file):
        with open(processed_file, 'rb') as pklFile:
            processed_items = pkl.load(pklFile)
    else:
        processed_items = set()

    segmented_4sec_segs = []
    segmented_6sec_segs = []
    segmented_10sec_segs = []

    for item in items_df.itertuples():
        if batch_proc < batch_size:
            if item.Index not in processed_items:
                try:
                    audio_seg, voice_segs = extract_audio_segment_for_item(item)
                    segmented_4sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_4_SEC, SEC_4_DATA_DIR, item))
                    segmented_6sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_6_SEC, SEC_6_DATA_DIR, item))
                    segmented_10sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_10_SEC, SEC_10_DATA_DIR, item))
                except:
                    print('exception')
                    pass

                # we want to add an item that has an exception so it is not reprocessed on every batch
                processed_items.add(item.Index)
                batch_proc += 1

        else:
            break

    update_dataframes(SEG_4_SEC_DF, segmented_4sec_segs)
    update_dataframes(SEG_6_SEC_DF, segmented_6sec_segs)
    update_dataframes(SEG_10_SEC_DF, segmented_10sec_segs)

    with open(processed_file, 'wb') as pklFile:
        pkl.dump(processed_items, pklFile)

    return processed_items

# %%
start_time = time.time()
# form the language classification file
items_processed = 0
items_to_process = len(items)
while items_to_process > items_processed:
    processed_items = process_record_batch(items, batch_size=50)
    items_processed = len(processed_items)
    print(f'Processed {items_processed} out of {items_to_process} in {time.time()-start_time} seconds')
# Out:
# Processed 50 out of 17198 in 360.21086144447327 seconds
# Processed 100 out of 17198 in 682.4858827590942 seconds
# Processed 150 out of 17198 in 855.639965057373 seconds
# Processed 200 out of 17198 in 986.9773600101471 seconds
# Processed 250 out of 17198 in 1139.5160057544708 seconds
# Processed 300 out of 17198 in 1341.178947687149 seconds
# Processed 350 out of 17198 in 1618.5494701862335 seconds
# Processed 400 out of 17198 in 2029.86576795578 seconds
# Processed 450 out of 17198 in 2456.654363155365 seconds
# Processed 500 out of 17198 in 2801.915151834488 seconds
# Processed 550 out of 17198 in 3023.486241340637 seconds
# Processed 600 out of 17198 in 3202.5960891246796 seconds
# Processed 650 out of 17198 in 3321.2475986480713 seconds
# Processed 700 out of 17198 in 3485.426293849945 seconds
# Processed 750 out of 17198 in 3649.9012129306793 seconds
# Processed 800 out of 17198 in 4146.889976024628 seconds
# Processed 850 out of 17198 in 7238.5005259513855 seconds
# Processed 900 out of 17198 in 7476.266340255737 seconds
# Processed 950 out of 17198 in 7693.874898195267 seconds
# Processed 1000 out of 17198 in 8003.134219408035 seconds
# Processed 1050 out of 17198 in 8404.527537584305 seconds
# Processed 1100 out of 17198 in 8802.665246248245 seconds
# Processed 1150 out of 17198 in 9277.526063203812 seconds
# Processed 1200 out of 17198 in 9765.689691781998 seconds
# Processed 1250 out of 17198 in 10104.016632080078 seconds
# Processed 1300 out of 17198 in 10438.381248235703 seconds
# Processed 1350 out of 17198 in 10841.754156589508 seconds
# Processed 1400 out of 17198 in 11148.201737642288 seconds
# Processed 1450 out of 17198 in 11368.374328613281 seconds
# Processed 1500 out of 17198 in 11456.36924648285 seconds
# Processed 1550 out of 17198 in 11603.115211248398 seconds
# Processed 1600 out of 17198 in 11952.640094041824 seconds
# Processed 1650 out of 17198 in 12231.778662204742 seconds
# Processed 1700 out of 17198 in 12399.396553516388 seconds
# Processed 1750 out of 17198 in 12804.084899187088 seconds
# Processed 1800 out of 17198 in 13010.348132133484 seconds
# Processed 1850 out of 17198 in 13497.204295396805 seconds
# Processed 1900 out of 17198 in 13765.942772388458 seconds
# Processed 1950 out of 17198 in 14091.61728978157 seconds
# Processed 2000 out of 17198 in 14581.075127840042 seconds
# Processed 2050 out of 17198 in 15058.268680095673 seconds
# Processed 2100 out of 17198 in 15239.595105409622 seconds
# Processed 2150 out of 17198 in 15570.543238162994 seconds
# Processed 2200 out of 17198 in 15973.67220902443 seconds
# Processed 2250 out of 17198 in 16548.918632745743 seconds
# Processed 2300 out of 17198 in 16776.188561201096 seconds
# Processed 2350 out of 17198 in 17031.976842403412 seconds
# Processed 2400 out of 17198 in 17556.87517952919 seconds
# Processed 2450 out of 17198 in 18011.08141350746 seconds
# Processed 2500 out of 17198 in 18307.716374874115 seconds
# Processed 2550 out of 17198 in 18730.041477918625 seconds
# Processed 2600 out of 17198 in 19437.688269138336 seconds
# Processed 2650 out of 17198 in 20014.33650779724 seconds
# Processed 2700 out of 17198 in 20698.713136196136 seconds
# Processed 2750 out of 17198 in 21506.353076457977 seconds
# Processed 2800 out of 17198 in 22463.764996290207 seconds
# Processed 2850 out of 17198 in 23160.858033180237 seconds
# Processed 2900 out of 17198 in 23824.547324180603 seconds
# Processed 2950 out of 17198 in 24504.019753217697 seconds
# Processed 3000 out of 17198 in 25120.593919992447 seconds
# Processed 3050 out of 17198 in 25901.289823055267 seconds
# Processed 3100 out of 17198 in 26556.95550107956 seconds
# Processed 3150 out of 17198 in 27304.929034471512 seconds
# Processed 3200 out of 17198 in 27987.54373049736 seconds
# Processed 3250 out of 17198 in 28535.15909409523 seconds
# Processed 3300 out of 17198 in 28985.90279150009 seconds
# Processed 3350 out of 17198 in 29521.48528957367 seconds
# Processed 3400 out of 17198 in 30024.083659648895 seconds
# Processed 3450 out of 17198 in 30502.552696943283 seconds
# Processed 3500 out of 17198 in 31034.342477321625 seconds
# Processed 3550 out of 17198 in 31686.609991788864 seconds
# Processed 3600 out of 17198 in 32338.278215646744 seconds
# Processed 3650 out of 17198 in 33065.36291718483 seconds
# Processed 3700 out of 17198 in 33768.161598443985 seconds
# Processed 3750 out of 17198 in 34287.79875230789 seconds
# Processed 3800 out of 17198 in 34727.80247712135 seconds
# Processed 3850 out of 17198 in 34960.52194070816 seconds
# Processed 3900 out of 17198 in 35327.765456438065 seconds
# Processed 3950 out of 17198 in 35888.52136301994 seconds
# Processed 4000 out of 17198 in 36144.06776857376 seconds
# Processed 4050 out of 17198 in 36520.40810775757 seconds
# Processed 4100 out of 17198 in 36928.91388106346 seconds
# Processed 4150 out of 17198 in 37626.230746269226 seconds
# Processed 4200 out of 17198 in 39360.457656383514 seconds
# Processed 4250 out of 17198 in 39610.26511096954 seconds
# Processed 4300 out of 17198 in 39816.310505867004 seconds
# Processed 4350 out of 17198 in 41186.58522605896 seconds
# Processed 4400 out of 17198 in 42195.047879457474 seconds
# Processed 4450 out of 17198 in 42516.77501702309 seconds
# Processed 4500 out of 17198 in 42911.131551742554 seconds
# Processed 4550 out of 17198 in 43061.93391895294 seconds
# Processed 4600 out of 17198 in 43395.71966958046 seconds
# Processed 4650 out of 17198 in 43693.677109479904 seconds
# Processed 4700 out of 17198 in 44279.658802986145 seconds
# Processed 4750 out of 17198 in 44761.622253894806 seconds
# Processed 4800 out of 17198 in 45123.95102286339 seconds
# Processed 4850 out of 17198 in 45355.44984459877 seconds
# Processed 4900 out of 17198 in 45661.69990205765 seconds
# Processed 4950 out of 17198 in 45997.163942575455 seconds
# Processed 5000 out of 17198 in 46701.94375705719 seconds
# Processed 5050 out of 17198 in 46972.757992982864 seconds
# Processed 5100 out of 17198 in 47701.332085847855 seconds
# Processed 5150 out of 17198 in 48832.63644862175 seconds
# Processed 5200 out of 17198 in 49280.50202894211 seconds
# Processed 5250 out of 17198 in 49912.66623854637 seconds
# Processed 5300 out of 17198 in 51486.67548060417 seconds
# Processed 5350 out of 17198 in 51678.11048960686 seconds
# Processed 5400 out of 17198 in 52000.095854759216 seconds
# Processed 5450 out of 17198 in 52338.92141246796 seconds
# Processed 5500 out of 17198 in 52744.89088821411 seconds
# Processed 5550 out of 17198 in 53129.32087945938 seconds
# Processed 5600 out of 17198 in 53782.08673405647 seconds
# Processed 5650 out of 17198 in 54044.0559899807 seconds
# Processed 5700 out of 17198 in 54246.64765334129 seconds
# Processed 5750 out of 17198 in 54542.80139064789 seconds
# Processed 5800 out of 17198 in 55040.4517621994 seconds
# Processed 5850 out of 17198 in 55447.59899902344 seconds
# Processed 5900 out of 17198 in 55809.983254909515 seconds
# Processed 5950 out of 17198 in 56384.33841753006 seconds
# Processed 6000 out of 17198 in 56612.20559644699 seconds
# Processed 6050 out of 17198 in 56838.65048503876 seconds
# Processed 6100 out of 17198 in 57100.750064611435 seconds
# Processed 6150 out of 17198 in 57314.67202448845 seconds
# Processed 6200 out of 17198 in 57596.510046720505 seconds
# Processed 6250 out of 17198 in 57850.44658088684 seconds
# Processed 6300 out of 17198 in 58065.55881357193 seconds
# Processed 6350 out of 17198 in 58235.833991765976 seconds
# Processed 6400 out of 17198 in 58414.62847971916 seconds
# Processed 6450 out of 17198 in 58570.6294066906 seconds
# Processed 6500 out of 17198 in 58860.19231271744 seconds
# Processed 6550 out of 17198 in 58997.77417755127 seconds
# Processed 6600 out of 17198 in 59288.146783828735 seconds
# Processed 6650 out of 17198 in 59580.4673769474 seconds
# Processed 6700 out of 17198 in 59867.78639984131 seconds
# Processed 6750 out of 17198 in 60163.54794573784 seconds
# Processed 6800 out of 17198 in 60400.33841061592 seconds
# Processed 6850 out of 17198 in 60791.931274175644 seconds
# Processed 6900 out of 17198 in 61047.766942977905 seconds
# Processed 6950 out of 17198 in 61345.19685602188 seconds
# Processed 7000 out of 17198 in 61531.14319777489 seconds
# Processed 7050 out of 17198 in 61769.86495614052 seconds
# Processed 7100 out of 17198 in 61976.43204855919 seconds
# Processed 7150 out of 17198 in 62206.97716283798 seconds
# Processed 7200 out of 17198 in 62466.608628988266 seconds
# Processed 7250 out of 17198 in 62854.46251344681 seconds
# Processed 7300 out of 17198 in 63168.160704135895 seconds
# Processed 7350 out of 17198 in 63564.270773887634 seconds
# Processed 7400 out of 17198 in 63754.95030617714 seconds
# Processed 7450 out of 17198 in 64383.63210582733 seconds
# Processed 7500 out of 17198 in 64623.39481496811 seconds
# Processed 7550 out of 17198 in 64772.247505903244 seconds
# Processed 7600 out of 17198 in 65012.55976271629 seconds
# Processed 7650 out of 17198 in 65424.420055150986 seconds
# Processed 7700 out of 17198 in 66112.31711125374 seconds
# Processed 7750 out of 17198 in 69139.92417502403 seconds
# Processed 7800 out of 17198 in 71037.49145412445 seconds
# Processed 7850 out of 17198 in 71266.12766647339 seconds
# Processed 7900 out of 17198 in 71688.92546153069 seconds
# Processed 7950 out of 17198 in 71979.48239541054 seconds
# Processed 8000 out of 17198 in 72785.98102974892 seconds
# Processed 8050 out of 17198 in 73034.57531690598 seconds
# Processed 8100 out of 17198 in 73335.38242840767 seconds
# Processed 8150 out of 17198 in 73687.37291836739 seconds
# Processed 8200 out of 17198 in 74137.48507761955 seconds
# Processed 8250 out of 17198 in 74446.14293050766 seconds
# Processed 8300 out of 17198 in 74714.7090549469 seconds
# Processed 8350 out of 17198 in 75111.95622110367 seconds
# Processed 8400 out of 17198 in 75376.50817847252 seconds
# Processed 8450 out of 17198 in 78546.5378677845 seconds
# Processed 8500 out of 17198 in 79228.71537518501 seconds
# Processed 8550 out of 17198 in 79476.7235481739 seconds
# Processed 8600 out of 17198 in 79987.64390468597 seconds
# Processed 8650 out of 17198 in 80465.80448698997 seconds
# Processed 8700 out of 17198 in 80834.52490901947 seconds
# Processed 8750 out of 17198 in 81046.9030020237 seconds
# Processed 8800 out of 17198 in 81240.99697041512 seconds
# Processed 8850 out of 17198 in 81404.61823129654 seconds
# Processed 8900 out of 17198 in 81625.72451925278 seconds
# Processed 8950 out of 17198 in 82025.00746917725 seconds
# Processed 9000 out of 17198 in 82343.02718615532 seconds
# Processed 9050 out of 17198 in 82676.26312375069 seconds
# Processed 9100 out of 17198 in 82928.53084731102 seconds
# Processed 9150 out of 17198 in 83170.5404419899 seconds
# Processed 9200 out of 17198 in 83319.19549322128 seconds
# Processed 9250 out of 17198 in 83487.72508096695 seconds
# Processed 9300 out of 17198 in 83677.89380669594 seconds
# Processed 9350 out of 17198 in 83855.0954144001 seconds
# Processed 9400 out of 17198 in 84122.5159804821 seconds
# Processed 9450 out of 17198 in 84721.11528968811 seconds
# Processed 9500 out of 17198 in 85012.47958564758 seconds
# Processed 9550 out of 17198 in 85720.29549098015 seconds
# Processed 9600 out of 17198 in 86133.38995862007 seconds
# Processed 9650 out of 17198 in 86362.68966722488 seconds
# Processed 9700 out of 17198 in 86582.32457995415 seconds
# Processed 9750 out of 17198 in 86904.0971660614 seconds
# Processed 9800 out of 17198 in 87223.1826095581 seconds
# Processed 9850 out of 17198 in 87585.18405103683 seconds
# Processed 9900 out of 17198 in 87858.74135255814 seconds
# Processed 9950 out of 17198 in 88014.13704705238 seconds
# Processed 10000 out of 17198 in 88272.77952623367 seconds
# Processed 10050 out of 17198 in 88548.14072942734 seconds
# Processed 10100 out of 17198 in 88664.88343000412 seconds
# Processed 10150 out of 17198 in 89130.98031067848 seconds
# Processed 10200 out of 17198 in 89396.77876830101 seconds
# Processed 10250 out of 17198 in 89902.65515303612 seconds
# Processed 10300 out of 17198 in 90325.91439056396 seconds
# Processed 10350 out of 17198 in 90747.5120112896 seconds
# Processed 10400 out of 17198 in 90933.41562438011 seconds
# Processed 10450 out of 17198 in 91218.86214637756 seconds
# Processed 10500 out of 17198 in 91817.8859026432 seconds
# Processed 10550 out of 17198 in 92108.30517911911 seconds
# Processed 10600 out of 17198 in 92306.84512042999 seconds
# Processed 10650 out of 17198 in 92578.34837412834 seconds
# Processed 10700 out of 17198 in 92740.63900899887 seconds
# Processed 10750 out of 17198 in 93410.4813504219 seconds
# Processed 10800 out of 17198 in 93702.77418661118 seconds
# Processed 10850 out of 17198 in 95531.4515285492 seconds
# Processed 10900 out of 17198 in 95897.63514566422 seconds
# Processed 10950 out of 17198 in 96131.69467616081 seconds
# Processed 11000 out of 17198 in 96444.64836239815 seconds
# Processed 11050 out of 17198 in 96704.99192714691 seconds
# Processed 11100 out of 17198 in 96917.35031986237 seconds
# Processed 11150 out of 17198 in 97144.4725599289 seconds
# Processed 11200 out of 17198 in 97426.00804615021 seconds
# Processed 11250 out of 17198 in 97687.37256383896 seconds
# Processed 11300 out of 17198 in 99262.98743748665 seconds
# Processed 11350 out of 17198 in 99470.55339360237 seconds
# Processed 11400 out of 17198 in 99645.33757066727 seconds
# Processed 11450 out of 17198 in 99773.16863656044 seconds
# Processed 11500 out of 17198 in 100051.47326517105 seconds
# Processed 11550 out of 17198 in 100456.11390209198 seconds
# Processed 11600 out of 17198 in 100966.81971907616 seconds
# Processed 11650 out of 17198 in 101260.90465974808 seconds
# Processed 11700 out of 17198 in 101551.16885018349 seconds
# Processed 11750 out of 17198 in 102284.39961695671 seconds
# Processed 11800 out of 17198 in 102721.8626332283 seconds
# Processed 11850 out of 17198 in 103213.84970736504 seconds
# Processed 11900 out of 17198 in 103599.22772932053 seconds
# Processed 11950 out of 17198 in 103863.50198173523 seconds
# Processed 12000 out of 17198 in 104307.2432255745 seconds
# Processed 12050 out of 17198 in 104865.88272571564 seconds
# Processed 12100 out of 17198 in 105755.26138806343 seconds
# Processed 12150 out of 17198 in 106135.75968956947 seconds
# Processed 12200 out of 17198 in 106391.68748927116 seconds
# Processed 12250 out of 17198 in 106803.64644598961 seconds
# Processed 12300 out of 17198 in 107001.8414735794 seconds
# Processed 12350 out of 17198 in 107365.55068445206 seconds
# Processed 12400 out of 17198 in 110614.07630634308 seconds
# Processed 12450 out of 17198 in 113466.78624153137 seconds
# Processed 12500 out of 17198 in 117593.65660595894 seconds
# Processed 12550 out of 17198 in 120557.88877105713 seconds
# Processed 12600 out of 17198 in 120781.65927433968 seconds
# Processed 12650 out of 17198 in 121062.09674549103 seconds
# Processed 12700 out of 17198 in 121380.25202035904 seconds
# Processed 12750 out of 17198 in 121586.69890213013 seconds
# Processed 12800 out of 17198 in 121767.30523824692 seconds
# Processed 12850 out of 17198 in 121927.35534358025 seconds
# Processed 12900 out of 17198 in 122073.83710336685 seconds
# Processed 12950 out of 17198 in 122619.75918531418 seconds
# Processed 13000 out of 17198 in 123291.67987012863 seconds
# Processed 13050 out of 17198 in 123793.52131223679 seconds
# Processed 13100 out of 17198 in 124609.210003376 seconds
# Processed 13150 out of 17198 in 125125.22327280045 seconds
# Processed 13200 out of 17198 in 126125.80000424385 seconds
# Processed 13250 out of 17198 in 127560.06375169754 seconds
# Processed 13300 out of 17198 in 128484.7107720375 seconds
# Processed 13350 out of 17198 in 129038.35526251793 seconds
# Processed 13400 out of 17198 in 129827.6390311718 seconds
# Processed 13450 out of 17198 in 130390.85745668411 seconds
# Processed 13500 out of 17198 in 130951.92485404015 seconds
# Processed 13550 out of 17198 in 131361.0642132759 seconds
# Processed 13600 out of 17198 in 131724.3735666275 seconds
# Processed 13650 out of 17198 in 131920.53396368027 seconds
# Processed 13700 out of 17198 in 132253.58605790138 seconds
# Processed 13750 out of 17198 in 132460.61108899117 seconds
# Processed 13800 out of 17198 in 132792.3256368637 seconds
# Processed 13850 out of 17198 in 133027.52713227272 seconds
# Processed 13900 out of 17198 in 133239.17139554024 seconds
# Processed 13950 out of 17198 in 133679.02422356606 seconds
# Processed 14000 out of 17198 in 134134.70688080788 seconds
# Processed 14050 out of 17198 in 134718.20583438873 seconds
# Processed 14100 out of 17198 in 135130.9961745739 seconds
# Processed 14150 out of 17198 in 135563.5671555996 seconds
# Processed 14200 out of 17198 in 135923.90469884872 seconds
# Processed 14250 out of 17198 in 136228.00687932968 seconds
# Processed 14300 out of 17198 in 136593.55507326126 seconds
# Processed 14350 out of 17198 in 137171.4088408947 seconds
# Processed 14400 out of 17198 in 138511.1585533619 seconds
# Processed 14450 out of 17198 in 138771.0805528164 seconds
# Processed 14500 out of 17198 in 138883.18117022514 seconds
# Processed 14550 out of 17198 in 138956.97903466225 seconds
# Processed 14600 out of 17198 in 139187.63254261017 seconds
# Processed 14650 out of 17198 in 142790.7595591545 seconds
# Processed 14700 out of 17198 in 143093.88420701027 seconds
# Processed 14750 out of 17198 in 143380.42047572136 seconds
# Processed 14800 out of 17198 in 143617.3873245716 seconds
# Processed 14850 out of 17198 in 143886.8375339508 seconds
# Processed 14900 out of 17198 in 144182.8416864872 seconds
# Processed 14950 out of 17198 in 146053.57692170143 seconds
# Processed 15000 out of 17198 in 146735.7260541916 seconds
# Processed 15050 out of 17198 in 147037.10657405853 seconds
# Processed 15100 out of 17198 in 147262.20210766792 seconds
# Processed 15150 out of 17198 in 148229.4270298481 seconds
# Processed 15200 out of 17198 in 148503.5795507431 seconds
# Processed 15250 out of 17198 in 148626.34966516495 seconds
# Processed 15300 out of 17198 in 148828.86574411392 seconds
# Processed 15350 out of 17198 in 149192.85425782204 seconds
# Processed 15400 out of 17198 in 149483.7874674797 seconds
# Processed 15450 out of 17198 in 149734.69516563416 seconds
# Processed 15500 out of 17198 in 149989.16462302208 seconds
# Processed 15550 out of 17198 in 150448.83760380745 seconds
# Processed 15600 out of 17198 in 150726.90622234344 seconds
# Processed 15650 out of 17198 in 150976.32391047478 seconds
# Processed 15700 out of 17198 in 151163.22327280045 seconds
# Processed 15750 out of 17198 in 151437.13790917397 seconds
# Processed 15800 out of 17198 in 151819.6686141491 seconds
# Processed 15850 out of 17198 in 152126.38650536537 seconds
# Processed 15900 out of 17198 in 152463.97241163254 seconds
# Processed 15950 out of 17198 in 152770.8584227562 seconds
# Processed 16000 out of 17198 in 153029.1332807541 seconds
# Processed 16050 out of 17198 in 153214.30152344704 seconds
# Processed 16100 out of 17198 in 153440.43668723106 seconds
# Processed 16150 out of 17198 in 153718.72365164757 seconds
# Processed 16200 out of 17198 in 154572.7732310295 seconds
# Processed 16250 out of 17198 in 154844.9926662445 seconds
# Processed 16300 out of 17198 in 154966.90841388702 seconds
# Processed 16350 out of 17198 in 155078.65145993233 seconds
# Processed 16400 out of 17198 in 155157.25012803078 seconds
# Processed 16450 out of 17198 in 155250.74263954163 seconds
# Processed 16500 out of 17198 in 155336.49588036537 seconds
# Processed 16550 out of 17198 in 155376.56835508347 seconds
# Processed 16600 out of 17198 in 155523.9544157982 seconds
# Processed 16650 out of 17198 in 155688.99219822884 seconds
# Processed 16700 out of 17198 in 155815.95260810852 seconds
# Processed 16750 out of 17198 in 155872.15524983406 seconds
# Processed 16800 out of 17198 in 156092.9434428215 seconds
# Processed 16850 out of 17198 in 156372.2789337635 seconds
# Processed 16900 out of 17198 in 156436.23070573807 seconds
# Processed 16950 out of 17198 in 156518.84668970108 seconds
# Processed 17000 out of 17198 in 156663.7456431389 seconds
# Processed 17050 out of 17198 in 156808.2299206257 seconds
# Processed 17100 out of 17198 in 156854.67992043495 seconds
# Processed 17150 out of 17198 in 156881.40415596962 seconds
# Processed 17198 out of 17198 in 156976.6911354065 seconds
