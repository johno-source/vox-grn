# %% [markdown]
# # Partial Process of Segment GRN Data for vox-grn
#
# See SegmentVox.ipynb for full description.
#
# In an attempt to speed up the processing I have divided the items up into 10 groups and want to have them all process in parallel. It probably won't be 10 times faster but it should still be quicker.

# %%
import pandas as pd
import numpy as np
import os
import sys
module_path = os.path.abspath(os.path.join('../vad_utils'))
if module_path not in sys.path:
    sys.path.append(module_path)
from vad_utils import SAMPLING_RATE, FRAME_SIZE_MS, SAMPLES_PER_FRAME
import vad_utils as vu
from pydub import AudioSegment
import pickle as pkl
from pathlib import Path
import time

# %%
# define the locations for each of the file types
NOTEBOOK_ID=8
SEGMENTS_DIR = '/media/originals/segments/'
DATASETS_DIR = '/media/originals/datasets/'
SEC_4_DATA_DIR = 'seg_4sec/data/'
SEC_6_DATA_DIR = 'seg_6sec/data/'
SEC_10_DATA_DIR = 'seg_10sec/data/'

# define specific files used in the process
SEG_4_SEC_DF = f'{SEGMENTS_DIR}seg_4sec_{NOTEBOOK_ID}.csv'
SEG_6_SEC_DF = f'{SEGMENTS_DIR}seg_6sec_{NOTEBOOK_ID}.csv'
SEG_10_SEC_DF = f'{SEGMENTS_DIR}seg_10sec_{NOTEBOOK_ID}.csv'

# define segment sizes for each dataset
SEG_4_SEC = 4.0
SEG_6_SEC = 6.0
SEG_10_SEC = 10.0

# %%
# Now read in the description of the input and remove the unwanted columns and rename the rest to be python attribute names.
items = pd.read_csv(f'/media/originals/segments/items_{NOTEBOOK_ID}.csv')
items.set_index('ID', inplace=True)
items.columns
# Out:
# Index(['iso', 'program', 'location', 'year', 'path', 'filename', 'item_no',
#        'title', 'start', 'end'],
#       dtype='object')

# %%
print(items.iloc[100])
# Out:
# iso                                             ssi
# program                                      A64285
# location                                     Sukkur
# year                                         2013.0
# path        Programs/64/64285/A64285/PM-1311-24bit/
# filename                             A64285-003.wav
# item_no                                           3
# title                                     Picture 3
# start                                           0.0
# end                                            15.0
# Name: A64285_003, dtype: object

# %%
print(items.index)
# Out:
# Index(['A65509_005', 'A65509_018', 'A65509_003', 'A65509_002', 'A65509_001',
#        'A65512_019', 'A65512_018', 'A65512_017', 'A65512_016', 'A65512_015',
#        ...
#        'A64593_005', 'A64593_004', 'A64593_003', 'A64593_002', 'A64593_001',
#        'A64593_008', 'A64593_018', 'A64593_019', 'A64593_020', 'A64593_038'],
#       dtype='object', name='ID', length=17198)

# %%
# generate directories and filenames
def prepare_dir(dirname):
    if dirname[-1] != '/':
        dirname = dirname + '/'
    Path(dirname).mkdir(parents=True, exist_ok=True)
    return dirname

def prepare_raw_seg_dir(item):
    return prepare_dir(SEGMENTS_DIR + item.iso)

def raw_seg_filename(item):
    return f'{item.program}_{item.item_no:03d}.pkl'

def prepare_dataset_data_dir(item, dataset_dir):
    return prepare_dir(DATASETS_DIR + dataset_dir + item.iso)

def seg_mp3_filename(item, seg):
    return f'{item.program}_{item.item_no:03d}_{seg:03d}.mp3'

# %%
def condition_audio_segment(audio_seg):
    if audio_seg.channels != 1:
        audio_seg = audio_seg.set_channels(1)

    if audio_seg.sample_width != 2:
        audio_seg = audio_seg.set_sample_width(2)

    if audio_seg.frame_rate != SAMPLING_RATE:
        audio_seg = audio_seg.set_frame_rate(SAMPLING_RATE)

    return audio_seg

# %%
def save_the_segment_info(item, segs):
    fname = prepare_raw_seg_dir(item) + raw_seg_filename(item)
    with open(fname, 'wb') as pklFile:
         pkl.dump(segs, pklFile)

def read_the_segment_info(item):
    fname = prepare_raw_seg_dir(item) + raw_seg_filename(item)
    if os.path.exists(fname):
        if os.path.getsize(fname) > 0:
            with open(fname, 'rb') as pklFile:
                return pkl.load(pklFile)
    return []
    
def extract_audio_segment_for_item(item):
    fmt = 'wav'
    if item.filename[-4:] == '.mp3' :
        fmt = 'mp3'
    audio_seg = AudioSegment.from_file('/media/programs/' + item.path + item.filename, format=fmt)
    start_ms = int(item.start * 1000)
    end_ms = int(item.end * 1000)
    audio_seg = audio_seg[start_ms:end_ms]

    # now condition the segment and extract the raw segments.
    audio_seg = condition_audio_segment(audio_seg)
    segs = read_the_segment_info(item)
    if len(segs) == 0:
        segs = vu.audio_to_raw_voice_segments(audio_seg)
        save_the_segment_info(item, segs)

    return audio_seg, segs

def create_mp3_files(audio_seg, segs, time_per_segment, dataset_dir, item):
    segs_for_time = vu.divide_into_segments(segs, time_per_segment)

    # now write out the 4 sec segments
    dirname = prepare_dataset_data_dir(item, dataset_dir)
    rows = list()
    for i, seg in enumerate(segs_for_time):
        file_name = dataset_dir + item.iso + '/' + seg_mp3_filename(item, i)
        fname = dirname + seg_mp3_filename(item, i)
        if not os.path.exists(fname):
            start = vu.convert_frames_to_ms(seg.start)
            stop = vu.convert_frames_to_ms(seg.stop)
            audio_seg[start:stop].export(fname, format='mp3', bitrate='32k')
        desc = dict(item._asdict())
        desc['seg_start'] = vu.convert_frames_to_seconds(seg.start)
        desc['seg_stop'] = vu.convert_frames_to_seconds(seg.stop)
        desc['seg'] = i
        desc['file_name'] = file_name
        rows.append(desc)

    return rows

def update_dataframes(seg_df_csv, seg_records):
    # now update the dataframes
    if len(seg_records) > 0:
        if os.path.isfile(seg_df_csv):
            seg_sec_df = pd.concat([pd.read_csv(seg_df_csv, index_col='file_name'), pd.DataFrame.from_records(seg_records, index='file_name')])
        else:
            seg_sec_df = pd.DataFrame.from_records(seg_records, index='file_name')
        seg_sec_df.to_csv(seg_df_csv)

# %%
# processing these items might take a very long time. To permit the process to be interrupted and restarted the indexes of processed items
# are maintained in a set that is pickled on each batch. This allows the batch to quickly pick up where it left off.
def process_record_batch(items_df, *, batch_size=10):
    batch_proc = 0
    processed_file = f'/media/originals/segments/processed16_{NOTEBOOK_ID}.pkl'
    if os.path.isfile(processed_file):
        with open(processed_file, 'rb') as pklFile:
            processed_items = pkl.load(pklFile)
    else:
        processed_items = set()

    segmented_4sec_segs = []
    segmented_6sec_segs = []
    segmented_10sec_segs = []

    for item in items_df.itertuples():
        if batch_proc < batch_size:
            if item.Index not in processed_items:
                try:
                    audio_seg, voice_segs = extract_audio_segment_for_item(item)
                    segmented_4sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_4_SEC, SEC_4_DATA_DIR, item))
                    segmented_6sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_6_SEC, SEC_6_DATA_DIR, item))
                    segmented_10sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_10_SEC, SEC_10_DATA_DIR, item))
                except:
                    print('exception')
                    pass

                # we want to add an item that has an exception so it is not reprocessed on every batch
                processed_items.add(item.Index)
                batch_proc += 1

        else:
            break

    update_dataframes(SEG_4_SEC_DF, segmented_4sec_segs)
    update_dataframes(SEG_6_SEC_DF, segmented_6sec_segs)
    update_dataframes(SEG_10_SEC_DF, segmented_10sec_segs)

    with open(processed_file, 'wb') as pklFile:
        pkl.dump(processed_items, pklFile)

    return processed_items

# %%
start_time = time.time()
# form the language classification file
items_processed = 0
items_to_process = len(items)
while items_to_process > items_processed:
    processed_items = process_record_batch(items, batch_size=50)
    items_processed = len(processed_items)
    print(f'Processed {items_processed} out of {items_to_process} in {time.time()-start_time} seconds')
# Out:
# Processed 50 out of 17198 in 302.9485125541687 seconds
# Processed 100 out of 17198 in 615.9244496822357 seconds
# Processed 150 out of 17198 in 858.7506828308105 seconds
# Processed 200 out of 17198 in 1092.970852613449 seconds
# Processed 250 out of 17198 in 1257.0849568843842 seconds
# Processed 300 out of 17198 in 1572.9709181785583 seconds
# Processed 350 out of 17198 in 1939.4934384822845 seconds
# Processed 400 out of 17198 in 2260.7660009860992 seconds
# Processed 450 out of 17198 in 2539.182901620865 seconds
# Processed 500 out of 17198 in 2802.5111503601074 seconds
# Processed 550 out of 17198 in 3072.93452167511 seconds
# Processed 600 out of 17198 in 3387.944887161255 seconds
# Processed 650 out of 17198 in 3609.1424992084503 seconds
# Processed 700 out of 17198 in 4029.475925207138 seconds
# Processed 750 out of 17198 in 4658.899115085602 seconds
# Processed 800 out of 17198 in 5101.87846159935 seconds
# Processed 850 out of 17198 in 5241.16647362709 seconds
# Processed 900 out of 17198 in 6614.639803647995 seconds
# Processed 950 out of 17198 in 6955.785193681717 seconds
# Processed 1000 out of 17198 in 7211.331946372986 seconds
# Processed 1050 out of 17198 in 7494.531310558319 seconds
# Processed 1100 out of 17198 in 7831.918562173843 seconds
# Processed 1150 out of 17198 in 8199.039200782776 seconds
# Processed 1200 out of 17198 in 13919.015502691269 seconds
# Processed 1250 out of 17198 in 15555.670723199844 seconds
# Processed 1300 out of 17198 in 17097.386725902557 seconds
# Processed 1350 out of 17198 in 18595.70883321762 seconds
# Processed 1400 out of 17198 in 19146.285627126694 seconds
# Processed 1450 out of 17198 in 19516.340103387833 seconds
# Processed 1500 out of 17198 in 19874.551689624786 seconds
# Processed 1550 out of 17198 in 20093.88163805008 seconds
# Processed 1600 out of 17198 in 20295.376225471497 seconds
# Processed 1650 out of 17198 in 20797.64727830887 seconds
# Processed 1700 out of 17198 in 21241.630249261856 seconds
# Processed 1750 out of 17198 in 21527.94073343277 seconds
# Processed 1800 out of 17198 in 21736.04939556122 seconds
# Processed 1850 out of 17198 in 22058.961613178253 seconds
# Processed 1900 out of 17198 in 22381.59181714058 seconds
# Processed 1950 out of 17198 in 22719.811600208282 seconds
# Processed 2000 out of 17198 in 23146.702571630478 seconds
# Processed 2050 out of 17198 in 23486.233444213867 seconds
# Processed 2100 out of 17198 in 23930.920466423035 seconds
# Processed 2150 out of 17198 in 24313.285938978195 seconds
# Processed 2200 out of 17198 in 24600.83233833313 seconds
# Processed 2250 out of 17198 in 24953.012357711792 seconds
# Processed 2300 out of 17198 in 25229.281533002853 seconds
# Processed 2350 out of 17198 in 25576.047111272812 seconds
# Processed 2400 out of 17198 in 25807.743503332138 seconds
# Processed 2450 out of 17198 in 26128.63583922386 seconds
# Processed 2500 out of 17198 in 26449.973984479904 seconds
# Processed 2550 out of 17198 in 26620.818851470947 seconds
# Processed 2600 out of 17198 in 27001.861515283585 seconds
# Processed 2650 out of 17198 in 27474.119827985764 seconds
# Processed 2700 out of 17198 in 27888.118310451508 seconds
# Processed 2750 out of 17198 in 28271.98860859871 seconds
# Processed 2800 out of 17198 in 28598.50913953781 seconds
# Processed 2850 out of 17198 in 28947.480110406876 seconds
# Processed 2900 out of 17198 in 29190.469051361084 seconds
# Processed 2950 out of 17198 in 29331.32000374794 seconds
# Processed 3000 out of 17198 in 29503.423459291458 seconds
# Processed 3050 out of 17198 in 29675.853199243546 seconds
# Processed 3100 out of 17198 in 29870.96546769142 seconds
# Processed 3150 out of 17198 in 30020.933987617493 seconds
# Processed 3200 out of 17198 in 30220.545895576477 seconds
# Processed 3250 out of 17198 in 30436.803506612778 seconds
# Processed 3300 out of 17198 in 30719.370114564896 seconds
# Processed 3350 out of 17198 in 31507.723534822464 seconds
# Processed 3400 out of 17198 in 31956.465005159378 seconds
# Processed 3450 out of 17198 in 32620.668986320496 seconds
# Processed 3500 out of 17198 in 33192.88042926788 seconds
# Processed 3550 out of 17198 in 33453.2599337101 seconds
# Processed 3600 out of 17198 in 33717.815084695816 seconds
# Processed 3650 out of 17198 in 34585.922139406204 seconds
# Processed 3700 out of 17198 in 36090.58135986328 seconds
# Processed 3750 out of 17198 in 36254.7754573822 seconds
# Processed 3800 out of 17198 in 36438.65906047821 seconds
# Processed 3850 out of 17198 in 36623.476212501526 seconds
# Processed 3900 out of 17198 in 36762.93236160278 seconds
# Processed 3950 out of 17198 in 37071.43181228638 seconds
# Processed 4000 out of 17198 in 37399.51053714752 seconds
# Processed 4050 out of 17198 in 37625.88585519791 seconds
# Processed 4100 out of 17198 in 37842.06002020836 seconds
# Processed 4150 out of 17198 in 38973.64961504936 seconds
# Processed 4200 out of 17198 in 39794.46177172661 seconds
# Processed 4250 out of 17198 in 40179.734004974365 seconds
# Processed 4300 out of 17198 in 40558.43118715286 seconds
# Processed 4350 out of 17198 in 40869.5039229393 seconds
# Processed 4400 out of 17198 in 41261.588175058365 seconds
# Processed 4450 out of 17198 in 41763.84416651726 seconds
# Processed 4500 out of 17198 in 42159.416546583176 seconds
# Processed 4550 out of 17198 in 42567.82978963852 seconds
# Processed 4600 out of 17198 in 42930.22313809395 seconds
# Processed 4650 out of 17198 in 43288.10278630257 seconds
# Processed 4700 out of 17198 in 43661.995347976685 seconds
# Processed 4750 out of 17198 in 43911.63237953186 seconds
# Processed 4800 out of 17198 in 44153.569751024246 seconds
# Processed 4850 out of 17198 in 44402.13739490509 seconds
# Processed 4900 out of 17198 in 44619.35841321945 seconds
# Processed 4950 out of 17198 in 44806.5297267437 seconds
# Processed 5000 out of 17198 in 45243.67955970764 seconds
# Processed 5050 out of 17198 in 45908.72534251213 seconds
# Processed 5100 out of 17198 in 46227.95415043831 seconds
# Processed 5150 out of 17198 in 46482.8248257637 seconds
# Processed 5200 out of 17198 in 46976.19636845589 seconds
# Processed 5250 out of 17198 in 47280.41093444824 seconds
# Processed 5300 out of 17198 in 47796.80297541618 seconds
# Processed 5350 out of 17198 in 48431.733229875565 seconds
# Processed 5400 out of 17198 in 48811.70040011406 seconds
# Processed 5450 out of 17198 in 49049.3772187233 seconds
# Processed 5500 out of 17198 in 49201.254227638245 seconds
# Processed 5550 out of 17198 in 49818.04439616203 seconds
# Processed 5600 out of 17198 in 50651.913039922714 seconds
# Processed 5650 out of 17198 in 51066.72837162018 seconds
# Processed 5700 out of 17198 in 51439.6359231472 seconds
# Processed 5750 out of 17198 in 51856.8255610466 seconds
# Processed 5800 out of 17198 in 52179.0809366703 seconds
# Processed 5850 out of 17198 in 52465.01161766052 seconds
# Processed 5900 out of 17198 in 52716.47927355766 seconds
# Processed 5950 out of 17198 in 52943.04570770264 seconds
# Processed 6000 out of 17198 in 53383.95498251915 seconds
# Processed 6050 out of 17198 in 53752.20190620422 seconds
# Processed 6100 out of 17198 in 53994.963200330734 seconds
# Processed 6150 out of 17198 in 54236.70172929764 seconds
# Processed 6200 out of 17198 in 54383.89128398895 seconds
# Processed 6250 out of 17198 in 54581.37996721268 seconds
# Processed 6300 out of 17198 in 54874.732112407684 seconds
# Processed 6350 out of 17198 in 55057.9345099926 seconds
# Processed 6400 out of 17198 in 55352.8776371479 seconds
# Processed 6450 out of 17198 in 55759.85736370087 seconds
# Processed 6500 out of 17198 in 55960.556064367294 seconds
# Processed 6550 out of 17198 in 56231.06581187248 seconds
# Processed 6600 out of 17198 in 56908.90289711952 seconds
# Processed 6650 out of 17198 in 57399.8915040493 seconds
# Processed 6700 out of 17198 in 57757.60815382004 seconds
# Processed 6750 out of 17198 in 58278.499054670334 seconds
# Processed 6800 out of 17198 in 58580.213416814804 seconds
# Processed 6850 out of 17198 in 58924.34884142876 seconds
# Processed 6900 out of 17198 in 59285.73425221443 seconds
# Processed 6950 out of 17198 in 59453.89069247246 seconds
# Processed 7000 out of 17198 in 59636.84727048874 seconds
# Processed 7050 out of 17198 in 59843.793744802475 seconds
# Processed 7100 out of 17198 in 60096.2652990818 seconds
# Processed 7150 out of 17198 in 60364.32197833061 seconds
# Processed 7200 out of 17198 in 60846.6608068943 seconds
# Processed 7250 out of 17198 in 61434.3712413311 seconds
# Processed 7300 out of 17198 in 62522.21016764641 seconds
# Processed 7350 out of 17198 in 64215.47306418419 seconds
# Processed 7400 out of 17198 in 65739.02608704567 seconds
# Processed 7450 out of 17198 in 67651.27012395859 seconds
# Processed 7500 out of 17198 in 68911.30030155182 seconds
# Processed 7550 out of 17198 in 70408.80631685257 seconds
# Processed 7600 out of 17198 in 71846.21901273727 seconds
# Processed 7650 out of 17198 in 72218.66439318657 seconds
# Processed 7700 out of 17198 in 72671.7929763794 seconds
# Processed 7750 out of 17198 in 73636.83775663376 seconds
# Processed 7800 out of 17198 in 74123.31037402153 seconds
# Processed 7850 out of 17198 in 74591.3721575737 seconds
# Processed 7900 out of 17198 in 75248.95788288116 seconds
# Processed 7950 out of 17198 in 75723.66415262222 seconds
# Processed 8000 out of 17198 in 76639.35670900345 seconds
# Processed 8050 out of 17198 in 78293.24426174164 seconds
# Processed 8100 out of 17198 in 78866.64674401283 seconds
# Processed 8150 out of 17198 in 79130.61350607872 seconds
# Processed 8200 out of 17198 in 79761.87267875671 seconds
# Processed 8250 out of 17198 in 80161.04861736298 seconds
# Processed 8300 out of 17198 in 80517.22828364372 seconds
# Processed 8350 out of 17198 in 80768.12417507172 seconds
# Processed 8400 out of 17198 in 81017.96533942223 seconds
# Processed 8450 out of 17198 in 81210.08785510063 seconds
# Processed 8500 out of 17198 in 81567.30117797852 seconds
# Processed 8550 out of 17198 in 81945.7913517952 seconds
# Processed 8600 out of 17198 in 82305.38874387741 seconds
# Processed 8650 out of 17198 in 84071.00516152382 seconds
# Processed 8700 out of 17198 in 84748.04806232452 seconds
# Processed 8750 out of 17198 in 85066.81983470917 seconds
# Processed 8800 out of 17198 in 85939.46141862869 seconds
# Processed 8850 out of 17198 in 87008.81753444672 seconds
# Processed 8900 out of 17198 in 87433.59601545334 seconds
# Processed 8950 out of 17198 in 87681.50443863869 seconds
# Processed 9000 out of 17198 in 87913.2574121952 seconds
# Processed 9050 out of 17198 in 88161.78215694427 seconds
# Processed 9100 out of 17198 in 88380.40985918045 seconds
# Processed 9150 out of 17198 in 88525.54266047478 seconds
# Processed 9200 out of 17198 in 88809.08262348175 seconds
# Processed 9250 out of 17198 in 88998.96435546875 seconds
# Processed 9300 out of 17198 in 89282.20111298561 seconds
# Processed 9350 out of 17198 in 89513.58312368393 seconds
# Processed 9400 out of 17198 in 90102.26017355919 seconds
# Processed 9450 out of 17198 in 90402.1617732048 seconds
# Processed 9500 out of 17198 in 90648.64277625084 seconds
# Processed 9550 out of 17198 in 90913.51163744926 seconds
# Processed 9600 out of 17198 in 91108.02689623833 seconds
# Processed 9650 out of 17198 in 91295.50066518784 seconds
# Processed 9700 out of 17198 in 91526.50887346268 seconds
# Processed 9750 out of 17198 in 91784.62206554413 seconds
# Processed 9800 out of 17198 in 92131.03375601768 seconds
# Processed 9850 out of 17198 in 92265.14518928528 seconds
# Processed 9900 out of 17198 in 92416.812084198 seconds
# Processed 9950 out of 17198 in 92597.51280021667 seconds
# Processed 10000 out of 17198 in 92805.15137505531 seconds
# Processed 10050 out of 17198 in 93158.58887410164 seconds
# Processed 10100 out of 17198 in 93517.91584062576 seconds
# Processed 10150 out of 17198 in 95137.98112535477 seconds
# Processed 10200 out of 17198 in 97983.04428553581 seconds
# Processed 10250 out of 17198 in 98247.79379868507 seconds
# Processed 10300 out of 17198 in 98906.85800528526 seconds
# Processed 10350 out of 17198 in 99989.29093170166 seconds
# Processed 10400 out of 17198 in 100632.93095850945 seconds
# Processed 10450 out of 17198 in 101131.31981253624 seconds
# Processed 10500 out of 17198 in 101368.53649640083 seconds
# Processed 10550 out of 17198 in 101622.0956504345 seconds
# Processed 10600 out of 17198 in 101777.94436502457 seconds
# Processed 10650 out of 17198 in 101954.65486359596 seconds
# Processed 10700 out of 17198 in 102149.74878525734 seconds
# Processed 10750 out of 17198 in 102418.23466491699 seconds
# Processed 10800 out of 17198 in 102641.43271160126 seconds
# Processed 10850 out of 17198 in 102970.37113261223 seconds
# Processed 10900 out of 17198 in 103500.50596523285 seconds
# Processed 10950 out of 17198 in 105504.86692643166 seconds
# Processed 11000 out of 17198 in 106755.78657317162 seconds
# Processed 11050 out of 17198 in 107632.79088377953 seconds
# Processed 11100 out of 17198 in 108148.91832065582 seconds
# Processed 11150 out of 17198 in 108394.51839923859 seconds
# Processed 11200 out of 17198 in 108857.20530200005 seconds
# Processed 11250 out of 17198 in 109266.2489259243 seconds
# Processed 11300 out of 17198 in 109514.98939728737 seconds
# Processed 11350 out of 17198 in 109790.00867342949 seconds
# Processed 11400 out of 17198 in 110002.77953743935 seconds
# Processed 11450 out of 17198 in 110262.09372019768 seconds
# Processed 11500 out of 17198 in 110610.56387448311 seconds
# Processed 11550 out of 17198 in 111132.56389451027 seconds
# Processed 11600 out of 17198 in 111379.22354507446 seconds
# Processed 11650 out of 17198 in 111482.13596129417 seconds
# Processed 11700 out of 17198 in 111605.95996260643 seconds
# Processed 11750 out of 17198 in 111728.86571383476 seconds
# Processed 11800 out of 17198 in 112138.9483897686 seconds
# Processed 11850 out of 17198 in 112389.54948878288 seconds
# Processed 11900 out of 17198 in 112706.49057602882 seconds
# Processed 11950 out of 17198 in 112983.80628752708 seconds
# Processed 12000 out of 17198 in 113314.59013104439 seconds
# Processed 12050 out of 17198 in 113517.07214403152 seconds
# Processed 12100 out of 17198 in 113736.30716443062 seconds
# Processed 12150 out of 17198 in 114050.2141623497 seconds
# Processed 12200 out of 17198 in 114379.49246644974 seconds
# Processed 12250 out of 17198 in 114605.75651478767 seconds
# Processed 12300 out of 17198 in 115008.53029537201 seconds
# Processed 12350 out of 17198 in 115227.42875933647 seconds
# Processed 12400 out of 17198 in 115726.68889713287 seconds
# Processed 12450 out of 17198 in 116310.72600507736 seconds
# Processed 12500 out of 17198 in 116906.21956062317 seconds
# Processed 12550 out of 17198 in 117429.07269215584 seconds
# Processed 12600 out of 17198 in 117629.91301298141 seconds
# Processed 12650 out of 17198 in 117827.64233827591 seconds
# Processed 12700 out of 17198 in 118006.24833750725 seconds
# Processed 12750 out of 17198 in 118151.72362184525 seconds
# Processed 12800 out of 17198 in 118388.03793048859 seconds
# Processed 12850 out of 17198 in 118892.44655323029 seconds
# Processed 12900 out of 17198 in 119113.35807967186 seconds
# Processed 12950 out of 17198 in 119316.50642323494 seconds
# Processed 13000 out of 17198 in 119467.34451341629 seconds
# Processed 13050 out of 17198 in 119705.76486158371 seconds
# Processed 13100 out of 17198 in 120002.33386540413 seconds
# Processed 13150 out of 17198 in 120209.77352285385 seconds
# Processed 13200 out of 17198 in 120487.67556762695 seconds
# Processed 13250 out of 17198 in 120892.58934140205 seconds
# Processed 13300 out of 17198 in 121172.15793609619 seconds
# Processed 13350 out of 17198 in 121503.13227033615 seconds
# Processed 13400 out of 17198 in 121897.55950713158 seconds
# Processed 13450 out of 17198 in 122436.49879312515 seconds
# Processed 13500 out of 17198 in 123174.90136098862 seconds
# Processed 13550 out of 17198 in 123499.02527141571 seconds
# Processed 13600 out of 17198 in 124047.6301252842 seconds
# Processed 13650 out of 17198 in 124423.58901143074 seconds
# Processed 13700 out of 17198 in 124899.72327136993 seconds
# Processed 13750 out of 17198 in 125236.26454114914 seconds
# Processed 13800 out of 17198 in 125412.72412896156 seconds
# Processed 13850 out of 17198 in 126104.02543115616 seconds
# Processed 13900 out of 17198 in 126481.97431778908 seconds
# Processed 13950 out of 17198 in 126811.59913802147 seconds
# Processed 14000 out of 17198 in 127102.25379347801 seconds
# Processed 14050 out of 17198 in 127802.61164784431 seconds
# Processed 14100 out of 17198 in 128062.88328695297 seconds
# Processed 14150 out of 17198 in 128311.94453024864 seconds
# Processed 14200 out of 17198 in 128501.26149344444 seconds
# Processed 14250 out of 17198 in 128730.26569509506 seconds
# Processed 14300 out of 17198 in 128905.10643696785 seconds
# Processed 14350 out of 17198 in 129228.40799379349 seconds
# Processed 14400 out of 17198 in 129553.51619386673 seconds
# Processed 14450 out of 17198 in 129944.37823748589 seconds
# Processed 14500 out of 17198 in 130258.51605057716 seconds
# Processed 14550 out of 17198 in 130536.76433944702 seconds
# Processed 14600 out of 17198 in 130843.42534708977 seconds
# Processed 14650 out of 17198 in 131870.28969955444 seconds
# Processed 14700 out of 17198 in 132219.91856241226 seconds
# Processed 14750 out of 17198 in 132907.63399529457 seconds
# Processed 14800 out of 17198 in 133469.99745893478 seconds
# Processed 14850 out of 17198 in 134009.1401541233 seconds
# Processed 14900 out of 17198 in 134495.18291807175 seconds
# Processed 14950 out of 17198 in 135335.14279270172 seconds
# Processed 15000 out of 17198 in 139379.58560061455 seconds
# Processed 15050 out of 17198 in 142188.92578673363 seconds
# Processed 15100 out of 17198 in 143280.2268590927 seconds
# Processed 15150 out of 17198 in 144247.43362689018 seconds
# Processed 15200 out of 17198 in 144664.67085528374 seconds
# Processed 15250 out of 17198 in 145007.8471364975 seconds
# Processed 15300 out of 17198 in 145399.43091201782 seconds
# Processed 15350 out of 17198 in 146269.9765689373 seconds
# Processed 15400 out of 17198 in 146646.60667800903 seconds
# Processed 15450 out of 17198 in 147156.80665016174 seconds
# Processed 15500 out of 17198 in 147606.6059372425 seconds
# Processed 15550 out of 17198 in 148149.87169122696 seconds
# Processed 15600 out of 17198 in 148573.54794073105 seconds
# Processed 15650 out of 17198 in 148884.13865923882 seconds
# Processed 15700 out of 17198 in 149191.54866576195 seconds
# Processed 15750 out of 17198 in 149535.69612121582 seconds
# Processed 15800 out of 17198 in 149835.04921984673 seconds
# Processed 15850 out of 17198 in 150158.99140381813 seconds
# Processed 15900 out of 17198 in 150487.2873389721 seconds
# Processed 15950 out of 17198 in 150876.18453884125 seconds
# Processed 16000 out of 17198 in 151150.62171173096 seconds
# Processed 16050 out of 17198 in 151408.24354076385 seconds
# Processed 16100 out of 17198 in 151683.7001452446 seconds
# Processed 16150 out of 17198 in 152036.93733787537 seconds
# Processed 16200 out of 17198 in 152295.0880405903 seconds
# Processed 16250 out of 17198 in 152658.72911310196 seconds
# Processed 16300 out of 17198 in 152868.92828679085 seconds
# Processed 16350 out of 17198 in 153017.62432789803 seconds
# Processed 16400 out of 17198 in 153184.25623774529 seconds
# Processed 16450 out of 17198 in 153372.58349084854 seconds
# Processed 16500 out of 17198 in 153593.0507888794 seconds
# Processed 16550 out of 17198 in 153806.45431947708 seconds
# Processed 16600 out of 17198 in 154001.14715600014 seconds
# Processed 16650 out of 17198 in 154246.95093631744 seconds
# Processed 16700 out of 17198 in 154414.8829085827 seconds
# Processed 16750 out of 17198 in 154767.36814975739 seconds
# Processed 16800 out of 17198 in 155002.61925005913 seconds
# Processed 16850 out of 17198 in 155248.06571626663 seconds
# Processed 16900 out of 17198 in 155424.14086580276 seconds
# Processed 16950 out of 17198 in 155588.39550685883 seconds
# Processed 17000 out of 17198 in 155830.36768054962 seconds
# Processed 17050 out of 17198 in 156048.3567919731 seconds
# Processed 17100 out of 17198 in 156315.2974050045 seconds
# Processed 17150 out of 17198 in 156494.04894065857 seconds
# Processed 17198 out of 17198 in 156712.24662923813 seconds
