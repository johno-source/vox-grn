# %% [markdown]
# # Partial Process of Segment GRN Data for vox-grn
#
# See SegmentVox.ipynb for full description.
#
# In an attempt to speed up the processing I have divided the items up into 10 groups and want to have them all process in parallel. It probably won't be 10 times faster but it should still be quicker.

# %%
import pandas as pd
import numpy as np
import os
import sys
module_path = os.path.abspath(os.path.join('../vad_utils'))
if module_path not in sys.path:
    sys.path.append(module_path)
from vad_utils import SAMPLING_RATE, FRAME_SIZE_MS, SAMPLES_PER_FRAME
import vad_utils as vu
from pydub import AudioSegment
import pickle as pkl
from pathlib import Path
import time

# %%
# define the locations for each of the file types
NOTEBOOK_ID=7
SEGMENTS_DIR = '/media/originals/segments/'
DATASETS_DIR = '/media/originals/datasets/'
SEC_4_DATA_DIR = 'seg_4sec/data/'
SEC_6_DATA_DIR = 'seg_6sec/data/'
SEC_10_DATA_DIR = 'seg_10sec/data/'

# define specific files used in the process
SEG_4_SEC_DF = f'{SEGMENTS_DIR}seg_4sec_{NOTEBOOK_ID}.csv'
SEG_6_SEC_DF = f'{SEGMENTS_DIR}seg_6sec_{NOTEBOOK_ID}.csv'
SEG_10_SEC_DF = f'{SEGMENTS_DIR}seg_10sec_{NOTEBOOK_ID}.csv'

# define segment sizes for each dataset
SEG_4_SEC = 4.0
SEG_6_SEC = 6.0
SEG_10_SEC = 10.0

# %%
# Now read in the description of the input and remove the unwanted columns and rename the rest to be python attribute names.
items = pd.read_csv(f'/media/originals/segments/items_{NOTEBOOK_ID}.csv')
items.set_index('ID', inplace=True)
items.columns
# Out:
# Index(['iso', 'program', 'location', 'year', 'path', 'filename', 'item_no',
#        'title', 'start', 'end'],
#       dtype='object')

# %%
print(items.iloc[100])
# Out:
# iso                                  quw
# program                           A38065
# location                             NaN
# year                              2010.0
# path        Programs/38/38065/A38065/PM/
# filename                   A38065-13.wav
# item_no                               13
# title                         Picture 13
# start                                0.0
# end                                 56.0
# Name: A38065_013, dtype: object

# %%
print(items.index)
# Out:
# Index(['A34740_017', 'A34740_018', 'A34740_019', 'A34740_020', 'A34740_021',
#        'A34430_000', 'A34740_022', 'A34740_023', 'A34430_001', 'A34430_004',
#        ...
#        'A65511_003', 'A65511_002', 'A65511_001', 'A65510_025', 'A65510_024',
#        'A65511_010', 'A65509_008', 'A65511_024', 'A65512_001', 'A65509_006'],
#       dtype='object', name='ID', length=17198)

# %%
# generate directories and filenames
def prepare_dir(dirname):
    if dirname[-1] != '/':
        dirname = dirname + '/'
    Path(dirname).mkdir(parents=True, exist_ok=True)
    return dirname

def prepare_raw_seg_dir(item):
    return prepare_dir(SEGMENTS_DIR + item.iso)

def raw_seg_filename(item):
    return f'{item.program}_{item.item_no:03d}.pkl'

def prepare_dataset_data_dir(item, dataset_dir):
    return prepare_dir(DATASETS_DIR + dataset_dir + item.iso)

def seg_mp3_filename(item, seg):
    return f'{item.program}_{item.item_no:03d}_{seg:03d}.mp3'

# %%
def condition_audio_segment(audio_seg):
    if audio_seg.channels != 1:
        audio_seg = audio_seg.set_channels(1)

    if audio_seg.sample_width != 2:
        audio_seg = audio_seg.set_sample_width(2)

    if audio_seg.frame_rate != SAMPLING_RATE:
        audio_seg = audio_seg.set_frame_rate(SAMPLING_RATE)

    return audio_seg

# %%
def save_the_segment_info(item, segs):
    fname = prepare_raw_seg_dir(item) + raw_seg_filename(item)
    with open(fname, 'wb') as pklFile:
         pkl.dump(segs, pklFile)

def read_the_segment_info(item):
    fname = prepare_raw_seg_dir(item) + raw_seg_filename(item)
    if os.path.exists(fname):
        if os.path.getsize(fname) > 0:
            with open(fname, 'rb') as pklFile:
                return pkl.load(pklFile)
    return []
    
def extract_audio_segment_for_item(item):
    fmt = 'wav'
    if item.filename[-4:] == '.mp3' :
        fmt = 'mp3'
    audio_seg = AudioSegment.from_file('/media/programs/' + item.path + item.filename, format=fmt)
    start_ms = int(item.start * 1000)
    end_ms = int(item.end * 1000)
    audio_seg = audio_seg[start_ms:end_ms]

    # now condition the segment and extract the raw segments.
    audio_seg = condition_audio_segment(audio_seg)
    segs = read_the_segment_info(item)
    if len(segs) == 0:
        segs = vu.audio_to_raw_voice_segments(audio_seg)
        save_the_segment_info(item, segs)

    return audio_seg, segs

def create_mp3_files(audio_seg, segs, time_per_segment, dataset_dir, item):
    segs_for_time = vu.divide_into_segments(segs, time_per_segment)

    # now write out the 4 sec segments
    dirname = prepare_dataset_data_dir(item, dataset_dir)
    rows = list()
    for i, seg in enumerate(segs_for_time):
        file_name = dataset_dir + item.iso + '/' + seg_mp3_filename(item, i)
        fname = dirname + seg_mp3_filename(item, i)
        if not os.path.exists(fname):
            start = vu.convert_frames_to_ms(seg.start)
            stop = vu.convert_frames_to_ms(seg.stop)
            audio_seg[start:stop].export(fname, format='mp3', bitrate='32k')
        desc = dict(item._asdict())
        desc['seg_start'] = vu.convert_frames_to_seconds(seg.start)
        desc['seg_stop'] = vu.convert_frames_to_seconds(seg.stop)
        desc['seg'] = i
        desc['file_name'] = file_name
        rows.append(desc)

    return rows

def update_dataframes(seg_df_csv, seg_records):
    # now update the dataframes
    if len(seg_records) > 0:
        if os.path.isfile(seg_df_csv):
            seg_sec_df = pd.concat([pd.read_csv(seg_df_csv, index_col='file_name'), pd.DataFrame.from_records(seg_records, index='file_name')])
        else:
            seg_sec_df = pd.DataFrame.from_records(seg_records, index='file_name')
        seg_sec_df.to_csv(seg_df_csv)

# %%
# processing these items might take a very long time. To permit the process to be interrupted and restarted the indexes of processed items
# are maintained in a set that is pickled on each batch. This allows the batch to quickly pick up where it left off.
def process_record_batch(items_df, *, batch_size=10):
    batch_proc = 0
    processed_file = f'/media/originals/segments/processed16_{NOTEBOOK_ID}.pkl'
    if os.path.isfile(processed_file):
        with open(processed_file, 'rb') as pklFile:
            processed_items = pkl.load(pklFile)
    else:
        processed_items = set()

    segmented_4sec_segs = []
    segmented_6sec_segs = []
    segmented_10sec_segs = []

    for item in items_df.itertuples():
        if batch_proc < batch_size:
            if item.Index not in processed_items:
                try:
                    audio_seg, voice_segs = extract_audio_segment_for_item(item)
                    segmented_4sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_4_SEC, SEC_4_DATA_DIR, item))
                    segmented_6sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_6_SEC, SEC_6_DATA_DIR, item))
                    segmented_10sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_10_SEC, SEC_10_DATA_DIR, item))
                except:
                    print('exception')
                    pass

                # we want to add an item that has an exception so it is not reprocessed on every batch
                processed_items.add(item.Index)
                batch_proc += 1

        else:
            break

    update_dataframes(SEG_4_SEC_DF, segmented_4sec_segs)
    update_dataframes(SEG_6_SEC_DF, segmented_6sec_segs)
    update_dataframes(SEG_10_SEC_DF, segmented_10sec_segs)

    with open(processed_file, 'wb') as pklFile:
        pkl.dump(processed_items, pklFile)

    return processed_items

# %%
start_time = time.time()
# form the language classification file
items_processed = 0
items_to_process = len(items)
while items_to_process > items_processed:
    processed_items = process_record_batch(items, batch_size=50)
    items_processed = len(processed_items)
    print(f'Processed {items_processed} out of {items_to_process} in {time.time()-start_time} seconds')
# Out:
# Processed 50 out of 17198 in 263.1019971370697 seconds
# Processed 100 out of 17198 in 427.8968172073364 seconds
# Processed 150 out of 17198 in 811.683792591095 seconds
# Processed 200 out of 17198 in 1196.7191784381866 seconds
# Processed 250 out of 17198 in 1418.9101870059967 seconds
# Processed 300 out of 17198 in 1680.5994403362274 seconds
# Processed 350 out of 17198 in 2018.4223477840424 seconds
# Processed 400 out of 17198 in 2382.0411109924316 seconds
# Processed 450 out of 17198 in 2673.414215564728 seconds
# Processed 500 out of 17198 in 3021.5291521549225 seconds
# Processed 550 out of 17198 in 3328.707935333252 seconds
# Processed 600 out of 17198 in 3558.1055212020874 seconds
# Processed 650 out of 17198 in 3816.308929681778 seconds
# Processed 700 out of 17198 in 3942.9093301296234 seconds
# Processed 750 out of 17198 in 4200.114609241486 seconds
# Processed 800 out of 17198 in 4600.270491838455 seconds
# Processed 850 out of 17198 in 4821.958763122559 seconds
# Processed 900 out of 17198 in 5111.571439504623 seconds
# Processed 950 out of 17198 in 5403.84698677063 seconds
# Processed 1000 out of 17198 in 5743.305229663849 seconds
# Processed 1050 out of 17198 in 6147.679609775543 seconds
# Processed 1100 out of 17198 in 6500.387780189514 seconds
# Processed 1150 out of 17198 in 6752.431168556213 seconds
# Processed 1200 out of 17198 in 7031.365754365921 seconds
# Processed 1250 out of 17198 in 7266.576899528503 seconds
# Processed 1300 out of 17198 in 7524.792756080627 seconds
# Processed 1350 out of 17198 in 8314.138783931732 seconds
# Processed 1400 out of 17198 in 9076.495948791504 seconds
# Processed 1450 out of 17198 in 11389.242359161377 seconds
# Processed 1500 out of 17198 in 16921.360746860504 seconds
# Processed 1550 out of 17198 in 22143.658711910248 seconds
# Processed 1600 out of 17198 in 22399.944378376007 seconds
# Processed 1650 out of 17198 in 22689.368780851364 seconds
# Processed 1700 out of 17198 in 22960.6071228981 seconds
# Processed 1750 out of 17198 in 23228.746151208878 seconds
# Processed 1800 out of 17198 in 23604.27044391632 seconds
# Processed 1850 out of 17198 in 24219.427782535553 seconds
# Processed 1900 out of 17198 in 24464.23268342018 seconds
# Processed 1950 out of 17198 in 24910.053365945816 seconds
# Processed 2000 out of 17198 in 25194.733318567276 seconds
# Processed 2050 out of 17198 in 25319.155244112015 seconds
# Processed 2100 out of 17198 in 25536.19870710373 seconds
# Processed 2150 out of 17198 in 26000.724152326584 seconds
# Processed 2200 out of 17198 in 26252.063296318054 seconds
# Processed 2250 out of 17198 in 26454.44587445259 seconds
# Processed 2300 out of 17198 in 26660.163846731186 seconds
# Processed 2350 out of 17198 in 26926.723866939545 seconds
# Processed 2400 out of 17198 in 27091.74149107933 seconds
# Processed 2450 out of 17198 in 27261.248725414276 seconds
# Processed 2500 out of 17198 in 27445.939242362976 seconds
# Processed 2550 out of 17198 in 27612.374792099 seconds
# Processed 2600 out of 17198 in 28151.255246162415 seconds
# Processed 2650 out of 17198 in 28456.64235973358 seconds
# Processed 2700 out of 17198 in 28915.336136102676 seconds
# Processed 2750 out of 17198 in 29209.30325961113 seconds
# Processed 2800 out of 17198 in 29359.756504058838 seconds
# Processed 2850 out of 17198 in 29688.620531082153 seconds
# Processed 2900 out of 17198 in 29987.35754799843 seconds
# Processed 2950 out of 17198 in 30272.235159158707 seconds
# Processed 3000 out of 17198 in 30558.0803732872 seconds
# Processed 3050 out of 17198 in 30785.393250226974 seconds
# Processed 3100 out of 17198 in 31037.556283712387 seconds
# Processed 3150 out of 17198 in 31513.78280687332 seconds
# Processed 3200 out of 17198 in 31726.52416920662 seconds
# Processed 3250 out of 17198 in 32365.760541915894 seconds
# Processed 3300 out of 17198 in 33676.24484539032 seconds
# Processed 3350 out of 17198 in 36149.847255945206 seconds
# Processed 3400 out of 17198 in 37872.84542322159 seconds
# Processed 3450 out of 17198 in 38268.26785182953 seconds
# Processed 3500 out of 17198 in 38517.702694654465 seconds
# Processed 3550 out of 17198 in 38896.065588474274 seconds
# Processed 3600 out of 17198 in 39293.260239839554 seconds
# Processed 3650 out of 17198 in 39702.078127622604 seconds
# Processed 3700 out of 17198 in 40054.32096195221 seconds
# Processed 3750 out of 17198 in 40241.920263290405 seconds
# Processed 3800 out of 17198 in 40426.79942750931 seconds
# Processed 3850 out of 17198 in 40703.775648117065 seconds
# Processed 3900 out of 17198 in 40952.66171479225 seconds
# Processed 3950 out of 17198 in 41153.20830273628 seconds
# Processed 4000 out of 17198 in 41360.64817070961 seconds
# Processed 4050 out of 17198 in 41667.50331521034 seconds
# Processed 4100 out of 17198 in 42164.91067504883 seconds
# Processed 4150 out of 17198 in 42825.853912353516 seconds
# Processed 4200 out of 17198 in 43505.488619565964 seconds
# Processed 4250 out of 17198 in 44291.21024274826 seconds
# Processed 4300 out of 17198 in 45347.27764105797 seconds
# Processed 4350 out of 17198 in 46762.30005836487 seconds
# Processed 4400 out of 17198 in 48259.96564936638 seconds
# Processed 4450 out of 17198 in 49592.707604408264 seconds
# Processed 4500 out of 17198 in 50960.140219926834 seconds
# Processed 4550 out of 17198 in 52235.211428403854 seconds
# Processed 4600 out of 17198 in 52948.27988433838 seconds
# Processed 4650 out of 17198 in 54112.98346757889 seconds
# Processed 4700 out of 17198 in 55215.0213868618 seconds
# Processed 4750 out of 17198 in 55973.11761546135 seconds
# Processed 4800 out of 17198 in 56091.62906193733 seconds
# Processed 4850 out of 17198 in 56344.54749798775 seconds
# Processed 4900 out of 17198 in 56591.096333265305 seconds
# Processed 4950 out of 17198 in 56817.60289478302 seconds
# Processed 5000 out of 17198 in 57004.24391531944 seconds
# Processed 5050 out of 17198 in 57324.391404390335 seconds
# Processed 5100 out of 17198 in 57583.8293132782 seconds
# Processed 5150 out of 17198 in 58019.00016999245 seconds
# Processed 5200 out of 17198 in 58262.916619062424 seconds
# Processed 5250 out of 17198 in 59125.73571753502 seconds
# Processed 5300 out of 17198 in 59557.07355761528 seconds
# Processed 5350 out of 17198 in 59778.755642175674 seconds
# Processed 5400 out of 17198 in 60168.28936171532 seconds
# Processed 5450 out of 17198 in 60427.70361018181 seconds
# Processed 5500 out of 17198 in 60830.30186367035 seconds
# Processed 5550 out of 17198 in 60962.64108633995 seconds
# Processed 5600 out of 17198 in 61186.13650512695 seconds
# Processed 5650 out of 17198 in 61646.00176811218 seconds
# Processed 5700 out of 17198 in 61960.21758365631 seconds
# Processed 5750 out of 17198 in 62344.68573498726 seconds
# Processed 5800 out of 17198 in 62581.420665979385 seconds
# Processed 5850 out of 17198 in 63224.00799226761 seconds
# Processed 5900 out of 17198 in 64384.97439455986 seconds
# Processed 5950 out of 17198 in 64815.413232803345 seconds
# Processed 6000 out of 17198 in 65138.52391910553 seconds
# Processed 6050 out of 17198 in 66283.4908876419 seconds
# Processed 6100 out of 17198 in 66685.75378465652 seconds
# Processed 6150 out of 17198 in 66820.4919295311 seconds
# Processed 6200 out of 17198 in 66957.75791835785 seconds
# Processed 6250 out of 17198 in 67059.41101169586 seconds
# Processed 6300 out of 17198 in 67183.27539944649 seconds
# Processed 6350 out of 17198 in 67335.62860870361 seconds
# Processed 6400 out of 17198 in 67507.1945476532 seconds
# Processed 6450 out of 17198 in 67672.37422394753 seconds
# Processed 6500 out of 17198 in 67840.35162901878 seconds
# Processed 6550 out of 17198 in 68091.5771048069 seconds
# Processed 6600 out of 17198 in 68446.54438662529 seconds
# Processed 6650 out of 17198 in 68708.99412918091 seconds
# Processed 6700 out of 17198 in 69060.97549581528 seconds
# Processed 6750 out of 17198 in 69192.28432226181 seconds
# Processed 6800 out of 17198 in 69335.42296981812 seconds
# Processed 6850 out of 17198 in 69466.47732782364 seconds
# Processed 6900 out of 17198 in 69788.59275984764 seconds
# Processed 6950 out of 17198 in 70278.36553096771 seconds
# Processed 7000 out of 17198 in 73437.35141468048 seconds
# Processed 7050 out of 17198 in 74313.90665221214 seconds
# Processed 7100 out of 17198 in 76226.089864254 seconds
# Processed 7150 out of 17198 in 77472.6505124569 seconds
# Processed 7200 out of 17198 in 78306.04126429558 seconds
# Processed 7250 out of 17198 in 78770.65977978706 seconds
# Processed 7300 out of 17198 in 79554.13947701454 seconds
# Processed 7350 out of 17198 in 79712.21256780624 seconds
# Processed 7400 out of 17198 in 79894.96353387833 seconds
# Processed 7450 out of 17198 in 80074.86295461655 seconds
# Processed 7500 out of 17198 in 80390.79201579094 seconds
# Processed 7550 out of 17198 in 81311.37354683876 seconds
# Processed 7600 out of 17198 in 81670.68758773804 seconds
# Processed 7650 out of 17198 in 81833.54515814781 seconds
# Processed 7700 out of 17198 in 82048.44116830826 seconds
# Processed 7750 out of 17198 in 82211.0312743187 seconds
# Processed 7800 out of 17198 in 82415.53060531616 seconds
# Processed 7850 out of 17198 in 82768.67921185493 seconds
# Processed 7900 out of 17198 in 83179.4717001915 seconds
# Processed 7950 out of 17198 in 83467.8560166359 seconds
# Processed 8000 out of 17198 in 83599.88850951195 seconds
# /tmp/ipykernel_434337/3773699355.py:58: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   seg_sec_df = pd.concat([pd.read_csv(seg_df_csv, index_col='file_name'), pd.DataFrame.from_records(seg_records, index='file_name')])
# Processed 8050 out of 17198 in 83759.97998738289 seconds
# /tmp/ipykernel_434337/3773699355.py:58: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   seg_sec_df = pd.concat([pd.read_csv(seg_df_csv, index_col='file_name'), pd.DataFrame.from_records(seg_records, index='file_name')])
# Processed 8100 out of 17198 in 83909.90260505676 seconds
# /tmp/ipykernel_434337/3773699355.py:58: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   seg_sec_df = pd.concat([pd.read_csv(seg_df_csv, index_col='file_name'), pd.DataFrame.from_records(seg_records, index='file_name')])
# Processed 8150 out of 17198 in 84080.0690832138 seconds
# /tmp/ipykernel_434337/3773699355.py:58: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   seg_sec_df = pd.concat([pd.read_csv(seg_df_csv, index_col='file_name'), pd.DataFrame.from_records(seg_records, index='file_name')])
# Processed 8200 out of 17198 in 84266.98104739189 seconds
# Processed 8250 out of 17198 in 84486.23222780228 seconds
# Processed 8300 out of 17198 in 84907.92709136009 seconds
# Processed 8350 out of 17198 in 85278.03494381905 seconds
# Processed 8400 out of 17198 in 85519.71409392357 seconds
# Processed 8450 out of 17198 in 85706.68019294739 seconds
# Processed 8500 out of 17198 in 86142.52204108238 seconds
# Processed 8550 out of 17198 in 86265.44525313377 seconds
# Processed 8600 out of 17198 in 86324.30108714104 seconds
# Processed 8650 out of 17198 in 86638.3285279274 seconds
# Processed 8700 out of 17198 in 86769.86448287964 seconds
# Processed 8750 out of 17198 in 87012.4134259224 seconds
# Processed 8800 out of 17198 in 87745.72955465317 seconds
# Processed 8850 out of 17198 in 89541.6727399826 seconds
# Processed 8900 out of 17198 in 90456.42256259918 seconds
# Processed 8950 out of 17198 in 90823.83060264587 seconds
# Processed 9000 out of 17198 in 90991.65710043907 seconds
# Processed 9050 out of 17198 in 91179.29589986801 seconds
# Processed 9100 out of 17198 in 91493.3870434761 seconds
# Processed 9150 out of 17198 in 92281.24123644829 seconds
# Processed 9200 out of 17198 in 94399.75286436081 seconds
# Processed 9250 out of 17198 in 99073.99923324585 seconds
# Processed 9300 out of 17198 in 99903.86627364159 seconds
# Processed 9350 out of 17198 in 100190.07387471199 seconds
# Processed 9400 out of 17198 in 100641.56837153435 seconds
# Processed 9450 out of 17198 in 100809.13173627853 seconds
# Processed 9500 out of 17198 in 101149.2606022358 seconds
# Processed 9550 out of 17198 in 101634.64193820953 seconds
# Processed 9600 out of 17198 in 101813.07820415497 seconds
# Processed 9650 out of 17198 in 102077.57370114326 seconds
# Processed 9700 out of 17198 in 102467.28664207458 seconds
# Processed 9750 out of 17198 in 102681.2175321579 seconds
# Processed 9800 out of 17198 in 102987.51054596901 seconds
# Processed 9850 out of 17198 in 103338.31405305862 seconds
# Processed 9900 out of 17198 in 103787.49306488037 seconds
# Processed 9950 out of 17198 in 104077.78855419159 seconds
# Processed 10000 out of 17198 in 104538.6886754036 seconds
# Processed 10050 out of 17198 in 105013.21913266182 seconds
# Processed 10100 out of 17198 in 105369.90916585922 seconds
# Processed 10150 out of 17198 in 105589.96713280678 seconds
# Processed 10200 out of 17198 in 105831.15701699257 seconds
# Processed 10250 out of 17198 in 106085.66381192207 seconds
# Processed 10300 out of 17198 in 106411.11478257179 seconds
# Processed 10350 out of 17198 in 106634.85538887978 seconds
# Processed 10400 out of 17198 in 106762.26240897179 seconds
# Processed 10450 out of 17198 in 106969.47359728813 seconds
# Processed 10500 out of 17198 in 107163.50746297836 seconds
# Processed 10550 out of 17198 in 107345.43046689034 seconds
# Processed 10600 out of 17198 in 107565.91481876373 seconds
# Processed 10650 out of 17198 in 107819.84854793549 seconds
# Processed 10700 out of 17198 in 108138.6767129898 seconds
# Processed 10750 out of 17198 in 108393.5811085701 seconds
# Processed 10800 out of 17198 in 108647.6861975193 seconds
# Processed 10850 out of 17198 in 108835.89105391502 seconds
# Processed 10900 out of 17198 in 109155.17844319344 seconds
# Processed 10950 out of 17198 in 109415.05312108994 seconds
# Processed 11000 out of 17198 in 109756.87774276733 seconds
# Processed 11050 out of 17198 in 109932.3032746315 seconds
# Processed 11100 out of 17198 in 110221.50731277466 seconds
# Processed 11150 out of 17198 in 110457.66406536102 seconds
# Processed 11200 out of 17198 in 110632.83018255234 seconds
# Processed 11250 out of 17198 in 110996.5960521698 seconds
# Processed 11300 out of 17198 in 111462.01984763145 seconds
# Processed 11350 out of 17198 in 111711.6064286232 seconds
# Processed 11400 out of 17198 in 111954.43425869942 seconds
# Processed 11450 out of 17198 in 112193.10569667816 seconds
# Processed 11500 out of 17198 in 112469.04154753685 seconds
# Processed 11550 out of 17198 in 112780.1219933033 seconds
# Processed 11600 out of 17198 in 113059.93035936356 seconds
# Processed 11650 out of 17198 in 113709.45085573196 seconds
# Processed 11700 out of 17198 in 113982.02505040169 seconds
# Processed 11750 out of 17198 in 114417.23975300789 seconds
# Processed 11800 out of 17198 in 114638.00548243523 seconds
# Processed 11850 out of 17198 in 115241.86790728569 seconds
# Processed 11900 out of 17198 in 115803.53474783897 seconds
# Processed 11950 out of 17198 in 116023.66477632523 seconds
# Processed 12000 out of 17198 in 116206.64822292328 seconds
# Processed 12050 out of 17198 in 116393.6030151844 seconds
# Processed 12100 out of 17198 in 116651.39968538284 seconds
# Processed 12150 out of 17198 in 116769.0976319313 seconds
# Processed 12200 out of 17198 in 116929.56147646904 seconds
# Processed 12250 out of 17198 in 117066.1225039959 seconds
# Processed 12300 out of 17198 in 117270.89778470993 seconds
# Processed 12350 out of 17198 in 117408.9509601593 seconds
# Processed 12400 out of 17198 in 117556.33003997803 seconds
# Processed 12450 out of 17198 in 117877.77460670471 seconds
# Processed 12500 out of 17198 in 117993.9531686306 seconds
# Processed 12550 out of 17198 in 118075.61761569977 seconds
# Processed 12600 out of 17198 in 118235.63742613792 seconds
# Processed 12650 out of 17198 in 118543.54868364334 seconds
# Processed 12700 out of 17198 in 119515.27912187576 seconds
# Processed 12750 out of 17198 in 121334.30025458336 seconds
# Processed 12800 out of 17198 in 121522.61451935768 seconds
# Processed 12850 out of 17198 in 121823.00907063484 seconds
# Processed 12900 out of 17198 in 122097.71795392036 seconds
# Processed 12950 out of 17198 in 122377.85608673096 seconds
# Processed 13000 out of 17198 in 122613.23747110367 seconds
# Processed 13050 out of 17198 in 123124.1650083065 seconds
# Processed 13100 out of 17198 in 123387.58776116371 seconds
# Processed 13150 out of 17198 in 123620.50693035126 seconds
# Processed 13200 out of 17198 in 123893.18910837173 seconds
# Processed 13250 out of 17198 in 124093.52250981331 seconds
# Processed 13300 out of 17198 in 124315.92042469978 seconds
# Processed 13350 out of 17198 in 124596.59351491928 seconds
# Processed 13400 out of 17198 in 124883.96101474762 seconds
# Processed 13450 out of 17198 in 125144.25999999046 seconds
# Processed 13500 out of 17198 in 125539.62054085732 seconds
# Processed 13550 out of 17198 in 125842.21837067604 seconds
# Processed 13600 out of 17198 in 126098.81545329094 seconds
# Processed 13650 out of 17198 in 126407.86623954773 seconds
# Processed 13700 out of 17198 in 126561.462474823 seconds
# Processed 13750 out of 17198 in 126769.50307106972 seconds
# Processed 13800 out of 17198 in 126969.24983596802 seconds
# Processed 13850 out of 17198 in 127297.81644701958 seconds
# Processed 13900 out of 17198 in 127672.28373241425 seconds
# Processed 13950 out of 17198 in 128895.76496362686 seconds
# Processed 14000 out of 17198 in 131593.3785762787 seconds
# Processed 14050 out of 17198 in 134052.00067305565 seconds
# Processed 14100 out of 17198 in 137163.49236178398 seconds
# Processed 14150 out of 17198 in 137549.29728794098 seconds
# Processed 14200 out of 17198 in 137713.20957231522 seconds
# Processed 14250 out of 17198 in 138065.47883367538 seconds
# /tmp/ipykernel_434337/3773699355.py:58: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   seg_sec_df = pd.concat([pd.read_csv(seg_df_csv, index_col='file_name'), pd.DataFrame.from_records(seg_records, index='file_name')])
# Processed 14300 out of 17198 in 138359.44613313675 seconds
# /tmp/ipykernel_434337/3773699355.py:58: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   seg_sec_df = pd.concat([pd.read_csv(seg_df_csv, index_col='file_name'), pd.DataFrame.from_records(seg_records, index='file_name')])
# Processed 14350 out of 17198 in 138582.4895477295 seconds
# /tmp/ipykernel_434337/3773699355.py:58: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   seg_sec_df = pd.concat([pd.read_csv(seg_df_csv, index_col='file_name'), pd.DataFrame.from_records(seg_records, index='file_name')])
# Processed 14400 out of 17198 in 138799.94277238846 seconds
# /tmp/ipykernel_434337/3773699355.py:58: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   seg_sec_df = pd.concat([pd.read_csv(seg_df_csv, index_col='file_name'), pd.DataFrame.from_records(seg_records, index='file_name')])
# Processed 14450 out of 17198 in 139350.4405734539 seconds
# Processed 14500 out of 17198 in 139954.2424850464 seconds
# Processed 14550 out of 17198 in 140408.61074519157 seconds
# Processed 14600 out of 17198 in 141038.8837440014 seconds
# Processed 14650 out of 17198 in 141446.90666484833 seconds
# Processed 14700 out of 17198 in 142424.43882727623 seconds
# Processed 14750 out of 17198 in 142689.5172495842 seconds
# Processed 14800 out of 17198 in 143032.63289022446 seconds
# Processed 14850 out of 17198 in 143461.50898599625 seconds
# Processed 14900 out of 17198 in 143852.58762073517 seconds
# Processed 14950 out of 17198 in 144305.713865757 seconds
# Processed 15000 out of 17198 in 144493.64251565933 seconds
# Processed 15050 out of 17198 in 145205.45147514343 seconds
# Processed 15100 out of 17198 in 146509.06533384323 seconds
# Processed 15150 out of 17198 in 146688.50338816643 seconds
# Processed 15200 out of 17198 in 147503.4920129776 seconds
# Processed 15250 out of 17198 in 147821.58409023285 seconds
# Processed 15300 out of 17198 in 148080.7881910801 seconds
# Processed 15350 out of 17198 in 148467.62165236473 seconds
# Processed 15400 out of 17198 in 148742.72523474693 seconds
# Processed 15450 out of 17198 in 148932.50517821312 seconds
# Processed 15500 out of 17198 in 149098.11164975166 seconds
# Processed 15550 out of 17198 in 149503.10893654823 seconds
# Processed 15600 out of 17198 in 149756.0785021782 seconds
# Processed 15650 out of 17198 in 149899.47279810905 seconds
# Processed 15700 out of 17198 in 150042.40849542618 seconds
# Processed 15750 out of 17198 in 150275.45834422112 seconds
# Processed 15800 out of 17198 in 150472.309623003 seconds
# Processed 15850 out of 17198 in 150699.16850590706 seconds
# Processed 15900 out of 17198 in 150832.87189793587 seconds
# Processed 15950 out of 17198 in 150935.1099665165 seconds
# Processed 16000 out of 17198 in 151087.13401842117 seconds
# Processed 16050 out of 17198 in 151340.76368618011 seconds
# Processed 16100 out of 17198 in 151412.6213696003 seconds
# Processed 16150 out of 17198 in 151574.22779345512 seconds
# Processed 16200 out of 17198 in 151729.6702618599 seconds
# Processed 16250 out of 17198 in 151931.99635338783 seconds
# Processed 16300 out of 17198 in 152221.14282655716 seconds
# Processed 16350 out of 17198 in 152568.7337052822 seconds
# Processed 16400 out of 17198 in 152658.18232154846 seconds
# Processed 16450 out of 17198 in 152787.29262804985 seconds
# Processed 16500 out of 17198 in 152838.6022400856 seconds
# Processed 16550 out of 17198 in 152979.36169719696 seconds
# Processed 16600 out of 17198 in 153069.83420467377 seconds
# Processed 16650 out of 17198 in 153179.98383831978 seconds
# Processed 16700 out of 17198 in 153331.29977369308 seconds
# Processed 16750 out of 17198 in 153419.27908444405 seconds
# Processed 16800 out of 17198 in 153536.1096522808 seconds
# Processed 16850 out of 17198 in 153609.24391818047 seconds
# Processed 16900 out of 17198 in 153727.5828344822 seconds
# Processed 16950 out of 17198 in 153824.80358839035 seconds
# Processed 17000 out of 17198 in 153998.98074030876 seconds
# Processed 17050 out of 17198 in 154046.08108496666 seconds
# Processed 17100 out of 17198 in 154095.59676671028 seconds
# Processed 17150 out of 17198 in 154139.79691648483 seconds
# Processed 17198 out of 17198 in 154194.57196855545 seconds
