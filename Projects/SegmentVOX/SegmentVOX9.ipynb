# %% [markdown]
# # Partial Process of Segment GRN Data for vox-grn
#
# See SegmentVox.ipynb for full description.
#
# In an attempt to speed up the processing I have divided the items up into 10 groups and want to have them all process in parallel. It probably won't be 10 times faster but it should still be quicker.

# %%
import pandas as pd
import numpy as np
import os
import sys
module_path = os.path.abspath(os.path.join('../vad_utils'))
if module_path not in sys.path:
    sys.path.append(module_path)
from vad_utils import SAMPLING_RATE, FRAME_SIZE_MS, SAMPLES_PER_FRAME
import vad_utils as vu
from pydub import AudioSegment
import pickle as pkl
from pathlib import Path
import time

# %%
# define the locations for each of the file types
NOTEBOOK_ID=9
SEGMENTS_DIR = '/media/originals/segments/'
DATASETS_DIR = '/media/originals/datasets/'
SEC_4_DATA_DIR = 'seg_4sec/data/'
SEC_6_DATA_DIR = 'seg_6sec/data/'
SEC_10_DATA_DIR = 'seg_10sec/data/'

# define specific files used in the process
SEG_4_SEC_DF = f'{SEGMENTS_DIR}seg_4sec_{NOTEBOOK_ID}.csv'
SEG_6_SEC_DF = f'{SEGMENTS_DIR}seg_6sec_{NOTEBOOK_ID}.csv'
SEG_10_SEC_DF = f'{SEGMENTS_DIR}seg_10sec_{NOTEBOOK_ID}.csv'

# define segment sizes for each dataset
SEG_4_SEC = 4.0
SEG_6_SEC = 6.0
SEG_10_SEC = 10.0

# %%
# Now read in the description of the input and remove the unwanted columns and rename the rest to be python attribute names.
items = pd.read_csv(f'/media/originals/segments/items_{NOTEBOOK_ID}.csv')
items.set_index('ID', inplace=True)
items.columns
# Out:
# Index(['iso', 'program', 'location', 'year', 'path', 'filename', 'item_no',
#        'title', 'start', 'end'],
#       dtype='object')

# %%
print(items.iloc[100])
# Out:
# iso                                                       tzh
# program                                                A30571
# location                           San Cristobal de las Casas
# year                                                   2004.0
# path                        Programs/30/30571/A30571/From_CM/
# filename    C30571B Region 00_03_45_962 to 00_04_48_426 (0...
# item_no                                                    28
# title                                              Picture 25
# start                                                     0.0
# end                                                    62.464
# Name: A30571_028, dtype: object

# %%
print(items.index)
# Out:
# Index(['A64593_037', 'A64593_036', 'A64593_035', 'A64593_034', 'A64593_032',
#        'A64593_031', 'A64593_030', 'A64593_029', 'A64593_028', 'A64593_027',
#        ...
#        'C29541_008', 'A29531_001', 'A29531_002', 'A29531_004', 'A29531_005',
#        'A29531_006', 'A29531_007', 'A29531_008', 'A29531_009', 'A29531_010'],
#       dtype='object', name='ID', length=17198)

# %%
# generate directories and filenames
def prepare_dir(dirname):
    if dirname[-1] != '/':
        dirname = dirname + '/'
    Path(dirname).mkdir(parents=True, exist_ok=True)
    return dirname

def prepare_raw_seg_dir(item):
    return prepare_dir(SEGMENTS_DIR + item.iso)

def raw_seg_filename(item):
    return f'{item.program}_{item.item_no:03d}.pkl'

def prepare_dataset_data_dir(item, dataset_dir):
    return prepare_dir(DATASETS_DIR + dataset_dir + item.iso)

def seg_mp3_filename(item, seg):
    return f'{item.program}_{item.item_no:03d}_{seg:03d}.mp3'

# %%
def condition_audio_segment(audio_seg):
    if audio_seg.channels != 1:
        audio_seg = audio_seg.set_channels(1)

    if audio_seg.sample_width != 2:
        audio_seg = audio_seg.set_sample_width(2)

    if audio_seg.frame_rate != SAMPLING_RATE:
        audio_seg = audio_seg.set_frame_rate(SAMPLING_RATE)

    return audio_seg

# %%
def save_the_segment_info(item, segs):
    fname = prepare_raw_seg_dir(item) + raw_seg_filename(item)
    with open(fname, 'wb') as pklFile:
         pkl.dump(segs, pklFile)

def read_the_segment_info(item):
    fname = prepare_raw_seg_dir(item) + raw_seg_filename(item)
    if os.path.exists(fname):
        if os.path.getsize(fname) > 0:
            with open(fname, 'rb') as pklFile:
                return pkl.load(pklFile)
    return []
    
def extract_audio_segment_for_item(item):
    fmt = 'wav'
    if item.filename[-4:] == '.mp3' :
        fmt = 'mp3'
    audio_seg = AudioSegment.from_file('/media/programs/' + item.path + item.filename, format=fmt)
    start_ms = int(item.start * 1000)
    end_ms = int(item.end * 1000)
    audio_seg = audio_seg[start_ms:end_ms]

    # now condition the segment and extract the raw segments.
    audio_seg = condition_audio_segment(audio_seg)
    segs = read_the_segment_info(item)
    if len(segs) == 0:
        segs = vu.audio_to_raw_voice_segments(audio_seg)
        save_the_segment_info(item, segs)

    return audio_seg, segs

def create_mp3_files(audio_seg, segs, time_per_segment, dataset_dir, item):
    segs_for_time = vu.divide_into_segments(segs, time_per_segment)

    # now write out the 4 sec segments
    dirname = prepare_dataset_data_dir(item, dataset_dir)
    rows = list()
    for i, seg in enumerate(segs_for_time):
        file_name = dataset_dir + item.iso + '/' + seg_mp3_filename(item, i)
        fname = dirname + seg_mp3_filename(item, i)
        if not os.path.exists(fname):
            start = vu.convert_frames_to_ms(seg.start)
            stop = vu.convert_frames_to_ms(seg.stop)
            audio_seg[start:stop].export(fname, format='mp3', bitrate='32k')
        desc = dict(item._asdict())
        desc['seg_start'] = vu.convert_frames_to_seconds(seg.start)
        desc['seg_stop'] = vu.convert_frames_to_seconds(seg.stop)
        desc['seg'] = i
        desc['file_name'] = file_name
        rows.append(desc)

    return rows

def update_dataframes(seg_df_csv, seg_records):
    # now update the dataframes
    if len(seg_records) > 0:
        if os.path.isfile(seg_df_csv):
            seg_sec_df = pd.concat([pd.read_csv(seg_df_csv, index_col='file_name'), pd.DataFrame.from_records(seg_records, index='file_name')])
        else:
            seg_sec_df = pd.DataFrame.from_records(seg_records, index='file_name')
        seg_sec_df.to_csv(seg_df_csv)

# %%
# processing these items might take a very long time. To permit the process to be interrupted and restarted the indexes of processed items
# are maintained in a set that is pickled on each batch. This allows the batch to quickly pick up where it left off.
def process_record_batch(items_df, *, batch_size=10):
    batch_proc = 0
    processed_file = f'/media/originals/segments/processed16_{NOTEBOOK_ID}.pkl'
    if os.path.isfile(processed_file):
        with open(processed_file, 'rb') as pklFile:
            processed_items = pkl.load(pklFile)
    else:
        processed_items = set()

    segmented_4sec_segs = []
    segmented_6sec_segs = []
    segmented_10sec_segs = []

    for item in items_df.itertuples():
        if batch_proc < batch_size:
            if item.Index not in processed_items:
                try:
                    audio_seg, voice_segs = extract_audio_segment_for_item(item)
                    segmented_4sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_4_SEC, SEC_4_DATA_DIR, item))
                    segmented_6sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_6_SEC, SEC_6_DATA_DIR, item))
                    segmented_10sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_10_SEC, SEC_10_DATA_DIR, item))
                except:
                    print('exception')
                    pass

                # we want to add an item that has an exception so it is not reprocessed on every batch
                processed_items.add(item.Index)
                batch_proc += 1

        else:
            break

    update_dataframes(SEG_4_SEC_DF, segmented_4sec_segs)
    update_dataframes(SEG_6_SEC_DF, segmented_6sec_segs)
    update_dataframes(SEG_10_SEC_DF, segmented_10sec_segs)

    with open(processed_file, 'wb') as pklFile:
        pkl.dump(processed_items, pklFile)

    return processed_items

# %%
start_time = time.time()
# form the language classification file
items_processed = 0
items_to_process = len(items)
while items_to_process > items_processed:
    processed_items = process_record_batch(items, batch_size=50)
    items_processed = len(processed_items)
    print(f'Processed {items_processed} out of {items_to_process} in {time.time()-start_time} seconds')
# Out:
# Processed 50 out of 17198 in 118.43254566192627 seconds
# Processed 100 out of 17198 in 417.221431016922 seconds
# Processed 150 out of 17198 in 788.3551738262177 seconds
# Processed 200 out of 17198 in 1106.5831699371338 seconds
# Processed 250 out of 17198 in 1283.5452644824982 seconds
# Processed 300 out of 17198 in 1435.4097881317139 seconds
# Processed 350 out of 17198 in 1938.6844437122345 seconds
# Processed 400 out of 17198 in 2136.9631123542786 seconds
# Processed 450 out of 17198 in 2387.9279708862305 seconds
# Processed 500 out of 17198 in 2872.7990214824677 seconds
# Processed 550 out of 17198 in 3425.077317237854 seconds
# Processed 600 out of 17198 in 3840.6667954921722 seconds
# Processed 650 out of 17198 in 4269.451601743698 seconds
# Processed 700 out of 17198 in 4685.621798992157 seconds
# Processed 750 out of 17198 in 5005.791155338287 seconds
# Processed 800 out of 17198 in 5375.59584736824 seconds
# Processed 850 out of 17198 in 5667.771150350571 seconds
# Processed 900 out of 17198 in 5895.92062997818 seconds
# Processed 950 out of 17198 in 6369.703453302383 seconds
# Processed 1000 out of 17198 in 6795.022034645081 seconds
# Processed 1050 out of 17198 in 8030.20342206955 seconds
# Processed 1100 out of 17198 in 9601.30278134346 seconds
# Processed 1150 out of 17198 in 9812.512573957443 seconds
# Processed 1200 out of 17198 in 10088.45314669609 seconds
# Processed 1250 out of 17198 in 10508.70594072342 seconds
# Processed 1300 out of 17198 in 10898.48920917511 seconds
# Processed 1350 out of 17198 in 11182.844903230667 seconds
# Processed 1400 out of 17198 in 11486.975554943085 seconds
# Processed 1450 out of 17198 in 11855.151548147202 seconds
# Processed 1500 out of 17198 in 12160.196373939514 seconds
# Processed 1550 out of 17198 in 12552.315252780914 seconds
# Processed 1600 out of 17198 in 13130.467210054398 seconds
# Processed 1650 out of 17198 in 13603.385488033295 seconds
# Processed 1700 out of 17198 in 13972.744614124298 seconds
# Processed 1750 out of 17198 in 14722.088964939117 seconds
# Processed 1800 out of 17198 in 15167.79428076744 seconds
# Processed 1850 out of 17198 in 15579.616144895554 seconds
# Processed 1900 out of 17198 in 16256.134299993515 seconds
# Processed 1950 out of 17198 in 16834.053790330887 seconds
# Processed 2000 out of 17198 in 17066.538434267044 seconds
# Processed 2050 out of 17198 in 17744.78746199608 seconds
# Processed 2100 out of 17198 in 19722.185600042343 seconds
# Processed 2150 out of 17198 in 20112.321390867233 seconds
# Processed 2200 out of 17198 in 20405.740577220917 seconds
# Processed 2250 out of 17198 in 20593.19063925743 seconds
# Processed 2300 out of 17198 in 20724.03549194336 seconds
# Processed 2350 out of 17198 in 20853.19016599655 seconds
# Processed 2400 out of 17198 in 20987.144590854645 seconds
# Processed 2450 out of 17198 in 21138.412747859955 seconds
# Processed 2500 out of 17198 in 21333.995400428772 seconds
# Processed 2550 out of 17198 in 21519.844702482224 seconds
# Processed 2600 out of 17198 in 21726.035009384155 seconds
# Processed 2650 out of 17198 in 22001.565708637238 seconds
# Processed 2700 out of 17198 in 22257.31432890892 seconds
# Processed 2750 out of 17198 in 22481.022248983383 seconds
# Processed 2800 out of 17198 in 22643.677817344666 seconds
# Processed 2850 out of 17198 in 22892.31268310547 seconds
# Processed 2900 out of 17198 in 23065.345777988434 seconds
# Processed 2950 out of 17198 in 23307.253546237946 seconds
# Processed 3000 out of 17198 in 23549.448761701584 seconds
# Processed 3050 out of 17198 in 23867.759094953537 seconds
# Processed 3100 out of 17198 in 24115.4280128479 seconds
# Processed 3150 out of 17198 in 24407.19691300392 seconds
# Processed 3200 out of 17198 in 24682.12259221077 seconds
# Processed 3250 out of 17198 in 24981.375791549683 seconds
# Processed 3300 out of 17198 in 25164.113168001175 seconds
# Processed 3350 out of 17198 in 26044.864671945572 seconds
# Processed 3400 out of 17198 in 26359.304666519165 seconds
# Processed 3450 out of 17198 in 26614.33639240265 seconds
# Processed 3500 out of 17198 in 27394.118350982666 seconds
# Processed 3550 out of 17198 in 27791.3765604496 seconds
# Processed 3600 out of 17198 in 28081.83659219742 seconds
# Processed 3650 out of 17198 in 28328.952616930008 seconds
# Processed 3700 out of 17198 in 28709.862283468246 seconds
# Processed 3750 out of 17198 in 29220.066536188126 seconds
# Processed 3800 out of 17198 in 29619.309401750565 seconds
# Processed 3850 out of 17198 in 30268.591524600983 seconds
# Processed 3900 out of 17198 in 30828.033920526505 seconds
# Processed 3950 out of 17198 in 31126.219842910767 seconds
# Processed 4000 out of 17198 in 31649.090234279633 seconds
# Processed 4050 out of 17198 in 32021.638214826584 seconds
# Processed 4100 out of 17198 in 32532.93266415596 seconds
# Processed 4150 out of 17198 in 32998.2309012413 seconds
# Processed 4200 out of 17198 in 33392.62933802605 seconds
# Processed 4250 out of 17198 in 33702.86492586136 seconds
# Processed 4300 out of 17198 in 34051.456464767456 seconds
# Processed 4350 out of 17198 in 34362.12376785278 seconds
# Processed 4400 out of 17198 in 34715.68509864807 seconds
# Processed 4450 out of 17198 in 34977.11525464058 seconds
# Processed 4500 out of 17198 in 35311.07664656639 seconds
# Processed 4550 out of 17198 in 35697.36220860481 seconds
# Processed 4600 out of 17198 in 36211.56473708153 seconds
# Processed 4650 out of 17198 in 37159.612981557846 seconds
# Processed 4700 out of 17198 in 37611.13196706772 seconds
# Processed 4750 out of 17198 in 38218.612998723984 seconds
# Processed 4800 out of 17198 in 39000.98514842987 seconds
# Processed 4850 out of 17198 in 39603.32909321785 seconds
# Processed 4900 out of 17198 in 39962.740142822266 seconds
# Processed 4950 out of 17198 in 40630.180547237396 seconds
# Processed 5000 out of 17198 in 41154.31586885452 seconds
# Processed 5050 out of 17198 in 41584.61519289017 seconds
# Processed 5100 out of 17198 in 41881.50419092178 seconds
# Processed 5150 out of 17198 in 42164.011382341385 seconds
# Processed 5200 out of 17198 in 43190.29259824753 seconds
# Processed 5250 out of 17198 in 43617.1691069603 seconds
# Processed 5300 out of 17198 in 44108.14289212227 seconds
# Processed 5350 out of 17198 in 44727.79409074783 seconds
# Processed 5400 out of 17198 in 45272.48004603386 seconds
# Processed 5450 out of 17198 in 45581.55296754837 seconds
# Processed 5500 out of 17198 in 45955.795647621155 seconds
# Processed 5550 out of 17198 in 46412.44381427765 seconds
# Processed 5600 out of 17198 in 46886.795560359955 seconds
# Processed 5650 out of 17198 in 47211.718781232834 seconds
# Processed 5700 out of 17198 in 47933.12851405144 seconds
# Processed 5750 out of 17198 in 48513.57870745659 seconds
# Processed 5800 out of 17198 in 48999.39519190788 seconds
# Processed 5850 out of 17198 in 49207.300652980804 seconds
# Processed 5900 out of 17198 in 50296.54673051834 seconds
# Processed 5950 out of 17198 in 52139.54765415192 seconds
# Processed 6000 out of 17198 in 52415.218485593796 seconds
# Processed 6050 out of 17198 in 52779.97066998482 seconds
# Processed 6100 out of 17198 in 53090.27440428734 seconds
# Processed 6150 out of 17198 in 53346.80045604706 seconds
# Processed 6200 out of 17198 in 53597.01461815834 seconds
# Processed 6250 out of 17198 in 54723.9787607193 seconds
# Processed 6300 out of 17198 in 56277.767340660095 seconds
# Processed 6350 out of 17198 in 57607.70349097252 seconds
# Processed 6400 out of 17198 in 59118.88082242012 seconds
# Processed 6450 out of 17198 in 60403.05065822601 seconds
# Processed 6500 out of 17198 in 61219.41367125511 seconds
# Processed 6550 out of 17198 in 62013.785702466965 seconds
# Processed 6600 out of 17198 in 62668.974241018295 seconds
# Processed 6650 out of 17198 in 63267.34202718735 seconds
# Processed 6700 out of 17198 in 63763.34851717949 seconds
# Processed 6750 out of 17198 in 64244.95089221001 seconds
# Processed 6800 out of 17198 in 64780.7465069294 seconds
# Processed 6850 out of 17198 in 65353.40208911896 seconds
# Processed 6900 out of 17198 in 66119.55643057823 seconds
# Processed 6950 out of 17198 in 66541.6885869503 seconds
# Processed 7000 out of 17198 in 66976.72724246979 seconds
# Processed 7050 out of 17198 in 67291.65607905388 seconds
# Processed 7100 out of 17198 in 67580.4191186428 seconds
# Processed 7150 out of 17198 in 67945.32696533203 seconds
# Processed 7200 out of 17198 in 68278.17595052719 seconds
# Processed 7250 out of 17198 in 68563.94923210144 seconds
# Processed 7300 out of 17198 in 68847.17601490021 seconds
# Processed 7350 out of 17198 in 69141.24619197845 seconds
# Processed 7400 out of 17198 in 69457.28178930283 seconds
# Processed 7450 out of 17198 in 69748.35854434967 seconds
# Processed 7500 out of 17198 in 69946.40215086937 seconds
# Processed 7550 out of 17198 in 70197.85441589355 seconds
# Processed 7600 out of 17198 in 70451.75309419632 seconds
# Processed 7650 out of 17198 in 70905.34205293655 seconds
# Processed 7700 out of 17198 in 71212.46587991714 seconds
# Processed 7750 out of 17198 in 71678.86608695984 seconds
# Processed 7800 out of 17198 in 71930.75822329521 seconds
# Processed 7850 out of 17198 in 72258.90907597542 seconds
# Processed 7900 out of 17198 in 72555.28151035309 seconds
# Processed 7950 out of 17198 in 72910.02466130257 seconds
# Processed 8000 out of 17198 in 73233.48917460442 seconds
# Processed 8050 out of 17198 in 73547.54649853706 seconds
# Processed 8100 out of 17198 in 74118.71960926056 seconds
# Processed 8150 out of 17198 in 75176.94072031975 seconds
# Processed 8200 out of 17198 in 75718.92572164536 seconds
# Processed 8250 out of 17198 in 76428.94685029984 seconds
# Processed 8300 out of 17198 in 76819.73055100441 seconds
# Processed 8350 out of 17198 in 77163.58837604523 seconds
# Processed 8400 out of 17198 in 77410.21148705482 seconds
# Processed 8450 out of 17198 in 80998.28823828697 seconds
# Processed 8500 out of 17198 in 87075.2646727562 seconds
# Processed 8550 out of 17198 in 88828.85138487816 seconds
# Processed 8600 out of 17198 in 89647.9407222271 seconds
# Processed 8650 out of 17198 in 90014.49647641182 seconds
# Processed 8700 out of 17198 in 90225.65035438538 seconds
# Processed 8750 out of 17198 in 90667.02028727531 seconds
# Processed 8800 out of 17198 in 90974.36266684532 seconds
# Processed 8850 out of 17198 in 91249.19419813156 seconds
# Processed 8900 out of 17198 in 91801.55727291107 seconds
# Processed 8950 out of 17198 in 92249.15899515152 seconds
# Processed 9000 out of 17198 in 92608.89158654213 seconds
# Processed 9050 out of 17198 in 92935.36672377586 seconds
# Processed 9100 out of 17198 in 93276.40294766426 seconds
# Processed 9150 out of 17198 in 93621.96664071083 seconds
# Processed 9200 out of 17198 in 96294.01797747612 seconds
# Processed 9250 out of 17198 in 98050.82482290268 seconds
# Processed 9300 out of 17198 in 98463.74464893341 seconds
# Processed 9350 out of 17198 in 98850.82006406784 seconds
# Processed 9400 out of 17198 in 99155.00224685669 seconds
# Processed 9450 out of 17198 in 99587.23421740532 seconds
# Processed 9500 out of 17198 in 100083.88989973068 seconds
# Processed 9550 out of 17198 in 100437.45897984505 seconds
# Processed 9600 out of 17198 in 101915.46642518044 seconds
# Processed 9650 out of 17198 in 103962.34605360031 seconds
# Processed 9700 out of 17198 in 104215.91073203087 seconds
# Processed 9750 out of 17198 in 104493.47990512848 seconds
# Processed 9800 out of 17198 in 104782.29612398148 seconds
# Processed 9850 out of 17198 in 105189.22039198875 seconds
# Processed 9900 out of 17198 in 105576.14643764496 seconds
# Processed 9950 out of 17198 in 106011.91396379471 seconds
# Processed 10000 out of 17198 in 106317.42867136002 seconds
# Processed 10050 out of 17198 in 106593.64845728874 seconds
# Processed 10100 out of 17198 in 106779.05633330345 seconds
# Processed 10150 out of 17198 in 107097.34530854225 seconds
# Processed 10200 out of 17198 in 107314.41766357422 seconds
# Processed 10250 out of 17198 in 107532.1455783844 seconds
# Processed 10300 out of 17198 in 107864.3711900711 seconds
# Processed 10350 out of 17198 in 108296.05584836006 seconds
# Processed 10400 out of 17198 in 108978.64684963226 seconds
# Processed 10450 out of 17198 in 109691.42173790932 seconds
# Processed 10500 out of 17198 in 109927.95940256119 seconds
# Processed 10550 out of 17198 in 110309.06377601624 seconds
# Processed 10600 out of 17198 in 110945.14137864113 seconds
# Processed 10650 out of 17198 in 111607.91699624062 seconds
# Processed 10700 out of 17198 in 112100.38967013359 seconds
# Processed 10750 out of 17198 in 112590.03545379639 seconds
# Processed 10800 out of 17198 in 113080.64258503914 seconds
# Processed 10850 out of 17198 in 113323.74177265167 seconds
# Processed 10900 out of 17198 in 113728.20655083656 seconds
# Processed 10950 out of 17198 in 114029.13709807396 seconds
# Processed 11000 out of 17198 in 114443.80767679214 seconds
# Processed 11050 out of 17198 in 114839.6035387516 seconds
# Processed 11100 out of 17198 in 115048.3360710144 seconds
# Processed 11150 out of 17198 in 115210.57884025574 seconds
# Processed 11200 out of 17198 in 115512.79359555244 seconds
# Processed 11250 out of 17198 in 115942.83100891113 seconds
# Processed 11300 out of 17198 in 116215.77873921394 seconds
# Processed 11350 out of 17198 in 117172.40597248077 seconds
# Processed 11400 out of 17198 in 117500.81120371819 seconds
# Processed 11450 out of 17198 in 117839.25606560707 seconds
# Processed 11500 out of 17198 in 118099.66952419281 seconds
# Processed 11550 out of 17198 in 118395.30047416687 seconds
# Processed 11600 out of 17198 in 118744.04186701775 seconds
# Processed 11650 out of 17198 in 119153.266320467 seconds
# Processed 11700 out of 17198 in 119558.95607352257 seconds
# Processed 11750 out of 17198 in 119834.6428539753 seconds
# Processed 11800 out of 17198 in 120075.14820361137 seconds
# Processed 11850 out of 17198 in 120236.06582689285 seconds
# Processed 11900 out of 17198 in 121723.40478253365 seconds
# Processed 11950 out of 17198 in 122022.32073545456 seconds
# Processed 12000 out of 17198 in 122232.52230620384 seconds
# Processed 12050 out of 17198 in 122400.31774783134 seconds
# Processed 12100 out of 17198 in 122631.46198797226 seconds
# Processed 12150 out of 17198 in 122834.98314976692 seconds
# Processed 12200 out of 17198 in 123150.59898710251 seconds
# Processed 12250 out of 17198 in 123462.78578948975 seconds
# Processed 12300 out of 17198 in 123914.80797839165 seconds
# Processed 12350 out of 17198 in 124163.57785248756 seconds
# Processed 12400 out of 17198 in 124501.34145474434 seconds
# Processed 12450 out of 17198 in 124738.73246240616 seconds
# Processed 12500 out of 17198 in 124938.91303682327 seconds
# Processed 12550 out of 17198 in 125199.8314332962 seconds
# Processed 12600 out of 17198 in 125506.35632753372 seconds
# Processed 12650 out of 17198 in 125790.31289124489 seconds
# Processed 12700 out of 17198 in 126028.89189505577 seconds
# Processed 12750 out of 17198 in 126289.64349889755 seconds
# Processed 12800 out of 17198 in 126952.40893387794 seconds
# Processed 12850 out of 17198 in 127548.33326745033 seconds
# Processed 12900 out of 17198 in 128252.8770878315 seconds
# Processed 12950 out of 17198 in 128774.96892952919 seconds
# Processed 13000 out of 17198 in 129042.49626660347 seconds
# Processed 13050 out of 17198 in 129489.31571221352 seconds
# Processed 13100 out of 17198 in 129771.79910135269 seconds
# Processed 13150 out of 17198 in 130012.03861474991 seconds
# Processed 13200 out of 17198 in 131886.1842262745 seconds
# Processed 13250 out of 17198 in 132401.46860694885 seconds
# Processed 13300 out of 17198 in 132779.00459861755 seconds
# Processed 13350 out of 17198 in 133551.26451444626 seconds
# Processed 13400 out of 17198 in 134009.18202710152 seconds
# Processed 13450 out of 17198 in 136329.16655611992 seconds
# Processed 13500 out of 17198 in 136586.535674572 seconds
# Processed 13550 out of 17198 in 136768.84968948364 seconds
# Processed 13600 out of 17198 in 137840.67028093338 seconds
# Processed 13650 out of 17198 in 138281.56923365593 seconds
# Processed 13700 out of 17198 in 138735.7911348343 seconds
# Processed 13750 out of 17198 in 139048.43237519264 seconds
# Processed 13800 out of 17198 in 139155.29671549797 seconds
# Processed 13850 out of 17198 in 139312.04867434502 seconds
# Processed 13900 out of 17198 in 139445.8091044426 seconds
# Processed 13950 out of 17198 in 139589.1353955269 seconds
# Processed 14000 out of 17198 in 139801.49765014648 seconds
# Processed 14050 out of 17198 in 140389.9270951748 seconds
# Processed 14100 out of 17198 in 140955.0355861187 seconds
# Processed 14150 out of 17198 in 141423.74319911003 seconds
# Processed 14200 out of 17198 in 141705.85504841805 seconds
# Processed 14250 out of 17198 in 142002.61299204826 seconds
# Processed 14300 out of 17198 in 142270.7527141571 seconds
# Processed 14350 out of 17198 in 142606.28434109688 seconds
# Processed 14400 out of 17198 in 143140.53517365456 seconds
# Processed 14450 out of 17198 in 143864.87389993668 seconds
# Processed 14500 out of 17198 in 144315.5223491192 seconds
# Processed 14550 out of 17198 in 144718.02912330627 seconds
# Processed 14600 out of 17198 in 145232.71340560913 seconds
# Processed 14650 out of 17198 in 145444.19694399834 seconds
# Processed 14700 out of 17198 in 145624.09930610657 seconds
# Processed 14750 out of 17198 in 146044.06680512428 seconds
# Processed 14800 out of 17198 in 146324.88774371147 seconds
# Processed 14850 out of 17198 in 146584.06681752205 seconds
# Processed 14900 out of 17198 in 147382.1717221737 seconds
# Processed 14950 out of 17198 in 147730.57633638382 seconds
# Processed 15000 out of 17198 in 148085.16843628883 seconds
# Processed 15050 out of 17198 in 148380.090143919 seconds
# Processed 15100 out of 17198 in 148755.3783378601 seconds
# Processed 15150 out of 17198 in 148921.35434055328 seconds
# Processed 15200 out of 17198 in 149091.05126547813 seconds
# Processed 15250 out of 17198 in 149232.55708694458 seconds
# Processed 15300 out of 17198 in 149463.46971440315 seconds
# Processed 15350 out of 17198 in 149626.14747738838 seconds
# Processed 15400 out of 17198 in 149755.24072027206 seconds
# Processed 15450 out of 17198 in 149970.6933684349 seconds
# Processed 15500 out of 17198 in 150325.2194726467 seconds
# Processed 15550 out of 17198 in 150585.51228308678 seconds
# Processed 15600 out of 17198 in 151101.18434882164 seconds
# Processed 15650 out of 17198 in 151408.85447716713 seconds
# Processed 15700 out of 17198 in 151716.13268327713 seconds
# Processed 15750 out of 17198 in 152193.1352379322 seconds
# Processed 15800 out of 17198 in 152665.89316630363 seconds
# Processed 15850 out of 17198 in 153502.2664244175 seconds
# Processed 15900 out of 17198 in 153936.1982834339 seconds
# Processed 15950 out of 17198 in 154201.64856147766 seconds
# Processed 16000 out of 17198 in 154324.0194246769 seconds
# Processed 16050 out of 17198 in 154462.7816002369 seconds
# Processed 16100 out of 17198 in 154774.12977981567 seconds
# Processed 16150 out of 17198 in 154884.817633152 seconds
# Processed 16200 out of 17198 in 155765.19695091248 seconds
# Processed 16250 out of 17198 in 156325.71082639694 seconds
# Processed 16300 out of 17198 in 157549.96832180023 seconds
# Processed 16350 out of 17198 in 157687.15604782104 seconds
# Processed 16400 out of 17198 in 157874.0457868576 seconds
# Processed 16450 out of 17198 in 158160.6465499401 seconds
# Processed 16500 out of 17198 in 158365.0104842186 seconds
# Processed 16550 out of 17198 in 158485.2202486992 seconds
# Processed 16600 out of 17198 in 158611.60641932487 seconds
# Processed 16650 out of 17198 in 158743.6211822033 seconds
# Processed 16700 out of 17198 in 158782.4906527996 seconds
# Processed 16750 out of 17198 in 158875.1315896511 seconds
# Processed 16800 out of 17198 in 159082.30699706078 seconds
# Processed 16850 out of 17198 in 159145.91974067688 seconds
# Processed 16900 out of 17198 in 159548.0442531109 seconds
# Processed 16950 out of 17198 in 159881.50501298904 seconds
# Processed 17000 out of 17198 in 160079.9075510502 seconds
# Processed 17050 out of 17198 in 160193.19701194763 seconds
# Processed 17100 out of 17198 in 160432.51727962494 seconds
# Processed 17150 out of 17198 in 160677.2531337738 seconds
# Processed 17198 out of 17198 in 160884.31921219826 seconds
