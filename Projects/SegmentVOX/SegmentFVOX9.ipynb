# %% [markdown]
# # Partial Process of Segment GRN Data for vox-grn
#
# To speed up processing the files have been broken into 10 groups and processed in parallel.
#
# # Data to be Created
#
# Three sets of data will be made, 4, 6, and 10 second data.
#
# This file will take a long time to run. For that reason it will check point its progress at regular intervals by writing smaller files. If its progress is restarted for any reason it will use those files to determine where it was up to. Segmenting the data is the slow part. For each audio file a segment file will be generated. If mp3 files are to be generated later using different parameters the segmented files should make the process much quicker.
#
# The input to this process is all_items_for_processing.csv with musical items removed.
#
# The output will be:
#
#     1. /media/originals/fsegs/[iso]/[filename].pkl
#         where each pkl file contains the list of raw segments for the item.
#     2. /media/originals/fsegs/seg_4sec.csv
#         all the metadata for the seg_4sec dataset. Metadata needed for the dataset can be derived from this.
#     3. /media/originals/fsegs/seg_6sec.csv
#         all the metadata for the seg_6sec dataset. Metadata needed for the dataset can be derived from this.
#     4. /media/originals/fsegs/seg_10sec.csv
#         all the metadata for the seg_10sec dataset. Metadata needed for the dataset can be derived from this.
#     5. /media/originals/datasets/fseg_4sec/data/[iso]/[program_id]_[item_no]_[seg].mp3
#         which is an mp3 for each segment
#     6. /media/originals/datasets/fseg_6sec/data/[iso]/[program_id]_[item_no]_[seg].mp3
#         which is an mp3 for each segment
#     7. /media/originals/datasets/fseg_10sec/data/[iso]/[program_id]_[item_no]_[seg].mp3
#         which is an mp3 for each segment

# %%
import pandas as pd
import numpy as np
import os
import sys
module_path = os.path.abspath(os.path.join('../vad_utils'))
if module_path not in sys.path:
    sys.path.append(module_path)
from vad_utils import SAMPLING_RATE, FRAME_SIZE_MS, SAMPLES_PER_FRAME
import vad_utils as vu
from pydub import AudioSegment
import pickle as pkl
from pathlib import Path
import time
import glob

# %%
# define the locations for each of the file types
NOTEBOOK_ID=9
SEGMENTS_DIR = '/media/originals/fsegs/'
DATASETS_DIR = '/media/originals/datasets/'
SEC_4_DATA_DIR = 'fseg_4sec/data/'
SEC_6_DATA_DIR = 'fseg_6sec/data/'
SEC_10_DATA_DIR = 'fseg_10sec/data/'

# define specific files used in the process
SEG_4_SEC_DF = f'{SEGMENTS_DIR}seg_4sec_{NOTEBOOK_ID}.csv'
SEG_6_SEC_DF = f'{SEGMENTS_DIR}seg_6sec_{NOTEBOOK_ID}.csv'
SEG_10_SEC_DF = f'{SEGMENTS_DIR}seg_10sec_{NOTEBOOK_ID}.csv'

# define segment sizes for each dataset
SEG_4_SEC = 4.0
SEG_6_SEC = 6.0
SEG_10_SEC = 10.0

# %%
# Now read in the description of the input and remove the unwanted columns and rename the rest to be python attribute names.
fd = pd.read_csv(f'/media/originals/fsegs/files_{NOTEBOOK_ID}.csv')
fd.set_index('ID', inplace=True)
fd.columns
# Out:
# Index(['Unnamed: 0', 'iso', 'language_name', 'track', 'location', 'year',
#        'path', 'filename', 'length', 'program'],
#       dtype='object')

# %%
print(fd.iloc[100])
# Out:
# Unnamed: 0                                 155213
# iso                                           ubr
# language_name                                Ubir
# track                                          12
# location                   Alotau, Milne Bay, PNG
# year                                       2008.0
# path             Programs/62/62980/A62980/PM0811/
# filename                            A62980-12.wav
# length                                  78.773333
# program                                     62980
# Name: 62980_012, dtype: object

# %%
print(fd.index)
# Out:
# Index(['62977_021', '63826_009', '63826_008', '63826_007', '63826_006',
#        '63826_005', '63826_004', '63826_003', '63826_002', '63826_001',
#        ...
#        '29531_002', '29531_006', '32241_002', '29531_008', '29531_009',
#        '29531_010', '29531_011', '32241_001', '29531_007', '29541_002'],
#       dtype='object', name='ID', length=20841)

# %%
# generate directories and filenames
def prepare_dir(dirname):
    if dirname[-1] != '/':
        dirname = dirname + '/'
    Path(dirname).mkdir(parents=True, exist_ok=True)
    return dirname

def prepare_raw_seg_dir(fd):
    return prepare_dir(SEGMENTS_DIR + fd.iso)

def raw_seg_filename(fd):
    return f'{fd.filename}.pkl'

def prepare_dataset_data_dir(fd, dataset_dir):
    return prepare_dir(DATASETS_DIR + dataset_dir + fd.iso)

def seg_mp3_filename(fd, seg):
    return f'{fd.filename[:-4]}_{seg:03d}.mp3'

def get_fname(fd):
    path = fd.path
    if path[-1] != '/':
        path = path + '/'
    files = glob.glob('/media/programs/' + path + fd.filename.replace('\ufffd', '*'))
    if len(files) == 1:
        return files[0]
    return '/media/programs/' + path + fd.filename

# %%
def condition_audio_segment(audio_seg):
    if audio_seg.channels != 1:
        audio_seg = audio_seg.set_channels(1)

    if audio_seg.sample_width != 2:
        audio_seg = audio_seg.set_sample_width(2)

    if audio_seg.frame_rate != SAMPLING_RATE:
        audio_seg = audio_seg.set_frame_rate(SAMPLING_RATE)

    return audio_seg

# %%
def save_the_segment_info(fd, segs):
    fname = prepare_raw_seg_dir(fd) + raw_seg_filename(fd)
    with open(fname, 'wb') as pklFile:
         pkl.dump(segs, pklFile)

def read_the_segment_info(fd):
    fname = prepare_raw_seg_dir(fd) + raw_seg_filename(fd)
    if os.path.exists(fname):
        if os.path.getsize(fname) > 0:
            with open(fname, 'rb') as pklFile:
                return pkl.load(pklFile)
    return []
    
def extract_audio_segments_for_file(fd):
    fmt = 'wav'
    if fd.filename[-4:].lower() == '.mp3' :
        fmt = 'mp3'
    audio_seg = AudioSegment.from_file(get_fname(fd), format=fmt)

    # now condition the segment and extract the raw segments.
    audio_seg = condition_audio_segment(audio_seg)
    segs = read_the_segment_info(fd)
    if len(segs) == 0:
        segs = vu.audio_to_raw_voice_segments(audio_seg)
        save_the_segment_info(fd, segs)

    return audio_seg, segs

def create_mp3_files(audio_seg, segs, time_per_segment, dataset_dir, fd):
    segs_for_time = vu.divide_into_segments(segs, time_per_segment)

    # now write out the 4 sec segments
    dirname = prepare_dataset_data_dir(fd, dataset_dir)
    rows = list()

    # note that we discard the first segment
    if len(segs_for_time) > 1:
        for i, seg in enumerate(segs_for_time[1:]):
            file_name = dataset_dir + fd.iso + '/' + seg_mp3_filename(fd, i)
            fname = dirname + seg_mp3_filename(fd, i)
            if not os.path.exists(fname):
                start = vu.convert_frames_to_ms(seg.start)
                stop = vu.convert_frames_to_ms(seg.stop)
                audio_seg[start:stop].export(fname, format='mp3', bitrate='32k')
            desc = dict(fd._asdict())
            desc['seg_start'] = vu.convert_frames_to_seconds(seg.start)
            desc['seg_stop'] = vu.convert_frames_to_seconds(seg.stop)
            desc['seg'] = i
            desc['file_name'] = file_name
            rows.append(desc)

    return rows

def update_dataframes(seg_df_csv, seg_records):
    # now update the dataframes
    if len(seg_records) > 0:
        if os.path.isfile(seg_df_csv):
            seg_sec_df = pd.concat([pd.read_csv(seg_df_csv, index_col='file_name'), pd.DataFrame.from_records(seg_records, index='file_name')])
        else:
            seg_sec_df = pd.DataFrame.from_records(seg_records, index='file_name')
        seg_sec_df.to_csv(seg_df_csv)

# %%
# processing these items might take a very long time. To permit the process to be interrupted and restarted the indexes of processed items
# are maintained in a set that is pickled on each batch. This allows the batch to quickly pick up where it left off.
def process_record_batch(files_df, *, batch_size=10):
    batch_proc = 0
    processed_file = f'/media/originals/fsegs/processed16_{NOTEBOOK_ID}.pkl'
    if os.path.isfile(processed_file):
        with open(processed_file, 'rb') as pklFile:
            processed_files = pkl.load(pklFile)
    else:
        processed_files = set()

    segmented_4sec_segs = []
    segmented_6sec_segs = []
    segmented_10sec_segs = []

    for fd in files_df.itertuples():
        if batch_proc < batch_size:
            if fd.Index not in processed_files:
                try:
                    audio_seg, voice_segs = extract_audio_segments_for_file(fd)
                    segmented_4sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_4_SEC, SEC_4_DATA_DIR, fd))
                    segmented_6sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_6_SEC, SEC_6_DATA_DIR, fd))
                    segmented_10sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_10_SEC, SEC_10_DATA_DIR, fd))
                except:
                    print(f'exception {fd.filename}')
                    pass

                # we want to add an fd that has an exception so it is not reprocessed on every batch
                processed_files.add(fd.Index)
                batch_proc += 1

        else:
            break

    update_dataframes(SEG_4_SEC_DF, segmented_4sec_segs)
    update_dataframes(SEG_6_SEC_DF, segmented_6sec_segs)
    update_dataframes(SEG_10_SEC_DF, segmented_10sec_segs)

    with open(processed_file, 'wb') as pklFile:
        pkl.dump(processed_files, pklFile)

    return processed_files

# %%
start_time = time.time()
# form the language classification file
files_processed = 0
files_to_process = len(fd)
while files_to_process > files_processed:
    processed_files = process_record_batch(fd, batch_size=50)
    files_processed = len(processed_files)
    print(f'Processed {files_processed} out of {files_to_process} in {time.time()-start_time} seconds')
# Out:
# Processed 50 out of 20841 in 260.48073506355286 seconds
# Processed 100 out of 20841 in 595.5309369564056 seconds
# Processed 150 out of 20841 in 1020.8450644016266 seconds
# Processed 200 out of 20841 in 1471.2473404407501 seconds
# Processed 250 out of 20841 in 1768.9233555793762 seconds
# Processed 300 out of 20841 in 1950.4344067573547 seconds
# Processed 350 out of 20841 in 2187.379518032074 seconds
# Processed 400 out of 20841 in 2432.2129571437836 seconds
# Processed 450 out of 20841 in 2652.1713931560516 seconds
# Processed 500 out of 20841 in 2938.128747701645 seconds
# Processed 550 out of 20841 in 3376.877020597458 seconds
# Processed 600 out of 20841 in 3681.3197026252747 seconds
# Processed 650 out of 20841 in 4477.344723701477 seconds
# Processed 700 out of 20841 in 4632.774639606476 seconds
# Processed 750 out of 20841 in 4727.883152723312 seconds
# Processed 800 out of 20841 in 4847.727269887924 seconds
# Processed 850 out of 20841 in 5045.174699544907 seconds
# Processed 900 out of 20841 in 5208.817234754562 seconds
# Processed 950 out of 20841 in 5477.605374336243 seconds
# Processed 1000 out of 20841 in 5772.033236503601 seconds
# Processed 1050 out of 20841 in 6065.725593090057 seconds
# Processed 1100 out of 20841 in 6314.533659934998 seconds
# Processed 1150 out of 20841 in 6564.638911247253 seconds
# Processed 1200 out of 20841 in 6843.700100660324 seconds
# Processed 1250 out of 20841 in 7066.101660013199 seconds
# Processed 1300 out of 20841 in 7392.903951883316 seconds
# Processed 1350 out of 20841 in 7739.395703315735 seconds
# Processed 1400 out of 20841 in 8086.579750537872 seconds
# Processed 1450 out of 20841 in 8401.671903371811 seconds
# Processed 1500 out of 20841 in 8698.883161067963 seconds
# Processed 1550 out of 20841 in 9347.875393629074 seconds
# Processed 1600 out of 20841 in 9920.96721482277 seconds
# Processed 1650 out of 20841 in 10442.42263174057 seconds
# Processed 1700 out of 20841 in 10877.199659824371 seconds
# Processed 1750 out of 20841 in 11090.528118610382 seconds
# Processed 1800 out of 20841 in 11215.730933189392 seconds
# Processed 1850 out of 20841 in 11598.370792150497 seconds
# Processed 1900 out of 20841 in 12018.929584503174 seconds
# Processed 1950 out of 20841 in 12463.630265951157 seconds
# Processed 2000 out of 20841 in 12779.29148197174 seconds
# Processed 2050 out of 20841 in 13608.034942150116 seconds
# Processed 2100 out of 20841 in 13802.749457359314 seconds
# Processed 2150 out of 20841 in 14485.086376667023 seconds
# Processed 2200 out of 20841 in 14808.457993030548 seconds
# Processed 2250 out of 20841 in 15247.967711925507 seconds
# Processed 2300 out of 20841 in 16090.553465127945 seconds
# Processed 2350 out of 20841 in 16432.42625975609 seconds
# Processed 2400 out of 20841 in 16808.875283241272 seconds
# Processed 2450 out of 20841 in 17097.68981909752 seconds
# Processed 2500 out of 20841 in 17255.35169196129 seconds
# Processed 2550 out of 20841 in 17424.03885793686 seconds
# Processed 2600 out of 20841 in 17639.577685832977 seconds
# Processed 2650 out of 20841 in 17876.438771486282 seconds
# Processed 2700 out of 20841 in 18035.010957717896 seconds
# Processed 2750 out of 20841 in 18227.99778842926 seconds
# Processed 2800 out of 20841 in 18427.22402215004 seconds
# Processed 2850 out of 20841 in 18739.190383911133 seconds
# Processed 2900 out of 20841 in 19058.90759754181 seconds
# Processed 2950 out of 20841 in 19378.841705083847 seconds
# Processed 3000 out of 20841 in 20178.91347026825 seconds
# Processed 3050 out of 20841 in 20633.385268449783 seconds
# Processed 3100 out of 20841 in 20842.112243652344 seconds
# Processed 3150 out of 20841 in 21352.947197675705 seconds
# Processed 3200 out of 20841 in 21613.71901369095 seconds
# Processed 3250 out of 20841 in 21973.83486843109 seconds
# Processed 3300 out of 20841 in 22296.851754188538 seconds
# Processed 3350 out of 20841 in 22760.55843949318 seconds
# Processed 3400 out of 20841 in 22979.69661140442 seconds
# Processed 3450 out of 20841 in 23394.223139047623 seconds
# Processed 3500 out of 20841 in 23917.45548915863 seconds
# Processed 3550 out of 20841 in 24310.624070882797 seconds
# Processed 3600 out of 20841 in 25162.146555662155 seconds
# Processed 3650 out of 20841 in 25341.506623506546 seconds
# Processed 3700 out of 20841 in 25661.687002897263 seconds
# Processed 3750 out of 20841 in 25987.73299741745 seconds
# Processed 3800 out of 20841 in 26248.95998597145 seconds
# Processed 3850 out of 20841 in 26515.44961643219 seconds
# Processed 3900 out of 20841 in 27002.316859722137 seconds
# Processed 3950 out of 20841 in 27567.546772003174 seconds
# Processed 4000 out of 20841 in 27787.098654031754 seconds
# Processed 4050 out of 20841 in 28141.59701371193 seconds
# Processed 4100 out of 20841 in 28364.96041560173 seconds
# Processed 4150 out of 20841 in 28690.075447320938 seconds
# Processed 4200 out of 20841 in 29024.64566206932 seconds
# Processed 4250 out of 20841 in 29426.1679520607 seconds
# Processed 4300 out of 20841 in 29965.00679731369 seconds
# Processed 4350 out of 20841 in 30194.519947767258 seconds
# Processed 4400 out of 20841 in 30598.818254232407 seconds
# Processed 4450 out of 20841 in 31194.34358906746 seconds
# Processed 4500 out of 20841 in 31818.170104265213 seconds
# Processed 4550 out of 20841 in 32054.995785474777 seconds
# Processed 4600 out of 20841 in 32553.04926300049 seconds
# Processed 4650 out of 20841 in 33027.79339170456 seconds
# Processed 4700 out of 20841 in 33430.15332078934 seconds
# Processed 4750 out of 20841 in 33588.934295892715 seconds
# Processed 4800 out of 20841 in 33857.38450574875 seconds
# Processed 4850 out of 20841 in 34114.893206596375 seconds
# Processed 4900 out of 20841 in 34406.46677565575 seconds
# Processed 4950 out of 20841 in 34674.059265851974 seconds
# Processed 5000 out of 20841 in 34801.31649684906 seconds
# Processed 5050 out of 20841 in 35113.78542804718 seconds
# Processed 5100 out of 20841 in 35367.79503250122 seconds
# Processed 5150 out of 20841 in 35752.15100312233 seconds
# Processed 5200 out of 20841 in 35963.07101583481 seconds
# Processed 5250 out of 20841 in 37211.518944740295 seconds
# Processed 5300 out of 20841 in 38199.23561859131 seconds
# Processed 5350 out of 20841 in 38547.70424127579 seconds
# Processed 5400 out of 20841 in 39009.748102903366 seconds
# Processed 5450 out of 20841 in 39636.6034245491 seconds
# Processed 5500 out of 20841 in 40069.64670443535 seconds
# Processed 5550 out of 20841 in 40325.68239569664 seconds
# Processed 5600 out of 20841 in 40733.70419049263 seconds
# Processed 5650 out of 20841 in 41239.08304643631 seconds
# Processed 5700 out of 20841 in 41608.33412218094 seconds
# Processed 5750 out of 20841 in 42135.4111635685 seconds
# Processed 5800 out of 20841 in 42496.56568813324 seconds
# Processed 5850 out of 20841 in 42709.83507061005 seconds
# Processed 5900 out of 20841 in 42888.41275143623 seconds
# Processed 5950 out of 20841 in 43078.47823405266 seconds
# Processed 6000 out of 20841 in 43434.287989377975 seconds
# Processed 6050 out of 20841 in 44329.33683824539 seconds
# Processed 6100 out of 20841 in 44733.895803928375 seconds
# Processed 6150 out of 20841 in 44963.62732076645 seconds
# Processed 6200 out of 20841 in 45196.53738260269 seconds
# Processed 6250 out of 20841 in 45476.40230965614 seconds
# Processed 6300 out of 20841 in 45648.91660904884 seconds
# Processed 6350 out of 20841 in 46180.83085632324 seconds
# Processed 6400 out of 20841 in 46368.32389950752 seconds
# Processed 6450 out of 20841 in 46788.32005190849 seconds
# Processed 6500 out of 20841 in 47050.214673519135 seconds
# Processed 6550 out of 20841 in 47399.27815437317 seconds
# Processed 6600 out of 20841 in 47627.4385201931 seconds
# Processed 6650 out of 20841 in 48020.129101514816 seconds
# Processed 6700 out of 20841 in 48434.914998054504 seconds
# Processed 6750 out of 20841 in 48907.514085292816 seconds
# Processed 6800 out of 20841 in 49508.19857931137 seconds
# Processed 6850 out of 20841 in 49740.17814350128 seconds
# Processed 6900 out of 20841 in 50037.51011157036 seconds
# Processed 6950 out of 20841 in 50245.80793809891 seconds
# Processed 7000 out of 20841 in 51035.32962656021 seconds
# Processed 7050 out of 20841 in 52302.373861551285 seconds
# Processed 7100 out of 20841 in 52997.556436777115 seconds
# Processed 7150 out of 20841 in 53296.40220999718 seconds
# Processed 7200 out of 20841 in 53590.765644311905 seconds
# Processed 7250 out of 20841 in 53942.0473921299 seconds
# Processed 7300 out of 20841 in 55240.404915094376 seconds
# Processed 7350 out of 20841 in 55434.58506369591 seconds
# Processed 7400 out of 20841 in 56435.061806201935 seconds
# Processed 7450 out of 20841 in 57802.48528933525 seconds
# Processed 7500 out of 20841 in 58737.41252923012 seconds
# Processed 7550 out of 20841 in 59160.49839878082 seconds
# Processed 7600 out of 20841 in 59580.68075466156 seconds
# Processed 7650 out of 20841 in 60531.92257285118 seconds
# Processed 7700 out of 20841 in 61163.747628211975 seconds
# Processed 7750 out of 20841 in 61659.837032318115 seconds
# Processed 7800 out of 20841 in 62538.89891123772 seconds
# Processed 7850 out of 20841 in 63310.19093155861 seconds
# Processed 7900 out of 20841 in 64004.33918094635 seconds
# Processed 7950 out of 20841 in 64281.56375026703 seconds
# Processed 8000 out of 20841 in 64809.404391765594 seconds
# Processed 8050 out of 20841 in 65037.961151599884 seconds
# Processed 8100 out of 20841 in 65257.6790766716 seconds
# Processed 8150 out of 20841 in 65443.70759797096 seconds
# Processed 8200 out of 20841 in 65658.41435933113 seconds
# Processed 8250 out of 20841 in 66148.21794581413 seconds
# Processed 8300 out of 20841 in 66502.63865637779 seconds
# Processed 8350 out of 20841 in 67065.35154747963 seconds
# Processed 8400 out of 20841 in 67679.03336882591 seconds
# Processed 8450 out of 20841 in 68128.53568339348 seconds
# Processed 8500 out of 20841 in 68430.97098636627 seconds
# Processed 8550 out of 20841 in 69125.80308175087 seconds
# Processed 8600 out of 20841 in 69457.72848939896 seconds
# Processed 8650 out of 20841 in 69723.25322890282 seconds
# Processed 8700 out of 20841 in 69966.96853280067 seconds
# Processed 8750 out of 20841 in 70167.1894185543 seconds
# Processed 8800 out of 20841 in 70367.34981966019 seconds
# Processed 8850 out of 20841 in 70603.85920071602 seconds
# Processed 8900 out of 20841 in 70856.25922226906 seconds
# Processed 8950 out of 20841 in 71125.07356476784 seconds
# Processed 9000 out of 20841 in 71469.55067062378 seconds
# Processed 9050 out of 20841 in 71664.49472665787 seconds
# Processed 9100 out of 20841 in 71954.75394153595 seconds
# Processed 9150 out of 20841 in 72181.49235129356 seconds
# Processed 9200 out of 20841 in 72510.23089957237 seconds
# Processed 9250 out of 20841 in 72693.1540260315 seconds
# Processed 9300 out of 20841 in 72980.43299412727 seconds
# Processed 9350 out of 20841 in 73335.70750808716 seconds
# Processed 9400 out of 20841 in 73675.65918421745 seconds
# Processed 9450 out of 20841 in 73942.23641610146 seconds
# Processed 9500 out of 20841 in 74106.24533820152 seconds
# Processed 9550 out of 20841 in 74368.15187573433 seconds
# Processed 9600 out of 20841 in 74623.14056372643 seconds
# Processed 9650 out of 20841 in 75187.65341377258 seconds
# Processed 9700 out of 20841 in 75481.60186696053 seconds
# Processed 9750 out of 20841 in 76091.94901371002 seconds
# Processed 9800 out of 20841 in 76587.8398578167 seconds
# Processed 9850 out of 20841 in 77335.94054555893 seconds
# Processed 9900 out of 20841 in 77567.58393120766 seconds
# Processed 9950 out of 20841 in 78227.67063379288 seconds
# Processed 10000 out of 20841 in 78670.67003440857 seconds
# Processed 10050 out of 20841 in 79077.79289841652 seconds
# Processed 10100 out of 20841 in 79544.35976982117 seconds
# Processed 10150 out of 20841 in 79954.47043633461 seconds
# Processed 10200 out of 20841 in 80163.14008140564 seconds
# Processed 10250 out of 20841 in 80431.19920921326 seconds
# Processed 10300 out of 20841 in 80724.34674406052 seconds
# Processed 10350 out of 20841 in 81055.41746211052 seconds
# Processed 10400 out of 20841 in 81251.15561556816 seconds
# Processed 10450 out of 20841 in 82376.99168634415 seconds
# Processed 10500 out of 20841 in 82542.76821637154 seconds
# Processed 10550 out of 20841 in 82730.14029717445 seconds
# Processed 10600 out of 20841 in 82944.21139645576 seconds
# Processed 10650 out of 20841 in 83229.72359538078 seconds
# Processed 10700 out of 20841 in 83253.82970905304 seconds
# Processed 10750 out of 20841 in 83407.12906432152 seconds
# Processed 10800 out of 20841 in 83553.52866744995 seconds
# Processed 10850 out of 20841 in 83812.86551070213 seconds
# Processed 10900 out of 20841 in 84066.14020395279 seconds
# Processed 10950 out of 20841 in 84805.11414861679 seconds
# Processed 11000 out of 20841 in 85103.12705135345 seconds
# Processed 11050 out of 20841 in 85607.19960045815 seconds
# Processed 11100 out of 20841 in 85922.01393198967 seconds
# Processed 11150 out of 20841 in 86234.63048934937 seconds
# Processed 11200 out of 20841 in 86564.04587006569 seconds
# Processed 11250 out of 20841 in 86812.43004584312 seconds
# Processed 11300 out of 20841 in 87145.42987775803 seconds
# Processed 11350 out of 20841 in 87521.07383131981 seconds
# Processed 11400 out of 20841 in 87685.37163281441 seconds
# Processed 11450 out of 20841 in 88068.60106444359 seconds
# Processed 11500 out of 20841 in 88358.51062893867 seconds
# Processed 11550 out of 20841 in 88642.50298595428 seconds
# Processed 11600 out of 20841 in 88919.27625393867 seconds
# Processed 11650 out of 20841 in 89141.604752779 seconds
# Processed 11700 out of 20841 in 89494.65464305878 seconds
# Processed 11750 out of 20841 in 91236.23236894608 seconds
# Processed 11800 out of 20841 in 91531.63454794884 seconds
# Processed 11850 out of 20841 in 91755.37883329391 seconds
# Processed 11900 out of 20841 in 91941.06039428711 seconds
# Processed 11950 out of 20841 in 92160.15921497345 seconds
# Processed 12000 out of 20841 in 92496.56549334526 seconds
# Processed 12050 out of 20841 in 93801.63707065582 seconds
# Processed 12100 out of 20841 in 93912.22824454308 seconds
# Processed 12150 out of 20841 in 94078.29206061363 seconds
# Processed 12200 out of 20841 in 94314.83203339577 seconds
# Processed 12250 out of 20841 in 94561.63724350929 seconds
# Processed 12300 out of 20841 in 94689.15964818001 seconds
# Processed 12350 out of 20841 in 94989.19499135017 seconds
# Processed 12400 out of 20841 in 95405.81379389763 seconds
# Processed 12450 out of 20841 in 95946.52570295334 seconds
# Processed 12500 out of 20841 in 96821.93375873566 seconds
# Processed 12550 out of 20841 in 97367.35487627983 seconds
# Processed 12600 out of 20841 in 98501.42336654663 seconds
# Processed 12650 out of 20841 in 99092.54116749763 seconds
# Processed 12700 out of 20841 in 99687.62895154953 seconds
# Processed 12750 out of 20841 in 100031.89797282219 seconds
# Processed 12800 out of 20841 in 100456.3978357315 seconds
# Processed 12850 out of 20841 in 100585.42463994026 seconds
# Processed 12900 out of 20841 in 100910.33621287346 seconds
# Processed 12950 out of 20841 in 101238.00481104851 seconds
# Processed 13000 out of 20841 in 101514.95115494728 seconds
# Processed 13050 out of 20841 in 101765.55559968948 seconds
# Processed 13100 out of 20841 in 102175.48918437958 seconds
# Processed 13150 out of 20841 in 102286.67956900597 seconds
# Processed 13200 out of 20841 in 102553.97534489632 seconds
# Processed 13250 out of 20841 in 102747.53388977051 seconds
# Processed 13300 out of 20841 in 103081.83063554764 seconds
# Processed 13350 out of 20841 in 103285.78176617622 seconds
# Processed 13400 out of 20841 in 103663.91614818573 seconds
# Processed 13450 out of 20841 in 104121.35349583626 seconds
# Processed 13500 out of 20841 in 104518.48910355568 seconds
# Processed 13550 out of 20841 in 104805.85680508614 seconds
# Processed 13600 out of 20841 in 105083.01791906357 seconds
# Processed 13650 out of 20841 in 105353.38594603539 seconds
# Processed 13700 out of 20841 in 105590.50311350822 seconds
# Processed 13750 out of 20841 in 105844.21419334412 seconds
# Processed 13800 out of 20841 in 106344.84954762459 seconds
# Processed 13850 out of 20841 in 106924.54820513725 seconds
# Processed 13900 out of 20841 in 107226.58717083931 seconds
# Processed 13950 out of 20841 in 107762.16209626198 seconds
# Processed 14000 out of 20841 in 108259.96516013145 seconds
# Processed 14050 out of 20841 in 108854.07913088799 seconds
# Processed 14100 out of 20841 in 109410.33824944496 seconds
# Processed 14150 out of 20841 in 109668.67882418633 seconds
# Processed 14200 out of 20841 in 110069.84365320206 seconds
# Processed 14250 out of 20841 in 110359.40178322792 seconds
# Processed 14300 out of 20841 in 110629.00973296165 seconds
# Processed 14350 out of 20841 in 110885.80258727074 seconds
# Processed 14400 out of 20841 in 111249.81571555138 seconds
# Processed 14450 out of 20841 in 111589.2143471241 seconds
# Processed 14500 out of 20841 in 112095.01660680771 seconds
# Processed 14550 out of 20841 in 112409.08151769638 seconds
# Processed 14600 out of 20841 in 112674.52329134941 seconds
# Processed 14650 out of 20841 in 112863.02375292778 seconds
# Processed 14700 out of 20841 in 113166.6199605465 seconds
# Processed 14750 out of 20841 in 113474.84753632545 seconds
# Processed 14800 out of 20841 in 113854.83928656578 seconds
# Processed 14850 out of 20841 in 114191.11926674843 seconds
# Processed 14900 out of 20841 in 114428.07090210915 seconds
# Processed 14950 out of 20841 in 114602.91694188118 seconds
# Processed 15000 out of 20841 in 114902.5625011921 seconds
# Processed 15050 out of 20841 in 115849.3621096611 seconds
# Processed 15100 out of 20841 in 116485.10534477234 seconds
# Processed 15150 out of 20841 in 117551.45536160469 seconds
# Processed 15200 out of 20841 in 117810.19579529762 seconds
# Processed 15250 out of 20841 in 118182.28346800804 seconds
# Processed 15300 out of 20841 in 118602.07828712463 seconds
# Processed 15350 out of 20841 in 118979.95884251595 seconds
# Processed 15400 out of 20841 in 119235.34404873848 seconds
# Processed 15450 out of 20841 in 119500.84622764587 seconds
# Processed 15500 out of 20841 in 120362.0553715229 seconds
# Processed 15550 out of 20841 in 120665.61021447182 seconds
# Processed 15600 out of 20841 in 121032.9552872181 seconds
# Processed 15650 out of 20841 in 121978.04897546768 seconds
# Processed 15700 out of 20841 in 122524.25705599785 seconds
# Processed 15750 out of 20841 in 122707.11856198311 seconds
# Processed 15800 out of 20841 in 123745.49705314636 seconds
# Processed 15850 out of 20841 in 124238.62966823578 seconds
# Processed 15900 out of 20841 in 124496.0118508339 seconds
# Processed 15950 out of 20841 in 125313.21393322945 seconds
# Processed 16000 out of 20841 in 125703.85480690002 seconds
# Processed 16050 out of 20841 in 126247.46708106995 seconds
# Processed 16100 out of 20841 in 126676.32867717743 seconds
# Processed 16150 out of 20841 in 126931.96736550331 seconds
# Processed 16200 out of 20841 in 127100.3234949112 seconds
# Processed 16250 out of 20841 in 127227.92943882942 seconds
# Processed 16300 out of 20841 in 127364.51633954048 seconds
# Processed 16350 out of 20841 in 127566.77400565147 seconds
# Processed 16400 out of 20841 in 127762.11360931396 seconds
# Processed 16450 out of 20841 in 128775.04600214958 seconds
# Processed 16500 out of 20841 in 129365.71466469765 seconds
# Processed 16550 out of 20841 in 129835.69783592224 seconds
# Processed 16600 out of 20841 in 130254.17321109772 seconds
# Processed 16650 out of 20841 in 130532.919008255 seconds
# Processed 16700 out of 20841 in 130835.02360391617 seconds
# Processed 16750 out of 20841 in 131157.52263188362 seconds
# Processed 16800 out of 20841 in 131576.23446941376 seconds
# Processed 16850 out of 20841 in 132271.23687934875 seconds
# exception V37849 NHEENGATU GNAV 1.m4v
# exception V37850 NHEENGATU GNAV 2.m4v
# Processed 16900 out of 20841 in 132594.69264388084 seconds
# Processed 16950 out of 20841 in 132922.52107048035 seconds
# Processed 17000 out of 20841 in 133530.3616859913 seconds
# Processed 17050 out of 20841 in 134046.36052680016 seconds
# Processed 17100 out of 20841 in 134346.5941722393 seconds
# Processed 17150 out of 20841 in 134900.06322288513 seconds
# Processed 17200 out of 20841 in 135099.55000066757 seconds
# Processed 17250 out of 20841 in 135407.7862393856 seconds
# Processed 17300 out of 20841 in 135644.03930020332 seconds
# Processed 17350 out of 20841 in 136084.12712860107 seconds
# Processed 17400 out of 20841 in 136463.8890452385 seconds
# Processed 17450 out of 20841 in 137198.96951913834 seconds
# Processed 17500 out of 20841 in 137623.998660326 seconds
# Processed 17550 out of 20841 in 138465.94154047966 seconds
# Processed 17600 out of 20841 in 138910.01270794868 seconds
# Processed 17650 out of 20841 in 139275.3997642994 seconds
# Processed 17700 out of 20841 in 139671.04965353012 seconds
# Processed 17750 out of 20841 in 139846.83062386513 seconds
# Processed 17800 out of 20841 in 139959.5510213375 seconds
# Processed 17850 out of 20841 in 140263.68043994904 seconds
# Processed 17900 out of 20841 in 140386.77283883095 seconds
# Processed 17950 out of 20841 in 140690.52582263947 seconds
# Processed 18000 out of 20841 in 140956.0636730194 seconds
# Processed 18050 out of 20841 in 141140.32387590408 seconds
# Processed 18100 out of 20841 in 141645.28646874428 seconds
# Processed 18150 out of 20841 in 141797.67182826996 seconds
# Processed 18200 out of 20841 in 142194.4139816761 seconds
# Processed 18250 out of 20841 in 142466.87405467033 seconds
# Processed 18300 out of 20841 in 142991.13049650192 seconds
# Processed 18350 out of 20841 in 143461.26289010048 seconds
# Processed 18400 out of 20841 in 143829.80318927765 seconds
# Processed 18450 out of 20841 in 144072.63984894753 seconds
# Processed 18500 out of 20841 in 144548.3685209751 seconds
# Processed 18550 out of 20841 in 145510.85277223587 seconds
# Processed 18600 out of 20841 in 145961.9568812847 seconds
# Processed 18650 out of 20841 in 146510.5031530857 seconds
# Processed 18700 out of 20841 in 147269.99456191063 seconds
# Processed 18750 out of 20841 in 147799.4069378376 seconds
# Processed 18800 out of 20841 in 148073.06649255753 seconds
# Processed 18850 out of 20841 in 148259.03916096687 seconds
# Processed 18900 out of 20841 in 149701.8994011879 seconds
# Processed 18950 out of 20841 in 149770.9231402874 seconds
# Processed 19000 out of 20841 in 149944.6152627468 seconds
# Processed 19050 out of 20841 in 150129.47818779945 seconds
# Processed 19100 out of 20841 in 150250.4920349121 seconds
# Processed 19150 out of 20841 in 150832.8560450077 seconds
# Processed 19200 out of 20841 in 151300.494535923 seconds
# Processed 19250 out of 20841 in 151673.4662668705 seconds
# Processed 19300 out of 20841 in 152091.4598069191 seconds
# Processed 19350 out of 20841 in 152631.9564871788 seconds
# Processed 19400 out of 20841 in 153079.23789262772 seconds
# Processed 19450 out of 20841 in 153478.384642601 seconds
# Processed 19500 out of 20841 in 154391.9774096012 seconds
# Processed 19550 out of 20841 in 154747.32536363602 seconds
# Processed 19600 out of 20841 in 155098.45214676857 seconds
# Processed 19650 out of 20841 in 155333.95575118065 seconds
# Processed 19700 out of 20841 in 155619.13734912872 seconds
# Processed 19750 out of 20841 in 155971.7965414524 seconds
# Processed 19800 out of 20841 in 156107.29604363441 seconds
# Processed 19850 out of 20841 in 156447.00255179405 seconds
# Processed 19900 out of 20841 in 156702.9543735981 seconds
# Processed 19950 out of 20841 in 156958.9643380642 seconds
# Processed 20000 out of 20841 in 157238.9810974598 seconds
# Processed 20050 out of 20841 in 157423.23419237137 seconds
# Processed 20100 out of 20841 in 157723.31961083412 seconds
# Processed 20150 out of 20841 in 158431.719353199 seconds
# Processed 20200 out of 20841 in 158718.7242166996 seconds
# Processed 20250 out of 20841 in 158979.09262132645 seconds
# Processed 20300 out of 20841 in 159087.82889652252 seconds
# Processed 20350 out of 20841 in 159275.16515016556 seconds
# Processed 20400 out of 20841 in 159516.09661960602 seconds
# Processed 20450 out of 20841 in 159774.44348931313 seconds
# Processed 20500 out of 20841 in 159983.77434945107 seconds
# Processed 20550 out of 20841 in 160398.90876960754 seconds
# Processed 20600 out of 20841 in 160551.33480715752 seconds
# Processed 20650 out of 20841 in 160888.72395420074 seconds
# Processed 20700 out of 20841 in 161786.80947875977 seconds
# Processed 20750 out of 20841 in 162530.1530327797 seconds
# Processed 20800 out of 20841 in 162935.10366153717 seconds
# Processed 20841 out of 20841 in 163501.91157197952 seconds
