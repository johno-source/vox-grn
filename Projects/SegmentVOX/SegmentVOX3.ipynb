# %% [markdown]
# # Partial Process of Segment GRN Data for vox-grn
#
# See SegmentVox.ipynb for full description.
#
# In an attempt to speed up the processing I have divided the items up into 10 groups and want to have them all process in parallel. It probably won't be 10 times faster but it should still be quicker.

# %%
import pandas as pd
import numpy as np
import os
import sys
module_path = os.path.abspath(os.path.join('../vad_utils'))
if module_path not in sys.path:
    sys.path.append(module_path)
from vad_utils import SAMPLING_RATE, FRAME_SIZE_MS, SAMPLES_PER_FRAME
import vad_utils as vu
from pydub import AudioSegment
import pickle as pkl
from pathlib import Path
import time

# %%
# define the locations for each of the file types
NOTEBOOK_ID=3
SEGMENTS_DIR = '/media/originals/segments/'
DATASETS_DIR = '/media/originals/datasets/'
SEC_4_DATA_DIR = 'seg_4sec/data/'
SEC_6_DATA_DIR = 'seg_6sec/data/'
SEC_10_DATA_DIR = 'seg_10sec/data/'

# define specific files used in the process
SEG_4_SEC_DF = f'{SEGMENTS_DIR}seg_4sec_{NOTEBOOK_ID}.csv'
SEG_6_SEC_DF = f'{SEGMENTS_DIR}seg_6sec_{NOTEBOOK_ID}.csv'
SEG_10_SEC_DF = f'{SEGMENTS_DIR}seg_10sec_{NOTEBOOK_ID}.csv'

# define segment sizes for each dataset
SEG_4_SEC = 4.0
SEG_6_SEC = 6.0
SEG_10_SEC = 10.0

# %%
# Now read in the description of the input and remove the unwanted columns and rename the rest to be python attribute names.
items = pd.read_csv(f'/media/originals/segments/items_{NOTEBOOK_ID}.csv')
items.set_index('ID', inplace=True)
items.columns
# Out:
# Index(['iso', 'program', 'location', 'year', 'path', 'filename', 'item_no',
#        'title', 'start', 'end'],
#       dtype='object')

# %%
print(items.iloc[100])
# Out:
# iso                                       gur
# program                                C78408
# location                                Duusi
# year                                   2001.0
# path        Programs/78/78408/C78408/MM-1101/
# filename                         C78408-A.wav
# item_no                                     3
# title                               Picture 1
# start                                   173.0
# end                                     222.0
# Name: C78408_003, dtype: object

# %%
print(items.index)
# Out:
# Index(['A78442_005', 'A78443_003', 'A78442_026', 'A78442_007', 'A78442_008',
#        'A78442_009', 'A78442_010', 'A78442_011', 'C78402_004', 'C78402_005',
#        ...
#        'A65072_025', 'A65073_001', 'A65073_002', 'A65073_003', 'A65072_018',
#        'A65072_024', 'A65073_013', 'A09510_001', 'A75203_004', 'A75203_005'],
#       dtype='object', name='ID', length=17198)

# %%
# generate directories and filenames
def prepare_dir(dirname):
    if dirname[-1] != '/':
        dirname = dirname + '/'
    Path(dirname).mkdir(parents=True, exist_ok=True)
    return dirname

def prepare_raw_seg_dir(item):
    return prepare_dir(SEGMENTS_DIR + item.iso)

def raw_seg_filename(item):
    return f'{item.program}_{item.item_no:03d}.pkl'

def prepare_dataset_data_dir(item, dataset_dir):
    return prepare_dir(DATASETS_DIR + dataset_dir + item.iso)

def seg_mp3_filename(item, seg):
    return f'{item.program}_{item.item_no:03d}_{seg:03d}.mp3'

# %%
def condition_audio_segment(audio_seg):
    if audio_seg.channels != 1:
        audio_seg = audio_seg.set_channels(1)

    if audio_seg.sample_width != 2:
        audio_seg = audio_seg.set_sample_width(2)

    if audio_seg.frame_rate != SAMPLING_RATE:
        audio_seg = audio_seg.set_frame_rate(SAMPLING_RATE)

    return audio_seg

# %%
def save_the_segment_info(item, segs):
    fname = prepare_raw_seg_dir(item) + raw_seg_filename(item)
    with open(fname, 'wb') as pklFile:
         pkl.dump(segs, pklFile)

def read_the_segment_info(item):
    fname = prepare_raw_seg_dir(item) + raw_seg_filename(item)
    if os.path.exists(fname):
        if os.path.getsize(fname) > 0:
            with open(fname, 'rb') as pklFile:
                return pkl.load(pklFile)
    return []
    
def extract_audio_segment_for_item(item):
    fmt = 'wav'
    if item.filename[-4:] == '.mp3' :
        fmt = 'mp3'
    audio_seg = AudioSegment.from_file('/media/programs/' + item.path + item.filename, format=fmt)
    start_ms = int(item.start * 1000)
    end_ms = int(item.end * 1000)
    audio_seg = audio_seg[start_ms:end_ms]

    # now condition the segment and extract the raw segments.
    audio_seg = condition_audio_segment(audio_seg)
    segs = read_the_segment_info(item)
    if len(segs) == 0:
        segs = vu.audio_to_raw_voice_segments(audio_seg)
        save_the_segment_info(item, segs)

    return audio_seg, segs

def create_mp3_files(audio_seg, segs, time_per_segment, dataset_dir, item):
    segs_for_time = vu.divide_into_segments(segs, time_per_segment)

    # now write out the 4 sec segments
    dirname = prepare_dataset_data_dir(item, dataset_dir)
    rows = list()
    for i, seg in enumerate(segs_for_time):
        file_name = dataset_dir + item.iso + '/' + seg_mp3_filename(item, i)
        fname = dirname + seg_mp3_filename(item, i)
        if not os.path.exists(fname):
            start = vu.convert_frames_to_ms(seg.start)
            stop = vu.convert_frames_to_ms(seg.stop)
            audio_seg[start:stop].export(fname, format='mp3', bitrate='32k')
        desc = dict(item._asdict())
        desc['seg_start'] = vu.convert_frames_to_seconds(seg.start)
        desc['seg_stop'] = vu.convert_frames_to_seconds(seg.stop)
        desc['seg'] = i
        desc['file_name'] = file_name
        rows.append(desc)

    return rows

def update_dataframes(seg_df_csv, seg_records):
    # now update the dataframes
    if len(seg_records) > 0:
        if os.path.isfile(seg_df_csv):
            seg_sec_df = pd.concat([pd.read_csv(seg_df_csv, index_col='file_name'), pd.DataFrame.from_records(seg_records, index='file_name')])
        else:
            seg_sec_df = pd.DataFrame.from_records(seg_records, index='file_name')
        seg_sec_df.to_csv(seg_df_csv)

# %%
# processing these items might take a very long time. To permit the process to be interrupted and restarted the indexes of processed items
# are maintained in a set that is pickled on each batch. This allows the batch to quickly pick up where it left off.
def process_record_batch(items_df, *, batch_size=10):
    batch_proc = 0
    processed_file = f'/media/originals/segments/processed16_{NOTEBOOK_ID}.pkl'
    if os.path.isfile(processed_file):
        with open(processed_file, 'rb') as pklFile:
            processed_items = pkl.load(pklFile)
    else:
        processed_items = set()

    segmented_4sec_segs = []
    segmented_6sec_segs = []
    segmented_10sec_segs = []

    for item in items_df.itertuples():
        if batch_proc < batch_size:
            if item.Index not in processed_items:
                try:
                    audio_seg, voice_segs = extract_audio_segment_for_item(item)
                    segmented_4sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_4_SEC, SEC_4_DATA_DIR, item))
                    segmented_6sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_6_SEC, SEC_6_DATA_DIR, item))
                    segmented_10sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_10_SEC, SEC_10_DATA_DIR, item))
                except:
                    print('exception')
                    pass

                # we want to add an item that has an exception so it is not reprocessed on every batch
                processed_items.add(item.Index)
                batch_proc += 1

        else:
            break

    update_dataframes(SEG_4_SEC_DF, segmented_4sec_segs)
    update_dataframes(SEG_6_SEC_DF, segmented_6sec_segs)
    update_dataframes(SEG_10_SEC_DF, segmented_10sec_segs)

    with open(processed_file, 'wb') as pklFile:
        pkl.dump(processed_items, pklFile)

    return processed_items

# %%
start_time = time.time()
# form the language classification file
items_processed = 0
items_to_process = len(items)
while items_to_process > items_processed:
    processed_items = process_record_batch(items, batch_size=50)
    items_processed = len(processed_items)
    print(f'Processed {items_processed} out of {items_to_process} in {time.time()-start_time} seconds')
# Out:
# Processed 50 out of 17198 in 269.989218711853 seconds
# Processed 100 out of 17198 in 402.1477885246277 seconds
# Processed 150 out of 17198 in 561.7854533195496 seconds
# Processed 200 out of 17198 in 833.4689691066742 seconds
# Processed 250 out of 17198 in 1113.242264032364 seconds
# Processed 300 out of 17198 in 1386.7247295379639 seconds
# Processed 350 out of 17198 in 1663.9174847602844 seconds
# Processed 400 out of 17198 in 1907.4257464408875 seconds
# Processed 450 out of 17198 in 2874.2964317798615 seconds
# Processed 500 out of 17198 in 3238.787173986435 seconds
# Processed 550 out of 17198 in 3669.3103613853455 seconds
# Processed 600 out of 17198 in 3933.7123823165894 seconds
# Processed 650 out of 17198 in 4224.895198106766 seconds
# Processed 700 out of 17198 in 4400.58709692955 seconds
# Processed 750 out of 17198 in 4842.091403961182 seconds
# Processed 800 out of 17198 in 5147.299101829529 seconds
# Processed 850 out of 17198 in 5308.902413606644 seconds
# Processed 900 out of 17198 in 5661.158010959625 seconds
# Processed 950 out of 17198 in 6809.060548782349 seconds
# Processed 1000 out of 17198 in 7508.894428730011 seconds
# Processed 1050 out of 17198 in 8243.795640945435 seconds
# Processed 1100 out of 17198 in 8998.207984924316 seconds
# Processed 1150 out of 17198 in 10219.119156122208 seconds
# Processed 1200 out of 17198 in 10735.228970766068 seconds
# Processed 1250 out of 17198 in 11505.44644832611 seconds
# Processed 1300 out of 17198 in 12314.450291156769 seconds
# Processed 1350 out of 17198 in 12563.586588382721 seconds
# Processed 1400 out of 17198 in 13014.910662174225 seconds
# Processed 1450 out of 17198 in 13796.77195239067 seconds
# Processed 1500 out of 17198 in 14245.706032276154 seconds
# Processed 1550 out of 17198 in 14648.706805706024 seconds
# Processed 1600 out of 17198 in 15110.302096366882 seconds
# Processed 1650 out of 17198 in 15389.182183980942 seconds
# Processed 1700 out of 17198 in 15598.939254045486 seconds
# Processed 1750 out of 17198 in 16833.401128053665 seconds
# Processed 1800 out of 17198 in 17221.100078344345 seconds
# Processed 1850 out of 17198 in 17700.13626551628 seconds
# Processed 1900 out of 17198 in 19580.19303202629 seconds
# Processed 1950 out of 17198 in 24225.422741413116 seconds
# Processed 2000 out of 17198 in 25476.59902238846 seconds
# Processed 2050 out of 17198 in 25824.66783928871 seconds
# Processed 2100 out of 17198 in 26138.859639167786 seconds
# Processed 2150 out of 17198 in 26392.3000831604 seconds
# Processed 2200 out of 17198 in 26648.220359563828 seconds
# Processed 2250 out of 17198 in 26866.55565929413 seconds
# Processed 2300 out of 17198 in 27110.053258657455 seconds
# Processed 2350 out of 17198 in 27326.539275169373 seconds
# Processed 2400 out of 17198 in 27516.46479153633 seconds
# Processed 2450 out of 17198 in 27730.44949245453 seconds
# Processed 2500 out of 17198 in 28034.929953575134 seconds
# Processed 2550 out of 17198 in 28311.51086330414 seconds
# Processed 2600 out of 17198 in 28636.6103014946 seconds
# Processed 2650 out of 17198 in 29044.751672506332 seconds
# Processed 2700 out of 17198 in 29671.167154550552 seconds
# Processed 2750 out of 17198 in 30172.455815076828 seconds
# Processed 2800 out of 17198 in 30359.389137268066 seconds
# Processed 2850 out of 17198 in 30721.652697086334 seconds
# Processed 2900 out of 17198 in 30930.168605089188 seconds
# Processed 2950 out of 17198 in 31135.220046281815 seconds
# Processed 3000 out of 17198 in 31334.95098423958 seconds
# Processed 3050 out of 17198 in 31490.810163259506 seconds
# Processed 3100 out of 17198 in 32205.85269665718 seconds
# Processed 3150 out of 17198 in 32673.213999271393 seconds
# Processed 3200 out of 17198 in 32801.1997423172 seconds
# Processed 3250 out of 17198 in 32967.678695201874 seconds
# Processed 3300 out of 17198 in 33219.77358341217 seconds
# Processed 3350 out of 17198 in 33464.1387193203 seconds
# Processed 3400 out of 17198 in 33649.289704322815 seconds
# Processed 3450 out of 17198 in 33815.767359018326 seconds
# Processed 3500 out of 17198 in 34319.14104485512 seconds
# Processed 3550 out of 17198 in 34664.59152984619 seconds
# Processed 3600 out of 17198 in 34955.85328793526 seconds
# Processed 3650 out of 17198 in 35317.11058139801 seconds
# Processed 3700 out of 17198 in 35739.63635349274 seconds
# Processed 3750 out of 17198 in 36310.65222787857 seconds
# Processed 3800 out of 17198 in 36696.48999333382 seconds
# Processed 3850 out of 17198 in 36852.46183514595 seconds
# Processed 3900 out of 17198 in 37060.353454351425 seconds
# Processed 3950 out of 17198 in 37836.59419441223 seconds
# Processed 4000 out of 17198 in 38273.963265419006 seconds
# Processed 4050 out of 17198 in 38824.03515648842 seconds
# Processed 4100 out of 17198 in 39146.56557941437 seconds
# Processed 4150 out of 17198 in 39768.604518175125 seconds
# Processed 4200 out of 17198 in 40047.09848690033 seconds
# Processed 4250 out of 17198 in 40530.394515514374 seconds
# Processed 4300 out of 17198 in 41006.153656721115 seconds
# Processed 4350 out of 17198 in 42385.737838983536 seconds
# Processed 4400 out of 17198 in 49739.81226181984 seconds
# Processed 4450 out of 17198 in 53156.78531336784 seconds
# Processed 4500 out of 17198 in 53650.930332660675 seconds
# Processed 4550 out of 17198 in 54388.853660821915 seconds
# Processed 4600 out of 17198 in 54539.34261012077 seconds
# Processed 4650 out of 17198 in 54922.41076683998 seconds
# Processed 4700 out of 17198 in 55034.97743296623 seconds
# Processed 4750 out of 17198 in 55384.11589717865 seconds
# Processed 4800 out of 17198 in 56145.05135536194 seconds
# Processed 4850 out of 17198 in 56484.070405721664 seconds
# Processed 4900 out of 17198 in 56838.798988580704 seconds
# Processed 4950 out of 17198 in 57093.73242378235 seconds
# Processed 5000 out of 17198 in 57383.582451581955 seconds
# Processed 5050 out of 17198 in 57752.951875925064 seconds
# Processed 5100 out of 17198 in 57947.97972393036 seconds
# Processed 5150 out of 17198 in 58121.475274801254 seconds
# Processed 5200 out of 17198 in 58330.68783044815 seconds
# Processed 5250 out of 17198 in 58500.02806973457 seconds
# Processed 5300 out of 17198 in 58714.182599782944 seconds
# Processed 5350 out of 17198 in 58857.2378282547 seconds
# Processed 5400 out of 17198 in 59012.671367645264 seconds
# Processed 5450 out of 17198 in 59328.081854104996 seconds
# Processed 5500 out of 17198 in 59611.60035085678 seconds
# Processed 5550 out of 17198 in 59851.089495420456 seconds
# Processed 5600 out of 17198 in 60108.39429783821 seconds
# Processed 5650 out of 17198 in 60622.00398874283 seconds
# Processed 5700 out of 17198 in 60814.78765749931 seconds
# Processed 5750 out of 17198 in 61072.36311984062 seconds
# Processed 5800 out of 17198 in 61424.670798540115 seconds
# Processed 5850 out of 17198 in 61735.901696681976 seconds
# Processed 5900 out of 17198 in 62126.99175429344 seconds
# Processed 5950 out of 17198 in 62396.77828669548 seconds
# Processed 6000 out of 17198 in 62735.078607559204 seconds
# Processed 6050 out of 17198 in 63309.61840200424 seconds
# Processed 6100 out of 17198 in 64610.51210975647 seconds
# Processed 6150 out of 17198 in 66861.08265256882 seconds
# Processed 6200 out of 17198 in 67404.746114254 seconds
# Processed 6250 out of 17198 in 67870.24618625641 seconds
# Processed 6300 out of 17198 in 68346.05068421364 seconds
# Processed 6350 out of 17198 in 68932.6167113781 seconds
# Processed 6400 out of 17198 in 69402.1342625618 seconds
# Processed 6450 out of 17198 in 69697.89046502113 seconds
# Processed 6500 out of 17198 in 69961.1209423542 seconds
# Processed 6550 out of 17198 in 70977.88452339172 seconds
# Processed 6600 out of 17198 in 71753.61399006844 seconds
# Processed 6650 out of 17198 in 72075.27911376953 seconds
# Processed 6700 out of 17198 in 73126.66149640083 seconds
# Processed 6750 out of 17198 in 74380.77228689194 seconds
# Processed 6800 out of 17198 in 74915.04496073723 seconds
# Processed 6850 out of 17198 in 76017.36953997612 seconds
# Processed 6900 out of 17198 in 76216.70026397705 seconds
# Processed 6950 out of 17198 in 76657.21875882149 seconds
# Processed 7000 out of 17198 in 76962.31764125824 seconds
# Processed 7050 out of 17198 in 77242.35934972763 seconds
# Processed 7100 out of 17198 in 77430.12044453621 seconds
# Processed 7150 out of 17198 in 77940.5988368988 seconds
# Processed 7200 out of 17198 in 78270.4547188282 seconds
# Processed 7250 out of 17198 in 78625.79929089546 seconds
# Processed 7300 out of 17198 in 78919.47562718391 seconds
# Processed 7350 out of 17198 in 79234.0061340332 seconds
# Processed 7400 out of 17198 in 79552.4505610466 seconds
# Processed 7450 out of 17198 in 79995.56784272194 seconds
# Processed 7500 out of 17198 in 80370.10398054123 seconds
# Processed 7550 out of 17198 in 80609.01794195175 seconds
# Processed 7600 out of 17198 in 80961.62605762482 seconds
# Processed 7650 out of 17198 in 81214.8859910965 seconds
# Processed 7700 out of 17198 in 81585.13023924828 seconds
# Processed 7750 out of 17198 in 82037.25636529922 seconds
# Processed 7800 out of 17198 in 82716.14397287369 seconds
# Processed 7850 out of 17198 in 83245.37133860588 seconds
# Processed 7900 out of 17198 in 83507.17708945274 seconds
# Processed 7950 out of 17198 in 83989.54107570648 seconds
# Processed 8000 out of 17198 in 84355.7284731865 seconds
# Processed 8050 out of 17198 in 84629.31768202782 seconds
# Processed 8100 out of 17198 in 85148.33924293518 seconds
# Processed 8150 out of 17198 in 85710.91475129128 seconds
# Processed 8200 out of 17198 in 86275.79675769806 seconds
# Processed 8250 out of 17198 in 87078.39449286461 seconds
# Processed 8300 out of 17198 in 87433.63958382607 seconds
# Processed 8350 out of 17198 in 87807.17383956909 seconds
# Processed 8400 out of 17198 in 88547.62100243568 seconds
# Processed 8450 out of 17198 in 89793.78657603264 seconds
# Processed 8500 out of 17198 in 91771.99398732185 seconds
# Processed 8550 out of 17198 in 92023.25976133347 seconds
# Processed 8600 out of 17198 in 92182.46678137779 seconds
# Processed 8650 out of 17198 in 92487.4449942112 seconds
# Processed 8700 out of 17198 in 92574.65866160393 seconds
# Processed 8750 out of 17198 in 93327.44382357597 seconds
# Processed 8800 out of 17198 in 93730.63700079918 seconds
# Processed 8850 out of 17198 in 93876.77892875671 seconds
# Processed 8900 out of 17198 in 94119.75950050354 seconds
# Processed 8950 out of 17198 in 94570.83622789383 seconds
# Processed 9000 out of 17198 in 95111.69893932343 seconds
# Processed 9050 out of 17198 in 95722.76585650444 seconds
# Processed 9100 out of 17198 in 96200.58504104614 seconds
# Processed 9150 out of 17198 in 96460.21130728722 seconds
# Processed 9200 out of 17198 in 96782.80298113823 seconds
# Processed 9250 out of 17198 in 97064.32669067383 seconds
# Processed 9300 out of 17198 in 97329.54505586624 seconds
# Processed 9350 out of 17198 in 97599.94411349297 seconds
# Processed 9400 out of 17198 in 97907.76819324493 seconds
# Processed 9450 out of 17198 in 98089.43658351898 seconds
# Processed 9500 out of 17198 in 98246.42318463326 seconds
# Processed 9550 out of 17198 in 98614.5211057663 seconds
# Processed 9600 out of 17198 in 99119.2258849144 seconds
# Processed 9650 out of 17198 in 99619.63976764679 seconds
# Processed 9700 out of 17198 in 100182.41946220398 seconds
# Processed 9750 out of 17198 in 100631.24658727646 seconds
# Processed 9800 out of 17198 in 101004.10241484642 seconds
# Processed 9850 out of 17198 in 101548.8392560482 seconds
# Processed 9900 out of 17198 in 102160.27979207039 seconds
# Processed 9950 out of 17198 in 102614.28435635567 seconds
# Processed 10000 out of 17198 in 102838.82872033119 seconds
# Processed 10050 out of 17198 in 103051.05192565918 seconds
# Processed 10100 out of 17198 in 103304.12241506577 seconds
# Processed 10150 out of 17198 in 103579.36044716835 seconds
# Processed 10200 out of 17198 in 104213.04181551933 seconds
# Processed 10250 out of 17198 in 104612.55120611191 seconds
# Processed 10300 out of 17198 in 105114.97381567955 seconds
# Processed 10350 out of 17198 in 105558.86001634598 seconds
# Processed 10400 out of 17198 in 105750.01156401634 seconds
# Processed 10450 out of 17198 in 106639.74614620209 seconds
# Processed 10500 out of 17198 in 107181.40129828453 seconds
# Processed 10550 out of 17198 in 107592.0995631218 seconds
# Processed 10600 out of 17198 in 108099.80872535706 seconds
# Processed 10650 out of 17198 in 108519.44352293015 seconds
# Processed 10700 out of 17198 in 108800.61891055107 seconds
# Processed 10750 out of 17198 in 109145.83298826218 seconds
# Processed 10800 out of 17198 in 110489.14549827576 seconds
# Processed 10850 out of 17198 in 111478.75180792809 seconds
# Processed 10900 out of 17198 in 112430.99057912827 seconds
# Processed 10950 out of 17198 in 112804.81770944595 seconds
# Processed 11000 out of 17198 in 113455.21763515472 seconds
# Processed 11050 out of 17198 in 114580.54033136368 seconds
# Processed 11100 out of 17198 in 114986.57898759842 seconds
# Processed 11150 out of 17198 in 115295.8827264309 seconds
# Processed 11200 out of 17198 in 116094.78843569756 seconds
# Processed 11250 out of 17198 in 116626.22661066055 seconds
# Processed 11300 out of 17198 in 116945.50118160248 seconds
# Processed 11350 out of 17198 in 117272.5570936203 seconds
# Processed 11400 out of 17198 in 117486.33273744583 seconds
# Processed 11450 out of 17198 in 117740.56946659088 seconds
# Processed 11500 out of 17198 in 118043.52381658554 seconds
# Processed 11550 out of 17198 in 118377.82093453407 seconds
# Processed 11600 out of 17198 in 118838.46806001663 seconds
# Processed 11650 out of 17198 in 119143.88423657417 seconds
# Processed 11700 out of 17198 in 119629.5323882103 seconds
# Processed 11750 out of 17198 in 119912.53964686394 seconds
# Processed 11800 out of 17198 in 120086.11492705345 seconds
# Processed 11850 out of 17198 in 120293.73312735558 seconds
# Processed 11900 out of 17198 in 120713.43998146057 seconds
# Processed 11950 out of 17198 in 121051.93869972229 seconds
# Processed 12000 out of 17198 in 121424.42007565498 seconds
# Processed 12050 out of 17198 in 121703.29500389099 seconds
# Processed 12100 out of 17198 in 122072.88217830658 seconds
# Processed 12150 out of 17198 in 122375.43947720528 seconds
# Processed 12200 out of 17198 in 123057.24756932259 seconds
# Processed 12250 out of 17198 in 123778.28125500679 seconds
# Processed 12300 out of 17198 in 124544.61727547646 seconds
# Processed 12350 out of 17198 in 124929.38788580894 seconds
# Processed 12400 out of 17198 in 125258.43632483482 seconds
# Processed 12450 out of 17198 in 125487.84321689606 seconds
# Processed 12500 out of 17198 in 126318.7812898159 seconds
# Processed 12550 out of 17198 in 126525.76196503639 seconds
# Processed 12600 out of 17198 in 126875.15772771835 seconds
# Processed 12650 out of 17198 in 127172.14349770546 seconds
# Processed 12700 out of 17198 in 127505.87163901329 seconds
# Processed 12750 out of 17198 in 127695.45802044868 seconds
# Processed 12800 out of 17198 in 128068.36887145042 seconds
# Processed 12850 out of 17198 in 128399.89007902145 seconds
# Processed 12900 out of 17198 in 128945.91051840782 seconds
# Processed 12950 out of 17198 in 129546.86724495888 seconds
# Processed 13000 out of 17198 in 130075.80625200272 seconds
# Processed 13050 out of 17198 in 130456.26955676079 seconds
# Processed 13100 out of 17198 in 130680.21388530731 seconds
# Processed 13150 out of 17198 in 130998.5218129158 seconds
# Processed 13200 out of 17198 in 131290.0722873211 seconds
# Processed 13250 out of 17198 in 131619.80939865112 seconds
# Processed 13300 out of 17198 in 132043.58356785774 seconds
# Processed 13350 out of 17198 in 132582.6678647995 seconds
# Processed 13400 out of 17198 in 132798.7208893299 seconds
# Processed 13450 out of 17198 in 132989.18344664574 seconds
# Processed 13500 out of 17198 in 133272.75007748604 seconds
# Processed 13550 out of 17198 in 133872.24426484108 seconds
# Processed 13600 out of 17198 in 134453.3671798706 seconds
# Processed 13650 out of 17198 in 135125.72061252594 seconds
# Processed 13700 out of 17198 in 136523.92604637146 seconds
# Processed 13750 out of 17198 in 137919.28672719002 seconds
# Processed 13800 out of 17198 in 138521.20808076859 seconds
# Processed 13850 out of 17198 in 138884.5820195675 seconds
# Processed 13900 out of 17198 in 139101.1719942093 seconds
# Processed 13950 out of 17198 in 139591.74787640572 seconds
# Processed 14000 out of 17198 in 140097.3594801426 seconds
# Processed 14050 out of 17198 in 140522.7804892063 seconds
# Processed 14100 out of 17198 in 140800.44017219543 seconds
# Processed 14150 out of 17198 in 141143.00409841537 seconds
# Processed 14200 out of 17198 in 141505.1590180397 seconds
# Processed 14250 out of 17198 in 142262.5495212078 seconds
# Processed 14300 out of 17198 in 142507.49736571312 seconds
# Processed 14350 out of 17198 in 142781.4406762123 seconds
# Processed 14400 out of 17198 in 143044.34564352036 seconds
# Processed 14450 out of 17198 in 143320.93140864372 seconds
# Processed 14500 out of 17198 in 143493.08982992172 seconds
# Processed 14550 out of 17198 in 143812.0727713108 seconds
# Processed 14600 out of 17198 in 144114.45688843727 seconds
# Processed 14650 out of 17198 in 144360.1591951847 seconds
# Processed 14700 out of 17198 in 144563.4743127823 seconds
# Processed 14750 out of 17198 in 144767.42057418823 seconds
# Processed 14800 out of 17198 in 145103.50001692772 seconds
# Processed 14850 out of 17198 in 145441.48092365265 seconds
# Processed 14900 out of 17198 in 145722.5380268097 seconds
# Processed 14950 out of 17198 in 146521.14689540863 seconds
# Processed 15000 out of 17198 in 146708.0011870861 seconds
# Processed 15050 out of 17198 in 146954.99000549316 seconds
# Processed 15100 out of 17198 in 147165.34980463982 seconds
# Processed 15150 out of 17198 in 147367.02934885025 seconds
# Processed 15200 out of 17198 in 147602.04332327843 seconds
# Processed 15250 out of 17198 in 147960.18719029427 seconds
# Processed 15300 out of 17198 in 148134.40728402138 seconds
# Processed 15350 out of 17198 in 148390.31813144684 seconds
# Processed 15400 out of 17198 in 148812.72811341286 seconds
# Processed 15450 out of 17198 in 149189.18979883194 seconds
# Processed 15500 out of 17198 in 149704.1946966648 seconds
# Processed 15550 out of 17198 in 150033.23894405365 seconds
# Processed 15600 out of 17198 in 150773.1026380062 seconds
# Processed 15650 out of 17198 in 152114.14293122292 seconds
# Processed 15700 out of 17198 in 154270.36268162727 seconds
# Processed 15750 out of 17198 in 155266.86809635162 seconds
# Processed 15800 out of 17198 in 155666.2249956131 seconds
# Processed 15850 out of 17198 in 155805.2266535759 seconds
# Processed 15900 out of 17198 in 156204.43718838692 seconds
# Processed 15950 out of 17198 in 156622.08560943604 seconds
# Processed 16000 out of 17198 in 156771.32942962646 seconds
# Processed 16050 out of 17198 in 156972.4272634983 seconds
# Processed 16100 out of 17198 in 157017.6908106804 seconds
# Processed 16150 out of 17198 in 157065.9991543293 seconds
# Processed 16200 out of 17198 in 157102.7021226883 seconds
# Processed 16250 out of 17198 in 157115.62360978127 seconds
# Processed 16300 out of 17198 in 157127.89247012138 seconds
# Processed 16350 out of 17198 in 157152.51617717743 seconds
# Processed 16400 out of 17198 in 157174.12700676918 seconds
# Processed 16450 out of 17198 in 157197.9374921322 seconds
# Processed 16500 out of 17198 in 157250.27294945717 seconds
# Processed 16550 out of 17198 in 158777.6371703148 seconds
# Processed 16600 out of 17198 in 159108.80512452126 seconds
# Processed 16650 out of 17198 in 159123.24845051765 seconds
# Processed 16700 out of 17198 in 159160.194545269 seconds
# Processed 16750 out of 17198 in 159464.05259108543 seconds
# Processed 16800 out of 17198 in 159549.29109191895 seconds
# Processed 16850 out of 17198 in 159734.75268530846 seconds
# Processed 16900 out of 17198 in 159773.226988554 seconds
# Processed 16950 out of 17198 in 159889.02396965027 seconds
# Processed 17000 out of 17198 in 159941.4918217659 seconds
# Processed 17050 out of 17198 in 159993.71942830086 seconds
# Processed 17100 out of 17198 in 160045.77879691124 seconds
# Processed 17150 out of 17198 in 160090.60725402832 seconds
# Processed 17198 out of 17198 in 160148.18345952034 seconds
