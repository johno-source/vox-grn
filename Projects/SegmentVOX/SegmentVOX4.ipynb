# %% [markdown]
# # Partial Process of Segment GRN Data for vox-grn
#
# See SegmentVox.ipynb for full description.
#
# In an attempt to speed up the processing I have divided the items up into 10 groups and want to have them all process in parallel. It probably won't be 10 times faster but it should still be quicker.

# %%
import pandas as pd
import numpy as np
import os
import sys
module_path = os.path.abspath(os.path.join('../vad_utils'))
if module_path not in sys.path:
    sys.path.append(module_path)
from vad_utils import SAMPLING_RATE, FRAME_SIZE_MS, SAMPLES_PER_FRAME
import vad_utils as vu
from pydub import AudioSegment
import pickle as pkl
from pathlib import Path
import time

# %%
# define the locations for each of the file types
NOTEBOOK_ID=4
SEGMENTS_DIR = '/media/originals/segments/'
DATASETS_DIR = '/media/originals/datasets/'
SEC_4_DATA_DIR = 'seg_4sec/data/'
SEC_6_DATA_DIR = 'seg_6sec/data/'
SEC_10_DATA_DIR = 'seg_10sec/data/'

# define specific files used in the process
SEG_4_SEC_DF = f'{SEGMENTS_DIR}seg_4sec_{NOTEBOOK_ID}.csv'
SEG_6_SEC_DF = f'{SEGMENTS_DIR}seg_6sec_{NOTEBOOK_ID}.csv'
SEG_10_SEC_DF = f'{SEGMENTS_DIR}seg_10sec_{NOTEBOOK_ID}.csv'

# define segment sizes for each dataset
SEG_4_SEC = 4.0
SEG_6_SEC = 6.0
SEG_10_SEC = 10.0

# %%
# Now read in the description of the input and remove the unwanted columns and rename the rest to be python attribute names.
items = pd.read_csv(f'/media/originals/segments/items_{NOTEBOOK_ID}.csv')
items.set_index('ID', inplace=True)
items.columns
# Out:
# Index(['iso', 'program', 'location', 'year', 'path', 'filename', 'item_no',
#        'title', 'start', 'end'],
#       dtype='object')

# %%
print(items.iloc[100])
# Out:
# iso                                        kma
# program                                 A78156
# location                            Bolgatanga
# year                                    1996.0
# path        Programs/78/78156/A78156/PM-Clone/
# filename                         A78156-17.wav
# item_no                                     18
# title                               Picture 17
# start                                      0.0
# end                                      126.0
# Name: A78156_018, dtype: object

# %%
print(items.index)
# Out:
# Index(['A75203_006', 'A75203_001', 'A09510_002', 'A09510_003', 'A09510_004',
#        'A09510_005', 'A09510_006', 'A75203_003', 'A75203_002', 'A26070_005',
#        ...
#        'A11690_010', 'A11690_008', 'A11690_034', 'A11690_022', 'A11690_026',
#        'A11690_024', 'A11690_025', 'A04041_006', 'A04041_004', 'A04041_005'],
#       dtype='object', name='ID', length=17198)

# %%
# generate directories and filenames
def prepare_dir(dirname):
    if dirname[-1] != '/':
        dirname = dirname + '/'
    Path(dirname).mkdir(parents=True, exist_ok=True)
    return dirname

def prepare_raw_seg_dir(item):
    return prepare_dir(SEGMENTS_DIR + item.iso)

def raw_seg_filename(item):
    return f'{item.program}_{item.item_no:03d}.pkl'

def prepare_dataset_data_dir(item, dataset_dir):
    return prepare_dir(DATASETS_DIR + dataset_dir + item.iso)

def seg_mp3_filename(item, seg):
    return f'{item.program}_{item.item_no:03d}_{seg:03d}.mp3'

# %%
def condition_audio_segment(audio_seg):
    if audio_seg.channels != 1:
        audio_seg = audio_seg.set_channels(1)

    if audio_seg.sample_width != 2:
        audio_seg = audio_seg.set_sample_width(2)

    if audio_seg.frame_rate != SAMPLING_RATE:
        audio_seg = audio_seg.set_frame_rate(SAMPLING_RATE)

    return audio_seg

# %%
def save_the_segment_info(item, segs):
    fname = prepare_raw_seg_dir(item) + raw_seg_filename(item)
    with open(fname, 'wb') as pklFile:
         pkl.dump(segs, pklFile)

def read_the_segment_info(item):
    fname = prepare_raw_seg_dir(item) + raw_seg_filename(item)
    if os.path.exists(fname):
        if os.path.getsize(fname) > 0:
            with open(fname, 'rb') as pklFile:
                return pkl.load(pklFile)
    return []
    
def extract_audio_segment_for_item(item):
    fmt = 'wav'
    if item.filename[-4:] == '.mp3' :
        fmt = 'mp3'
    audio_seg = AudioSegment.from_file('/media/programs/' + item.path + item.filename, format=fmt)
    start_ms = int(item.start * 1000)
    end_ms = int(item.end * 1000)
    audio_seg = audio_seg[start_ms:end_ms]

    # now condition the segment and extract the raw segments.
    audio_seg = condition_audio_segment(audio_seg)
    segs = read_the_segment_info(item)
    if len(segs) == 0:
        segs = vu.audio_to_raw_voice_segments(audio_seg)
        save_the_segment_info(item, segs)

    return audio_seg, segs

def create_mp3_files(audio_seg, segs, time_per_segment, dataset_dir, item):
    segs_for_time = vu.divide_into_segments(segs, time_per_segment)

    # now write out the 4 sec segments
    dirname = prepare_dataset_data_dir(item, dataset_dir)
    rows = list()
    for i, seg in enumerate(segs_for_time):
        file_name = dataset_dir + item.iso + '/' + seg_mp3_filename(item, i)
        fname = dirname + seg_mp3_filename(item, i)
        if not os.path.exists(fname):
            start = vu.convert_frames_to_ms(seg.start)
            stop = vu.convert_frames_to_ms(seg.stop)
            audio_seg[start:stop].export(fname, format='mp3', bitrate='32k')
        desc = dict(item._asdict())
        desc['seg_start'] = vu.convert_frames_to_seconds(seg.start)
        desc['seg_stop'] = vu.convert_frames_to_seconds(seg.stop)
        desc['seg'] = i
        desc['file_name'] = file_name
        rows.append(desc)

    return rows

def update_dataframes(seg_df_csv, seg_records):
    # now update the dataframes
    if len(seg_records) > 0:
        if os.path.isfile(seg_df_csv):
            seg_sec_df = pd.concat([pd.read_csv(seg_df_csv, index_col='file_name'), pd.DataFrame.from_records(seg_records, index='file_name')])
        else:
            seg_sec_df = pd.DataFrame.from_records(seg_records, index='file_name')
        seg_sec_df.to_csv(seg_df_csv)

# %%
# processing these items might take a very long time. To permit the process to be interrupted and restarted the indexes of processed items
# are maintained in a set that is pickled on each batch. This allows the batch to quickly pick up where it left off.
def process_record_batch(items_df, *, batch_size=10):
    batch_proc = 0
    processed_file = f'/media/originals/segments/processed16_{NOTEBOOK_ID}.pkl'
    if os.path.isfile(processed_file):
        with open(processed_file, 'rb') as pklFile:
            processed_items = pkl.load(pklFile)
    else:
        processed_items = set()

    segmented_4sec_segs = []
    segmented_6sec_segs = []
    segmented_10sec_segs = []

    for item in items_df.itertuples():
        if batch_proc < batch_size:
            if item.Index not in processed_items:
                try:
                    audio_seg, voice_segs = extract_audio_segment_for_item(item)
                    segmented_4sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_4_SEC, SEC_4_DATA_DIR, item))
                    segmented_6sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_6_SEC, SEC_6_DATA_DIR, item))
                    segmented_10sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_10_SEC, SEC_10_DATA_DIR, item))
                except:
                    print('exception')
                    pass

                # we want to add an item that has an exception so it is not reprocessed on every batch
                processed_items.add(item.Index)
                batch_proc += 1

        else:
            break

    update_dataframes(SEG_4_SEC_DF, segmented_4sec_segs)
    update_dataframes(SEG_6_SEC_DF, segmented_6sec_segs)
    update_dataframes(SEG_10_SEC_DF, segmented_10sec_segs)

    with open(processed_file, 'wb') as pklFile:
        pkl.dump(processed_items, pklFile)

    return processed_items

# %%
start_time = time.time()
# form the language classification file
items_processed = 0
items_to_process = len(items)
while items_to_process > items_processed:
    processed_items = process_record_batch(items, batch_size=50)
    items_processed = len(processed_items)
    print(f'Processed {items_processed} out of {items_to_process} in {time.time()-start_time} seconds')
# Out:
# Processed 50 out of 17198 in 251.53108310699463 seconds
# Processed 100 out of 17198 in 590.0225675106049 seconds
# Processed 150 out of 17198 in 872.5061590671539 seconds
# Processed 200 out of 17198 in 1223.759745836258 seconds
# Processed 250 out of 17198 in 1851.7259051799774 seconds
# Processed 300 out of 17198 in 2256.040492773056 seconds
# Processed 350 out of 17198 in 2680.199652671814 seconds
# Processed 400 out of 17198 in 3114.831130504608 seconds
# Processed 450 out of 17198 in 3699.443448781967 seconds
# Processed 500 out of 17198 in 3991.1788630485535 seconds
# Processed 550 out of 17198 in 4336.122111082077 seconds
# Processed 600 out of 17198 in 4741.343466281891 seconds
# Processed 650 out of 17198 in 6565.093524932861 seconds
# Processed 700 out of 17198 in 6882.86442732811 seconds
# Processed 750 out of 17198 in 7055.844404220581 seconds
# Processed 800 out of 17198 in 7277.695928096771 seconds
# Processed 850 out of 17198 in 7640.686103343964 seconds
# Processed 900 out of 17198 in 7915.789931058884 seconds
# Processed 950 out of 17198 in 8057.924521446228 seconds
# Processed 1000 out of 17198 in 8325.868870735168 seconds
# Processed 1050 out of 17198 in 8438.785423755646 seconds
# Processed 1100 out of 17198 in 8553.729699373245 seconds
# Processed 1150 out of 17198 in 8652.36302280426 seconds
# Processed 1200 out of 17198 in 8952.432814836502 seconds
# Processed 1250 out of 17198 in 9069.096179485321 seconds
# Processed 1300 out of 17198 in 9176.124502420425 seconds
# Processed 1350 out of 17198 in 9372.55079627037 seconds
# Processed 1400 out of 17198 in 9558.581867456436 seconds
# Processed 1450 out of 17198 in 9758.911481142044 seconds
# Processed 1500 out of 17198 in 9913.803649425507 seconds
# Processed 1550 out of 17198 in 10070.50140619278 seconds
# Processed 1600 out of 17198 in 10433.144831418991 seconds
# Processed 1650 out of 17198 in 12207.536497116089 seconds
# Processed 1700 out of 17198 in 18112.57629776001 seconds
# Processed 1750 out of 17198 in 23139.6452627182 seconds
# Processed 1800 out of 17198 in 23373.77641224861 seconds
# Processed 1850 out of 17198 in 23656.772890806198 seconds
# Processed 1900 out of 17198 in 23858.280905246735 seconds
# Processed 1950 out of 17198 in 24007.154390335083 seconds
# Processed 2000 out of 17198 in 24142.588248729706 seconds
# Processed 2050 out of 17198 in 24293.07732319832 seconds
# Processed 2100 out of 17198 in 24457.976597070694 seconds
# Processed 2150 out of 17198 in 24612.53155732155 seconds
# Processed 2200 out of 17198 in 24882.221202373505 seconds
# Processed 2250 out of 17198 in 25058.32842516899 seconds
# Processed 2300 out of 17198 in 25381.82327055931 seconds
# Processed 2350 out of 17198 in 25578.60523033142 seconds
# Processed 2400 out of 17198 in 25723.056062459946 seconds
# Processed 2450 out of 17198 in 26501.285615682602 seconds
# Processed 2500 out of 17198 in 26995.945894241333 seconds
# Processed 2550 out of 17198 in 27258.79276061058 seconds
# Processed 2600 out of 17198 in 27460.56188392639 seconds
# Processed 2650 out of 17198 in 27681.3393034935 seconds
# Processed 2700 out of 17198 in 27926.20976305008 seconds
# Processed 2750 out of 17198 in 28429.970427274704 seconds
# Processed 2800 out of 17198 in 29052.538175344467 seconds
# Processed 2850 out of 17198 in 29380.528594493866 seconds
# Processed 2900 out of 17198 in 29832.178478956223 seconds
# Processed 2950 out of 17198 in 30172.371785879135 seconds
# Processed 3000 out of 17198 in 30625.137216567993 seconds
# Processed 3050 out of 17198 in 31457.53965330124 seconds
# Processed 3100 out of 17198 in 32853.4767408371 seconds
# Processed 3150 out of 17198 in 34124.0715777874 seconds
# Processed 3200 out of 17198 in 35031.3297162056 seconds
# Processed 3250 out of 17198 in 35901.205156326294 seconds
# Processed 3300 out of 17198 in 37221.93730568886 seconds
# Processed 3350 out of 17198 in 37606.374155282974 seconds
# Processed 3400 out of 17198 in 37976.91212773323 seconds
# Processed 3450 out of 17198 in 38203.925765275955 seconds
# Processed 3500 out of 17198 in 38481.89648389816 seconds
# Processed 3550 out of 17198 in 38663.912816762924 seconds
# Processed 3600 out of 17198 in 38839.448184251785 seconds
# Processed 3650 out of 17198 in 39021.06950855255 seconds
# Processed 3700 out of 17198 in 39418.95005774498 seconds
# Processed 3750 out of 17198 in 39694.85278606415 seconds
# Processed 3800 out of 17198 in 39903.848576784134 seconds
# Processed 3850 out of 17198 in 40136.5418548584 seconds
# Processed 3900 out of 17198 in 40497.560349702835 seconds
# Processed 3950 out of 17198 in 40735.501410484314 seconds
# Processed 4000 out of 17198 in 41308.43835425377 seconds
# Processed 4050 out of 17198 in 41591.8445353508 seconds
# Processed 4100 out of 17198 in 42032.73153591156 seconds
# Processed 4150 out of 17198 in 42413.999183654785 seconds
# Processed 4200 out of 17198 in 42711.02276325226 seconds
# Processed 4250 out of 17198 in 43243.27624320984 seconds
# Processed 4300 out of 17198 in 43720.03539252281 seconds
# Processed 4350 out of 17198 in 44236.5153362751 seconds
# Processed 4400 out of 17198 in 44613.859770298004 seconds
# Processed 4450 out of 17198 in 44954.29468989372 seconds
# Processed 4500 out of 17198 in 45305.350017786026 seconds
# Processed 4550 out of 17198 in 45684.52351307869 seconds
# Processed 4600 out of 17198 in 46363.34311556816 seconds
# Processed 4650 out of 17198 in 46942.21933031082 seconds
# Processed 4700 out of 17198 in 47386.26725721359 seconds
# Processed 4750 out of 17198 in 48022.81384706497 seconds
# Processed 4800 out of 17198 in 48549.477244377136 seconds
# Processed 4850 out of 17198 in 49022.002217531204 seconds
# Processed 4900 out of 17198 in 49389.41027092934 seconds
# Processed 4950 out of 17198 in 49692.18128633499 seconds
# Processed 5000 out of 17198 in 50148.82349705696 seconds
# Processed 5050 out of 17198 in 50755.68613886833 seconds
# Processed 5100 out of 17198 in 51266.70274424553 seconds
# Processed 5150 out of 17198 in 51419.16259884834 seconds
# Processed 5200 out of 17198 in 51573.86235356331 seconds
# Processed 5250 out of 17198 in 51748.17988204956 seconds
# Processed 5300 out of 17198 in 51986.60300254822 seconds
# Processed 5350 out of 17198 in 52296.22308397293 seconds
# Processed 5400 out of 17198 in 52584.2508225441 seconds
# Processed 5450 out of 17198 in 52898.083865880966 seconds
# Processed 5500 out of 17198 in 53106.68895363808 seconds
# Processed 5550 out of 17198 in 53421.59492397308 seconds
# Processed 5600 out of 17198 in 53804.62353897095 seconds
# Processed 5650 out of 17198 in 54566.46833252907 seconds
# Processed 5700 out of 17198 in 54896.841849565506 seconds
# Processed 5750 out of 17198 in 55313.07909798622 seconds
# Processed 5800 out of 17198 in 55508.801938056946 seconds
# Processed 5850 out of 17198 in 56091.221594810486 seconds
# Processed 5900 out of 17198 in 56326.467792749405 seconds
# Processed 5950 out of 17198 in 56616.05167579651 seconds
# Processed 6000 out of 17198 in 56820.33383536339 seconds
# Processed 6050 out of 17198 in 57052.02136325836 seconds
# Processed 6100 out of 17198 in 57604.133607149124 seconds
# Processed 6150 out of 17198 in 57800.7141122818 seconds
# Processed 6200 out of 17198 in 58081.500648736954 seconds
# Processed 6250 out of 17198 in 58648.76559686661 seconds
# Processed 6300 out of 17198 in 59220.22340154648 seconds
# Processed 6350 out of 17198 in 59421.47930812836 seconds
# Processed 6400 out of 17198 in 59684.85632824898 seconds
# Processed 6450 out of 17198 in 60169.39628505707 seconds
# Processed 6500 out of 17198 in 60429.01614689827 seconds
# Processed 6550 out of 17198 in 60774.572087049484 seconds
# Processed 6600 out of 17198 in 61177.78443479538 seconds
# Processed 6650 out of 17198 in 61455.58091926575 seconds
# Processed 6700 out of 17198 in 61686.45867109299 seconds
# Processed 6750 out of 17198 in 61971.29125952721 seconds
# Processed 6800 out of 17198 in 62294.48176789284 seconds
# Processed 6850 out of 17198 in 62490.527569532394 seconds
# Processed 6900 out of 17198 in 62747.30362176895 seconds
# Processed 6950 out of 17198 in 62893.32231378555 seconds
# Processed 7000 out of 17198 in 63023.592532873154 seconds
# Processed 7050 out of 17198 in 63198.264602184296 seconds
# Processed 7100 out of 17198 in 63351.97388744354 seconds
# Processed 7150 out of 17198 in 63719.682121276855 seconds
# Processed 7200 out of 17198 in 64077.91526532173 seconds
# Processed 7250 out of 17198 in 64473.100938797 seconds
# Processed 7300 out of 17198 in 64928.2603635788 seconds
# Processed 7350 out of 17198 in 65178.584305524826 seconds
# Processed 7400 out of 17198 in 65389.196925640106 seconds
# Processed 7450 out of 17198 in 65959.1322107315 seconds
# Processed 7500 out of 17198 in 66135.82941031456 seconds
# Processed 7550 out of 17198 in 66759.53973269463 seconds
# Processed 7600 out of 17198 in 67060.17109155655 seconds
# Processed 7650 out of 17198 in 67400.04076361656 seconds
# Processed 7700 out of 17198 in 67711.04376149178 seconds
# Processed 7750 out of 17198 in 67983.32171010971 seconds
# Processed 7800 out of 17198 in 68211.10171937943 seconds
# Processed 7850 out of 17198 in 68521.28374576569 seconds
# Processed 7900 out of 17198 in 68716.80269765854 seconds
# Processed 7950 out of 17198 in 68881.49176120758 seconds
# Processed 8000 out of 17198 in 69063.90226149559 seconds
# Processed 8050 out of 17198 in 69377.02473378181 seconds
# Processed 8100 out of 17198 in 69688.46330595016 seconds
# Processed 8150 out of 17198 in 69830.48091387749 seconds
# Processed 8200 out of 17198 in 69997.84029269218 seconds
# Processed 8250 out of 17198 in 70330.35755848885 seconds
# Processed 8300 out of 17198 in 70857.90599703789 seconds
# Processed 8350 out of 17198 in 71122.00951910019 seconds
# Processed 8400 out of 17198 in 71362.33070278168 seconds
# Processed 8450 out of 17198 in 71588.1984474659 seconds
# Processed 8500 out of 17198 in 72108.89311885834 seconds
# Processed 8550 out of 17198 in 72921.1805999279 seconds
# Processed 8600 out of 17198 in 73952.70577073097 seconds
# Processed 8650 out of 17198 in 74580.57009077072 seconds
# Processed 8700 out of 17198 in 74905.69309854507 seconds
# Processed 8750 out of 17198 in 75226.13865852356 seconds
# Processed 8800 out of 17198 in 75537.08815073967 seconds
# Processed 8850 out of 17198 in 75688.57938718796 seconds
# Processed 8900 out of 17198 in 75967.55120825768 seconds
# Processed 8950 out of 17198 in 82941.33022212982 seconds
# Processed 9000 out of 17198 in 83333.06963729858 seconds
# Processed 9050 out of 17198 in 83548.16150093079 seconds
# Processed 9100 out of 17198 in 83685.63646054268 seconds
# Processed 9150 out of 17198 in 83875.8555905819 seconds
# Processed 9200 out of 17198 in 84183.88938117027 seconds
# Processed 9250 out of 17198 in 84431.21839594841 seconds
# Processed 9300 out of 17198 in 84660.01447987556 seconds
# Processed 9350 out of 17198 in 84786.47679114342 seconds
# Processed 9400 out of 17198 in 85131.03128504753 seconds
# Processed 9450 out of 17198 in 85517.6236937046 seconds
# Processed 9500 out of 17198 in 86171.90021634102 seconds
# Processed 9550 out of 17198 in 86400.68982458115 seconds
# Processed 9600 out of 17198 in 86635.89054012299 seconds
# Processed 9650 out of 17198 in 87435.73081612587 seconds
# Processed 9700 out of 17198 in 87636.0010406971 seconds
# Processed 9750 out of 17198 in 88002.57352161407 seconds
# Processed 9800 out of 17198 in 88360.91190767288 seconds
# Processed 9850 out of 17198 in 88614.55434298515 seconds
# Processed 9900 out of 17198 in 88915.24030828476 seconds
# Processed 9950 out of 17198 in 89197.99023723602 seconds
# Processed 10000 out of 17198 in 89549.84609866142 seconds
# Processed 10050 out of 17198 in 89842.47434329987 seconds
# Processed 10100 out of 17198 in 90083.36052918434 seconds
# Processed 10150 out of 17198 in 90291.7734503746 seconds
# Processed 10200 out of 17198 in 90463.86129951477 seconds
# Processed 10250 out of 17198 in 90679.05604672432 seconds
# Processed 10300 out of 17198 in 91006.10030078888 seconds
# Processed 10350 out of 17198 in 91314.0800216198 seconds
# Processed 10400 out of 17198 in 91648.9668469429 seconds
# Processed 10450 out of 17198 in 91908.86951422691 seconds
# Processed 10500 out of 17198 in 92151.72101306915 seconds
# Processed 10550 out of 17198 in 92563.90224266052 seconds
# Processed 10600 out of 17198 in 93356.26419353485 seconds
# Processed 10650 out of 17198 in 93838.55409550667 seconds
# Processed 10700 out of 17198 in 94833.01570987701 seconds
# Processed 10750 out of 17198 in 95255.61997437477 seconds
# Processed 10800 out of 17198 in 95995.29278063774 seconds
# Processed 10850 out of 17198 in 96939.11450839043 seconds
# Processed 10900 out of 17198 in 97484.26206636429 seconds
# Processed 10950 out of 17198 in 97890.8158402443 seconds
# Processed 11000 out of 17198 in 98252.11833548546 seconds
# Processed 11050 out of 17198 in 98468.23676776886 seconds
# Processed 11100 out of 17198 in 98798.88259673119 seconds
# Processed 11150 out of 17198 in 99127.50185728073 seconds
# Processed 11200 out of 17198 in 99391.56580233574 seconds
# Processed 11250 out of 17198 in 99753.31900024414 seconds
# Processed 11300 out of 17198 in 100234.80339550972 seconds
# Processed 11350 out of 17198 in 100700.35356163979 seconds
# Processed 11400 out of 17198 in 101008.81901025772 seconds
# Processed 11450 out of 17198 in 101397.74145913124 seconds
# Processed 11500 out of 17198 in 101656.72879195213 seconds
# Processed 11550 out of 17198 in 101828.22707438469 seconds
# Processed 11600 out of 17198 in 102068.00802969933 seconds
# Processed 11650 out of 17198 in 102266.0947458744 seconds
# Processed 11700 out of 17198 in 102511.72149729729 seconds
# Processed 11750 out of 17198 in 102762.37158250809 seconds
# Processed 11800 out of 17198 in 102940.68780088425 seconds
# Processed 11850 out of 17198 in 103221.26290774345 seconds
# Processed 11900 out of 17198 in 103452.46253633499 seconds
# Processed 11950 out of 17198 in 103678.35190105438 seconds
# Processed 12000 out of 17198 in 104079.60693788528 seconds
# Processed 12050 out of 17198 in 104306.25302791595 seconds
# Processed 12100 out of 17198 in 104693.85009241104 seconds
# Processed 12150 out of 17198 in 104981.19271206856 seconds
# Processed 12200 out of 17198 in 105311.40478348732 seconds
# Processed 12250 out of 17198 in 105753.57634735107 seconds
# Processed 12300 out of 17198 in 106062.22873020172 seconds
# Processed 12350 out of 17198 in 106507.29981398582 seconds
# Processed 12400 out of 17198 in 106864.50064325333 seconds
# Processed 12450 out of 17198 in 107473.92166924477 seconds
# /tmp/ipykernel_435327/3773699355.py:58: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   seg_sec_df = pd.concat([pd.read_csv(seg_df_csv, index_col='file_name'), pd.DataFrame.from_records(seg_records, index='file_name')])
# Processed 12500 out of 17198 in 107701.2197880745 seconds
# Processed 12550 out of 17198 in 108073.25435137749 seconds
# Processed 12600 out of 17198 in 108407.77115750313 seconds
# Processed 12650 out of 17198 in 108704.04087948799 seconds
# Processed 12700 out of 17198 in 110491.70066523552 seconds
# Processed 12750 out of 17198 in 111172.45036244392 seconds
# Processed 12800 out of 17198 in 111373.4591679573 seconds
# Processed 12850 out of 17198 in 111510.5872220993 seconds
# Processed 12900 out of 17198 in 111644.75471544266 seconds
# Processed 12950 out of 17198 in 111725.1980574131 seconds
# Processed 13000 out of 17198 in 112083.93150401115 seconds
# Processed 13050 out of 17198 in 112307.52321529388 seconds
# Processed 13100 out of 17198 in 112758.69218420982 seconds
# Processed 13150 out of 17198 in 112978.39096283913 seconds
# Processed 13200 out of 17198 in 113560.9360396862 seconds
# Processed 13250 out of 17198 in 113961.68906188011 seconds
# Processed 13300 out of 17198 in 114447.31799459457 seconds
# Processed 13350 out of 17198 in 114724.62030553818 seconds
# Processed 13400 out of 17198 in 114802.26419091225 seconds
# Processed 13450 out of 17198 in 114956.07174801826 seconds
# Processed 13500 out of 17198 in 115053.14597582817 seconds
# Processed 13550 out of 17198 in 115310.19796442986 seconds
# Processed 13600 out of 17198 in 115559.10912108421 seconds
# Processed 13650 out of 17198 in 115695.74966931343 seconds
# Processed 13700 out of 17198 in 115902.85767245293 seconds
# Processed 13750 out of 17198 in 116190.24557733536 seconds
# Processed 13800 out of 17198 in 116471.0286898613 seconds
# Processed 13850 out of 17198 in 116719.27841377258 seconds
# Processed 13900 out of 17198 in 116937.10772895813 seconds
# Processed 13950 out of 17198 in 117555.60711026192 seconds
# Processed 14000 out of 17198 in 118995.70404648781 seconds
# Processed 14050 out of 17198 in 119182.5515024662 seconds
# Processed 14100 out of 17198 in 119426.16161966324 seconds
# Processed 14150 out of 17198 in 119652.36847615242 seconds
# Processed 14200 out of 17198 in 119914.90738964081 seconds
# Processed 14250 out of 17198 in 120119.71680402756 seconds
# Processed 14300 out of 17198 in 120338.51292991638 seconds
# Processed 14350 out of 17198 in 120506.08513474464 seconds
# Processed 14400 out of 17198 in 120625.46290493011 seconds
# Processed 14450 out of 17198 in 120749.49652576447 seconds
# Processed 14500 out of 17198 in 120925.58698105812 seconds
# Processed 14550 out of 17198 in 121129.21549987793 seconds
# Processed 14600 out of 17198 in 121368.61658883095 seconds
# Processed 14650 out of 17198 in 121631.2310860157 seconds
# Processed 14700 out of 17198 in 122787.33142900467 seconds
# Processed 14750 out of 17198 in 123290.74638938904 seconds
# Processed 14800 out of 17198 in 123753.20545554161 seconds
# Processed 14850 out of 17198 in 124128.63406801224 seconds
# Processed 14900 out of 17198 in 124541.64615559578 seconds
# Processed 14950 out of 17198 in 124904.69419121742 seconds
# Processed 15000 out of 17198 in 125184.53689217567 seconds
# Processed 15050 out of 17198 in 125469.91522288322 seconds
# Processed 15100 out of 17198 in 126242.71341633797 seconds
# Processed 15150 out of 17198 in 126624.14652323723 seconds
# Processed 15200 out of 17198 in 126759.34948992729 seconds
# Processed 15250 out of 17198 in 127163.37537717819 seconds
# Processed 15300 out of 17198 in 128653.34595608711 seconds
# Processed 15350 out of 17198 in 129318.90671682358 seconds
# Processed 15400 out of 17198 in 129905.72221136093 seconds
# Processed 15450 out of 17198 in 130092.85326862335 seconds
# Processed 15500 out of 17198 in 130425.13019442558 seconds
# Processed 15550 out of 17198 in 130730.69733738899 seconds
# Processed 15600 out of 17198 in 131010.5975484848 seconds
# Processed 15650 out of 17198 in 131249.7916355133 seconds
# Processed 15700 out of 17198 in 132210.99590039253 seconds
# Processed 15750 out of 17198 in 134814.01810598373 seconds
# Processed 15800 out of 17198 in 135076.88191461563 seconds
# Processed 15850 out of 17198 in 135520.0874876976 seconds
# Processed 15900 out of 17198 in 135844.6726884842 seconds
# Processed 15950 out of 17198 in 136060.02610945702 seconds
# Processed 16000 out of 17198 in 136699.403621912 seconds
# Processed 16050 out of 17198 in 136989.67187595367 seconds
# Processed 16100 out of 17198 in 137783.0316567421 seconds
# Processed 16150 out of 17198 in 138100.05529165268 seconds
# Processed 16200 out of 17198 in 138474.11504864693 seconds
# Processed 16250 out of 17198 in 138938.36553359032 seconds
# Processed 16300 out of 17198 in 139216.67119145393 seconds
# Processed 16350 out of 17198 in 139479.97296905518 seconds
# Processed 16400 out of 17198 in 139904.9822192192 seconds
# Processed 16450 out of 17198 in 140122.2451827526 seconds
# Processed 16500 out of 17198 in 140454.34960365295 seconds
# Processed 16550 out of 17198 in 140903.84443974495 seconds
# Processed 16600 out of 17198 in 142160.27820777893 seconds
# Processed 16650 out of 17198 in 142511.20664048195 seconds
# Processed 16700 out of 17198 in 142632.48594355583 seconds
# Processed 16750 out of 17198 in 142838.3822684288 seconds
# Processed 16800 out of 17198 in 143035.62017416954 seconds
# Processed 16850 out of 17198 in 143234.81511974335 seconds
# Processed 16900 out of 17198 in 143437.89389681816 seconds
# Processed 16950 out of 17198 in 144245.02140116692 seconds
# Processed 17000 out of 17198 in 144565.13056588173 seconds
# Processed 17050 out of 17198 in 144985.3264119625 seconds
# Processed 17100 out of 17198 in 145445.28115081787 seconds
# Processed 17150 out of 17198 in 145681.921189785 seconds
# Processed 17198 out of 17198 in 145849.96323418617 seconds

# %%
# so it appears that some items do not get into processed items. Lets see why.
dup_items = items[items.index.duplicated(False)]
