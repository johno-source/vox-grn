# %% [markdown]
# # Partial Process of Segment GRN Data for vox-grn
#
# See SegmentVox.ipynb for full description.
#
# In an attempt to speed up the processing I have divided the items up into 10 groups and want to have them all process in parallel. It probably won't be 10 times faster but it should still be quicker.

# %%
import pandas as pd
import numpy as np
import os
import sys
module_path = os.path.abspath(os.path.join('../vad_utils'))
if module_path not in sys.path:
    sys.path.append(module_path)
from vad_utils import SAMPLING_RATE, FRAME_SIZE_MS, SAMPLES_PER_FRAME
import vad_utils as vu
from pydub import AudioSegment
import pickle as pkl
from pathlib import Path
import time

# %%
# define the locations for each of the file types
NOTEBOOK_ID=2
SEGMENTS_DIR = '/media/originals/segments/'
DATASETS_DIR = '/media/originals/datasets/'
SEC_4_DATA_DIR = 'seg_4sec/data/'
SEC_6_DATA_DIR = 'seg_6sec/data/'
SEC_10_DATA_DIR = 'seg_10sec/data/'

# define specific files used in the process
SEG_4_SEC_DF = f'{SEGMENTS_DIR}seg_4sec_{NOTEBOOK_ID}.csv'
SEG_6_SEC_DF = f'{SEGMENTS_DIR}seg_6sec_{NOTEBOOK_ID}.csv'
SEG_10_SEC_DF = f'{SEGMENTS_DIR}seg_10sec_{NOTEBOOK_ID}.csv'

# define segment sizes for each dataset
SEG_4_SEC = 4.0
SEG_6_SEC = 6.0
SEG_10_SEC = 10.0

# %%
# Now read in the description of the input and remove the unwanted columns and rename the rest to be python attribute names.
items = pd.read_csv(f'/media/originals/segments/items_{NOTEBOOK_ID}.csv')
items.set_index('ID', inplace=True)
items.columns
# Out:
# Index(['iso', 'program', 'location', 'year', 'path', 'filename', 'item_no',
#        'title', 'start', 'end'],
#       dtype='object')

# %%
print(items.iloc[100])
# Out:
# iso                                  dje
# program                           A75044
# location                          Niamey
# year                              1990.0
# path        Programs/75/75044/A75044/PM/
# filename                   A75044-24.wav
# item_no                               26
# title                         Picture 24
# start                                0.0
# end                                104.0
# Name: A75044_026, dtype: object

# %%
print(items.index)
# Out:
# Index(['C32941_021', 'C32941_002', 'C32941_009', 'C32941_042', 'C32941_017',
#        'C32941_023', 'C32941_007', 'C32941_011', 'A20290_001', 'A20290_002',
#        ...
#        'A78443_021', 'A78443_020', 'A78443_019', 'A78443_018', 'A78443_017',
#        'A78443_016', 'A78443_014', 'A78443_013', 'A78443_012', 'A78443_002'],
#       dtype='object', name='ID', length=17198)

# %%
# generate directories and filenames
def prepare_dir(dirname):
    if dirname[-1] != '/':
        dirname = dirname + '/'
    Path(dirname).mkdir(parents=True, exist_ok=True)
    return dirname

def prepare_raw_seg_dir(item):
    return prepare_dir(SEGMENTS_DIR + item.iso)

def raw_seg_filename(item):
    return f'{item.program}_{item.item_no:03d}.pkl'

def prepare_dataset_data_dir(item, dataset_dir):
    return prepare_dir(DATASETS_DIR + dataset_dir + item.iso)

def seg_mp3_filename(item, seg):
    return f'{item.program}_{item.item_no:03d}_{seg:03d}.mp3'

# %%
def condition_audio_segment(audio_seg):
    if audio_seg.channels != 1:
        audio_seg = audio_seg.set_channels(1)

    if audio_seg.sample_width != 2:
        audio_seg = audio_seg.set_sample_width(2)

    if audio_seg.frame_rate != SAMPLING_RATE:
        audio_seg = audio_seg.set_frame_rate(SAMPLING_RATE)

    return audio_seg

# %%
def save_the_segment_info(item, segs):
    fname = prepare_raw_seg_dir(item) + raw_seg_filename(item)
    with open(fname, 'wb') as pklFile:
         pkl.dump(segs, pklFile)

def read_the_segment_info(item):
    fname = prepare_raw_seg_dir(item) + raw_seg_filename(item)
    if os.path.exists(fname):
        if os.path.getsize(fname) > 0:
            with open(fname, 'rb') as pklFile:
                return pkl.load(pklFile)
    return []
    
def extract_audio_segment_for_item(item):
    fmt = 'wav'
    if item.filename[-4:] == '.mp3' :
        fmt = 'mp3'
    audio_seg = AudioSegment.from_file('/media/programs/' + item.path + item.filename, format=fmt)
    start_ms = int(item.start * 1000)
    end_ms = int(item.end * 1000)
    audio_seg = audio_seg[start_ms:end_ms]

    # now condition the segment and extract the raw segments.
    audio_seg = condition_audio_segment(audio_seg)
    segs = read_the_segment_info(item)
    if len(segs) == 0:
        segs = vu.audio_to_raw_voice_segments(audio_seg)
        save_the_segment_info(item, segs)

    return audio_seg, segs

def create_mp3_files(audio_seg, segs, time_per_segment, dataset_dir, item):
    segs_for_time = vu.divide_into_segments(segs, time_per_segment)

    # now write out the 4 sec segments
    dirname = prepare_dataset_data_dir(item, dataset_dir)
    rows = list()
    for i, seg in enumerate(segs_for_time):
        file_name = dataset_dir + item.iso + '/' + seg_mp3_filename(item, i)
        fname = dirname + seg_mp3_filename(item, i)
        if not os.path.exists(fname):
            start = vu.convert_frames_to_ms(seg.start)
            stop = vu.convert_frames_to_ms(seg.stop)
            audio_seg[start:stop].export(fname, format='mp3', bitrate='32k')
        desc = dict(item._asdict())
        desc['seg_start'] = vu.convert_frames_to_seconds(seg.start)
        desc['seg_stop'] = vu.convert_frames_to_seconds(seg.stop)
        desc['seg'] = i
        desc['file_name'] = file_name
        rows.append(desc)

    return rows

def update_dataframes(seg_df_csv, seg_records):
    # now update the dataframes
    if len(seg_records) > 0:
        if os.path.isfile(seg_df_csv):
            seg_sec_df = pd.concat([pd.read_csv(seg_df_csv, index_col='file_name'), pd.DataFrame.from_records(seg_records, index='file_name')])
        else:
            seg_sec_df = pd.DataFrame.from_records(seg_records, index='file_name')
        seg_sec_df.to_csv(seg_df_csv)

# %%
# processing these items might take a very long time. To permit the process to be interrupted and restarted the indexes of processed items
# are maintained in a set that is pickled on each batch. This allows the batch to quickly pick up where it left off.
def process_record_batch(items_df, *, batch_size=10):
    batch_proc = 0
    processed_file = f'/media/originals/segments/processed16_{NOTEBOOK_ID}.pkl'
    if os.path.isfile(processed_file):
        with open(processed_file, 'rb') as pklFile:
            processed_items = pkl.load(pklFile)
    else:
        processed_items = set()

    segmented_4sec_segs = []
    segmented_6sec_segs = []
    segmented_10sec_segs = []

    for item in items_df.itertuples():
        if batch_proc < batch_size:
            if item.Index not in processed_items:
                try:
                    audio_seg, voice_segs = extract_audio_segment_for_item(item)
                    segmented_4sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_4_SEC, SEC_4_DATA_DIR, item))
                    segmented_6sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_6_SEC, SEC_6_DATA_DIR, item))
                    segmented_10sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_10_SEC, SEC_10_DATA_DIR, item))
                except:
                    print('exception')
                    pass

                # we want to add an item that has an exception so it is not reprocessed on every batch
                processed_items.add(item.Index)
                batch_proc += 1

        else:
            break

    update_dataframes(SEG_4_SEC_DF, segmented_4sec_segs)
    update_dataframes(SEG_6_SEC_DF, segmented_6sec_segs)
    update_dataframes(SEG_10_SEC_DF, segmented_10sec_segs)

    with open(processed_file, 'wb') as pklFile:
        pkl.dump(processed_items, pklFile)

    return processed_items

# %%
start_time = time.time()
# form the language classification file
items_processed = 0
items_to_process = len(items)
while items_to_process > items_processed:
    processed_items = process_record_batch(items, batch_size=50)
    items_processed = len(processed_items)
    print(f'Processed {items_processed} out of {items_to_process} in {time.time()-start_time} seconds')
# Out:
# Processed 50 out of 17198 in 152.96102213859558 seconds
# Processed 100 out of 17198 in 368.91365456581116 seconds
# Processed 150 out of 17198 in 631.5022695064545 seconds
# Processed 200 out of 17198 in 809.84206199646 seconds
# Processed 250 out of 17198 in 992.8321049213409 seconds
# Processed 300 out of 17198 in 1317.3446989059448 seconds
# Processed 350 out of 17198 in 1512.8827011585236 seconds
# Processed 400 out of 17198 in 2187.0838572978973 seconds
# Processed 450 out of 17198 in 2976.7805581092834 seconds
# Processed 500 out of 17198 in 3101.925054550171 seconds
# Processed 550 out of 17198 in 3263.877706050873 seconds
# Processed 600 out of 17198 in 3476.7703187465668 seconds
# Processed 650 out of 17198 in 3690.568516731262 seconds
# Processed 700 out of 17198 in 3925.1804711818695 seconds
# Processed 750 out of 17198 in 4126.4864802360535 seconds
# Processed 800 out of 17198 in 4339.908647537231 seconds
# Processed 850 out of 17198 in 4759.037026882172 seconds
# Processed 900 out of 17198 in 6120.615122795105 seconds
# Processed 950 out of 17198 in 10451.301427602768 seconds
# Processed 1000 out of 17198 in 16186.524431705475 seconds
# Processed 1050 out of 17198 in 20882.125809669495 seconds
# Processed 1100 out of 17198 in 25454.116309165955 seconds
# Processed 1150 out of 17198 in 27798.907505989075 seconds
# Processed 1200 out of 17198 in 28010.811429739 seconds
# Processed 1250 out of 17198 in 28275.29984807968 seconds
# Processed 1300 out of 17198 in 28884.08122229576 seconds
# Processed 1350 out of 17198 in 29251.396234989166 seconds
# Processed 1400 out of 17198 in 29461.826623678207 seconds
# Processed 1450 out of 17198 in 29870.917089939117 seconds
# Processed 1500 out of 17198 in 30288.255036354065 seconds
# Processed 1550 out of 17198 in 30682.755237817764 seconds
# Processed 1600 out of 17198 in 31212.159487724304 seconds
# Processed 1650 out of 17198 in 31373.377789974213 seconds
# Processed 1700 out of 17198 in 31495.433775901794 seconds
# Processed 1750 out of 17198 in 31866.47363758087 seconds
# Processed 1800 out of 17198 in 32262.73019886017 seconds
# Processed 1850 out of 17198 in 32542.792569875717 seconds
# Processed 1900 out of 17198 in 33016.86480760574 seconds
# Processed 1950 out of 17198 in 33247.94620537758 seconds
# Processed 2000 out of 17198 in 33370.55802440643 seconds
# Processed 2050 out of 17198 in 33633.90717935562 seconds
# Processed 2100 out of 17198 in 34033.340492248535 seconds
# Processed 2150 out of 17198 in 34258.87534356117 seconds
# Processed 2200 out of 17198 in 34586.117735147476 seconds
# Processed 2250 out of 17198 in 34882.01666045189 seconds
# Processed 2300 out of 17198 in 35074.707228899 seconds
# Processed 2350 out of 17198 in 35669.59206175804 seconds
# Processed 2400 out of 17198 in 36461.74536728859 seconds
# Processed 2450 out of 17198 in 37851.36674761772 seconds
# Processed 2500 out of 17198 in 41299.17233753204 seconds
# Processed 2550 out of 17198 in 41539.87675714493 seconds
# Processed 2600 out of 17198 in 41695.975009441376 seconds
# Processed 2650 out of 17198 in 41911.2459859848 seconds
# Processed 2700 out of 17198 in 42219.23233342171 seconds
# Processed 2750 out of 17198 in 42436.58043384552 seconds
# Processed 2800 out of 17198 in 42744.38568329811 seconds
# Processed 2850 out of 17198 in 43396.32943916321 seconds
# Processed 2900 out of 17198 in 43725.74229931831 seconds
# Processed 2950 out of 17198 in 44157.288116931915 seconds
# Processed 3000 out of 17198 in 44482.69953107834 seconds
# Processed 3050 out of 17198 in 44694.83782577515 seconds
# Processed 3100 out of 17198 in 44842.97190141678 seconds
# Processed 3150 out of 17198 in 45004.15707945824 seconds
# Processed 3200 out of 17198 in 45145.91859936714 seconds
# Processed 3250 out of 17198 in 45283.19553780556 seconds
# Processed 3300 out of 17198 in 45394.572910785675 seconds
# Processed 3350 out of 17198 in 45623.0035636425 seconds
# Processed 3400 out of 17198 in 46162.649538993835 seconds
# Processed 3450 out of 17198 in 46390.587844610214 seconds
# Processed 3500 out of 17198 in 46628.07110095024 seconds
# Processed 3550 out of 17198 in 47083.96313166618 seconds
# Processed 3600 out of 17198 in 47443.859726667404 seconds
# Processed 3650 out of 17198 in 47604.62841820717 seconds
# Processed 3700 out of 17198 in 47767.63030219078 seconds
# Processed 3750 out of 17198 in 48016.717596292496 seconds
# Processed 3800 out of 17198 in 48276.81418991089 seconds
# Processed 3850 out of 17198 in 48580.6248319149 seconds
# Processed 3900 out of 17198 in 48850.489698171616 seconds
# Processed 3950 out of 17198 in 49136.05208468437 seconds
# Processed 4000 out of 17198 in 49316.477842092514 seconds
# Processed 4050 out of 17198 in 49975.43817901611 seconds
# Processed 4100 out of 17198 in 50299.57496714592 seconds
# Processed 4150 out of 17198 in 50797.09313964844 seconds
# Processed 4200 out of 17198 in 51188.90967178345 seconds
# Processed 4250 out of 17198 in 51533.38357543945 seconds
# Processed 4300 out of 17198 in 51916.51633358002 seconds
# Processed 4350 out of 17198 in 52202.18059372902 seconds
# Processed 4400 out of 17198 in 52648.04764533043 seconds
# Processed 4450 out of 17198 in 53105.85043954849 seconds
# Processed 4500 out of 17198 in 53539.7686753273 seconds
# Processed 4550 out of 17198 in 53817.26927757263 seconds
# Processed 4600 out of 17198 in 54572.25344204903 seconds
# Processed 4650 out of 17198 in 55081.98286771774 seconds
# Processed 4700 out of 17198 in 55373.135679244995 seconds
# Processed 4750 out of 17198 in 55816.18250155449 seconds
# Processed 4800 out of 17198 in 56165.20457100868 seconds
# Processed 4850 out of 17198 in 56529.01525735855 seconds
# Processed 4900 out of 17198 in 56994.45589065552 seconds
# Processed 4950 out of 17198 in 57516.970994234085 seconds
# Processed 5000 out of 17198 in 58122.402265548706 seconds
# Processed 5050 out of 17198 in 58484.43962264061 seconds
# Processed 5100 out of 17198 in 58828.36953616142 seconds
# Processed 5150 out of 17198 in 59280.227652311325 seconds
# Processed 5200 out of 17198 in 60094.67458939552 seconds
# Processed 5250 out of 17198 in 60586.44466114044 seconds
# Processed 5300 out of 17198 in 60949.98494887352 seconds
# Processed 5350 out of 17198 in 61553.338460445404 seconds
# Processed 5400 out of 17198 in 62066.800122499466 seconds
# Processed 5450 out of 17198 in 63377.34051036835 seconds
# Processed 5500 out of 17198 in 63939.78776073456 seconds
# Processed 5550 out of 17198 in 64869.88066601753 seconds
# Processed 5600 out of 17198 in 65106.00172352791 seconds
# Processed 5650 out of 17198 in 65742.94342136383 seconds
# Processed 5700 out of 17198 in 66104.05725741386 seconds
# Processed 5750 out of 17198 in 67042.72880840302 seconds
# Processed 5800 out of 17198 in 67449.22736263275 seconds
# Processed 5850 out of 17198 in 67678.19447779655 seconds
# Processed 5900 out of 17198 in 67920.5487048626 seconds
# Processed 5950 out of 17198 in 68116.81870818138 seconds
# Processed 6000 out of 17198 in 68516.32145738602 seconds
# Processed 6050 out of 17198 in 68926.0240893364 seconds
# Processed 6100 out of 17198 in 69152.06851792336 seconds
# Processed 6150 out of 17198 in 69310.14829516411 seconds
# Processed 6200 out of 17198 in 69647.66611528397 seconds
# Processed 6250 out of 17198 in 70232.72607803345 seconds
# Processed 6300 out of 17198 in 70565.6598803997 seconds
# Processed 6350 out of 17198 in 70959.62111353874 seconds
# Processed 6400 out of 17198 in 71539.36751937866 seconds
# Processed 6450 out of 17198 in 72156.02927803993 seconds
# Processed 6500 out of 17198 in 72535.85415053368 seconds
# Processed 6550 out of 17198 in 72738.89519190788 seconds
# Processed 6600 out of 17198 in 72914.88803434372 seconds
# Processed 6650 out of 17198 in 73206.96882247925 seconds
# Processed 6700 out of 17198 in 73320.28076124191 seconds
# Processed 6750 out of 17198 in 73487.03541707993 seconds
# Processed 6800 out of 17198 in 73645.4203646183 seconds
# Processed 6850 out of 17198 in 73836.4443295002 seconds
# Processed 6900 out of 17198 in 74140.45387220383 seconds
# Processed 6950 out of 17198 in 74363.12673997879 seconds
# Processed 7000 out of 17198 in 74547.18872618675 seconds
# Processed 7050 out of 17198 in 74774.34334421158 seconds
# Processed 7100 out of 17198 in 75017.8717288971 seconds
# Processed 7150 out of 17198 in 75254.58670568466 seconds
# Processed 7200 out of 17198 in 75438.77744531631 seconds
# Processed 7250 out of 17198 in 75692.14143681526 seconds
# Processed 7300 out of 17198 in 75983.00968170166 seconds
# Processed 7350 out of 17198 in 76145.24905657768 seconds
# Processed 7400 out of 17198 in 76659.94035100937 seconds
# Processed 7450 out of 17198 in 76846.18289422989 seconds
# Processed 7500 out of 17198 in 77423.34896087646 seconds
# Processed 7550 out of 17198 in 77785.1479640007 seconds
# Processed 7600 out of 17198 in 77893.49442911148 seconds
# Processed 7650 out of 17198 in 78036.70227956772 seconds
# Processed 7700 out of 17198 in 78374.65533280373 seconds
# Processed 7750 out of 17198 in 78744.07777357101 seconds
# Processed 7800 out of 17198 in 79061.52497410774 seconds
# Processed 7850 out of 17198 in 80793.84014177322 seconds
# Processed 7900 out of 17198 in 81194.28925228119 seconds
# Processed 7950 out of 17198 in 81579.14575624466 seconds
# Processed 8000 out of 17198 in 82098.36589074135 seconds
# Processed 8050 out of 17198 in 82699.02784585953 seconds
# Processed 8100 out of 17198 in 82883.26731395721 seconds
# Processed 8150 out of 17198 in 83330.86762332916 seconds
# Processed 8200 out of 17198 in 83806.68939709663 seconds
# Processed 8250 out of 17198 in 84137.33128166199 seconds
# Processed 8300 out of 17198 in 84489.56510567665 seconds
# Processed 8350 out of 17198 in 84798.62364411354 seconds
# Processed 8400 out of 17198 in 85238.78148388863 seconds
# Processed 8450 out of 17198 in 85673.05356478691 seconds
# Processed 8500 out of 17198 in 86057.62182235718 seconds
# Processed 8550 out of 17198 in 86432.74489665031 seconds
# Processed 8600 out of 17198 in 86857.6523668766 seconds
# Processed 8650 out of 17198 in 87113.67175078392 seconds
# Processed 8700 out of 17198 in 87405.00439977646 seconds
# Processed 8750 out of 17198 in 87728.73309826851 seconds
# Processed 8800 out of 17198 in 87950.70799708366 seconds
# Processed 8850 out of 17198 in 88240.7637064457 seconds
# Processed 8900 out of 17198 in 88538.39699149132 seconds
# Processed 8950 out of 17198 in 88798.77053761482 seconds
# Processed 9000 out of 17198 in 89103.90629935265 seconds
# Processed 9050 out of 17198 in 89308.2523367405 seconds
# Processed 9100 out of 17198 in 89462.51991820335 seconds
# Processed 9150 out of 17198 in 89677.60981702805 seconds
# Processed 9200 out of 17198 in 89791.86458158493 seconds
# Processed 9250 out of 17198 in 89930.94002199173 seconds
# Processed 9300 out of 17198 in 90121.7788245678 seconds
# Processed 9350 out of 17198 in 90295.99615907669 seconds
# Processed 9400 out of 17198 in 90459.9562330246 seconds
# Processed 9450 out of 17198 in 90619.60995483398 seconds
# Processed 9500 out of 17198 in 90809.55948710442 seconds
# Processed 9550 out of 17198 in 90970.72859144211 seconds
# Processed 9600 out of 17198 in 91313.64365434647 seconds
# Processed 9650 out of 17198 in 91604.08771705627 seconds
# Processed 9700 out of 17198 in 92231.80380225182 seconds
# Processed 9750 out of 17198 in 92732.09030747414 seconds
# Processed 9800 out of 17198 in 92969.76316022873 seconds
# Processed 9850 out of 17198 in 93122.86338448524 seconds
# Processed 9900 out of 17198 in 93673.74272489548 seconds
# Processed 9950 out of 17198 in 94130.2462823391 seconds
# Processed 10000 out of 17198 in 94362.3409743309 seconds
# Processed 10050 out of 17198 in 94584.75493836403 seconds
# Processed 10100 out of 17198 in 94903.65553736687 seconds
# Processed 10150 out of 17198 in 95178.67361068726 seconds
# Processed 10200 out of 17198 in 95282.84889364243 seconds
# Processed 10250 out of 17198 in 95445.44061493874 seconds
# Processed 10300 out of 17198 in 95603.1342856884 seconds
# Processed 10350 out of 17198 in 95933.64354324341 seconds
# Processed 10400 out of 17198 in 96195.70219230652 seconds
# Processed 10450 out of 17198 in 96463.45062279701 seconds
# Processed 10500 out of 17198 in 96676.46030163765 seconds
# Processed 10550 out of 17198 in 96935.44210720062 seconds
# Processed 10600 out of 17198 in 97033.41417598724 seconds
# Processed 10650 out of 17198 in 97582.28487253189 seconds
# Processed 10700 out of 17198 in 101388.42927527428 seconds
# Processed 10750 out of 17198 in 102129.02653861046 seconds
# Processed 10800 out of 17198 in 102998.1694509983 seconds
# Processed 10850 out of 17198 in 105720.99499034882 seconds
# Processed 10900 out of 17198 in 109523.40030145645 seconds
# Processed 10950 out of 17198 in 112078.90415906906 seconds
# Processed 11000 out of 17198 in 114133.58747410774 seconds
# Processed 11050 out of 17198 in 114441.76186013222 seconds
# Processed 11100 out of 17198 in 114636.35866975784 seconds
# Processed 11150 out of 17198 in 114902.13594460487 seconds
# Processed 11200 out of 17198 in 115249.04452443123 seconds
# Processed 11250 out of 17198 in 115614.16978287697 seconds
# Processed 11300 out of 17198 in 115783.07224822044 seconds
# Processed 11350 out of 17198 in 116062.67137908936 seconds
# Processed 11400 out of 17198 in 116254.07471394539 seconds
# Processed 11450 out of 17198 in 116449.81642222404 seconds
# Processed 11500 out of 17198 in 116658.78101849556 seconds
# Processed 11550 out of 17198 in 116781.59618711472 seconds
# Processed 11600 out of 17198 in 116948.6618988514 seconds
# Processed 11650 out of 17198 in 117240.53070998192 seconds
# Processed 11700 out of 17198 in 117499.19209313393 seconds
# Processed 11750 out of 17198 in 117676.8145415783 seconds
# Processed 11800 out of 17198 in 117856.26161193848 seconds
# Processed 11850 out of 17198 in 118013.61038017273 seconds
# Processed 11900 out of 17198 in 118108.1971001625 seconds
# Processed 11950 out of 17198 in 118429.67569327354 seconds
# Processed 12000 out of 17198 in 118812.75148200989 seconds
# Processed 12050 out of 17198 in 119393.35287261009 seconds
# Processed 12100 out of 17198 in 119850.56253480911 seconds
# Processed 12150 out of 17198 in 119996.35983085632 seconds
# Processed 12200 out of 17198 in 120184.64574217796 seconds
# Processed 12250 out of 17198 in 120285.00174641609 seconds
# Processed 12300 out of 17198 in 120550.43653035164 seconds
# Processed 12350 out of 17198 in 120712.47117424011 seconds
# Processed 12400 out of 17198 in 120891.42994689941 seconds
# Processed 12450 out of 17198 in 121154.94939303398 seconds
# Processed 12500 out of 17198 in 121423.85070037842 seconds
# Processed 12550 out of 17198 in 121672.67223024368 seconds
# Processed 12600 out of 17198 in 121939.74256134033 seconds
# Processed 12650 out of 17198 in 122207.38289737701 seconds
# Processed 12700 out of 17198 in 122407.3455760479 seconds
# Processed 12750 out of 17198 in 122625.63401436806 seconds
# Processed 12800 out of 17198 in 123009.24987697601 seconds
# Processed 12850 out of 17198 in 123165.03043437004 seconds
# Processed 12900 out of 17198 in 123387.67797470093 seconds
# Processed 12950 out of 17198 in 123727.37618756294 seconds
# Processed 13000 out of 17198 in 123928.44307541847 seconds
# Processed 13050 out of 17198 in 124294.5967040062 seconds
# Processed 13100 out of 17198 in 124522.07540464401 seconds
# Processed 13150 out of 17198 in 124981.00408029556 seconds
# Processed 13200 out of 17198 in 125206.65418958664 seconds
# Processed 13250 out of 17198 in 125434.26664423943 seconds
# Processed 13300 out of 17198 in 125735.83112001419 seconds
# Processed 13350 out of 17198 in 126022.00090575218 seconds
# Processed 13400 out of 17198 in 126302.3726952076 seconds
# Processed 13450 out of 17198 in 126544.78510403633 seconds
# Processed 13500 out of 17198 in 126792.905752182 seconds
# Processed 13550 out of 17198 in 126999.67666697502 seconds
# Processed 13600 out of 17198 in 127244.3233590126 seconds
# Processed 13650 out of 17198 in 127376.30739927292 seconds
# Processed 13700 out of 17198 in 127641.61716556549 seconds
# Processed 13750 out of 17198 in 127933.07178330421 seconds
# Processed 13800 out of 17198 in 128027.73329401016 seconds
# Processed 13850 out of 17198 in 128234.34102487564 seconds
# Processed 13900 out of 17198 in 128588.52672433853 seconds
# Processed 13950 out of 17198 in 128871.1297724247 seconds
# Processed 14000 out of 17198 in 129352.01991844177 seconds
# Processed 14050 out of 17198 in 129923.0645763874 seconds
# Processed 14100 out of 17198 in 130217.85993170738 seconds
# Processed 14150 out of 17198 in 130465.59036564827 seconds
# Processed 14200 out of 17198 in 130590.24929261208 seconds
# Processed 14250 out of 17198 in 130823.70383691788 seconds
# Processed 14300 out of 17198 in 131056.7322485447 seconds
# Processed 14350 out of 17198 in 131411.2550189495 seconds
# Processed 14400 out of 17198 in 131892.01386284828 seconds
# Processed 14450 out of 17198 in 132383.60028481483 seconds
# Processed 14500 out of 17198 in 133039.32311749458 seconds
# Processed 14550 out of 17198 in 133527.31506729126 seconds
# Processed 14600 out of 17198 in 133840.09980106354 seconds
# Processed 14650 out of 17198 in 134080.38153076172 seconds
# Processed 14700 out of 17198 in 134243.06201291084 seconds
# Processed 14750 out of 17198 in 134674.61516785622 seconds
# Processed 14800 out of 17198 in 134946.97991394997 seconds
# Processed 14850 out of 17198 in 135193.50783872604 seconds
# Processed 14900 out of 17198 in 135491.91851258278 seconds
# Processed 14950 out of 17198 in 135643.35425305367 seconds
# Processed 15000 out of 17198 in 136063.4610927105 seconds
# Processed 15050 out of 17198 in 136701.55566096306 seconds
# Processed 15100 out of 17198 in 137021.18775844574 seconds
# Processed 15150 out of 17198 in 137362.99652147293 seconds
# Processed 15200 out of 17198 in 137488.31750059128 seconds
# Processed 15250 out of 17198 in 137774.6582789421 seconds
# Processed 15300 out of 17198 in 138181.31139802933 seconds
# Processed 15350 out of 17198 in 138521.13035583496 seconds
# Processed 15400 out of 17198 in 138768.92505025864 seconds
# Processed 15450 out of 17198 in 139043.8067035675 seconds
# Processed 15500 out of 17198 in 139389.15457940102 seconds
# Processed 15550 out of 17198 in 139769.81626439095 seconds
# Processed 15600 out of 17198 in 140088.6163840294 seconds
# Processed 15650 out of 17198 in 140446.16685581207 seconds
# Processed 15700 out of 17198 in 140778.42984509468 seconds
# Processed 15750 out of 17198 in 141176.07380104065 seconds
# Processed 15800 out of 17198 in 141583.73533916473 seconds
# Processed 15850 out of 17198 in 141957.90164470673 seconds
# Processed 15900 out of 17198 in 142761.53226804733 seconds
# Processed 15950 out of 17198 in 143261.24429249763 seconds
# Processed 16000 out of 17198 in 143720.2573735714 seconds
# Processed 16050 out of 17198 in 143945.96490693092 seconds
# Processed 16100 out of 17198 in 144215.28013443947 seconds
# Processed 16150 out of 17198 in 144449.3530960083 seconds
# Processed 16200 out of 17198 in 144816.50807094574 seconds
# Processed 16250 out of 17198 in 145178.06987977028 seconds
# Processed 16300 out of 17198 in 145616.9037733078 seconds
# Processed 16350 out of 17198 in 146034.31453466415 seconds
# Processed 16400 out of 17198 in 146428.9414448738 seconds
# Processed 16450 out of 17198 in 146872.14266228676 seconds
# Processed 16500 out of 17198 in 147102.89283180237 seconds
# Processed 16550 out of 17198 in 147417.72404694557 seconds
# Processed 16600 out of 17198 in 147918.87406635284 seconds
# Processed 16650 out of 17198 in 148144.88379120827 seconds
# Processed 16700 out of 17198 in 148400.8173313141 seconds
# Processed 16750 out of 17198 in 148541.92990589142 seconds
# Processed 16800 out of 17198 in 148897.34791183472 seconds
# Processed 16850 out of 17198 in 149343.9248380661 seconds
# Processed 16900 out of 17198 in 149707.67331767082 seconds
# Processed 16950 out of 17198 in 150028.5635662079 seconds
# Processed 17000 out of 17198 in 150250.61802768707 seconds
# Processed 17050 out of 17198 in 150581.5094139576 seconds
# Processed 17100 out of 17198 in 150804.32019782066 seconds
# Processed 17150 out of 17198 in 151070.06475400925 seconds
# Processed 17198 out of 17198 in 151274.26694107056 seconds
