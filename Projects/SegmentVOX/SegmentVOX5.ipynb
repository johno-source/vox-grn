# %% [markdown]
# # Partial Process of Segment GRN Data for vox-grn
#
# See SegmentVox.ipynb for full description.
#
# In an attempt to speed up the processing I have divided the items up into 10 groups and want to have them all process in parallel. It probably won't be 10 times faster but it should still be quicker.

# %%
import pandas as pd
import numpy as np
import os
import sys
module_path = os.path.abspath(os.path.join('../vad_utils'))
if module_path not in sys.path:
    sys.path.append(module_path)
from vad_utils import SAMPLING_RATE, FRAME_SIZE_MS, SAMPLES_PER_FRAME
import vad_utils as vu
from pydub import AudioSegment
import pickle as pkl
from pathlib import Path
import time

# %%
# define the locations for each of the file types
NOTEBOOK_ID=5
SEGMENTS_DIR = '/media/originals/segments/'
DATASETS_DIR = '/media/originals/datasets/'
SEC_4_DATA_DIR = 'seg_4sec/data/'
SEC_6_DATA_DIR = 'seg_6sec/data/'
SEC_10_DATA_DIR = 'seg_10sec/data/'

# define specific files used in the process
SEG_4_SEC_DF = f'{SEGMENTS_DIR}seg_4sec_{NOTEBOOK_ID}.csv'
SEG_6_SEC_DF = f'{SEGMENTS_DIR}seg_6sec_{NOTEBOOK_ID}.csv'
SEG_10_SEC_DF = f'{SEGMENTS_DIR}seg_10sec_{NOTEBOOK_ID}.csv'

# define segment sizes for each dataset
SEG_4_SEC = 4.0
SEG_6_SEC = 6.0
SEG_10_SEC = 10.0

# %%
# Now read in the description of the input and remove the unwanted columns and rename the rest to be python attribute names.
items = pd.read_csv(f'/media/originals/segments/items_{NOTEBOOK_ID}.csv')
items.set_index('ID', inplace=True)
items.columns
# Out:
# Index(['iso', 'program', 'location', 'year', 'path', 'filename', 'item_no',
#        'title', 'start', 'end'],
#       dtype='object')

# %%
print(items.iloc[100])
# Out:
# iso                                       mcf
# program                                A64757
# location              Aldea Flor : Rio Curaca
# year                                   2014.0
# path        Programs/64/64757/A64757/PM-1411/
# filename                       A64757-025.wav
# item_no                                    25
# title                              Picture 24
# start                                     0.0
# end                                      61.0
# Name: A64757_025, dtype: object

# %%
print(items.index)
# Out:
# Index(['A04041_001', 'A04041_002', 'A04041_003', 'A13591_002', 'A13591_003',
#        'A13591_005', 'A13591_007', 'A13591_011', 'A13591_015', 'A13591_017',
#        ...
#        'A66741_001', 'A66741_002', 'A66741_003', 'A66556_001', 'A66582_001',
#        'A66558_001', 'A66832_002', 'A66603_001', 'A66601_001', 'A66696_001'],
#       dtype='object', name='ID', length=17198)

# %%
# generate directories and filenames
def prepare_dir(dirname):
    if dirname[-1] != '/':
        dirname = dirname + '/'
    Path(dirname).mkdir(parents=True, exist_ok=True)
    return dirname

def prepare_raw_seg_dir(item):
    return prepare_dir(SEGMENTS_DIR + item.iso)

def raw_seg_filename(item):
    return f'{item.program}_{item.item_no:03d}.pkl'

def prepare_dataset_data_dir(item, dataset_dir):
    return prepare_dir(DATASETS_DIR + dataset_dir + item.iso)

def seg_mp3_filename(item, seg):
    return f'{item.program}_{item.item_no:03d}_{seg:03d}.mp3'

# %%
def condition_audio_segment(audio_seg):
    if audio_seg.channels != 1:
        audio_seg = audio_seg.set_channels(1)

    if audio_seg.sample_width != 2:
        audio_seg = audio_seg.set_sample_width(2)

    if audio_seg.frame_rate != SAMPLING_RATE:
        audio_seg = audio_seg.set_frame_rate(SAMPLING_RATE)

    return audio_seg

# %%
def save_the_segment_info(item, segs):
    fname = prepare_raw_seg_dir(item) + raw_seg_filename(item)
    with open(fname, 'wb') as pklFile:
         pkl.dump(segs, pklFile)

def read_the_segment_info(item):
    fname = prepare_raw_seg_dir(item) + raw_seg_filename(item)
    if os.path.exists(fname):
        if os.path.getsize(fname) > 0:
            with open(fname, 'rb') as pklFile:
                return pkl.load(pklFile)
    return []
    
def extract_audio_segment_for_item(item):
    fmt = 'wav'
    if item.filename[-4:] == '.mp3' :
        fmt = 'mp3'
    audio_seg = AudioSegment.from_file('/media/programs/' + item.path + item.filename, format=fmt)
    start_ms = int(item.start * 1000)
    end_ms = int(item.end * 1000)
    audio_seg = audio_seg[start_ms:end_ms]

    # now condition the segment and extract the raw segments.
    audio_seg = condition_audio_segment(audio_seg)
    segs = read_the_segment_info(item)
    if len(segs) == 0:
        segs = vu.audio_to_raw_voice_segments(audio_seg)
        save_the_segment_info(item, segs)

    return audio_seg, segs

def create_mp3_files(audio_seg, segs, time_per_segment, dataset_dir, item):
    segs_for_time = vu.divide_into_segments(segs, time_per_segment)

    # now write out the 4 sec segments
    dirname = prepare_dataset_data_dir(item, dataset_dir)
    rows = list()
    for i, seg in enumerate(segs_for_time):
        file_name = dataset_dir + item.iso + '/' + seg_mp3_filename(item, i)
        fname = dirname + seg_mp3_filename(item, i)
        if not os.path.exists(fname):
            start = vu.convert_frames_to_ms(seg.start)
            stop = vu.convert_frames_to_ms(seg.stop)
            audio_seg[start:stop].export(fname, format='mp3', bitrate='32k')
        desc = dict(item._asdict())
        desc['seg_start'] = vu.convert_frames_to_seconds(seg.start)
        desc['seg_stop'] = vu.convert_frames_to_seconds(seg.stop)
        desc['seg'] = i
        desc['file_name'] = file_name
        rows.append(desc)

    return rows

def update_dataframes(seg_df_csv, seg_records):
    # now update the dataframes
    if len(seg_records) > 0:
        if os.path.isfile(seg_df_csv):
            seg_sec_df = pd.concat([pd.read_csv(seg_df_csv, index_col='file_name'), pd.DataFrame.from_records(seg_records, index='file_name')])
        else:
            seg_sec_df = pd.DataFrame.from_records(seg_records, index='file_name')
        seg_sec_df.to_csv(seg_df_csv)

# %%
# processing these items might take a very long time. To permit the process to be interrupted and restarted the indexes of processed items
# are maintained in a set that is pickled on each batch. This allows the batch to quickly pick up where it left off.
def process_record_batch(items_df, *, batch_size=10):
    batch_proc = 0
    processed_file = f'/media/originals/segments/processed16_{NOTEBOOK_ID}.pkl'
    if os.path.isfile(processed_file):
        with open(processed_file, 'rb') as pklFile:
            processed_items = pkl.load(pklFile)
    else:
        processed_items = set()

    segmented_4sec_segs = []
    segmented_6sec_segs = []
    segmented_10sec_segs = []

    for item in items_df.itertuples():
        if batch_proc < batch_size:
            if item.Index not in processed_items:
                try:
                    audio_seg, voice_segs = extract_audio_segment_for_item(item)
                    segmented_4sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_4_SEC, SEC_4_DATA_DIR, item))
                    segmented_6sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_6_SEC, SEC_6_DATA_DIR, item))
                    segmented_10sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_10_SEC, SEC_10_DATA_DIR, item))
                except:
                    print('exception')
                    pass

                # we want to add an item that has an exception so it is not reprocessed on every batch
                processed_items.add(item.Index)
                batch_proc += 1

        else:
            break

    update_dataframes(SEG_4_SEC_DF, segmented_4sec_segs)
    update_dataframes(SEG_6_SEC_DF, segmented_6sec_segs)
    update_dataframes(SEG_10_SEC_DF, segmented_10sec_segs)

    with open(processed_file, 'wb') as pklFile:
        pkl.dump(processed_items, pklFile)

    return processed_items

# %%
start_time = time.time()
# form the language classification file
items_processed = 0
items_to_process = len(items)
while items_to_process > items_processed:
    processed_items = process_record_batch(items, batch_size=50)
    items_processed = len(processed_items)
    print(f'Processed {items_processed} out of {items_to_process} in {time.time()-start_time} seconds')
# Out:
# Processed 50 out of 17198 in 327.8678228855133 seconds
# Processed 100 out of 17198 in 622.3444848060608 seconds
# Processed 150 out of 17198 in 958.0340132713318 seconds
# Processed 200 out of 17198 in 1430.8820011615753 seconds
# Processed 250 out of 17198 in 1702.3894164562225 seconds
# Processed 300 out of 17198 in 1964.3676283359528 seconds
# Processed 350 out of 17198 in 2314.62681555748 seconds
# Processed 400 out of 17198 in 2601.7593417167664 seconds
# Processed 450 out of 17198 in 3042.894159555435 seconds
# Processed 500 out of 17198 in 3294.1735322475433 seconds
# Processed 550 out of 17198 in 3425.0052111148834 seconds
# Processed 600 out of 17198 in 3663.471461057663 seconds
# Processed 650 out of 17198 in 3927.3908231258392 seconds
# Processed 700 out of 17198 in 4123.8450293540955 seconds
# Processed 750 out of 17198 in 4410.180380821228 seconds
# Processed 800 out of 17198 in 4579.761921405792 seconds
# Processed 850 out of 17198 in 5069.36171579361 seconds
# Processed 900 out of 17198 in 5583.01859998703 seconds
# Processed 950 out of 17198 in 6167.806746721268 seconds
# Processed 1000 out of 17198 in 6466.673305273056 seconds
# Processed 1050 out of 17198 in 7744.720946788788 seconds
# Processed 1100 out of 17198 in 9642.48363685608 seconds
# Processed 1150 out of 17198 in 10909.969932794571 seconds
# Processed 1200 out of 17198 in 12786.82133436203 seconds
# Processed 1250 out of 17198 in 16492.39680337906 seconds
# Processed 1300 out of 17198 in 18391.18440580368 seconds
# Processed 1350 out of 17198 in 21290.951950073242 seconds
# Processed 1400 out of 17198 in 22506.210082292557 seconds
# Processed 1450 out of 17198 in 24546.534779071808 seconds
# Processed 1500 out of 17198 in 24840.310621738434 seconds
# Processed 1550 out of 17198 in 25110.990575313568 seconds
# Processed 1600 out of 17198 in 26264.350555419922 seconds
# Processed 1650 out of 17198 in 26590.70873093605 seconds
# Processed 1700 out of 17198 in 27094.81861805916 seconds
# Processed 1750 out of 17198 in 27520.228802204132 seconds
# Processed 1800 out of 17198 in 27905.992230653763 seconds
# Processed 1850 out of 17198 in 28343.46495294571 seconds
# Processed 1900 out of 17198 in 28541.823115825653 seconds
# Processed 1950 out of 17198 in 31018.128077983856 seconds
# Processed 2000 out of 17198 in 33375.66660952568 seconds
# Processed 2050 out of 17198 in 33692.63272833824 seconds
# Processed 2100 out of 17198 in 34093.63118767738 seconds
# Processed 2150 out of 17198 in 34422.05864214897 seconds
# Processed 2200 out of 17198 in 34744.59713244438 seconds
# Processed 2250 out of 17198 in 35071.48527479172 seconds
# Processed 2300 out of 17198 in 35602.360213041306 seconds
# Processed 2350 out of 17198 in 35975.11093354225 seconds
# Processed 2400 out of 17198 in 36301.216347932816 seconds
# Processed 2450 out of 17198 in 36825.67582297325 seconds
# Processed 2500 out of 17198 in 37205.782835006714 seconds
# Processed 2550 out of 17198 in 37543.09284949303 seconds
# Processed 2600 out of 17198 in 37906.32216787338 seconds
# Processed 2650 out of 17198 in 38302.23172593117 seconds
# Processed 2700 out of 17198 in 38678.9215798378 seconds
# Processed 2750 out of 17198 in 39061.1835334301 seconds
# Processed 2800 out of 17198 in 39533.97789359093 seconds
# Processed 2850 out of 17198 in 49198.19958615303 seconds
# Processed 2900 out of 17198 in 52623.37144446373 seconds
# Processed 2950 out of 17198 in 53000.98451590538 seconds
# Processed 3000 out of 17198 in 53498.184498786926 seconds
# Processed 3050 out of 17198 in 54025.20315003395 seconds
# Processed 3100 out of 17198 in 54602.60663175583 seconds
# Processed 3150 out of 17198 in 55156.22661614418 seconds
# Processed 3200 out of 17198 in 55596.276983737946 seconds
# Processed 3250 out of 17198 in 55942.62193608284 seconds
# Processed 3300 out of 17198 in 56201.0438079834 seconds
# Processed 3350 out of 17198 in 56339.708574295044 seconds
# Processed 3400 out of 17198 in 56577.7389190197 seconds
# Processed 3450 out of 17198 in 56809.318128824234 seconds
# Processed 3500 out of 17198 in 57054.79334616661 seconds
# Processed 3550 out of 17198 in 57241.34663081169 seconds
# Processed 3600 out of 17198 in 57522.279004096985 seconds
# Processed 3650 out of 17198 in 57962.012920856476 seconds
# Processed 3700 out of 17198 in 58292.96982860565 seconds
# Processed 3750 out of 17198 in 58808.00949001312 seconds
# Processed 3800 out of 17198 in 59240.15173077583 seconds
# Processed 3850 out of 17198 in 59586.25059175491 seconds
# Processed 3900 out of 17198 in 59939.15271925926 seconds
# Processed 3950 out of 17198 in 60241.30592298508 seconds
# Processed 4000 out of 17198 in 60473.464540719986 seconds
# Processed 4050 out of 17198 in 60755.00495219231 seconds
# Processed 4100 out of 17198 in 61082.98112654686 seconds
# Processed 4150 out of 17198 in 61425.60657072067 seconds
# Processed 4200 out of 17198 in 61701.547321558 seconds
# Processed 4250 out of 17198 in 61856.1481628418 seconds
# Processed 4300 out of 17198 in 62133.7451004982 seconds
# Processed 4350 out of 17198 in 62418.49086999893 seconds
# Processed 4400 out of 17198 in 62579.50252366066 seconds
# Processed 4450 out of 17198 in 62851.90938282013 seconds
# Processed 4500 out of 17198 in 63091.08774495125 seconds
# Processed 4550 out of 17198 in 63297.493250370026 seconds
# Processed 4600 out of 17198 in 63553.381306409836 seconds
# Processed 4650 out of 17198 in 63773.96114039421 seconds
# Processed 4700 out of 17198 in 63959.8911690712 seconds
# Processed 4750 out of 17198 in 64169.47088885307 seconds
# Processed 4800 out of 17198 in 64369.031747579575 seconds
# Processed 4850 out of 17198 in 64560.8242790699 seconds
# Processed 4900 out of 17198 in 64879.409708976746 seconds
# Processed 4950 out of 17198 in 65315.24739551544 seconds
# Processed 5000 out of 17198 in 65926.58188152313 seconds
# Processed 5050 out of 17198 in 66084.62111067772 seconds
# Processed 5100 out of 17198 in 66275.76982426643 seconds
# Processed 5150 out of 17198 in 67019.44398236275 seconds
# Processed 5200 out of 17198 in 67444.42223954201 seconds
# Processed 5250 out of 17198 in 67873.13520741463 seconds
# Processed 5300 out of 17198 in 68188.32588005066 seconds
# Processed 5350 out of 17198 in 68462.2614929676 seconds
# Processed 5400 out of 17198 in 68714.66470718384 seconds
# Processed 5450 out of 17198 in 69038.86687088013 seconds
# Processed 5500 out of 17198 in 69372.66753196716 seconds
# Processed 5550 out of 17198 in 69991.52751278877 seconds
# Processed 5600 out of 17198 in 70170.97160291672 seconds
# Processed 5650 out of 17198 in 70359.34640932083 seconds
# Processed 5700 out of 17198 in 70598.17055344582 seconds
# Processed 5750 out of 17198 in 71239.29627990723 seconds
# Processed 5800 out of 17198 in 71940.18737912178 seconds
# Processed 5850 out of 17198 in 72331.82841277122 seconds
# Processed 5900 out of 17198 in 72581.41050696373 seconds
# Processed 5950 out of 17198 in 72763.65153717995 seconds
# Processed 6000 out of 17198 in 72960.75775766373 seconds
# Processed 6050 out of 17198 in 73172.11389660835 seconds
# Processed 6100 out of 17198 in 73350.81112265587 seconds
# Processed 6150 out of 17198 in 73521.99401187897 seconds
# Processed 6200 out of 17198 in 73739.51309585571 seconds
# Processed 6250 out of 17198 in 74061.0516345501 seconds
# Processed 6300 out of 17198 in 74398.75515532494 seconds
# Processed 6350 out of 17198 in 74804.32020401955 seconds
# Processed 6400 out of 17198 in 75305.00584483147 seconds
# Processed 6450 out of 17198 in 75462.33367371559 seconds
# Processed 6500 out of 17198 in 75596.41537427902 seconds
# Processed 6550 out of 17198 in 75713.00851082802 seconds
# Processed 6600 out of 17198 in 75933.32685899734 seconds
# Processed 6650 out of 17198 in 76192.54694366455 seconds
# Processed 6700 out of 17198 in 76451.95824170113 seconds
# Processed 6750 out of 17198 in 76613.80350208282 seconds
# Processed 6800 out of 17198 in 77617.43797945976 seconds
# Processed 6850 out of 17198 in 79530.45642232895 seconds
# Processed 6900 out of 17198 in 79879.84844279289 seconds
# Processed 6950 out of 17198 in 80192.08750963211 seconds
# Processed 7000 out of 17198 in 80539.22460341454 seconds
# Processed 7050 out of 17198 in 80802.33271431923 seconds
# Processed 7100 out of 17198 in 81067.39892554283 seconds
# Processed 7150 out of 17198 in 81377.82476377487 seconds
# Processed 7200 out of 17198 in 81658.82133698463 seconds
# Processed 7250 out of 17198 in 81830.19937348366 seconds
# Processed 7300 out of 17198 in 82060.94429254532 seconds
# Processed 7350 out of 17198 in 82230.84972143173 seconds
# Processed 7400 out of 17198 in 82806.38506102562 seconds
# Processed 7450 out of 17198 in 83069.93848514557 seconds
# Processed 7500 out of 17198 in 83464.34145450592 seconds
# Processed 7550 out of 17198 in 83840.72690272331 seconds
# Processed 7600 out of 17198 in 84280.88437986374 seconds
# Processed 7650 out of 17198 in 84820.60768771172 seconds
# Processed 7700 out of 17198 in 85102.75221538544 seconds
# Processed 7750 out of 17198 in 85429.11821651459 seconds
# Processed 7800 out of 17198 in 85671.84019422531 seconds
# Processed 7850 out of 17198 in 85937.19282078743 seconds
# Processed 7900 out of 17198 in 86365.8239967823 seconds
# Processed 7950 out of 17198 in 86902.87291884422 seconds
# Processed 8000 out of 17198 in 87390.97430562973 seconds
# Processed 8050 out of 17198 in 87617.39026808739 seconds
# Processed 8100 out of 17198 in 87729.79652881622 seconds
# Processed 8150 out of 17198 in 87852.0507235527 seconds
# Processed 8200 out of 17198 in 88010.23747777939 seconds
# Processed 8250 out of 17198 in 88212.01808214188 seconds
# Processed 8300 out of 17198 in 88484.38734006882 seconds
# Processed 8350 out of 17198 in 88788.63974785805 seconds
# Processed 8400 out of 17198 in 89309.0802423954 seconds
# Processed 8450 out of 17198 in 89573.16822338104 seconds
# Processed 8500 out of 17198 in 89738.9784977436 seconds
# Processed 8550 out of 17198 in 89876.25098538399 seconds
# Processed 8600 out of 17198 in 90055.88781404495 seconds
# Processed 8650 out of 17198 in 90234.48571157455 seconds
# Processed 8700 out of 17198 in 90365.83566260338 seconds
# Processed 8750 out of 17198 in 90513.20770931244 seconds
# Processed 8800 out of 17198 in 90729.1214530468 seconds
# Processed 8850 out of 17198 in 91009.28975367546 seconds
# Processed 8900 out of 17198 in 91524.28166222572 seconds
# Processed 8950 out of 17198 in 91945.34822750092 seconds
# Processed 9000 out of 17198 in 92215.642359972 seconds
# Processed 9050 out of 17198 in 92420.61284565926 seconds
# Processed 9100 out of 17198 in 93271.06380939484 seconds
# /tmp/ipykernel_433131/3773699355.py:58: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   seg_sec_df = pd.concat([pd.read_csv(seg_df_csv, index_col='file_name'), pd.DataFrame.from_records(seg_records, index='file_name')])
# Processed 9150 out of 17198 in 94601.10825634003 seconds
# /tmp/ipykernel_433131/3773699355.py:58: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   seg_sec_df = pd.concat([pd.read_csv(seg_df_csv, index_col='file_name'), pd.DataFrame.from_records(seg_records, index='file_name')])
# Processed 9200 out of 17198 in 95159.35888671875 seconds
# Processed 9250 out of 17198 in 95420.89989376068 seconds
# Processed 9300 out of 17198 in 95721.62741327286 seconds
# Processed 9350 out of 17198 in 96181.04978585243 seconds
# Processed 9400 out of 17198 in 96650.75831580162 seconds
# Processed 9450 out of 17198 in 97022.63435316086 seconds
# Processed 9500 out of 17198 in 97586.98214197159 seconds
# Processed 9550 out of 17198 in 97711.5376253128 seconds
# Processed 9600 out of 17198 in 98107.4476339817 seconds
# Processed 9650 out of 17198 in 98277.12276721 seconds
# Processed 9700 out of 17198 in 98528.15486335754 seconds
# Processed 9750 out of 17198 in 98781.29586553574 seconds
# Processed 9800 out of 17198 in 99007.76469421387 seconds
# Processed 9850 out of 17198 in 99385.43890404701 seconds
# Processed 9900 out of 17198 in 100226.3838853836 seconds
# Processed 9950 out of 17198 in 100843.40208029747 seconds
# Processed 10000 out of 17198 in 101492.30029034615 seconds
# Processed 10050 out of 17198 in 102178.15780568123 seconds
# Processed 10100 out of 17198 in 102989.13771414757 seconds
# Processed 10150 out of 17198 in 103378.93222308159 seconds
# Processed 10200 out of 17198 in 103632.0703549385 seconds
# Processed 10250 out of 17198 in 103927.11073493958 seconds
# Processed 10300 out of 17198 in 104163.80539155006 seconds
# Processed 10350 out of 17198 in 104291.13463234901 seconds
# Processed 10400 out of 17198 in 104466.6693046093 seconds
# Processed 10450 out of 17198 in 104669.33349823952 seconds
# Processed 10500 out of 17198 in 106865.07820868492 seconds
# Processed 10550 out of 17198 in 109539.7290482521 seconds
# Processed 10600 out of 17198 in 109719.05166077614 seconds
# Processed 10650 out of 17198 in 110090.39510416985 seconds
# Processed 10700 out of 17198 in 110312.61039662361 seconds
# Processed 10750 out of 17198 in 110925.20601010323 seconds
# Processed 10800 out of 17198 in 111072.44723176956 seconds
# Processed 10850 out of 17198 in 111295.6295876503 seconds
# Processed 10900 out of 17198 in 111393.83497595787 seconds
# Processed 10950 out of 17198 in 111564.20759248734 seconds
# Processed 11000 out of 17198 in 111729.08391690254 seconds
# Processed 11050 out of 17198 in 112374.56077480316 seconds
# Processed 11100 out of 17198 in 112584.98186945915 seconds
# Processed 11150 out of 17198 in 112912.0064394474 seconds
# Processed 11200 out of 17198 in 113112.77103090286 seconds
# Processed 11250 out of 17198 in 113212.31472539902 seconds
# Processed 11300 out of 17198 in 113456.45735740662 seconds
# Processed 11350 out of 17198 in 113595.54643011093 seconds
# Processed 11400 out of 17198 in 114994.04215860367 seconds
# Processed 11450 out of 17198 in 116771.04082083702 seconds
# Processed 11500 out of 17198 in 117111.92077827454 seconds
# Processed 11550 out of 17198 in 117434.84632468224 seconds
# Processed 11600 out of 17198 in 117858.5700135231 seconds
# Processed 11650 out of 17198 in 118149.15668034554 seconds
# Processed 11700 out of 17198 in 118512.48709845543 seconds
# Processed 11750 out of 17198 in 119026.52535486221 seconds
# Processed 11800 out of 17198 in 119234.60757541656 seconds
# Processed 11850 out of 17198 in 119420.67680573463 seconds
# Processed 11900 out of 17198 in 119584.70499110222 seconds
# Processed 11950 out of 17198 in 120151.3228468895 seconds
# Processed 12000 out of 17198 in 120758.86824536324 seconds
# Processed 12050 out of 17198 in 121574.38004803658 seconds
# Processed 12100 out of 17198 in 122105.20841622353 seconds
# Processed 12150 out of 17198 in 122510.47924375534 seconds
# Processed 12200 out of 17198 in 122972.79998207092 seconds
# Processed 12250 out of 17198 in 123367.0085349083 seconds
# Processed 12300 out of 17198 in 124408.2606048584 seconds
# Processed 12350 out of 17198 in 126045.3294107914 seconds
# Processed 12400 out of 17198 in 126674.05675673485 seconds
# Processed 12450 out of 17198 in 127543.2303416729 seconds
# Processed 12500 out of 17198 in 127740.41056036949 seconds
# Processed 12550 out of 17198 in 128376.83269572258 seconds
# Processed 12600 out of 17198 in 128871.39849448204 seconds
# Processed 12650 out of 17198 in 129541.91515421867 seconds
# Processed 12700 out of 17198 in 129887.9803788662 seconds
# Processed 12750 out of 17198 in 130173.96894907951 seconds
# Processed 12800 out of 17198 in 130592.45343089104 seconds
# Processed 12850 out of 17198 in 131022.86116051674 seconds
# Processed 12900 out of 17198 in 131512.45928621292 seconds
# Processed 12950 out of 17198 in 131889.44085764885 seconds
# Processed 13000 out of 17198 in 132174.6578116417 seconds
# Processed 13050 out of 17198 in 132399.18304896355 seconds
# Processed 13100 out of 17198 in 132638.5040102005 seconds
# Processed 13150 out of 17198 in 132916.7658278942 seconds
# Processed 13200 out of 17198 in 133242.860571146 seconds
# Processed 13250 out of 17198 in 133485.28650856018 seconds
# Processed 13300 out of 17198 in 133721.21923327446 seconds
# Processed 13350 out of 17198 in 133953.05041456223 seconds
# Processed 13400 out of 17198 in 134266.54953670502 seconds
# Processed 13450 out of 17198 in 134689.7872941494 seconds
# Processed 13500 out of 17198 in 135042.40220212936 seconds
# Processed 13550 out of 17198 in 135243.78586554527 seconds
# Processed 13600 out of 17198 in 135492.34378504753 seconds
# Processed 13650 out of 17198 in 135682.69001674652 seconds
# Processed 13700 out of 17198 in 136050.3905558586 seconds
# Processed 13750 out of 17198 in 136658.13433218002 seconds
# Processed 13800 out of 17198 in 136995.40970778465 seconds
# Processed 13850 out of 17198 in 137388.40789985657 seconds
# Processed 13900 out of 17198 in 137899.8441195488 seconds
# Processed 13950 out of 17198 in 138364.14640450478 seconds
# Processed 14000 out of 17198 in 138753.94289398193 seconds
# Processed 14050 out of 17198 in 139033.38784265518 seconds
# Processed 14100 out of 17198 in 139184.55441904068 seconds
# Processed 14150 out of 17198 in 139523.04701924324 seconds
# Processed 14200 out of 17198 in 140251.9378426075 seconds
# Processed 14250 out of 17198 in 140521.1703414917 seconds
# Processed 14300 out of 17198 in 140676.46031928062 seconds
# Processed 14350 out of 17198 in 140857.6522884369 seconds
# Processed 14400 out of 17198 in 141080.41922807693 seconds
# Processed 14450 out of 17198 in 141309.93295669556 seconds
# Processed 14500 out of 17198 in 141515.5367846489 seconds
# Processed 14550 out of 17198 in 141986.29330968857 seconds
# Processed 14600 out of 17198 in 142305.6606247425 seconds
# Processed 14650 out of 17198 in 142921.93016839027 seconds
# Processed 14700 out of 17198 in 143417.22449707985 seconds
# Processed 14750 out of 17198 in 144010.97710943222 seconds
# Processed 14800 out of 17198 in 144516.44910812378 seconds
# Processed 14850 out of 17198 in 144987.70988488197 seconds
# Processed 14900 out of 17198 in 145409.87439084053 seconds
# Processed 14950 out of 17198 in 145968.16922426224 seconds
# Processed 15000 out of 17198 in 146642.1338031292 seconds
# Processed 15050 out of 17198 in 146994.06966662407 seconds
# Processed 15100 out of 17198 in 147718.2478609085 seconds
# Processed 15150 out of 17198 in 148276.20373225212 seconds
# Processed 15200 out of 17198 in 148771.12341046333 seconds
# Processed 15250 out of 17198 in 149215.30526208878 seconds
# Processed 15300 out of 17198 in 149586.31184744835 seconds
# Processed 15350 out of 17198 in 150067.56647634506 seconds
# Processed 15400 out of 17198 in 150523.81234169006 seconds
# Processed 15450 out of 17198 in 151158.04136013985 seconds
# Processed 15500 out of 17198 in 151441.8620402813 seconds
# Processed 15550 out of 17198 in 151479.73945307732 seconds
# Processed 15600 out of 17198 in 151632.02739810944 seconds
# Processed 15650 out of 17198 in 153696.63989377022 seconds
# Processed 15700 out of 17198 in 154427.00868964195 seconds
# Processed 15750 out of 17198 in 154650.42026281357 seconds
# Processed 15800 out of 17198 in 154756.27590560913 seconds
# Processed 15850 out of 17198 in 154800.33278036118 seconds
# Processed 15900 out of 17198 in 154839.29514431953 seconds
# Processed 15950 out of 17198 in 154968.90588474274 seconds
# Processed 16000 out of 17198 in 155049.85355591774 seconds
# Processed 16050 out of 17198 in 155326.81208753586 seconds
# Processed 16100 out of 17198 in 155510.64796471596 seconds
# Processed 16150 out of 17198 in 155564.5204424858 seconds
# Processed 16200 out of 17198 in 155594.95234704018 seconds
# Processed 16250 out of 17198 in 155651.80428242683 seconds
# Processed 16300 out of 17198 in 155829.20576882362 seconds
# Processed 16350 out of 17198 in 156018.28698468208 seconds
# Processed 16400 out of 17198 in 156082.53989171982 seconds
# Processed 16450 out of 17198 in 156275.87555909157 seconds
# Processed 16500 out of 17198 in 156440.78103733063 seconds
# Processed 16550 out of 17198 in 156470.09138941765 seconds
# Processed 16600 out of 17198 in 156566.71679353714 seconds
# Processed 16650 out of 17198 in 156598.9349155426 seconds
# Processed 16700 out of 17198 in 156706.22541546822 seconds
# Processed 16750 out of 17198 in 156896.92973065376 seconds
# Processed 16800 out of 17198 in 157020.70760941505 seconds
# Processed 16850 out of 17198 in 157061.91196990013 seconds
# Processed 16900 out of 17198 in 157151.14522647858 seconds
# Processed 16950 out of 17198 in 157184.037460804 seconds
# Processed 17000 out of 17198 in 157294.3847978115 seconds
# Processed 17050 out of 17198 in 157413.83214330673 seconds
# Processed 17100 out of 17198 in 157514.40595722198 seconds
# Processed 17150 out of 17198 in 157654.12651634216 seconds
# Processed 17198 out of 17198 in 157770.80050969124 seconds
