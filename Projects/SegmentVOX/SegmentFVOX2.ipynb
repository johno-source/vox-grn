# %% [markdown]
# # Partial Process of Segment GRN Data for vox-grn
#
# To speed up processing the files have been broken into 10 groups and processed in parallel.
#
# # Data to be Created
#
# Three sets of data will be made, 4, 6, and 10 second data.
#
# This file will take a long time to run. For that reason it will check point its progress at regular intervals by writing smaller files. If its progress is restarted for any reason it will use those files to determine where it was up to. Segmenting the data is the slow part. For each audio file a segment file will be generated. If mp3 files are to be generated later using different parameters the segmented files should make the process much quicker.
#
# The input to this process is all_items_for_processing.csv with musical items removed.
#
# The output will be:
#
#     1. /media/originals/fsegs/[iso]/[filename].pkl
#         where each pkl file contains the list of raw segments for the item.
#     2. /media/originals/fsegs/seg_4sec.csv
#         all the metadata for the seg_4sec dataset. Metadata needed for the dataset can be derived from this.
#     3. /media/originals/fsegs/seg_6sec.csv
#         all the metadata for the seg_6sec dataset. Metadata needed for the dataset can be derived from this.
#     4. /media/originals/fsegs/seg_10sec.csv
#         all the metadata for the seg_10sec dataset. Metadata needed for the dataset can be derived from this.
#     5. /media/originals/datasets/fseg_4sec/data/[iso]/[program_id]_[item_no]_[seg].mp3
#         which is an mp3 for each segment
#     6. /media/originals/datasets/fseg_6sec/data/[iso]/[program_id]_[item_no]_[seg].mp3
#         which is an mp3 for each segment
#     7. /media/originals/datasets/fseg_10sec/data/[iso]/[program_id]_[item_no]_[seg].mp3
#         which is an mp3 for each segment

# %%
import pandas as pd
import numpy as np
import os
import sys
module_path = os.path.abspath(os.path.join('../vad_utils'))
if module_path not in sys.path:
    sys.path.append(module_path)
from vad_utils import SAMPLING_RATE, FRAME_SIZE_MS, SAMPLES_PER_FRAME
import vad_utils as vu
from pydub import AudioSegment
import pickle as pkl
from pathlib import Path
import time
import glob

# %%
# define the locations for each of the file types
NOTEBOOK_ID=2
SEGMENTS_DIR = '/media/originals/fsegs/'
DATASETS_DIR = '/media/originals/datasets/'
SEC_4_DATA_DIR = 'fseg_4sec/data/'
SEC_6_DATA_DIR = 'fseg_6sec/data/'
SEC_10_DATA_DIR = 'fseg_10sec/data/'

# define specific files used in the process
SEG_4_SEC_DF = f'{SEGMENTS_DIR}seg_4sec_{NOTEBOOK_ID}.csv'
SEG_6_SEC_DF = f'{SEGMENTS_DIR}seg_6sec_{NOTEBOOK_ID}.csv'
SEG_10_SEC_DF = f'{SEGMENTS_DIR}seg_10sec_{NOTEBOOK_ID}.csv'

# define segment sizes for each dataset
SEG_4_SEC = 4.0
SEG_6_SEC = 6.0
SEG_10_SEC = 10.0

# %%
# Now read in the description of the input and remove the unwanted columns and rename the rest to be python attribute names.
fd = pd.read_csv(f'/media/originals/fsegs/files_{NOTEBOOK_ID}.csv')
fd.set_index('ID', inplace=True)
fd.columns
# Out:
# Index(['Unnamed: 0', 'iso', 'language_name', 'track', 'location', 'year',
#        'path', 'filename', 'length', 'program'],
#       dtype='object')

# %%
print(fd.iloc[100])
# Out:
# Unnamed: 0                                                   16258
# iso                                                            duu
# language_name                                                Drung
# track                                                           11
# location                                                   Nujiang
# year                                                        2001.0
# path                             Programs/31/31860/A31860/From_CM/
# filename         C31860B Region 00_06_16_234 to 00_07_24_757 (0...
# length                                                   68.522667
# program                                                      31860
# Name: 31860_011, dtype: object

# %%
print(fd.index)
# Out:
# Index(['64418_019', '64418_030', '64418_017', '64418_016', '64418_031',
#        '64418_011', '64418_032', '64418_034', '64418_013', '64418_014',
#        ...
#        '74542_002', '74541_021', '74541_020', '74541_019', '10810_001',
#        '10810_002', '74541_031', '74541_035', '74541_034', '74541_018'],
#       dtype='object', name='ID', length=20837)

# %%
# generate directories and filenames
def prepare_dir(dirname):
    if dirname[-1] != '/':
        dirname = dirname + '/'
    Path(dirname).mkdir(parents=True, exist_ok=True)
    return dirname

def prepare_raw_seg_dir(fd):
    return prepare_dir(SEGMENTS_DIR + fd.iso)

def raw_seg_filename(fd):
    return f'{fd.filename}.pkl'

def prepare_dataset_data_dir(fd, dataset_dir):
    return prepare_dir(DATASETS_DIR + dataset_dir + fd.iso)

def seg_mp3_filename(fd, seg):
    return f'{fd.filename[:-4]}_{seg:03d}.mp3'

def get_fname(fd):
    path = fd.path
    if path[-1] != '/':
        path = path + '/'
    files = glob.glob('/media/programs/' + path + fd.filename.replace('\ufffd', '*'))
    if len(files) == 1:
        return files[0]
    return '/media/programs/' + path + fd.filename

# %%
def condition_audio_segment(audio_seg):
    if audio_seg.channels != 1:
        audio_seg = audio_seg.set_channels(1)

    if audio_seg.sample_width != 2:
        audio_seg = audio_seg.set_sample_width(2)

    if audio_seg.frame_rate != SAMPLING_RATE:
        audio_seg = audio_seg.set_frame_rate(SAMPLING_RATE)

    return audio_seg

# %%
def save_the_segment_info(fd, segs):
    fname = prepare_raw_seg_dir(fd) + raw_seg_filename(fd)
    with open(fname, 'wb') as pklFile:
         pkl.dump(segs, pklFile)

def read_the_segment_info(fd):
    fname = prepare_raw_seg_dir(fd) + raw_seg_filename(fd)
    if os.path.exists(fname):
        if os.path.getsize(fname) > 0:
            with open(fname, 'rb') as pklFile:
                return pkl.load(pklFile)
    return []
    
def extract_audio_segments_for_file(fd):
    fmt = 'wav'
    if fd.filename[-4:].lower() == '.mp3' :
        fmt = 'mp3'
    audio_seg = AudioSegment.from_file(get_fname(fd), format=fmt)

    # now condition the segment and extract the raw segments.
    audio_seg = condition_audio_segment(audio_seg)
    segs = read_the_segment_info(fd)
    if len(segs) == 0:
        segs = vu.audio_to_raw_voice_segments(audio_seg)
        save_the_segment_info(fd, segs)

    return audio_seg, segs

def create_mp3_files(audio_seg, segs, time_per_segment, dataset_dir, fd):
    segs_for_time = vu.divide_into_segments(segs, time_per_segment)

    # now write out the 4 sec segments
    dirname = prepare_dataset_data_dir(fd, dataset_dir)
    rows = list()

    # note that we discard the first segment
    if len(segs_for_time) > 1:
        for i, seg in enumerate(segs_for_time[1:]):
            file_name = dataset_dir + fd.iso + '/' + seg_mp3_filename(fd, i)
            fname = dirname + seg_mp3_filename(fd, i)
            if not os.path.exists(fname):
                start = vu.convert_frames_to_ms(seg.start)
                stop = vu.convert_frames_to_ms(seg.stop)
                audio_seg[start:stop].export(fname, format='mp3', bitrate='32k')
            desc = dict(fd._asdict())
            desc['seg_start'] = vu.convert_frames_to_seconds(seg.start)
            desc['seg_stop'] = vu.convert_frames_to_seconds(seg.stop)
            desc['seg'] = i
            desc['file_name'] = file_name
            rows.append(desc)

    return rows

def update_dataframes(seg_df_csv, seg_records):
    # now update the dataframes
    if len(seg_records) > 0:
        if os.path.isfile(seg_df_csv):
            seg_sec_df = pd.concat([pd.read_csv(seg_df_csv, index_col='file_name'), pd.DataFrame.from_records(seg_records, index='file_name')])
        else:
            seg_sec_df = pd.DataFrame.from_records(seg_records, index='file_name')
        seg_sec_df.to_csv(seg_df_csv)

# %%
# processing these items might take a very long time. To permit the process to be interrupted and restarted the indexes of processed items
# are maintained in a set that is pickled on each batch. This allows the batch to quickly pick up where it left off.
def process_record_batch(files_df, *, batch_size=10):
    batch_proc = 0
    processed_file = f'/media/originals/fsegs/processed16_{NOTEBOOK_ID}.pkl'
    if os.path.isfile(processed_file):
        with open(processed_file, 'rb') as pklFile:
            processed_files = pkl.load(pklFile)
    else:
        processed_files = set()

    segmented_4sec_segs = []
    segmented_6sec_segs = []
    segmented_10sec_segs = []

    for fd in files_df.itertuples():
        if batch_proc < batch_size:
            if fd.Index not in processed_files:
                try:
                    audio_seg, voice_segs = extract_audio_segments_for_file(fd)
                    segmented_4sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_4_SEC, SEC_4_DATA_DIR, fd))
                    segmented_6sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_6_SEC, SEC_6_DATA_DIR, fd))
                    segmented_10sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_10_SEC, SEC_10_DATA_DIR, fd))
                except:
                    print(f'exception {fd.filename}')
                    pass

                # we want to add an fd that has an exception so it is not reprocessed on every batch
                processed_files.add(fd.Index)
                batch_proc += 1

        else:
            break

    update_dataframes(SEG_4_SEC_DF, segmented_4sec_segs)
    update_dataframes(SEG_6_SEC_DF, segmented_6sec_segs)
    update_dataframes(SEG_10_SEC_DF, segmented_10sec_segs)

    with open(processed_file, 'wb') as pklFile:
        pkl.dump(processed_files, pklFile)

    return processed_files

# %%
start_time = time.time()
# form the language classification file
files_processed = 0
files_to_process = len(fd)
while files_to_process > files_processed:
    processed_files = process_record_batch(fd, batch_size=50)
    files_processed = len(processed_files)
    print(f'Processed {files_processed} out of {files_to_process} in {time.time()-start_time} seconds')
# Out:
# Processed 50 out of 20837 in 529.7877616882324 seconds
# Processed 100 out of 20837 in 1224.503234386444 seconds
# Processed 150 out of 20837 in 1440.7363302707672 seconds
# Processed 200 out of 20837 in 2264.6368448734283 seconds
# Processed 250 out of 20837 in 2439.598725795746 seconds
# Processed 300 out of 20837 in 2747.858740568161 seconds
# Processed 350 out of 20837 in 3088.296182870865 seconds
# Processed 400 out of 20837 in 3374.780348777771 seconds
# Processed 450 out of 20837 in 3541.9610612392426 seconds
# Processed 500 out of 20837 in 3718.4323172569275 seconds
# Processed 550 out of 20837 in 3824.746838092804 seconds
# Processed 600 out of 20837 in 4193.327301740646 seconds
# Processed 650 out of 20837 in 4623.998021602631 seconds
# Processed 700 out of 20837 in 4744.323668956757 seconds
# Processed 750 out of 20837 in 4887.376298427582 seconds
# Processed 800 out of 20837 in 4951.294691324234 seconds
# Processed 850 out of 20837 in 5098.947714328766 seconds
# Processed 900 out of 20837 in 5300.090702295303 seconds
# Processed 950 out of 20837 in 5532.433360815048 seconds
# Processed 1000 out of 20837 in 5727.4381856918335 seconds
# Processed 1050 out of 20837 in 5840.450413227081 seconds
# Processed 1100 out of 20837 in 6005.152312040329 seconds
# Processed 1150 out of 20837 in 6164.075300216675 seconds
# Processed 1200 out of 20837 in 6312.7225296497345 seconds
# Processed 1250 out of 20837 in 6409.349648237228 seconds
# Processed 1300 out of 20837 in 6671.168927192688 seconds
# Processed 1350 out of 20837 in 7240.389885425568 seconds
# Processed 1400 out of 20837 in 7920.179879665375 seconds
# Processed 1450 out of 20837 in 8572.229890823364 seconds
# Processed 1500 out of 20837 in 9038.405878782272 seconds
# Processed 1550 out of 20837 in 9244.62321805954 seconds
# Processed 1600 out of 20837 in 9611.327105522156 seconds
# Processed 1650 out of 20837 in 10376.273852825165 seconds
# Processed 1700 out of 20837 in 10535.846507549286 seconds
# Processed 1750 out of 20837 in 10719.027922153473 seconds
# Processed 1800 out of 20837 in 10898.448690652847 seconds
# Processed 1850 out of 20837 in 11259.85755443573 seconds
# Processed 1900 out of 20837 in 11528.04760670662 seconds
# Processed 1950 out of 20837 in 11827.991698503494 seconds
# Processed 2000 out of 20837 in 12252.351607561111 seconds
# Processed 2050 out of 20837 in 12642.160781860352 seconds
# Processed 2100 out of 20837 in 12823.91004729271 seconds
# Processed 2150 out of 20837 in 13476.452774047852 seconds
# Processed 2200 out of 20837 in 13898.482585191727 seconds
# Processed 2250 out of 20837 in 14327.705447673798 seconds
# Processed 2300 out of 20837 in 14588.438249826431 seconds
# Processed 2350 out of 20837 in 14831.18530869484 seconds
# Processed 2400 out of 20837 in 15033.009461164474 seconds
# Processed 2450 out of 20837 in 15261.727924346924 seconds
# Processed 2500 out of 20837 in 15626.623688697815 seconds
# Processed 2550 out of 20837 in 16219.257168293 seconds
# Processed 2600 out of 20837 in 16696.20266342163 seconds
# Processed 2650 out of 20837 in 16826.646189689636 seconds
# Processed 2700 out of 20837 in 17015.43673467636 seconds
# Processed 2750 out of 20837 in 17335.81162405014 seconds
# Processed 2800 out of 20837 in 17455.901884794235 seconds
# Processed 2850 out of 20837 in 17956.38763666153 seconds
# Processed 2900 out of 20837 in 18371.15908241272 seconds
# Processed 2950 out of 20837 in 18882.04398083687 seconds
# Processed 3000 out of 20837 in 19456.907638311386 seconds
# Processed 3050 out of 20837 in 19774.267157793045 seconds
# Processed 3100 out of 20837 in 20152.23393726349 seconds
# Processed 3150 out of 20837 in 20638.54943752289 seconds
# Processed 3200 out of 20837 in 20998.592550992966 seconds
# Processed 3250 out of 20837 in 21352.010743379593 seconds
# Processed 3300 out of 20837 in 21765.84766149521 seconds
# Processed 3350 out of 20837 in 22297.79365992546 seconds
# Processed 3400 out of 20837 in 22746.351165294647 seconds
# Processed 3450 out of 20837 in 22890.637888669968 seconds
# Processed 3500 out of 20837 in 23091.773454904556 seconds
# Processed 3550 out of 20837 in 23552.08430480957 seconds
# Processed 3600 out of 20837 in 23979.864414215088 seconds
# Processed 3650 out of 20837 in 24254.077970266342 seconds
# Processed 3700 out of 20837 in 24526.03076839447 seconds
# Processed 3750 out of 20837 in 24849.77758193016 seconds
# Processed 3800 out of 20837 in 25313.19676566124 seconds
# Processed 3850 out of 20837 in 25730.15128302574 seconds
# Processed 3900 out of 20837 in 26019.337698698044 seconds
# Processed 3950 out of 20837 in 26188.85693669319 seconds
# Processed 4000 out of 20837 in 26400.701637029648 seconds
# Processed 4050 out of 20837 in 26799.82962679863 seconds
# Processed 4100 out of 20837 in 27478.777232170105 seconds
# Processed 4150 out of 20837 in 27828.919214487076 seconds
# Processed 4200 out of 20837 in 28109.27564048767 seconds
# Processed 4250 out of 20837 in 28605.00713658333 seconds
# Processed 4300 out of 20837 in 29020.602789640427 seconds
# Processed 4350 out of 20837 in 29446.808341264725 seconds
# Processed 4400 out of 20837 in 29809.409821748734 seconds
# Processed 4450 out of 20837 in 30213.6882083416 seconds
# Processed 4500 out of 20837 in 30733.08842110634 seconds
# Processed 4550 out of 20837 in 31313.23701763153 seconds
# Processed 4600 out of 20837 in 31533.499131202698 seconds
# Processed 4650 out of 20837 in 31740.93238544464 seconds
# Processed 4700 out of 20837 in 32067.322839975357 seconds
# Processed 4750 out of 20837 in 32946.294337034225 seconds
# Processed 4800 out of 20837 in 33720.50349974632 seconds
# Processed 4850 out of 20837 in 34483.12986898422 seconds
# Processed 4900 out of 20837 in 34745.80620217323 seconds
# Processed 4950 out of 20837 in 36578.49599647522 seconds
# Processed 5000 out of 20837 in 37244.94505953789 seconds
# Processed 5050 out of 20837 in 37888.95448303223 seconds
# Processed 5100 out of 20837 in 38404.43313622475 seconds
# Processed 5150 out of 20837 in 38742.944371938705 seconds
# Processed 5200 out of 20837 in 39588.11084699631 seconds
# Processed 5250 out of 20837 in 40182.46827459335 seconds
# Processed 5300 out of 20837 in 40459.35881733894 seconds
# Processed 5350 out of 20837 in 40990.491844415665 seconds
# Processed 5400 out of 20837 in 41257.39612579346 seconds
# Processed 5450 out of 20837 in 41541.15683031082 seconds
# Processed 5500 out of 20837 in 41857.786291599274 seconds
# Processed 5550 out of 20837 in 42211.44682312012 seconds
# Processed 5600 out of 20837 in 42631.083851099014 seconds
# Processed 5650 out of 20837 in 43206.413860321045 seconds
# Processed 5700 out of 20837 in 43409.05635333061 seconds
# Processed 5750 out of 20837 in 43621.60380196571 seconds
# Processed 5800 out of 20837 in 44032.1971783638 seconds
# Processed 5850 out of 20837 in 44512.53691005707 seconds
# Processed 5900 out of 20837 in 44616.30929684639 seconds
# Processed 5950 out of 20837 in 45171.81713843346 seconds
# Processed 6000 out of 20837 in 45529.923446178436 seconds
# Processed 6050 out of 20837 in 46061.84272766113 seconds
# Processed 6100 out of 20837 in 46721.809034347534 seconds
# Processed 6150 out of 20837 in 47092.86663103104 seconds
# Processed 6200 out of 20837 in 47260.1402323246 seconds
# Processed 6250 out of 20837 in 47430.2668902874 seconds
# Processed 6300 out of 20837 in 47741.07532405853 seconds
# Processed 6350 out of 20837 in 48050.66139817238 seconds
# Processed 6400 out of 20837 in 48283.51225042343 seconds
# Processed 6450 out of 20837 in 48496.60746216774 seconds
# Processed 6500 out of 20837 in 48691.09240055084 seconds
# Processed 6550 out of 20837 in 48903.63674855232 seconds
# Processed 6600 out of 20837 in 49191.49650120735 seconds
# Processed 6650 out of 20837 in 49536.01753783226 seconds
# Processed 6700 out of 20837 in 49755.77511382103 seconds
# Processed 6750 out of 20837 in 50070.28944969177 seconds
# Processed 6800 out of 20837 in 50339.029138326645 seconds
# Processed 6850 out of 20837 in 50591.240881443024 seconds
# Processed 6900 out of 20837 in 50808.94859075546 seconds
# Processed 6950 out of 20837 in 51056.70437002182 seconds
# Processed 7000 out of 20837 in 51719.6036131382 seconds
# Processed 7050 out of 20837 in 51926.318967580795 seconds
# Processed 7100 out of 20837 in 52275.243086099625 seconds
# Processed 7150 out of 20837 in 52701.83481788635 seconds
# Processed 7200 out of 20837 in 53032.98839569092 seconds
# Processed 7250 out of 20837 in 53205.798614025116 seconds
# Processed 7300 out of 20837 in 53405.67421030998 seconds
# Processed 7350 out of 20837 in 53829.97725439072 seconds
# Processed 7400 out of 20837 in 54498.416111946106 seconds
# Processed 7450 out of 20837 in 54892.49631690979 seconds
# Processed 7500 out of 20837 in 55035.2713971138 seconds
# Processed 7550 out of 20837 in 55298.40373802185 seconds
# Processed 7600 out of 20837 in 55673.67743897438 seconds
# Processed 7650 out of 20837 in 56309.33211040497 seconds
# Processed 7700 out of 20837 in 56929.2101726532 seconds
# Processed 7750 out of 20837 in 57247.06561136246 seconds
# Processed 7800 out of 20837 in 58042.76511192322 seconds
# Processed 7850 out of 20837 in 58350.138962984085 seconds
# Processed 7900 out of 20837 in 58856.73195648193 seconds
# Processed 7950 out of 20837 in 59279.56130743027 seconds
# Processed 8000 out of 20837 in 59708.5605096817 seconds
# Processed 8050 out of 20837 in 60181.11192679405 seconds
# Processed 8100 out of 20837 in 60582.436698913574 seconds
# Processed 8150 out of 20837 in 61087.236590623856 seconds
# Processed 8200 out of 20837 in 61344.639672756195 seconds
# Processed 8250 out of 20837 in 61668.29016041756 seconds
# Processed 8300 out of 20837 in 61952.34211397171 seconds
# Processed 8350 out of 20837 in 62053.12538909912 seconds
# Processed 8400 out of 20837 in 62344.17146062851 seconds
# Processed 8450 out of 20837 in 62579.17028713226 seconds
# Processed 8500 out of 20837 in 62719.82422089577 seconds
# Processed 8550 out of 20837 in 62987.43339776993 seconds
# Processed 8600 out of 20837 in 63202.45355606079 seconds
# Processed 8650 out of 20837 in 63380.07863974571 seconds
# Processed 8700 out of 20837 in 63667.68638134003 seconds
# Processed 8750 out of 20837 in 64518.131989479065 seconds
# Processed 8800 out of 20837 in 64971.369777441025 seconds
# Processed 8850 out of 20837 in 65507.91429424286 seconds
# Processed 8900 out of 20837 in 65985.85424923897 seconds
# Processed 8950 out of 20837 in 66429.5758292675 seconds
# Processed 9000 out of 20837 in 66737.5493338108 seconds
# Processed 9050 out of 20837 in 67085.50492501259 seconds
# Processed 9100 out of 20837 in 67452.95448875427 seconds
# Processed 9150 out of 20837 in 67754.28483533859 seconds
# Processed 9200 out of 20837 in 68054.71041560173 seconds
# Processed 9250 out of 20837 in 68215.17097687721 seconds
# Processed 9300 out of 20837 in 68422.62159538269 seconds
# Processed 9350 out of 20837 in 68601.783046484 seconds
# Processed 9400 out of 20837 in 68861.88131165504 seconds
# Processed 9450 out of 20837 in 69130.09091472626 seconds
# Processed 9500 out of 20837 in 69351.7572593689 seconds
# Processed 9550 out of 20837 in 69525.16299247742 seconds
# Processed 9600 out of 20837 in 69693.29941248894 seconds
# Processed 9650 out of 20837 in 69921.89946937561 seconds
# Processed 9700 out of 20837 in 70070.39071798325 seconds
# Processed 9750 out of 20837 in 70235.9566526413 seconds
# Processed 9800 out of 20837 in 70408.89608693123 seconds
# Processed 9850 out of 20837 in 70629.33415865898 seconds
# Processed 9900 out of 20837 in 70818.05445599556 seconds
# Processed 9950 out of 20837 in 71204.04856276512 seconds
# Processed 10000 out of 20837 in 71472.14426922798 seconds
# Processed 10050 out of 20837 in 71732.91347551346 seconds
# Processed 10100 out of 20837 in 72300.58183979988 seconds
# Processed 10150 out of 20837 in 73034.81429052353 seconds
# Processed 10200 out of 20837 in 74075.2506723404 seconds
# Processed 10250 out of 20837 in 74838.28753733635 seconds
# Processed 10300 out of 20837 in 75075.9436955452 seconds
# Processed 10350 out of 20837 in 75327.78459453583 seconds
# Processed 10400 out of 20837 in 75582.32311224937 seconds
# Processed 10450 out of 20837 in 75837.07472681999 seconds
# Processed 10500 out of 20837 in 76208.16067886353 seconds
# Processed 10550 out of 20837 in 76691.86906933784 seconds
# Processed 10600 out of 20837 in 77486.89878249168 seconds
# Processed 10650 out of 20837 in 77876.87930512428 seconds
# Processed 10700 out of 20837 in 78209.57364368439 seconds
# Processed 10750 out of 20837 in 78571.88158249855 seconds
# Processed 10800 out of 20837 in 79478.87171769142 seconds
# Processed 10850 out of 20837 in 80038.68335032463 seconds
# Processed 10900 out of 20837 in 80730.27760648727 seconds
# Processed 10950 out of 20837 in 81891.67513012886 seconds
# Processed 11000 out of 20837 in 82583.02092289925 seconds
# Processed 11050 out of 20837 in 83546.60071349144 seconds
# Processed 11100 out of 20837 in 83723.92911052704 seconds
# Processed 11150 out of 20837 in 83838.04114198685 seconds
# Processed 11200 out of 20837 in 83990.00737333298 seconds
# Processed 11250 out of 20837 in 84298.08224487305 seconds
# Processed 11300 out of 20837 in 84769.48252677917 seconds
# Processed 11350 out of 20837 in 85329.69820952415 seconds
# Processed 11400 out of 20837 in 85857.19095396996 seconds
# Processed 11450 out of 20837 in 86320.06136608124 seconds
# Processed 11500 out of 20837 in 86637.6389670372 seconds
# Processed 11550 out of 20837 in 87292.30890345573 seconds
# Processed 11600 out of 20837 in 87667.52028083801 seconds
# Processed 11650 out of 20837 in 87863.39821529388 seconds
# Processed 11700 out of 20837 in 88115.18423080444 seconds
# Processed 11750 out of 20837 in 88329.93968892097 seconds
# Processed 11800 out of 20837 in 88547.75532364845 seconds
# Processed 11850 out of 20837 in 88878.66503667831 seconds
# Processed 11900 out of 20837 in 89184.86147594452 seconds
# Processed 11950 out of 20837 in 89764.3882689476 seconds
# Processed 12000 out of 20837 in 90301.97494077682 seconds
# Processed 12050 out of 20837 in 90808.25559282303 seconds
# Processed 12100 out of 20837 in 91107.27345943451 seconds
# Processed 12150 out of 20837 in 91430.15477991104 seconds
# Processed 12200 out of 20837 in 91988.31380796432 seconds
# Processed 12250 out of 20837 in 92112.53749155998 seconds
# Processed 12300 out of 20837 in 92307.56943655014 seconds
# Processed 12350 out of 20837 in 92850.66163396835 seconds
# Processed 12400 out of 20837 in 93622.46748924255 seconds
# Processed 12450 out of 20837 in 94005.23015069962 seconds
# Processed 12500 out of 20837 in 94892.45138978958 seconds
# Processed 12550 out of 20837 in 95213.8053894043 seconds
# Processed 12600 out of 20837 in 95490.76750993729 seconds
# Processed 12650 out of 20837 in 96111.92772936821 seconds
# Processed 12700 out of 20837 in 96458.52984499931 seconds
# Processed 12750 out of 20837 in 96826.08587646484 seconds
# Processed 12800 out of 20837 in 97081.74980211258 seconds
# Processed 12850 out of 20837 in 97427.60903716087 seconds
# Processed 12900 out of 20837 in 97883.40383458138 seconds
# Processed 12950 out of 20837 in 98677.70605993271 seconds
# Processed 13000 out of 20837 in 98851.46705293655 seconds
# Processed 13050 out of 20837 in 99117.10289239883 seconds
# Processed 13100 out of 20837 in 99392.45474386215 seconds
# Processed 13150 out of 20837 in 99670.87354040146 seconds
# Processed 13200 out of 20837 in 99968.47083544731 seconds
# Processed 13250 out of 20837 in 100238.48903775215 seconds
# Processed 13300 out of 20837 in 100635.12548136711 seconds
# Processed 13350 out of 20837 in 101026.81128168106 seconds
# Processed 13400 out of 20837 in 101497.5086505413 seconds
# Processed 13450 out of 20837 in 101706.30427265167 seconds
# Processed 13500 out of 20837 in 102073.43867754936 seconds
# Processed 13550 out of 20837 in 102534.19739723206 seconds
# Processed 13600 out of 20837 in 102779.59153699875 seconds
# Processed 13650 out of 20837 in 102999.7194674015 seconds
# Processed 13700 out of 20837 in 103369.62704086304 seconds
# Processed 13750 out of 20837 in 103670.93839883804 seconds
# Processed 13800 out of 20837 in 103884.72764706612 seconds
# Processed 13850 out of 20837 in 104062.88717746735 seconds
# Processed 13900 out of 20837 in 104569.93028593063 seconds
# Processed 13950 out of 20837 in 104780.08641314507 seconds
# Processed 14000 out of 20837 in 105574.22284626961 seconds
# Processed 14050 out of 20837 in 106319.42617368698 seconds
# Processed 14100 out of 20837 in 106759.28759551048 seconds
# Processed 14150 out of 20837 in 106980.67938637733 seconds
# Processed 14200 out of 20837 in 107846.04641008377 seconds
# Processed 14250 out of 20837 in 108053.2954967022 seconds
# Processed 14300 out of 20837 in 108162.2114815712 seconds
# Processed 14350 out of 20837 in 108668.61890363693 seconds
# Processed 14400 out of 20837 in 108780.63871502876 seconds
# Processed 14450 out of 20837 in 109107.87968206406 seconds
# Processed 14500 out of 20837 in 109329.59191465378 seconds
# Processed 14550 out of 20837 in 109634.30188703537 seconds
# Processed 14600 out of 20837 in 110056.9185655117 seconds
# Processed 14650 out of 20837 in 110238.21052908897 seconds
# Processed 14700 out of 20837 in 110434.87483811378 seconds
# Processed 14750 out of 20837 in 111185.44286084175 seconds
# Processed 14800 out of 20837 in 111725.53338861465 seconds
# Processed 14850 out of 20837 in 111899.09110021591 seconds
# Processed 14900 out of 20837 in 112200.64847135544 seconds
# Processed 14950 out of 20837 in 112586.77058434486 seconds
# Processed 15000 out of 20837 in 113033.07517886162 seconds
# Processed 15050 out of 20837 in 113230.30400323868 seconds
# Processed 15100 out of 20837 in 113674.93692493439 seconds
# Processed 15150 out of 20837 in 114552.35373401642 seconds
# Processed 15200 out of 20837 in 115675.14823794365 seconds
# Processed 15250 out of 20837 in 116005.86648201942 seconds
# Processed 15300 out of 20837 in 116533.79972553253 seconds
# Processed 15350 out of 20837 in 117020.23463606834 seconds
# Processed 15400 out of 20837 in 117313.76004433632 seconds
# Processed 15450 out of 20837 in 117708.65575695038 seconds
# Processed 15500 out of 20837 in 118409.1213042736 seconds
# Processed 15550 out of 20837 in 119128.66868066788 seconds
# Processed 15600 out of 20837 in 119588.71264433861 seconds
# Processed 15650 out of 20837 in 120412.78246617317 seconds
# Processed 15700 out of 20837 in 120778.30268764496 seconds
# Processed 15750 out of 20837 in 121168.75162124634 seconds
# Processed 15800 out of 20837 in 121467.1382265091 seconds
# Processed 15850 out of 20837 in 121701.62880158424 seconds
# Processed 15900 out of 20837 in 121858.24382257462 seconds
# Processed 15950 out of 20837 in 121968.3629348278 seconds
# Processed 16000 out of 20837 in 122143.3780810833 seconds
# Processed 16050 out of 20837 in 122664.45065760612 seconds
# Processed 16100 out of 20837 in 122788.8699851036 seconds
# Processed 16150 out of 20837 in 122938.6299688816 seconds
# Processed 16200 out of 20837 in 123425.74177765846 seconds
# Processed 16250 out of 20837 in 123919.29289197922 seconds
# Processed 16300 out of 20837 in 124365.339458704 seconds
# Processed 16350 out of 20837 in 124711.5969042778 seconds
# Processed 16400 out of 20837 in 125087.22073554993 seconds
# Processed 16450 out of 20837 in 125398.95610785484 seconds
# Processed 16500 out of 20837 in 125774.16416859627 seconds
# Processed 16550 out of 20837 in 126160.91654801369 seconds
# Processed 16600 out of 20837 in 126913.37640500069 seconds
# Processed 16650 out of 20837 in 127565.67475032806 seconds
# Processed 16700 out of 20837 in 127781.81452965736 seconds
# Processed 16750 out of 20837 in 128013.6180036068 seconds
# Processed 16800 out of 20837 in 128297.55130553246 seconds
# Processed 16850 out of 20837 in 128492.16347336769 seconds
# Processed 16900 out of 20837 in 128867.39877963066 seconds
# Processed 16950 out of 20837 in 129159.60266947746 seconds
# Processed 17000 out of 20837 in 129511.10011458397 seconds
# Processed 17050 out of 20837 in 129906.97121572495 seconds
# Processed 17100 out of 20837 in 130290.8559525013 seconds
# Processed 17150 out of 20837 in 131179.37643527985 seconds
# Processed 17200 out of 20837 in 132147.9079387188 seconds
# Processed 17250 out of 20837 in 132599.03751325607 seconds
# Processed 17300 out of 20837 in 132839.27237057686 seconds
# Processed 17350 out of 20837 in 133112.75247502327 seconds
# Processed 17400 out of 20837 in 133374.38173794746 seconds
# Processed 17450 out of 20837 in 133534.95663118362 seconds
# Processed 17500 out of 20837 in 133899.6098906994 seconds
# Processed 17550 out of 20837 in 134068.07889008522 seconds
# Processed 17600 out of 20837 in 134498.07824730873 seconds
# Processed 17650 out of 20837 in 134851.61055660248 seconds
# Processed 17700 out of 20837 in 135489.60894083977 seconds
# Processed 17750 out of 20837 in 136165.47837352753 seconds
# Processed 17800 out of 20837 in 136369.24515342712 seconds
# Processed 17850 out of 20837 in 136609.1335363388 seconds
# Processed 17900 out of 20837 in 136866.09308362007 seconds
# Processed 17950 out of 20837 in 137435.343937397 seconds
# Processed 18000 out of 20837 in 138221.40102148056 seconds
# Processed 18050 out of 20837 in 138914.74623918533 seconds
# Processed 18100 out of 20837 in 139344.1613330841 seconds
# Processed 18150 out of 20837 in 139669.6128065586 seconds
# Processed 18200 out of 20837 in 140263.87862491608 seconds
# Processed 18250 out of 20837 in 141651.3096561432 seconds
# Processed 18300 out of 20837 in 142546.40740919113 seconds
# Processed 18350 out of 20837 in 143349.62833881378 seconds
# Processed 18400 out of 20837 in 146261.53391051292 seconds
# Processed 18450 out of 20837 in 147299.92149853706 seconds
# Processed 18500 out of 20837 in 148249.18182468414 seconds
# Processed 18550 out of 20837 in 149260.43507933617 seconds
# Processed 18600 out of 20837 in 150964.27440309525 seconds
# Processed 18650 out of 20837 in 151754.43299126625 seconds
# Processed 18700 out of 20837 in 151949.24114584923 seconds
# Processed 18750 out of 20837 in 152476.2130253315 seconds
# Processed 18800 out of 20837 in 153804.8661687374 seconds
# Processed 18850 out of 20837 in 154132.4451816082 seconds
# Processed 18900 out of 20837 in 154481.11261487007 seconds
# Processed 18950 out of 20837 in 154736.59955835342 seconds
# Processed 19000 out of 20837 in 155012.2848212719 seconds
# Processed 19050 out of 20837 in 155380.99540901184 seconds
# Processed 19100 out of 20837 in 155785.59076595306 seconds
# Processed 19150 out of 20837 in 156223.80990576744 seconds
# Processed 19200 out of 20837 in 157162.709389925 seconds
# Processed 19250 out of 20837 in 157786.80596399307 seconds
# Processed 19300 out of 20837 in 158246.47368836403 seconds
# Processed 19350 out of 20837 in 158374.76786017418 seconds
# Processed 19400 out of 20837 in 158971.59580016136 seconds
# Processed 19450 out of 20837 in 159406.5741789341 seconds
# Processed 19500 out of 20837 in 159696.68319940567 seconds
# Processed 19550 out of 20837 in 161026.76984214783 seconds
# Processed 19600 out of 20837 in 161778.11560082436 seconds
# Processed 19650 out of 20837 in 162317.54736113548 seconds
# Processed 19700 out of 20837 in 162702.27941966057 seconds
# Processed 19750 out of 20837 in 163109.2529783249 seconds
# Processed 19800 out of 20837 in 163466.85537028313 seconds
# Processed 19850 out of 20837 in 163749.51415348053 seconds
# Processed 19900 out of 20837 in 163994.36058163643 seconds
# Processed 19950 out of 20837 in 164279.90261149406 seconds
# Processed 20000 out of 20837 in 165364.22542071342 seconds
# Processed 20050 out of 20837 in 165964.51579380035 seconds
# Processed 20100 out of 20837 in 166441.9313299656 seconds
# Processed 20150 out of 20837 in 167545.1591002941 seconds
# Processed 20200 out of 20837 in 169680.55866122246 seconds
# Processed 20250 out of 20837 in 169979.58167481422 seconds
# Processed 20300 out of 20837 in 170198.6906056404 seconds
# Processed 20350 out of 20837 in 170542.74808692932 seconds
# Processed 20400 out of 20837 in 170705.10444283485 seconds
# Processed 20450 out of 20837 in 170877.3888039589 seconds
# Processed 20500 out of 20837 in 171082.18614411354 seconds
# Processed 20550 out of 20837 in 171468.0142519474 seconds
# Processed 20600 out of 20837 in 171682.3544201851 seconds
# Processed 20650 out of 20837 in 172029.8936138153 seconds
# Processed 20700 out of 20837 in 172287.04062747955 seconds
# Processed 20750 out of 20837 in 172521.14489531517 seconds
# Processed 20800 out of 20837 in 172829.58533358574 seconds
# Processed 20837 out of 20837 in 173084.65784716606 seconds
