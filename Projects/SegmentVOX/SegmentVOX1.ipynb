# %% [markdown]
# # Partial Process of Segment GRN Data for vox-grn
#
# See SegmentVox.ipynb for full description.
#
# In an attempt to speed up the processing I have divided the items up into 10 groups and want to have them all process in parallel. It probably won't be 10 times faster but it should still be quicker.

# %%
import pandas as pd
import numpy as np
import os
import sys
module_path = os.path.abspath(os.path.join('../vad_utils'))
if module_path not in sys.path:
    sys.path.append(module_path)
from vad_utils import SAMPLING_RATE, FRAME_SIZE_MS, SAMPLES_PER_FRAME
import vad_utils as vu
from pydub import AudioSegment
import pickle as pkl
from pathlib import Path
import time

# %%
# define the locations for each of the file types
NOTEBOOK_ID=1
SEGMENTS_DIR = '/media/originals/segments/'
DATASETS_DIR = '/media/originals/datasets/'
SEC_4_DATA_DIR = 'seg_4sec/data/'
SEC_6_DATA_DIR = 'seg_6sec/data/'
SEC_10_DATA_DIR = 'seg_10sec/data/'

# define specific files used in the process
SEG_4_SEC_DF = f'{SEGMENTS_DIR}seg_4sec_{NOTEBOOK_ID}.csv'
SEG_6_SEC_DF = f'{SEGMENTS_DIR}seg_6sec_{NOTEBOOK_ID}.csv'
SEG_10_SEC_DF = f'{SEGMENTS_DIR}seg_10sec_{NOTEBOOK_ID}.csv'

# define segment sizes for each dataset
SEG_4_SEC = 4.0
SEG_6_SEC = 6.0
SEG_10_SEC = 10.0

# %%
# Now read in the description of the input and remove the unwanted columns and rename the rest to be python attribute names.
items = pd.read_csv(f'/media/originals/segments/items_{NOTEBOOK_ID}.csv')
items.set_index('ID', inplace=True)
items.columns
# Out:
# Index(['iso', 'program', 'location', 'year', 'path', 'filename', 'item_no',
#        'title', 'start', 'end'],
#       dtype='object')

# %%
print(items.iloc[100])
# Out:
# iso                                  bim
# program                           C78485
# location                      Bunkpurugu
# year                              2002.0
# path        Programs/78/78485/C78485/MM/
# filename                     C78485A.WAV
# item_no                                7
# title                          Picture 6
# start                              345.0
# end                                380.0
# Name: C78485_007, dtype: object

# %%
print(items.index)
# Out:
# Index(['A01471_006', 'A01471_002', 'A20710_003', 'A20710_006', 'A20710_005',
#        'A20710_002', 'A20710_004', 'A20710_001', 'A78489_010', 'A30510_003',
#        ...
#        'C32941_028', 'C32941_041', 'C32941_029', 'C32941_014', 'C32941_012',
#        'C32941_003', 'C32941_005', 'C32941_022', 'C32941_024', 'C32941_025'],
#       dtype='object', name='ID', length=17198)

# %%
# generate directories and filenames
def prepare_dir(dirname):
    if dirname[-1] != '/':
        dirname = dirname + '/'
    Path(dirname).mkdir(parents=True, exist_ok=True)
    return dirname

def prepare_raw_seg_dir(item):
    return prepare_dir(SEGMENTS_DIR + item.iso)

def raw_seg_filename(item):
    return f'{item.program}_{item.item_no:03d}.pkl'

def prepare_dataset_data_dir(item, dataset_dir):
    return prepare_dir(DATASETS_DIR + dataset_dir + item.iso)

def seg_mp3_filename(item, seg):
    return f'{item.program}_{item.item_no:03d}_{seg:03d}.mp3'

# %%
def condition_audio_segment(audio_seg):
    if audio_seg.channels != 1:
        audio_seg = audio_seg.set_channels(1)

    if audio_seg.sample_width != 2:
        audio_seg = audio_seg.set_sample_width(2)

    if audio_seg.frame_rate != SAMPLING_RATE:
        audio_seg = audio_seg.set_frame_rate(SAMPLING_RATE)

    return audio_seg

# %%
def save_the_segment_info(item, segs):
    fname = prepare_raw_seg_dir(item) + raw_seg_filename(item)
    with open(fname, 'wb') as pklFile:
         pkl.dump(segs, pklFile)

def read_the_segment_info(item):
    fname = prepare_raw_seg_dir(item) + raw_seg_filename(item)
    if os.path.exists(fname):
        if os.path.getsize(fname) > 0:
            with open(fname, 'rb') as pklFile:
                return pkl.load(pklFile)
    return []
    
def extract_audio_segment_for_item(item):
    fmt = 'wav'
    if item.filename[-4:] == '.mp3' :
        fmt = 'mp3'
    audio_seg = AudioSegment.from_file('/media/programs/' + item.path + item.filename, format=fmt)
    start_ms = int(item.start * 1000)
    end_ms = int(item.end * 1000)
    audio_seg = audio_seg[start_ms:end_ms]

    # now condition the segment and extract the raw segments.
    audio_seg = condition_audio_segment(audio_seg)
    segs = read_the_segment_info(item)
    if len(segs) == 0:
        segs = vu.audio_to_raw_voice_segments(audio_seg)
        save_the_segment_info(item, segs)

    return audio_seg, segs

def create_mp3_files(audio_seg, segs, time_per_segment, dataset_dir, item):
    segs_for_time = vu.divide_into_segments(segs, time_per_segment)

    # now write out the 4 sec segments
    dirname = prepare_dataset_data_dir(item, dataset_dir)
    rows = list()
    for i, seg in enumerate(segs_for_time):
        file_name = dataset_dir + item.iso + '/' + seg_mp3_filename(item, i)
        fname = dirname + seg_mp3_filename(item, i)
        if not os.path.exists(fname):
            start = vu.convert_frames_to_ms(seg.start)
            stop = vu.convert_frames_to_ms(seg.stop)
            audio_seg[start:stop].export(fname, format='mp3', bitrate='32k')
        desc = dict(item._asdict())
        desc['seg_start'] = vu.convert_frames_to_seconds(seg.start)
        desc['seg_stop'] = vu.convert_frames_to_seconds(seg.stop)
        desc['seg'] = i
        desc['file_name'] = file_name
        rows.append(desc)

    return rows

def update_dataframes(seg_df_csv, seg_records):
    # now update the dataframes
    if len(seg_records) > 0:
        if os.path.isfile(seg_df_csv):
            seg_sec_df = pd.concat([pd.read_csv(seg_df_csv, index_col='file_name'), pd.DataFrame.from_records(seg_records, index='file_name')])
        else:
            seg_sec_df = pd.DataFrame.from_records(seg_records, index='file_name')
        seg_sec_df.to_csv(seg_df_csv)

# %%
# processing these items might take a very long time. To permit the process to be interrupted and restarted the indexes of processed items
# are maintained in a set that is pickled on each batch. This allows the batch to quickly pick up where it left off.
def process_record_batch(items_df, *, batch_size=10):
    batch_proc = 0
    processed_file = f'/media/originals/segments/processed16_{NOTEBOOK_ID}.pkl'
    if os.path.isfile(processed_file):
        with open(processed_file, 'rb') as pklFile:
            processed_items = pkl.load(pklFile)
    else:
        processed_items = set()

    segmented_4sec_segs = []
    segmented_6sec_segs = []
    segmented_10sec_segs = []

    for item in items_df.itertuples():
        if batch_proc < batch_size:
            if item.Index not in processed_items:
                try:
                    audio_seg, voice_segs = extract_audio_segment_for_item(item)
                    segmented_4sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_4_SEC, SEC_4_DATA_DIR, item))
                    segmented_6sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_6_SEC, SEC_6_DATA_DIR, item))
                    segmented_10sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_10_SEC, SEC_10_DATA_DIR, item))
                except:
                    print('exception')
                    pass

                # we want to add an item that has an exception so it is not reprocessed on every batch
                processed_items.add(item.Index)
                batch_proc += 1

        else:
            break

    update_dataframes(SEG_4_SEC_DF, segmented_4sec_segs)
    update_dataframes(SEG_6_SEC_DF, segmented_6sec_segs)
    update_dataframes(SEG_10_SEC_DF, segmented_10sec_segs)

    with open(processed_file, 'wb') as pklFile:
        pkl.dump(processed_items, pklFile)

    return processed_items

# %%
start_time = time.time()
# form the language classification file
items_processed = 0
items_to_process = len(items)
while items_to_process > items_processed:
    processed_items = process_record_batch(items, batch_size=50)
    items_processed = len(processed_items)
    print(f'Processed {items_processed} out of {items_to_process} in {time.time()-start_time} seconds')
# Out:
# Processed 50 out of 17198 in 215.6698498725891 seconds
# Processed 100 out of 17198 in 393.8642387390137 seconds
# Processed 150 out of 17198 in 475.99681973457336 seconds
# Processed 200 out of 17198 in 636.1211228370667 seconds
# Processed 250 out of 17198 in 743.4072999954224 seconds
# Processed 300 out of 17198 in 972.6713192462921 seconds
# Processed 350 out of 17198 in 1150.813639640808 seconds
# Processed 400 out of 17198 in 1752.1893157958984 seconds
# Processed 450 out of 17198 in 2003.5488426685333 seconds
# Processed 500 out of 17198 in 2509.5474333763123 seconds
# Processed 550 out of 17198 in 2688.4021260738373 seconds
# Processed 600 out of 17198 in 3105.6563873291016 seconds
# Processed 650 out of 17198 in 3304.914027929306 seconds
# Processed 700 out of 17198 in 3461.2576739788055 seconds
# Processed 750 out of 17198 in 3687.7448666095734 seconds
# Processed 800 out of 17198 in 4239.23006939888 seconds
# Processed 850 out of 17198 in 4477.193395137787 seconds
# Processed 900 out of 17198 in 4693.581556081772 seconds
# Processed 950 out of 17198 in 4952.967748641968 seconds
# Processed 1000 out of 17198 in 5170.045060873032 seconds
# Processed 1050 out of 17198 in 5931.036416769028 seconds
# Processed 1100 out of 17198 in 6169.449683427811 seconds
# Processed 1150 out of 17198 in 6323.896157979965 seconds
# Processed 1200 out of 17198 in 6521.792062520981 seconds
# Processed 1250 out of 17198 in 6780.134044408798 seconds
# Processed 1300 out of 17198 in 7010.228448152542 seconds
# Processed 1350 out of 17198 in 7286.191611051559 seconds
# Processed 1400 out of 17198 in 7422.3230764865875 seconds
# Processed 1450 out of 17198 in 7605.720036268234 seconds
# Processed 1500 out of 17198 in 7916.698965787888 seconds
# Processed 1550 out of 17198 in 8164.770285606384 seconds
# Processed 1600 out of 17198 in 8442.685291051865 seconds
# Processed 1650 out of 17198 in 8889.660438537598 seconds
# Processed 1700 out of 17198 in 9083.847993850708 seconds
# Processed 1750 out of 17198 in 10525.152228832245 seconds
# Processed 1800 out of 17198 in 14252.171190023422 seconds
# Processed 1850 out of 17198 in 14509.038638830185 seconds
# Processed 1900 out of 17198 in 14795.382116794586 seconds
# Processed 1950 out of 17198 in 15078.99361038208 seconds
# Processed 2000 out of 17198 in 15347.63538146019 seconds
# Processed 2050 out of 17198 in 15590.300885915756 seconds
# Processed 2100 out of 17198 in 15932.682512760162 seconds
# Processed 2150 out of 17198 in 16163.095618009567 seconds
# Processed 2200 out of 17198 in 16398.34166240692 seconds
# Processed 2250 out of 17198 in 16677.01399421692 seconds
# Processed 2300 out of 17198 in 16897.193358898163 seconds
# Processed 2350 out of 17198 in 17673.449843406677 seconds
# Processed 2400 out of 17198 in 18033.160831451416 seconds
# Processed 2450 out of 17198 in 18938.660368442535 seconds
# Processed 2500 out of 17198 in 19147.353833436966 seconds
# Processed 2550 out of 17198 in 19334.89038491249 seconds
# Processed 2600 out of 17198 in 19510.53740978241 seconds
# Processed 2650 out of 17198 in 19952.341692209244 seconds
# Processed 2700 out of 17198 in 20236.579885482788 seconds
# Processed 2750 out of 17198 in 20453.53755903244 seconds
# Processed 2800 out of 17198 in 20914.331377506256 seconds
# Processed 2850 out of 17198 in 22394.35769033432 seconds
# Processed 2900 out of 17198 in 23137.691693782806 seconds
# Processed 2950 out of 17198 in 23268.0288066864 seconds
# Processed 3000 out of 17198 in 23749.865413427353 seconds
# Processed 3050 out of 17198 in 24081.389036417007 seconds
# Processed 3100 out of 17198 in 24312.423397302628 seconds
# Processed 3150 out of 17198 in 24684.31423997879 seconds
# Processed 3200 out of 17198 in 25311.758316516876 seconds
# Processed 3250 out of 17198 in 26032.7849047184 seconds
# Processed 3300 out of 17198 in 26644.627320051193 seconds
# Processed 3350 out of 17198 in 27052.21912074089 seconds
# Processed 3400 out of 17198 in 27474.460941553116 seconds
# Processed 3450 out of 17198 in 27613.730689048767 seconds
# Processed 3500 out of 17198 in 28921.365972280502 seconds
# Processed 3550 out of 17198 in 29165.762676239014 seconds
# Processed 3600 out of 17198 in 29515.905198574066 seconds
# Processed 3650 out of 17198 in 29909.44437456131 seconds
# Processed 3700 out of 17198 in 30394.094316005707 seconds
# Processed 3750 out of 17198 in 30662.84043765068 seconds
# Processed 3800 out of 17198 in 30865.513424634933 seconds
# Processed 3850 out of 17198 in 31590.82969713211 seconds
# Processed 3900 out of 17198 in 32014.68025803566 seconds
# Processed 3950 out of 17198 in 32315.96951174736 seconds
# Processed 4000 out of 17198 in 32515.54272890091 seconds
# Processed 4050 out of 17198 in 32778.451006412506 seconds
# Processed 4100 out of 17198 in 32910.352682590485 seconds
# Processed 4150 out of 17198 in 33276.01963162422 seconds
# Processed 4200 out of 17198 in 33478.46055364609 seconds
# Processed 4250 out of 17198 in 34248.577682971954 seconds
# Processed 4300 out of 17198 in 34647.58407878876 seconds
# Processed 4350 out of 17198 in 35191.96314549446 seconds
# Processed 4400 out of 17198 in 35426.79253268242 seconds
# Processed 4450 out of 17198 in 35724.63665890694 seconds
# Processed 4500 out of 17198 in 35999.800753593445 seconds
# Processed 4550 out of 17198 in 36526.36450219154 seconds
# Processed 4600 out of 17198 in 36647.33111000061 seconds
# Processed 4650 out of 17198 in 36850.61345458031 seconds
# Processed 4700 out of 17198 in 37131.69414019585 seconds
# Processed 4750 out of 17198 in 37439.43847846985 seconds
# Processed 4800 out of 17198 in 37850.2127161026 seconds
# Processed 4850 out of 17198 in 38175.48265695572 seconds
# Processed 4900 out of 17198 in 38568.60029697418 seconds
# Processed 4950 out of 17198 in 39019.64680862427 seconds
# Processed 5000 out of 17198 in 39690.2156662941 seconds
# Processed 5050 out of 17198 in 39974.43855404854 seconds
# Processed 5100 out of 17198 in 40186.20175862312 seconds
# Processed 5150 out of 17198 in 40399.29493403435 seconds
# Processed 5200 out of 17198 in 40738.31791257858 seconds
# Processed 5250 out of 17198 in 41238.787551641464 seconds
# Processed 5300 out of 17198 in 41540.84854888916 seconds
# Processed 5350 out of 17198 in 41868.411195516586 seconds
# Processed 5400 out of 17198 in 42173.92361855507 seconds
# Processed 5450 out of 17198 in 42501.78908252716 seconds
# Processed 5500 out of 17198 in 42821.755704164505 seconds
# Processed 5550 out of 17198 in 43130.50854420662 seconds
# Processed 5600 out of 17198 in 43539.49191617966 seconds
# Processed 5650 out of 17198 in 43821.460451602936 seconds
# Processed 5700 out of 17198 in 44107.670949697495 seconds
# Processed 5750 out of 17198 in 44465.2940120697 seconds
# Processed 5800 out of 17198 in 44637.540580034256 seconds
# Processed 5850 out of 17198 in 44862.37801170349 seconds
# Processed 5900 out of 17198 in 45046.299988508224 seconds
# Processed 5950 out of 17198 in 45329.44961428642 seconds
# Processed 6000 out of 17198 in 46117.95477581024 seconds
# Processed 6050 out of 17198 in 46909.08246779442 seconds
# Processed 6100 out of 17198 in 48862.11460542679 seconds
# Processed 6150 out of 17198 in 49810.55287742615 seconds
# Processed 6200 out of 17198 in 50244.474593400955 seconds
# Processed 6250 out of 17198 in 50722.70412635803 seconds
# Processed 6300 out of 17198 in 52380.54992508888 seconds
# Processed 6350 out of 17198 in 59573.984833955765 seconds
# Processed 6400 out of 17198 in 64981.189616918564 seconds
# Processed 6450 out of 17198 in 65562.20143771172 seconds
# Processed 6500 out of 17198 in 65932.57626509666 seconds
# Processed 6550 out of 17198 in 66444.78909420967 seconds
# Processed 6600 out of 17198 in 66643.20648956299 seconds
# Processed 6650 out of 17198 in 66813.99520349503 seconds
# Processed 6700 out of 17198 in 67129.04047012329 seconds
# Processed 6750 out of 17198 in 67397.7492620945 seconds
# Processed 6800 out of 17198 in 67590.703125 seconds
# Processed 6850 out of 17198 in 67877.36272001266 seconds
# Processed 6900 out of 17198 in 68117.99620008469 seconds
# Processed 6950 out of 17198 in 68325.24958276749 seconds
# Processed 7000 out of 17198 in 68531.95687246323 seconds
# Processed 7050 out of 17198 in 68826.6861076355 seconds
# Processed 7100 out of 17198 in 69040.82563710213 seconds
# Processed 7150 out of 17198 in 69309.97746157646 seconds
# Processed 7200 out of 17198 in 69604.36163878441 seconds
# Processed 7250 out of 17198 in 69872.62710881233 seconds
# Processed 7300 out of 17198 in 70177.11585474014 seconds
# Processed 7350 out of 17198 in 70513.43545794487 seconds
# Processed 7400 out of 17198 in 70864.00308418274 seconds
# Processed 7450 out of 17198 in 71168.37820386887 seconds
# Processed 7500 out of 17198 in 71501.07290935516 seconds
# Processed 7550 out of 17198 in 71784.1750319004 seconds
# Processed 7600 out of 17198 in 72299.09609818459 seconds
# Processed 7650 out of 17198 in 72609.39961481094 seconds
# Processed 7700 out of 17198 in 73535.68605351448 seconds
# Processed 7750 out of 17198 in 74556.124396801 seconds
# Processed 7800 out of 17198 in 76869.15311861038 seconds
# Processed 7850 out of 17198 in 80164.48101758957 seconds
# Processed 7900 out of 17198 in 83517.7446770668 seconds
# Processed 7950 out of 17198 in 85454.40816307068 seconds
# Processed 8000 out of 17198 in 86835.30273509026 seconds
# Processed 8050 out of 17198 in 87799.59461212158 seconds
# Processed 8100 out of 17198 in 87991.1411473751 seconds
# Processed 8150 out of 17198 in 88552.94674038887 seconds
# Processed 8200 out of 17198 in 89211.46333742142 seconds
# Processed 8250 out of 17198 in 89472.78165364265 seconds
# Processed 8300 out of 17198 in 89644.1209616661 seconds
# Processed 8350 out of 17198 in 91224.67892980576 seconds
# Processed 8400 out of 17198 in 92425.73874354362 seconds
# Processed 8450 out of 17198 in 92680.93468737602 seconds
# Processed 8500 out of 17198 in 92939.2335805893 seconds
# Processed 8550 out of 17198 in 93265.05513596535 seconds
# Processed 8600 out of 17198 in 93540.95883870125 seconds
# Processed 8650 out of 17198 in 93769.71348834038 seconds
# Processed 8700 out of 17198 in 94014.85672950745 seconds
# Processed 8750 out of 17198 in 94221.12128973007 seconds
# Processed 8800 out of 17198 in 94534.66854643822 seconds
# Processed 8850 out of 17198 in 94876.93068957329 seconds
# Processed 8900 out of 17198 in 95133.26154232025 seconds
# Processed 8950 out of 17198 in 95343.8341498375 seconds
# Processed 9000 out of 17198 in 95676.44258117676 seconds
# Processed 9050 out of 17198 in 95857.38672065735 seconds
# Processed 9100 out of 17198 in 96091.78512859344 seconds
# Processed 9150 out of 17198 in 96911.48289895058 seconds
# Processed 9200 out of 17198 in 97288.03820824623 seconds
# Processed 9250 out of 17198 in 97529.6049425602 seconds
# Processed 9300 out of 17198 in 97710.58855319023 seconds
# Processed 9350 out of 17198 in 98482.1524989605 seconds
# Processed 9400 out of 17198 in 98928.09541916847 seconds
# Processed 9450 out of 17198 in 99223.64368748665 seconds
# Processed 9500 out of 17198 in 99485.97312998772 seconds
# Processed 9550 out of 17198 in 99663.78061318398 seconds
# Processed 9600 out of 17198 in 100100.50065541267 seconds
# Processed 9650 out of 17198 in 100454.82653331757 seconds
# Processed 9700 out of 17198 in 100756.14203715324 seconds
# Processed 9750 out of 17198 in 100927.78522610664 seconds
# Processed 9800 out of 17198 in 101139.23369026184 seconds
# Processed 9850 out of 17198 in 101398.00094842911 seconds
# Processed 9900 out of 17198 in 101646.62322330475 seconds
# Processed 9950 out of 17198 in 101836.35747337341 seconds
# Processed 10000 out of 17198 in 102172.96903133392 seconds
# Processed 10050 out of 17198 in 102371.30437541008 seconds
# Processed 10100 out of 17198 in 102621.27649617195 seconds
# Processed 10150 out of 17198 in 102926.10822606087 seconds
# Processed 10200 out of 17198 in 103263.09172582626 seconds
# Processed 10250 out of 17198 in 103588.32263016701 seconds
# Processed 10300 out of 17198 in 103980.44009804726 seconds
# Processed 10350 out of 17198 in 104284.42098855972 seconds
# Processed 10400 out of 17198 in 104577.80642819405 seconds
# Processed 10450 out of 17198 in 104816.5922396183 seconds
# Processed 10500 out of 17198 in 105030.43550252914 seconds
# Processed 10550 out of 17198 in 105401.82194757462 seconds
# Processed 10600 out of 17198 in 105590.61556434631 seconds
# Processed 10650 out of 17198 in 105663.80303955078 seconds
# Processed 10700 out of 17198 in 106019.63356637955 seconds
# Processed 10750 out of 17198 in 106344.3700003624 seconds
# Processed 10800 out of 17198 in 107769.66507291794 seconds
# Processed 10850 out of 17198 in 108126.70781302452 seconds
# Processed 10900 out of 17198 in 108397.03779911995 seconds
# Processed 10950 out of 17198 in 108822.53870296478 seconds
# Processed 11000 out of 17198 in 109465.48213338852 seconds
# Processed 11050 out of 17198 in 110004.05636000633 seconds
# Processed 11100 out of 17198 in 110245.75556731224 seconds
# Processed 11150 out of 17198 in 110391.61409974098 seconds
# Processed 11200 out of 17198 in 110897.33589100838 seconds
# Processed 11250 out of 17198 in 111077.2683877945 seconds
# Processed 11300 out of 17198 in 111148.33678770065 seconds
# Processed 11350 out of 17198 in 111538.76022362709 seconds
# Processed 11400 out of 17198 in 111810.85367465019 seconds
# Processed 11450 out of 17198 in 112161.49713683128 seconds
# Processed 11500 out of 17198 in 112361.61557197571 seconds
# Processed 11550 out of 17198 in 112941.64778995514 seconds
# Processed 11600 out of 17198 in 113107.18195867538 seconds
# Processed 11650 out of 17198 in 113272.16377806664 seconds
# Processed 11700 out of 17198 in 113620.0758793354 seconds
# Processed 11750 out of 17198 in 114054.0635433197 seconds
# Processed 11800 out of 17198 in 114243.63142061234 seconds
# Processed 11850 out of 17198 in 114640.6454885006 seconds
# Processed 11900 out of 17198 in 114782.57720923424 seconds
# Processed 11950 out of 17198 in 114966.52216339111 seconds
# Processed 12000 out of 17198 in 115326.8284072876 seconds
# Processed 12050 out of 17198 in 115683.96811914444 seconds
# Processed 12100 out of 17198 in 116392.0833632946 seconds
# Processed 12150 out of 17198 in 116752.93186950684 seconds
# Processed 12200 out of 17198 in 116979.79773020744 seconds
# Processed 12250 out of 17198 in 117453.55950140953 seconds
# Processed 12300 out of 17198 in 117994.84433865547 seconds
# Processed 12350 out of 17198 in 118390.68984246254 seconds
# Processed 12400 out of 17198 in 118833.65249681473 seconds
# Processed 12450 out of 17198 in 119176.40066552162 seconds
# Processed 12500 out of 17198 in 119341.30625414848 seconds
# Processed 12550 out of 17198 in 119468.77112412453 seconds
# Processed 12600 out of 17198 in 119566.42153215408 seconds
# Processed 12650 out of 17198 in 119646.49298000336 seconds
# Processed 12700 out of 17198 in 119907.75758910179 seconds
# Processed 12750 out of 17198 in 120166.24708175659 seconds
# Processed 12800 out of 17198 in 120312.59441757202 seconds
# Processed 12850 out of 17198 in 120501.96217131615 seconds
# Processed 12900 out of 17198 in 120607.4156870842 seconds
# Processed 12950 out of 17198 in 120753.87701654434 seconds
# Processed 13000 out of 17198 in 121009.4181830883 seconds
# Processed 13050 out of 17198 in 121171.68780016899 seconds
# Processed 13100 out of 17198 in 121380.01173138618 seconds
# Processed 13150 out of 17198 in 121893.31448411942 seconds
# Processed 13200 out of 17198 in 122309.62285542488 seconds
# Processed 13250 out of 17198 in 122397.21565675735 seconds
# Processed 13300 out of 17198 in 122669.15662384033 seconds
# Processed 13350 out of 17198 in 122835.05402565002 seconds
# Processed 13400 out of 17198 in 123205.95427918434 seconds
# Processed 13450 out of 17198 in 123572.45472407341 seconds
# Processed 13500 out of 17198 in 123814.70507478714 seconds
# Processed 13550 out of 17198 in 124109.56513500214 seconds
# Processed 13600 out of 17198 in 124402.99687623978 seconds
# Processed 13650 out of 17198 in 124929.69380187988 seconds
# Processed 13700 out of 17198 in 125484.50032353401 seconds
# Processed 13750 out of 17198 in 125960.50444865227 seconds
# Processed 13800 out of 17198 in 126892.27927660942 seconds
# Processed 13850 out of 17198 in 129170.22790575027 seconds
# Processed 13900 out of 17198 in 129812.41968727112 seconds
# Processed 13950 out of 17198 in 130514.89578270912 seconds
# Processed 14000 out of 17198 in 131533.83779740334 seconds
# Processed 14050 out of 17198 in 132122.85063362122 seconds
# Processed 14100 out of 17198 in 132561.5446717739 seconds
# Processed 14150 out of 17198 in 133049.421728611 seconds
# Processed 14200 out of 17198 in 133290.77143859863 seconds
# Processed 14250 out of 17198 in 133520.45313692093 seconds
# Processed 14300 out of 17198 in 133707.36315965652 seconds
# Processed 14350 out of 17198 in 133926.570612669 seconds
# Processed 14400 out of 17198 in 134246.18650317192 seconds
# Processed 14450 out of 17198 in 136492.17328357697 seconds
# Processed 14500 out of 17198 in 136927.78889513016 seconds
# Processed 14550 out of 17198 in 137159.24540948868 seconds
# Processed 14600 out of 17198 in 137407.5591993332 seconds
# Processed 14650 out of 17198 in 137853.61116099358 seconds
# Processed 14700 out of 17198 in 138304.63419151306 seconds
# Processed 14750 out of 17198 in 138631.0774846077 seconds
# Processed 14800 out of 17198 in 138801.7111377716 seconds
# Processed 14850 out of 17198 in 139120.7484474182 seconds
# Processed 14900 out of 17198 in 139523.34741520882 seconds
# Processed 14950 out of 17198 in 140925.87306332588 seconds
# Processed 15000 out of 17198 in 141500.3179180622 seconds
# Processed 15050 out of 17198 in 141981.17643499374 seconds
# Processed 15100 out of 17198 in 142381.68496274948 seconds
# Processed 15150 out of 17198 in 143072.72437024117 seconds
# Processed 15200 out of 17198 in 143518.88359165192 seconds
# Processed 15250 out of 17198 in 143876.4357097149 seconds
# Processed 15300 out of 17198 in 144140.98303437233 seconds
# Processed 15350 out of 17198 in 144430.80642223358 seconds
# Processed 15400 out of 17198 in 144869.8661749363 seconds
# Processed 15450 out of 17198 in 145128.25686097145 seconds
# Processed 15500 out of 17198 in 145422.94977140427 seconds
# Processed 15550 out of 17198 in 145923.91888451576 seconds
# Processed 15600 out of 17198 in 146196.28557920456 seconds
# Processed 15650 out of 17198 in 146525.5898425579 seconds
# Processed 15700 out of 17198 in 146901.8762333393 seconds
# Processed 15750 out of 17198 in 147288.87096858025 seconds
# Processed 15800 out of 17198 in 147687.677901268 seconds
# Processed 15850 out of 17198 in 147934.3941180706 seconds
# Processed 15900 out of 17198 in 147960.64205360413 seconds
# Processed 15950 out of 17198 in 148173.2409875393 seconds
# Processed 16000 out of 17198 in 148325.59115052223 seconds
# Processed 16050 out of 17198 in 148739.82019853592 seconds
# Processed 16100 out of 17198 in 149059.3994808197 seconds
# Processed 16150 out of 17198 in 149246.18191218376 seconds
# Processed 16200 out of 17198 in 149539.1459619999 seconds
# Processed 16250 out of 17198 in 149737.36369657516 seconds
# Processed 16300 out of 17198 in 149916.34017395973 seconds
# Processed 16350 out of 17198 in 150190.03888726234 seconds
# Processed 16400 out of 17198 in 150607.3691458702 seconds
# Processed 16450 out of 17198 in 150993.47001814842 seconds
# Processed 16500 out of 17198 in 151293.4395904541 seconds
# Processed 16550 out of 17198 in 151470.97738456726 seconds
# Processed 16600 out of 17198 in 151681.5396027565 seconds
# Processed 16650 out of 17198 in 151911.4730052948 seconds
# Processed 16700 out of 17198 in 152040.44067883492 seconds
# Processed 16750 out of 17198 in 152193.64552354813 seconds
# Processed 16800 out of 17198 in 152373.619038105 seconds
# Processed 16850 out of 17198 in 152595.32829093933 seconds
# Processed 16900 out of 17198 in 152767.36837553978 seconds
# Processed 16950 out of 17198 in 152857.601811409 seconds
# Processed 17000 out of 17198 in 152881.868598938 seconds
# Processed 17050 out of 17198 in 153044.3899884224 seconds
# Processed 17100 out of 17198 in 153203.4075539112 seconds
# Processed 17150 out of 17198 in 153457.7464044094 seconds
# Processed 17198 out of 17198 in 153585.6452410221 seconds
