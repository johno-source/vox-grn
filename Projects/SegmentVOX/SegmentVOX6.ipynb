# %% [markdown]
# # Partial Process of Segment GRN Data for vox-grn
#
# See SegmentVox.ipynb for full description.
#
# In an attempt to speed up the processing I have divided the items up into 10 groups and want to have them all process in parallel. It probably won't be 10 times faster but it should still be quicker.

# %%
import pandas as pd
import numpy as np
import os
import sys
module_path = os.path.abspath(os.path.join('../vad_utils'))
if module_path not in sys.path:
    sys.path.append(module_path)
from vad_utils import SAMPLING_RATE, FRAME_SIZE_MS, SAMPLES_PER_FRAME
import vad_utils as vu
from pydub import AudioSegment
import pickle as pkl
from pathlib import Path
import time

# %%
# define the locations for each of the file types
NOTEBOOK_ID=6
SEGMENTS_DIR = '/media/originals/segments/'
DATASETS_DIR = '/media/originals/datasets/'
SEC_4_DATA_DIR = 'seg_4sec/data/'
SEC_6_DATA_DIR = 'seg_6sec/data/'
SEC_10_DATA_DIR = 'seg_10sec/data/'

# define specific files used in the process
SEG_4_SEC_DF = f'{SEGMENTS_DIR}seg_4sec_{NOTEBOOK_ID}.csv'
SEG_6_SEC_DF = f'{SEGMENTS_DIR}seg_6sec_{NOTEBOOK_ID}.csv'
SEG_10_SEC_DF = f'{SEGMENTS_DIR}seg_10sec_{NOTEBOOK_ID}.csv'

# define segment sizes for each dataset
SEG_4_SEC = 4.0
SEG_6_SEC = 6.0
SEG_10_SEC = 10.0

# %%
# Now read in the description of the input and remove the unwanted columns and rename the rest to be python attribute names.
items = pd.read_csv(f'/media/originals/segments/items_{NOTEBOOK_ID}.csv')
items.set_index('ID', inplace=True)
items.columns
# Out:
# Index(['iso', 'program', 'location', 'year', 'path', 'filename', 'item_no',
#        'title', 'start', 'end'],
#       dtype='object')

# %%
print(items.iloc[100])
# Out:
# iso                                       nhw
# program                                A37792
# location              San Louis Potosi, Mexic
# year                                   2008.0
# path        Programs/37/37792/A37792/PM-1903/
# filename                        A37792-03.wav
# item_no                                     3
# title                               Picture 2
# start                                     0.0
# end                                 20.812861
# Name: A37792_003, dtype: object

# %%
print(items.index)
# Out:
# Index(['A66696_002', 'A66696_003', 'A66623_001', 'A66700_001', 'A66590_001',
#        'A66592_001', 'A66830_001', 'A66591_001', 'A66627_001', 'A66832_001',
#        ...
#        'A34740_025', 'A34440_001', 'A34430_008', 'A34740_024', 'A34740_011',
#        'A34740_012', 'A34740_013', 'A34740_014', 'A34740_015', 'A34740_016'],
#       dtype='object', name='ID', length=17198)

# %%
# generate directories and filenames
def prepare_dir(dirname):
    if dirname[-1] != '/':
        dirname = dirname + '/'
    Path(dirname).mkdir(parents=True, exist_ok=True)
    return dirname

def prepare_raw_seg_dir(item):
    return prepare_dir(SEGMENTS_DIR + item.iso)

def raw_seg_filename(item):
    return f'{item.program}_{item.item_no:03d}.pkl'

def prepare_dataset_data_dir(item, dataset_dir):
    return prepare_dir(DATASETS_DIR + dataset_dir + item.iso)

def seg_mp3_filename(item, seg):
    return f'{item.program}_{item.item_no:03d}_{seg:03d}.mp3'

# %%
def condition_audio_segment(audio_seg):
    if audio_seg.channels != 1:
        audio_seg = audio_seg.set_channels(1)

    if audio_seg.sample_width != 2:
        audio_seg = audio_seg.set_sample_width(2)

    if audio_seg.frame_rate != SAMPLING_RATE:
        audio_seg = audio_seg.set_frame_rate(SAMPLING_RATE)

    return audio_seg

# %%
def save_the_segment_info(item, segs):
    fname = prepare_raw_seg_dir(item) + raw_seg_filename(item)
    with open(fname, 'wb') as pklFile:
         pkl.dump(segs, pklFile)

def read_the_segment_info(item):
    fname = prepare_raw_seg_dir(item) + raw_seg_filename(item)
    if os.path.exists(fname):
        if os.path.getsize(fname) > 0:
            with open(fname, 'rb') as pklFile:
                return pkl.load(pklFile)
    return []
    
def extract_audio_segment_for_item(item):
    fmt = 'wav'
    if item.filename[-4:] == '.mp3' :
        fmt = 'mp3'
    audio_seg = AudioSegment.from_file('/media/programs/' + item.path + item.filename, format=fmt)
    start_ms = int(item.start * 1000)
    end_ms = int(item.end * 1000)
    audio_seg = audio_seg[start_ms:end_ms]

    # now condition the segment and extract the raw segments.
    audio_seg = condition_audio_segment(audio_seg)
    segs = read_the_segment_info(item)
    if len(segs) == 0:
        segs = vu.audio_to_raw_voice_segments(audio_seg)
        save_the_segment_info(item, segs)

    return audio_seg, segs

def create_mp3_files(audio_seg, segs, time_per_segment, dataset_dir, item):
    segs_for_time = vu.divide_into_segments(segs, time_per_segment)

    # now write out the 4 sec segments
    dirname = prepare_dataset_data_dir(item, dataset_dir)
    rows = list()
    for i, seg in enumerate(segs_for_time):
        file_name = dataset_dir + item.iso + '/' + seg_mp3_filename(item, i)
        fname = dirname + seg_mp3_filename(item, i)
        if not os.path.exists(fname):
            start = vu.convert_frames_to_ms(seg.start)
            stop = vu.convert_frames_to_ms(seg.stop)
            audio_seg[start:stop].export(fname, format='mp3', bitrate='32k')
        desc = dict(item._asdict())
        desc['seg_start'] = vu.convert_frames_to_seconds(seg.start)
        desc['seg_stop'] = vu.convert_frames_to_seconds(seg.stop)
        desc['seg'] = i
        desc['file_name'] = file_name
        rows.append(desc)

    return rows

def update_dataframes(seg_df_csv, seg_records):
    # now update the dataframes
    if len(seg_records) > 0:
        if os.path.isfile(seg_df_csv):
            seg_sec_df = pd.concat([pd.read_csv(seg_df_csv, index_col='file_name'), pd.DataFrame.from_records(seg_records, index='file_name')])
        else:
            seg_sec_df = pd.DataFrame.from_records(seg_records, index='file_name')
        seg_sec_df.to_csv(seg_df_csv)

# %%
# processing these items might take a very long time. To permit the process to be interrupted and restarted the indexes of processed items
# are maintained in a set that is pickled on each batch. This allows the batch to quickly pick up where it left off.
def process_record_batch(items_df, *, batch_size=10):
    batch_proc = 0
    processed_file = f'/media/originals/segments/processed16_{NOTEBOOK_ID}.pkl'
    if os.path.isfile(processed_file):
        with open(processed_file, 'rb') as pklFile:
            processed_items = pkl.load(pklFile)
    else:
        processed_items = set()

    segmented_4sec_segs = []
    segmented_6sec_segs = []
    segmented_10sec_segs = []

    for item in items_df.itertuples():
        if batch_proc < batch_size:
            if item.Index not in processed_items:
                try:
                    audio_seg, voice_segs = extract_audio_segment_for_item(item)
                    segmented_4sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_4_SEC, SEC_4_DATA_DIR, item))
                    segmented_6sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_6_SEC, SEC_6_DATA_DIR, item))
                    segmented_10sec_segs.extend(create_mp3_files(audio_seg, voice_segs, SEG_10_SEC, SEC_10_DATA_DIR, item))
                except:
                    print('exception')
                    pass

                # we want to add an item that has an exception so it is not reprocessed on every batch
                processed_items.add(item.Index)
                batch_proc += 1

        else:
            break

    update_dataframes(SEG_4_SEC_DF, segmented_4sec_segs)
    update_dataframes(SEG_6_SEC_DF, segmented_6sec_segs)
    update_dataframes(SEG_10_SEC_DF, segmented_10sec_segs)

    with open(processed_file, 'wb') as pklFile:
        pkl.dump(processed_items, pklFile)

    return processed_items

# %%
start_time = time.time()
# form the language classification file
items_processed = 0
items_to_process = len(items)
while items_to_process > items_processed:
    processed_items = process_record_batch(items, batch_size=50)
    items_processed = len(processed_items)
    print(f'Processed {items_processed} out of {items_to_process} in {time.time()-start_time} seconds')
# Out:
# Processed 50 out of 17198 in 386.3357903957367 seconds
# Processed 100 out of 17198 in 593.5342888832092 seconds
# Processed 150 out of 17198 in 786.7057054042816 seconds
# Processed 200 out of 17198 in 1212.2845888137817 seconds
# Processed 250 out of 17198 in 1509.312600851059 seconds
# Processed 300 out of 17198 in 1815.237253189087 seconds
# Processed 350 out of 17198 in 2070.028988599777 seconds
# Processed 400 out of 17198 in 3163.986348628998 seconds
# Processed 450 out of 17198 in 5065.761297702789 seconds
# Processed 500 out of 17198 in 5358.414233922958 seconds
# Processed 550 out of 17198 in 5591.344643115997 seconds
# Processed 600 out of 17198 in 6124.182507753372 seconds
# Processed 650 out of 17198 in 8261.574622392654 seconds
# Processed 700 out of 17198 in 12151.4277176857 seconds
# Processed 750 out of 17198 in 16412.102035045624 seconds
# Processed 800 out of 17198 in 23415.765257120132 seconds
# Processed 850 out of 17198 in 23604.23136329651 seconds
# Processed 900 out of 17198 in 23756.859469890594 seconds
# Processed 950 out of 17198 in 23887.173902750015 seconds
# Processed 1000 out of 17198 in 24120.08657670021 seconds
# Processed 1050 out of 17198 in 24743.60814142227 seconds
# Processed 1100 out of 17198 in 25068.499304771423 seconds
# Processed 1150 out of 17198 in 25585.891620874405 seconds
# Processed 1200 out of 17198 in 25854.05436372757 seconds
# Processed 1250 out of 17198 in 26099.498528957367 seconds
# Processed 1300 out of 17198 in 26384.728219985962 seconds
# Processed 1350 out of 17198 in 26748.133239746094 seconds
# Processed 1400 out of 17198 in 26975.413381576538 seconds
# Processed 1450 out of 17198 in 27334.889789819717 seconds
# Processed 1500 out of 17198 in 27540.62048482895 seconds
# Processed 1550 out of 17198 in 28021.692660808563 seconds
# Processed 1600 out of 17198 in 28434.879886865616 seconds
# Processed 1650 out of 17198 in 29095.791651010513 seconds
# Processed 1700 out of 17198 in 29280.224707126617 seconds
# Processed 1750 out of 17198 in 29818.843740940094 seconds
# Processed 1800 out of 17198 in 30107.18579363823 seconds
# Processed 1850 out of 17198 in 30680.142976999283 seconds
# Processed 1900 out of 17198 in 30993.808617591858 seconds
# Processed 1950 out of 17198 in 31488.865225076675 seconds
# Processed 2000 out of 17198 in 32345.84083008766 seconds
# Processed 2050 out of 17198 in 32799.28827548027 seconds
# Processed 2100 out of 17198 in 33446.25737786293 seconds
# Processed 2150 out of 17198 in 33792.47984409332 seconds
# Processed 2200 out of 17198 in 34264.830614328384 seconds
# Processed 2250 out of 17198 in 34681.463310956955 seconds
# Processed 2300 out of 17198 in 35067.77528166771 seconds
# Processed 2350 out of 17198 in 35357.68925380707 seconds
# Processed 2400 out of 17198 in 35710.61532878876 seconds
# Processed 2450 out of 17198 in 36634.033188819885 seconds
# Processed 2500 out of 17198 in 36956.29240870476 seconds
# Processed 2550 out of 17198 in 37234.39346909523 seconds
# Processed 2600 out of 17198 in 37772.64757990837 seconds
# Processed 2650 out of 17198 in 38195.93930530548 seconds
# Processed 2700 out of 17198 in 38953.98924970627 seconds
# Processed 2750 out of 17198 in 39513.96914124489 seconds
# Processed 2800 out of 17198 in 39787.6751499176 seconds
# Processed 2850 out of 17198 in 40135.530953645706 seconds
# Processed 2900 out of 17198 in 40957.47358298302 seconds
# Processed 2950 out of 17198 in 41570.7392039299 seconds
# Processed 3000 out of 17198 in 41999.474999427795 seconds
# Processed 3050 out of 17198 in 42780.04046487808 seconds
# Processed 3100 out of 17198 in 43257.07362604141 seconds
# Processed 3150 out of 17198 in 44440.80925631523 seconds
# Processed 3200 out of 17198 in 44715.61530947685 seconds
# Processed 3250 out of 17198 in 45158.18720507622 seconds
# Processed 3300 out of 17198 in 45575.52265548706 seconds
# Processed 3350 out of 17198 in 45943.798129081726 seconds
# Processed 3400 out of 17198 in 46426.389377593994 seconds
# Processed 3450 out of 17198 in 46779.09109735489 seconds
# Processed 3500 out of 17198 in 46950.28205084801 seconds
# Processed 3550 out of 17198 in 47252.08571267128 seconds
# Processed 3600 out of 17198 in 47480.27923321724 seconds
# Processed 3650 out of 17198 in 47685.13720393181 seconds
# Processed 3700 out of 17198 in 48057.739864587784 seconds
# Processed 3750 out of 17198 in 48515.47120976448 seconds
# Processed 3800 out of 17198 in 48984.690460920334 seconds
# Processed 3850 out of 17198 in 49237.0332596302 seconds
# Processed 3900 out of 17198 in 49632.07602143288 seconds
# Processed 3950 out of 17198 in 50018.42678666115 seconds
# Processed 4000 out of 17198 in 50322.02881169319 seconds
# Processed 4050 out of 17198 in 50853.07416987419 seconds
# Processed 4100 out of 17198 in 52642.35916638374 seconds
# Processed 4150 out of 17198 in 54986.73182463646 seconds
# Processed 4200 out of 17198 in 56410.75839686394 seconds
# Processed 4250 out of 17198 in 59836.15557408333 seconds
# Processed 4300 out of 17198 in 62395.51413297653 seconds
# Processed 4350 out of 17198 in 62698.3679895401 seconds
# Processed 4400 out of 17198 in 62988.80107140541 seconds
# Processed 4450 out of 17198 in 63522.18653011322 seconds
# Processed 4500 out of 17198 in 63798.08044719696 seconds
# Processed 4550 out of 17198 in 64123.83742594719 seconds
# Processed 4600 out of 17198 in 64374.11828517914 seconds
# Processed 4650 out of 17198 in 64732.099041461945 seconds
# Processed 4700 out of 17198 in 65231.81303215027 seconds
# Processed 4750 out of 17198 in 65728.26596736908 seconds
# Processed 4800 out of 17198 in 65869.71576714516 seconds
# Processed 4850 out of 17198 in 65964.93015766144 seconds
# Processed 4900 out of 17198 in 66173.1314342022 seconds
# Processed 4950 out of 17198 in 66516.22716403008 seconds
# Processed 5000 out of 17198 in 66796.7863521576 seconds
# Processed 5050 out of 17198 in 67038.27144789696 seconds
# Processed 5100 out of 17198 in 67295.01976823807 seconds
# Processed 5150 out of 17198 in 67652.8325419426 seconds
# Processed 5200 out of 17198 in 67852.18927454948 seconds
# Processed 5250 out of 17198 in 68143.53468704224 seconds
# Processed 5300 out of 17198 in 68452.91775512695 seconds
# Processed 5350 out of 17198 in 68759.18361449242 seconds
# Processed 5400 out of 17198 in 69051.70551991463 seconds
# Processed 5450 out of 17198 in 69331.00120997429 seconds
# Processed 5500 out of 17198 in 69636.9471795559 seconds
# Processed 5550 out of 17198 in 69892.90309047699 seconds
# Processed 5600 out of 17198 in 70234.00385284424 seconds
# Processed 5650 out of 17198 in 70570.44958424568 seconds
# Processed 5700 out of 17198 in 71044.01311445236 seconds
# Processed 5750 out of 17198 in 71412.92206096649 seconds
# Processed 5800 out of 17198 in 71677.00249576569 seconds
# Processed 5850 out of 17198 in 71986.00797653198 seconds
# Processed 5900 out of 17198 in 72241.10786771774 seconds
# Processed 5950 out of 17198 in 72517.2215514183 seconds
# Processed 6000 out of 17198 in 72885.1133673191 seconds
# Processed 6050 out of 17198 in 73214.99248790741 seconds
# Processed 6100 out of 17198 in 73591.83343935013 seconds
# Processed 6150 out of 17198 in 73911.47114038467 seconds
# Processed 6200 out of 17198 in 74239.97116565704 seconds
# Processed 6250 out of 17198 in 74510.07155036926 seconds
# Processed 6300 out of 17198 in 74825.91150736809 seconds
# Processed 6350 out of 17198 in 75201.32160639763 seconds
# Processed 6400 out of 17198 in 75504.69804477692 seconds
# Processed 6450 out of 17198 in 75623.37431812286 seconds
# Processed 6500 out of 17198 in 75902.93735098839 seconds
# Processed 6550 out of 17198 in 76227.8777525425 seconds
# Processed 6600 out of 17198 in 76462.08020496368 seconds
# Processed 6650 out of 17198 in 76741.99606251717 seconds
# Processed 6700 out of 17198 in 77022.52241373062 seconds
# Processed 6750 out of 17198 in 77277.02765893936 seconds
# Processed 6800 out of 17198 in 77561.96968364716 seconds
# Processed 6850 out of 17198 in 77823.97636556625 seconds
# Processed 6900 out of 17198 in 78065.30159878731 seconds
# Processed 6950 out of 17198 in 78627.38432908058 seconds
# Processed 7000 out of 17198 in 78987.63703513145 seconds
# Processed 7050 out of 17198 in 79405.05854821205 seconds
# Processed 7100 out of 17198 in 79548.82877993584 seconds
# Processed 7150 out of 17198 in 79810.14185404778 seconds
# Processed 7200 out of 17198 in 80280.72374105453 seconds
# Processed 7250 out of 17198 in 80661.72375917435 seconds
# Processed 7300 out of 17198 in 80910.93139076233 seconds
# Processed 7350 out of 17198 in 81202.6027841568 seconds
# Processed 7400 out of 17198 in 81487.95116591454 seconds
# Processed 7450 out of 17198 in 81705.88006305695 seconds
# Processed 7500 out of 17198 in 81960.07639193535 seconds
# Processed 7550 out of 17198 in 82481.60252690315 seconds
# Processed 7600 out of 17198 in 82900.63982057571 seconds
# Processed 7650 out of 17198 in 83374.60645103455 seconds
# Processed 7700 out of 17198 in 84485.77140974998 seconds
# Processed 7750 out of 17198 in 84712.68293905258 seconds
# Processed 7800 out of 17198 in 84951.29842019081 seconds
# Processed 7850 out of 17198 in 85193.71214771271 seconds
# Processed 7900 out of 17198 in 85428.15613508224 seconds
# Processed 7950 out of 17198 in 85655.19329237938 seconds
# Processed 8000 out of 17198 in 85899.77880811691 seconds
# Processed 8050 out of 17198 in 86081.08562970161 seconds
# Processed 8100 out of 17198 in 86547.65888619423 seconds
# Processed 8150 out of 17198 in 86844.60769462585 seconds
# Processed 8200 out of 17198 in 87069.71162390709 seconds
# Processed 8250 out of 17198 in 87356.39827156067 seconds
# Processed 8300 out of 17198 in 87687.79981899261 seconds
# Processed 8350 out of 17198 in 87918.2469303608 seconds
# Processed 8400 out of 17198 in 88437.872112751 seconds
# Processed 8450 out of 17198 in 89402.32836174965 seconds
# Processed 8500 out of 17198 in 92755.46498250961 seconds
# Processed 8550 out of 17198 in 95078.65098333359 seconds
# Processed 8600 out of 17198 in 95512.79157733917 seconds
# Processed 8650 out of 17198 in 95882.54395079613 seconds
# Processed 8700 out of 17198 in 96077.20078158379 seconds
# Processed 8750 out of 17198 in 96370.23486065865 seconds
# Processed 8800 out of 17198 in 96854.37934279442 seconds
# Processed 8850 out of 17198 in 97339.20248198509 seconds
# Processed 8900 out of 17198 in 97578.45491933823 seconds
# Processed 8950 out of 17198 in 97963.65017485619 seconds
# Processed 9000 out of 17198 in 98266.16438770294 seconds
# Processed 9050 out of 17198 in 98480.3670835495 seconds
# Processed 9100 out of 17198 in 98700.26926279068 seconds
# Processed 9150 out of 17198 in 98841.11072230339 seconds
# Processed 9200 out of 17198 in 99008.39252257347 seconds
# Processed 9250 out of 17198 in 99259.03502488136 seconds
# Processed 9300 out of 17198 in 99582.04704737663 seconds
# Processed 9350 out of 17198 in 99844.21660923958 seconds
# Processed 9400 out of 17198 in 100282.56651639938 seconds
# Processed 9450 out of 17198 in 100649.00163340569 seconds
# Processed 9500 out of 17198 in 101101.37097215652 seconds
# Processed 9550 out of 17198 in 101373.67761683464 seconds
# Processed 9600 out of 17198 in 101554.89803314209 seconds
# Processed 9650 out of 17198 in 101702.68242955208 seconds
# Processed 9700 out of 17198 in 101825.06570911407 seconds
# Processed 9750 out of 17198 in 102002.91076397896 seconds
# Processed 9800 out of 17198 in 102156.52394652367 seconds
# Processed 9850 out of 17198 in 102428.09749650955 seconds
# Processed 9900 out of 17198 in 102723.14345169067 seconds
# Processed 9950 out of 17198 in 103374.25836133957 seconds
# Processed 10000 out of 17198 in 103590.71737098694 seconds
# Processed 10050 out of 17198 in 104258.406717062 seconds
# Processed 10100 out of 17198 in 104790.4132039547 seconds
# Processed 10150 out of 17198 in 105046.98470330238 seconds
# Processed 10200 out of 17198 in 105498.24471521378 seconds
# Processed 10250 out of 17198 in 105638.34698557854 seconds
# Processed 10300 out of 17198 in 105732.05472254753 seconds
# Processed 10350 out of 17198 in 105812.91544508934 seconds
# Processed 10400 out of 17198 in 106275.42645549774 seconds
# Processed 10450 out of 17198 in 106641.559394598 seconds
# Processed 10500 out of 17198 in 106765.55598282814 seconds
# Processed 10550 out of 17198 in 106985.27462530136 seconds
# Processed 10600 out of 17198 in 107350.25211024284 seconds
# Processed 10650 out of 17198 in 107596.10512113571 seconds
# Processed 10700 out of 17198 in 107932.28138709068 seconds
# Processed 10750 out of 17198 in 108245.25656533241 seconds
# Processed 10800 out of 17198 in 108424.65880799294 seconds
# Processed 10850 out of 17198 in 108608.60371375084 seconds
# Processed 10900 out of 17198 in 108769.47157096863 seconds
# Processed 10950 out of 17198 in 108826.36858224869 seconds
# Processed 11000 out of 17198 in 109110.68261289597 seconds
# Processed 11050 out of 17198 in 109506.22263455391 seconds
# Processed 11100 out of 17198 in 109936.0107281208 seconds
# Processed 11150 out of 17198 in 110335.11824965477 seconds
# Processed 11200 out of 17198 in 110540.87826609612 seconds
# Processed 11250 out of 17198 in 110781.95289635658 seconds
# Processed 11300 out of 17198 in 111540.19632816315 seconds
# Processed 11350 out of 17198 in 111912.21096420288 seconds
# Processed 11400 out of 17198 in 112169.17230677605 seconds
# Processed 11450 out of 17198 in 112391.21108150482 seconds
# Processed 11500 out of 17198 in 112712.00176644325 seconds
# Processed 11550 out of 17198 in 112981.4845392704 seconds
# Processed 11600 out of 17198 in 113178.6762008667 seconds
# Processed 11650 out of 17198 in 113372.93025970459 seconds
# Processed 11700 out of 17198 in 113633.465893507 seconds
# Processed 11750 out of 17198 in 114068.28594756126 seconds
# Processed 11800 out of 17198 in 114738.53699183464 seconds
# Processed 11850 out of 17198 in 115228.74452805519 seconds
# Processed 11900 out of 17198 in 115609.63250803947 seconds
# Processed 11950 out of 17198 in 117244.72866106033 seconds
# Processed 12000 out of 17198 in 119571.70012044907 seconds
# Processed 12050 out of 17198 in 121020.53976368904 seconds
# Processed 12100 out of 17198 in 121446.19748210907 seconds
# Processed 12150 out of 17198 in 121785.61170935631 seconds
# Processed 12200 out of 17198 in 122116.48702526093 seconds
# Processed 12250 out of 17198 in 122371.78645992279 seconds
# Processed 12300 out of 17198 in 122656.60550904274 seconds
# Processed 12350 out of 17198 in 123000.46467995644 seconds
# Processed 12400 out of 17198 in 123336.50477266312 seconds
# Processed 12450 out of 17198 in 123611.44441246986 seconds
# Processed 12500 out of 17198 in 123758.70417618752 seconds
# Processed 12550 out of 17198 in 124125.85827493668 seconds
# Processed 12600 out of 17198 in 124294.84359240532 seconds
# Processed 12650 out of 17198 in 124516.58146476746 seconds
# Processed 12700 out of 17198 in 124776.68452715874 seconds
# Processed 12750 out of 17198 in 124890.03757596016 seconds
# Processed 12800 out of 17198 in 127662.50005054474 seconds
# Processed 12850 out of 17198 in 128264.27219176292 seconds
# Processed 12900 out of 17198 in 128418.76148152351 seconds
# Processed 12950 out of 17198 in 128676.04813551903 seconds
# Processed 13000 out of 17198 in 128811.88413453102 seconds
# Processed 13050 out of 17198 in 128968.16463494301 seconds
# Processed 13100 out of 17198 in 129123.35469150543 seconds
# Processed 13150 out of 17198 in 129438.54829192162 seconds
# Processed 13200 out of 17198 in 129635.2552921772 seconds
# Processed 13250 out of 17198 in 129864.91435050964 seconds
# Processed 13300 out of 17198 in 130084.19601154327 seconds
# Processed 13350 out of 17198 in 130353.70482969284 seconds
# Processed 13400 out of 17198 in 130626.36564445496 seconds
# Processed 13450 out of 17198 in 130910.4909248352 seconds
# Processed 13500 out of 17198 in 131209.6105914116 seconds
# Processed 13550 out of 17198 in 131383.5664281845 seconds
# Processed 13600 out of 17198 in 131713.45370841026 seconds
# Processed 13650 out of 17198 in 131942.43967819214 seconds
# Processed 13700 out of 17198 in 132095.46601724625 seconds
# Processed 13750 out of 17198 in 132300.9570221901 seconds
# Processed 13800 out of 17198 in 132429.07965159416 seconds
# Processed 13850 out of 17198 in 132785.43766498566 seconds
# Processed 13900 out of 17198 in 133049.44465184212 seconds
# Processed 13950 out of 17198 in 133289.181961298 seconds
# Processed 14000 out of 17198 in 133469.66295909882 seconds
# Processed 14050 out of 17198 in 133628.84495544434 seconds
# Processed 14100 out of 17198 in 133823.7380039692 seconds
# Processed 14150 out of 17198 in 134003.92929577827 seconds
# Processed 14200 out of 17198 in 134297.68347883224 seconds
# Processed 14250 out of 17198 in 134656.83096814156 seconds
# Processed 14300 out of 17198 in 134887.25066709518 seconds
# Processed 14350 out of 17198 in 135228.22597169876 seconds
# Processed 14400 out of 17198 in 135583.86891293526 seconds
# Processed 14450 out of 17198 in 135763.31635451317 seconds
# Processed 14500 out of 17198 in 136022.2067039013 seconds
# Processed 14550 out of 17198 in 136189.20057606697 seconds
# Processed 14600 out of 17198 in 136355.50013017654 seconds
# Processed 14650 out of 17198 in 136501.01889181137 seconds
# Processed 14700 out of 17198 in 136699.8832743168 seconds
# Processed 14750 out of 17198 in 136858.0243487358 seconds
# Processed 14800 out of 17198 in 137015.45243501663 seconds
# Processed 14850 out of 17198 in 137180.16676807404 seconds
# Processed 14900 out of 17198 in 137362.29755067825 seconds
# Processed 14950 out of 17198 in 137553.27290439606 seconds
# Processed 15000 out of 17198 in 137767.3385207653 seconds
# Processed 15050 out of 17198 in 138512.5482056141 seconds
# Processed 15100 out of 17198 in 139052.53381299973 seconds
# Processed 15150 out of 17198 in 139150.04263710976 seconds
# Processed 15200 out of 17198 in 139347.43181943893 seconds
# Processed 15250 out of 17198 in 139502.12078905106 seconds
# Processed 15300 out of 17198 in 140018.52887678146 seconds
# Processed 15350 out of 17198 in 140252.77617621422 seconds
# Processed 15400 out of 17198 in 140400.5495159626 seconds
# Processed 15450 out of 17198 in 140727.9714665413 seconds
# Processed 15500 out of 17198 in 140895.0107357502 seconds
# Processed 15550 out of 17198 in 141121.90779924393 seconds
# Processed 15600 out of 17198 in 141367.09211540222 seconds
# Processed 15650 out of 17198 in 141622.07635951042 seconds
# Processed 15700 out of 17198 in 141938.15527033806 seconds
# Processed 15750 out of 17198 in 142176.26221132278 seconds
# Processed 15800 out of 17198 in 142366.42050266266 seconds
# Processed 15850 out of 17198 in 142506.45363783836 seconds
# Processed 15900 out of 17198 in 142625.67519831657 seconds
# Processed 15950 out of 17198 in 142822.35024642944 seconds
# Processed 16000 out of 17198 in 143033.41836428642 seconds
# Processed 16050 out of 17198 in 143263.27168989182 seconds
# Processed 16100 out of 17198 in 143746.75698399544 seconds
# Processed 16150 out of 17198 in 144178.25864195824 seconds
# Processed 16200 out of 17198 in 144347.42854499817 seconds
# Processed 16250 out of 17198 in 144597.37974524498 seconds
# Processed 16300 out of 17198 in 144848.49286413193 seconds
# Processed 16350 out of 17198 in 145038.78593826294 seconds
# Processed 16400 out of 17198 in 145435.28086662292 seconds
# Processed 16450 out of 17198 in 145956.34243059158 seconds
# Processed 16500 out of 17198 in 146328.36967635155 seconds
# Processed 16550 out of 17198 in 146392.94386720657 seconds
# Processed 16600 out of 17198 in 146617.30033874512 seconds
# Processed 16650 out of 17198 in 146867.93314647675 seconds
# Processed 16700 out of 17198 in 147024.5535709858 seconds
# Processed 16750 out of 17198 in 147192.37175750732 seconds
# Processed 16800 out of 17198 in 147379.26800370216 seconds
# Processed 16850 out of 17198 in 147636.72991919518 seconds
# Processed 16900 out of 17198 in 147814.6357562542 seconds
# Processed 16950 out of 17198 in 148061.57205438614 seconds
# Processed 17000 out of 17198 in 148532.45940375328 seconds
# Processed 17050 out of 17198 in 148716.0414133072 seconds
# Processed 17100 out of 17198 in 148854.2738904953 seconds
# Processed 17150 out of 17198 in 149015.79815363884 seconds
# Processed 17198 out of 17198 in 149227.35498332977 seconds
